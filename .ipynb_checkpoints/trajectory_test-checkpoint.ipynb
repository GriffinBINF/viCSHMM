# %%
# # Path to h5ad dataset
# dataset_path = '/work/vanaja_lab/griffin/projects/cshmm/results/pancreas_dev.h5ad'

# # Load and prepare AnnData
# if os.path.exists(dataset_path):
#     print("File exists. Loading the dataset...")
#     adata = sc.read_h5ad(dataset_path)
#     print("Dataset loaded successfully!")
#     print("Dataset shape:", adata.shape)
# else:
#     raise FileNotFoundError(f"File not found at: {dataset_path}")

# adata.obs_names_make_unique()

# # Preprocessing steps
# sc.pp.normalize_total(adata, target_sum=1e4)
# sc.pp.log1p(adata)

# # Min-max scaling
# scaler = MinMaxScaler()
# adata.X = scaler.fit_transform(adata.X.toarray())

# # HVG selection
# sc.pp.highly_variable_genes(adata, n_top_genes=1000, flavor='seurat')
# adata = adata[:, adata.var['highly_variable']].copy()

# print(f"Dataset shape after selecting top 1000 HVGs: {adata.shape}")

# %%
# Dimensionality reduction and clustering
# sc.pp.pca(adata)
# sc.pp.neighbors(adata)
# sc.tl.umap(adata)
# sc.tl.leiden(adata, resolution=2, key_added="leiden")

# # Plot UMAP with clusters
# sc.pl.umap(adata, color="leiden", legend_loc="on data", title="UMAP - Leiden Clusters")

# # PAGA
# sc.tl.paga(adata, groups='leiden')
# sc.pl.paga(adata, color='leiden', title="PAGA Connectivity Graph")
# sc.pl.umap(adata, color=['leiden'], edges=True, title="UMAP with PAGA Connectivity")

# %%
#adata.write('data/mouse_panc_dev.h5ad')

# %%
import os
import scanpy as sc
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler

from models import TrajectoryGraph, initialize_trajectory
# Out:
# /work/vanaja_lab/griffin/miniconda3/envs/cellrank/lib/python3.12/site-packages/anndata/utils.py:429: FutureWarning: Importing read_csv from `anndata` is deprecated. Import anndata.io.read_csv instead.
#   warnings.warn(msg, FutureWarning)
# /work/vanaja_lab/griffin/miniconda3/envs/cellrank/lib/python3.12/site-packages/anndata/utils.py:429: FutureWarning: Importing read_excel from `anndata` is deprecated. Import anndata.io.read_excel instead.
#   warnings.warn(msg, FutureWarning)
# /work/vanaja_lab/griffin/miniconda3/envs/cellrank/lib/python3.12/site-packages/anndata/utils.py:429: FutureWarning: Importing read_hdf from `anndata` is deprecated. Import anndata.io.read_hdf instead.
#   warnings.warn(msg, FutureWarning)
# /work/vanaja_lab/griffin/miniconda3/envs/cellrank/lib/python3.12/site-packages/anndata/utils.py:429: FutureWarning: Importing read_loom from `anndata` is deprecated. Import anndata.io.read_loom instead.
#   warnings.warn(msg, FutureWarning)
# /work/vanaja_lab/griffin/miniconda3/envs/cellrank/lib/python3.12/site-packages/anndata/utils.py:429: FutureWarning: Importing read_mtx from `anndata` is deprecated. Import anndata.io.read_mtx instead.
#   warnings.warn(msg, FutureWarning)
# /work/vanaja_lab/griffin/miniconda3/envs/cellrank/lib/python3.12/site-packages/anndata/utils.py:429: FutureWarning: Importing read_text from `anndata` is deprecated. Import anndata.io.read_text instead.
#   warnings.warn(msg, FutureWarning)
# /work/vanaja_lab/griffin/miniconda3/envs/cellrank/lib/python3.12/site-packages/anndata/utils.py:429: FutureWarning: Importing read_umi_tools from `anndata` is deprecated. Import anndata.io.read_umi_tools instead.
#   warnings.warn(msg, FutureWarning)

# %%
adata = sc.read('data/mouse_panc_dev.h5ad')

# %%
# Build the trajectory graph
traj_graph, cell_assignment = initialize_trajectory(
    adata=adata,
    random_state=41,
    debug=True
)
# Out:
# Trajectory graph nodes: ['leaf_0', 'leaf_1', 'leaf_2', 'split_3', 'leaf_4', 'split_5', 'leaf_6', 'split_7', 'leaf_8', 'split_9', 'root_split_10', 'split_11', 'leaf_12', 'leaf_13', 'split_14', 'split_15', 'int_16', 'leaf_17', 'RootNode_0_0']
# Trajectory graph edges: [('split_3', 'split_5'), ('split_3', 'split_7'), ('split_5', 'leaf_12'), ('split_5', 'leaf_17'), ('split_7', 'leaf_4'), ('split_7', 'leaf_6'), ('split_9', 'leaf_8'), ('split_9', 'int_16'), ('root_split_10', 'split_3'), ('root_split_10', 'split_15'), ('split_11', 'leaf_1'), ('split_11', 'leaf_13'), ('split_14', 'leaf_2'), ('split_14', 'split_11'), ('split_15', 'split_9'), ('split_15', 'split_14'), ('int_16', 'leaf_0'), ('RootNode_0_0', 'root_split_10')]
#
# Sample cell assignments:
#                                 edge  latent_time
# TAAGCGTAGGCCCGTT  (split_7, leaf_4)     0.773956
# GACCAATAGTCGTCGT  (split_9, leaf_8)     0.438878
# CGAGAAGCATGCTAGT  (split_7, leaf_4)     0.858598
# ACGATGTAGGATTCCC  (split_7, leaf_4)     0.697368
# GCAGTTAAGGTCATCT  (split_7, leaf_4)     0.094177

# %%
# Visualize trajectory graph with cells assigned
traj_graph.plot_cells_on_trajectory(
    cell_assignment=cell_assignment,
    color_key='leiden',
    curve_amount=0.8,
    node_size=500,
    cell_size=30,
    horizontal_thresh=0.01,
    edge_width=5,
    edge_color='lightgrey',
    title="Cells on Stochastic PAGA Trajectory",
    plot_transitions=True
)

# %%
# # === Imports ===

import torch
import numpy as np
from models.posterior import TreeVariationalPosterior
from models.belief import BeliefPropagator
from models.emission import pack_emission_params
from models.loss import compute_elbo
from utils.inference import initialize_beta_from_cell_assignment, find_path_index_for_edge

# # === Setup ===
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
# === Prepare expression data ===
X = torch.tensor(
    adata.X.toarray() if hasattr(adata.X, 'toarray') else adata.X,
    dtype=torch.float32,
    device=device
)

# === Initialize trajectory graph ===
traj_graph, cell_assignment = initialize_trajectory(adata, debug=True)

all_nodes = set(traj_graph.node_to_index.keys())
emission_nodes = set(traj_graph.node_emission.keys())
missing = all_nodes - emission_nodes
print(f"\nAll nodes:      {sorted(all_nodes)}")
print(f"Emission nodes: {sorted(emission_nodes)}")
print(f"Missing nodes:  {sorted(missing)}")

# === Emission parameter initialization ===
edge_to_index, g_a, g_b, K, sigma2, pi, g = pack_emission_params(traj_graph, device=device)

# === Wrap emission parameters in nn.Parameter for autograd ===
g = torch.nn.Parameter(g)
K = torch.nn.Parameter(K)
log_sigma2 = torch.nn.Parameter(torch.log(sigma2))

# === Posterior setup ===
n_cells = X.shape[0]
posterior = TreeVariationalPosterior(traj_graph, n_cells=n_cells, device=device)
print("edge_logits requires_grad:", posterior.edge_logits.requires_grad)

# === Initialize beta from trajectory assignment (optional) ===
initialize_beta_from_cell_assignment(posterior, cell_assignment, edge_to_index, sharpness=0.1)

# === Belief propagator ===
belief_propagator = BeliefPropagator(traj_graph, posterior)

# === Diagnostics ===
print("g requires_grad:", g.requires_grad)
print("Initial alpha mean:", posterior.alpha.mean().item())
print("Initial beta mean:", posterior.beta.mean().item())

# === Group learnable emission parameters (if needed elsewhere) ===
emission_params = [g, K, log_sigma2]
# Out:
# Trajectory graph nodes: ['leaf_0', 'leaf_1', 'leaf_2', 'split_3', 'leaf_4', 'split_5', 'leaf_6', 'split_7', 'split_8', 'split_9', 'split_10', 'leaf_11', 'root_split_12', 'leaf_13', 'leaf_14', 'int_15', 'split_16', 'leaf_17', 'RootNode_0_0']
# Trajectory graph edges: [('split_3', 'leaf_4'), ('split_3', 'leaf_17'), ('split_5', 'split_7'), ('split_5', 'split_8'), ('split_7', 'leaf_14'), ('split_7', 'int_15'), ('split_8', 'leaf_0'), ('split_8', 'leaf_6'), ('split_9', 'leaf_2'), ('split_9', 'split_10'), ('split_10', 'leaf_1'), ('split_10', 'leaf_11'), ('root_split_12', 'split_5'), ('root_split_12', 'split_16'), ('int_15', 'leaf_13'), ('split_16', 'split_3'), ('split_16', 'split_9'), ('RootNode_0_0', 'root_split_12')]
#
# Sample cell assignments:
#                                  edge  latent_time
# TAAGCGTAGGCCCGTT   (split_3, leaf_4)     0.773956
# GACCAATAGTCGTCGT  (split_5, split_8)     0.438878
# CGAGAAGCATGCTAGT   (split_3, leaf_4)     0.858598
# ACGATGTAGGATTCCC   (split_3, leaf_4)     0.697368
# GCAGTTAAGGTCATCT   (split_3, leaf_4)     0.094177
#
# All nodes:      ['RootNode_0_0', 'int_15', 'leaf_0', 'leaf_1', 'leaf_11', 'leaf_13', 'leaf_14', 'leaf_17', 'leaf_2', 'leaf_4', 'leaf_6', 'root_split_12', 'split_10', 'split_16', 'split_3', 'split_5', 'split_7', 'split_8', 'split_9']
# Emission nodes: ['RootNode_0_0', 'int_15', 'leaf_0', 'leaf_1', 'leaf_11', 'leaf_13', 'leaf_14', 'leaf_17', 'leaf_2', 'leaf_4', 'leaf_6', 'root_split_12', 'split_10', 'split_16', 'split_3', 'split_5', 'split_7', 'split_8', 'split_9']
# Missing nodes:  []
# edge_logits requires_grad: True
# g requires_grad: True
# Initial alpha mean: 1.2252330780029297
# Initial beta mean: 1.2192115783691406

# %% [markdown]
# # Test Standard Full Code

# %%
# # === Run Variational Model ===
# for epoch in range(num_epochs):
#     optimizer.zero_grad()

#     loss, metrics = compute_elbo(
#         X, traj_graph, posterior, edge_to_index,
#         g_a, g_b, K, log_sigma2.exp(),
#         pi=pi,
#         belief_propagator=belief_propagator,
#         n_samples=n_samples,
#         kl_weight=kl_weight,
#         kl_p_weight=kl_p_weight,
#         t_cont_weight=t_cont_weight
#     )

#     loss.backward()
#     print_grad_stats()
#     log_epoch(epoch, loss, metrics)
#     optimizer.step()

# %%
import os
os.environ["CUDA_LAUNCH_BLOCKING"] = "1"

# %%
import torch
from models.loss import compute_elbo_batch
from utils.inference import batch_indices

# === Logging containers ===
elbo_log, nll_log, kl_t_log, kl_p_log = [], [], [], []
t_cont_log, transition_log, l1_log, grad_log = [], [], [], []

# === Config ===
batch_size = 512
num_epochs = 500
n_samples = 3
kl_weight = 1.0
kl_p_weight = 1e4
t_cont_weight = 1.0
transition_weight = 1.0
l1_weight = 1.0
lr = 1e-2

# === Phase toggling ===
phase = "emission"
max_phase_epochs = 30
patience = 10
tol = 1e-3
best_loss = torch.tensor(float("inf"), device=X.device)
epochs_since_improvement = 0
phase_epoch = 0

# === Training loop ===
for epoch in range(num_epochs):
    # === Phase-specific parameter control ===
    if phase == "emission":
        posterior.freeze()
        for p in [g, K, log_sigma2]:
            p.requires_grad_(True)
        posterior.branch_logits.requires_grad_(True)  # <-- THIS IS THE FIX
    else:
        posterior.unfreeze()
        for p in [g, K, log_sigma2]:
            p.requires_grad_(False)


    # === Optimizer setup ===
    trainable_params = list(p for p in posterior.parameters() if p.requires_grad) + \
                       [p for p in [g, K, log_sigma2] if p.requires_grad]
    optimizer = torch.optim.Adam(trainable_params, lr=lr)

    total_loss = torch.tensor(0.0, device=X.device)
    total_batches = 0
    epoch_metrics = {k: 0.0 for k in ["nll", "kl_t", "kl_p", "t_cont", "transition", "l1"]}

    for batch in batch_indices(X.shape[0], batch_size):
        X_batch = X[batch]
        optimizer.zero_grad()

        loss, metrics = compute_elbo_batch(
            X_batch, batch, traj_graph, posterior, edge_to_index,
            g, K, log_sigma2.exp(),  # Ensure variance positivity
            belief_propagator=belief_propagator,
            n_samples=n_samples,
            kl_weight=kl_weight,
            kl_p_weight=kl_p_weight,
            t_cont_weight=t_cont_weight,
            transition_weight=transition_weight,
            l1_weight=l1_weight,
            pi=pi
        )

        loss.backward()
        optimizer.step()

        total_loss += loss
        for key in epoch_metrics:
            epoch_metrics[key] += metrics[key]
        total_batches += 1

    # === Normalize metrics ===
    for key in epoch_metrics:
        epoch_metrics[key] /= total_batches

    # === Gradient diagnostics ===
    grad_norms = {
        "edge_logits": posterior.edge_logits.grad.norm().item() if posterior.edge_logits.grad is not None else 0.0,
        "branch_logits": posterior.branch_logits.grad.norm().item() if posterior.branch_logits.grad is not None else 0.0,
        "alpha": posterior.alpha.grad.norm().item() if posterior.alpha.grad is not None else 0.0,
        "beta": posterior.beta.grad.norm().item() if posterior.beta.grad is not None else 0.0,
        "g": g.grad.norm().item() if g.grad is not None else 0.0,
        "K": K.grad.norm().item() if K.grad is not None else 0.0,
        "log_sigma2": log_sigma2.grad.norm().item() if log_sigma2.grad is not None else 0.0,
    }

    # === Logging ===
    avg_loss = total_loss / total_batches
    elbo_log.append(avg_loss.detach().item())
    nll_log.append(epoch_metrics["nll"])
    kl_t_log.append(epoch_metrics["kl_t"])
    kl_p_log.append(epoch_metrics["kl_p"])
    t_cont_log.append(epoch_metrics["t_cont"])
    transition_log.append(epoch_metrics["transition"])
    l1_log.append(epoch_metrics["l1"])
    grad_log.append(grad_norms)

    print(f"\n[Epoch {epoch}] | Phase: {phase}")
    print(f"  ELBO:       {avg_loss.item():.4e}")
    print(f"  NLL:        {epoch_metrics['nll']:.4e}")
    print(f"  KL(t):      {epoch_metrics['kl_t']:.4e}")
    print(f"  KL(p):      {epoch_metrics['kl_p']:.4e}")
    print(f"  t_cont:     {epoch_metrics['t_cont']:.4e}")
    print(f"  Transition: {epoch_metrics['transition']:.4e}")
    print(f"  L1:         {epoch_metrics['l1']:.4e}")
    print("  Grad Norms:")
    for k, v in grad_norms.items():
        print(f"    {k}: {v:.2e}")

    # === Phase switching ===
    if avg_loss < best_loss - tol:
        best_loss = avg_loss
        epochs_since_improvement = 0
    else:
        epochs_since_improvement += 1

    phase_epoch += 1
    if epochs_since_improvement >= patience or phase_epoch >= max_phase_epochs:
        phase = "posterior" if phase == "emission" else "emission"
        best_loss = torch.tensor(float("inf"), device=X.device)
        epochs_since_improvement = 0
        phase_epoch = 0
        print(f"--- Switching to {phase} phase ---")
# Out:
# [Epoch 0] | Phase: emission
#   ELBO:       4.8403e+04
#   NLL:        4.8343e+04
#   KL(t):      3.3902e-01
#   KL(p):      8.6734e-09
#   t_cont:     3.2696e-01
#   Transition: -1.6282e+01
#   L1:         4.2636e+01
#   Grad Norms:
#     edge_logits: 0.00e+00
#     branch_logits: 0.00e+00
#     alpha: 0.00e+00
#     beta: 0.00e+00
#     g: 8.81e+03
#     K: 1.12e+03
#     log_sigma2: 3.63e-01
#
# [Epoch 1] | Phase: emission
#   ELBO:       4.8318e+04
#   NLL:        4.8198e+04
#   KL(t):      5.8944e+01
#   KL(p):      8.5954e-09
#   t_cont:     3.2761e-01
#   Transition: -1.6338e+01
#   L1:         4.3814e+01
#   Grad Norms:
#     edge_logits: 0.00e+00
#     branch_logits: 0.00e+00
#     alpha: 0.00e+00
#     beta: 0.00e+00
#     g: 9.60e+03
#     K: 1.26e+03
#     log_sigma2: 3.86e-01
#
# [Epoch 2] | Phase: emission
#   ELBO:       4.7535e+04
#   NLL:        4.7415e+04
#   KL(t):      5.8936e+01
#   KL(p):      8.4164e-09
#   t_cont:     3.2930e-01
#   Transition: -1.6269e+01
#   L1:         4.4258e+01
#   Grad Norms:
#     edge_logits: 0.00e+00
#     branch_logits: 0.00e+00
#     alpha: 0.00e+00
#     beta: 0.00e+00
#     g: 8.39e+03
#     K: 1.06e+03
#     log_sigma2: 4.20e-01
#
# [Epoch 3] | Phase: emission
#   ELBO:       4.8625e+04
#   NLL:        4.8563e+04
#   KL(t):      3.4554e-01
#   KL(p):      8.4742e-09
#   t_cont:     3.2444e-01
#   Transition: -1.6309e+01
#   L1:         4.4703e+01
#   Grad Norms:
#     edge_logits: 0.00e+00
#     branch_logits: 0.00e+00
#     alpha: 0.00e+00
#     beta: 0.00e+00
#     g: 8.48e+03
#     K: 9.60e+02
#     log_sigma2: 3.76e-01
#
# [Epoch 4] | Phase: emission
#   ELBO:       4.8295e+04
#   NLL:        4.8233e+04
#   KL(t):      3.4268e-01
#   KL(p):      8.7959e-09
#   t_cont:     3.3861e-01
#   Transition: -1.6369e+01
#   L1:         4.5224e+01
#   Grad Norms:
#     edge_logits: 0.00e+00
#     branch_logits: 0.00e+00
#     alpha: 0.00e+00
#     beta: 0.00e+00
#     g: 8.92e+03
#     K: 1.13e+03
#     log_sigma2: 4.63e-01
#
# [Epoch 5] | Phase: emission
#   ELBO:       4.8115e+04
#   NLL:        4.8052e+04
#   KL(t):      3.3334e-01
#   KL(p):      8.7399e-09
#   t_cont:     3.2983e-01
#   Transition: -1.6281e+01
#   L1:         4.5293e+01
#   Grad Norms:
#     edge_logits: 0.00e+00
#     branch_logits: 0.00e+00
#     alpha: 0.00e+00
#     beta: 0.00e+00
#     g: 9.16e+03
#     K: 1.33e+03
#     log_sigma2: 3.75e-01
#
# [Epoch 6] | Phase: emission
#   ELBO:       4.8538e+04
#   NLL:        4.8475e+04
#   KL(t):      3.5095e-01
#   KL(p):      8.7074e-09
#   t_cont:     3.2786e-01
#   Transition: -1.6341e+01
#   L1:         4.5534e+01
#   Grad Norms:
#     edge_logits: 0.00e+00
#     branch_logits: 0.00e+00
#     alpha: 0.00e+00
#     beta: 0.00e+00
#     g: 8.22e+03
#     K: 1.06e+03
#     log_sigma2: 3.73e-01
#
# [Epoch 7] | Phase: emission
#   ELBO:       4.8053e+04
#   NLL:        4.7931e+04
#   KL(t):      5.8933e+01
#   KL(p):      8.5979e-09
#   t_cont:     3.3520e-01
#   Transition: -1.6322e+01
#   L1:         4.5860e+01
#   Grad Norms:
#     edge_logits: 0.00e+00
#     branch_logits: 0.00e+00
#     alpha: 0.00e+00
#     beta: 0.00e+00
#     g: 9.10e+03
#     K: 1.26e+03
#     log_sigma2: 3.97e-01
#
# [Epoch 8] | Phase: emission
#   ELBO:       4.8722e+04
#   NLL:        4.8659e+04
#   KL(t):      3.4212e-01
#   KL(p):      8.5706e-09
#   t_cont:     3.2554e-01
#   Transition: -1.6346e+01
#   L1:         4.5814e+01
#   Grad Norms:
#     edge_logits: 0.00e+00
#     branch_logits: 0.00e+00
#     alpha: 0.00e+00
#     beta: 0.00e+00
#     g: 9.47e+03
#     K: 9.96e+02
#     log_sigma2: 3.91e-01
#
# [Epoch 9] | Phase: emission
#   ELBO:       4.8205e+04
#   NLL:        4.8142e+04
#   KL(t):      3.4191e-01
#   KL(p):      8.4659e-09
#   t_cont:     3.2698e-01
#   Transition: -1.6385e+01
#   L1:         4.6011e+01
#   Grad Norms:
#     edge_logits: 0.00e+00
#     branch_logits: 0.00e+00
#     alpha: 0.00e+00
#     beta: 0.00e+00
#     g: 9.10e+03
#     K: 1.09e+03
#     log_sigma2: 3.88e-01
#
# [Epoch 10] | Phase: emission
#   ELBO:       4.7748e+04
#   NLL:        4.7685e+04
#   KL(t):      3.4660e-01
#   KL(p):      8.5435e-09
#   t_cont:     3.2607e-01
#   Transition: -1.6279e+01
#   L1:         4.5673e+01
#   Grad Norms:
#     edge_logits: 0.00e+00
#     branch_logits: 0.00e+00
#     alpha: 0.00e+00
#     beta: 0.00e+00
#     g: 8.33e+03
#     K: 1.04e+03
#     log_sigma2: 3.96e-01
#
# [Epoch 11] | Phase: emission
#   ELBO:       4.7422e+04
#   NLL:        4.7301e+04
#   KL(t):      5.8943e+01
#   KL(p):      8.5315e-09
#   t_cont:     3.3297e-01
#   Transition: -1.6319e+01
#   L1:         4.5981e+01
#   Grad Norms:
#     edge_logits: 0.00e+00
#     branch_logits: 0.00e+00
#     alpha: 0.00e+00
#     beta: 0.00e+00
#     g: 7.38e+03
#     K: 1.12e+03
#     log_sigma2: 4.11e-01
#
# [Epoch 12] | Phase: emission
#   ELBO:       4.9057e+04
#   NLL:        4.8994e+04
#   KL(t):      3.3876e-01
#   KL(p):      8.6898e-09
#   t_cont:     3.2955e-01
#   Transition: -1.6243e+01
#   L1:         4.6115e+01
#   Grad Norms:
#     edge_logits: 0.00e+00
#     branch_logits: 0.00e+00
#     alpha: 0.00e+00
#     beta: 0.00e+00
#     g: 9.33e+03
#     K: 1.30e+03
#     log_sigma2: 3.83e-01
#
# [Epoch 13] | Phase: emission
#   ELBO:       4.9888e+04
#   NLL:        4.9824e+04
#   KL(t):      3.5086e-01
#   KL(p):      8.5505e-09
#   t_cont:     3.2477e-01
#   Transition: -1.6352e+01
#   L1:         4.6292e+01
#   Grad Norms:
#     edge_logits: 0.00e+00
#     branch_logits: 0.00e+00
#     alpha: 0.00e+00
#     beta: 0.00e+00
#     g: 9.42e+03
#     K: 1.29e+03
#     log_sigma2: 3.65e-01
#
# [Epoch 14] | Phase: emission
#   ELBO:       4.6952e+04
#   NLL:        4.6889e+04
#   KL(t):      3.3644e-01
#   KL(p):      8.5545e-09
#   t_cont:     3.2749e-01
#   Transition: -1.6334e+01
#   L1:         4.6587e+01
#   Grad Norms:
#     edge_logits: 0.00e+00
#     branch_logits: 0.00e+00
#     alpha: 0.00e+00
#     beta: 0.00e+00
#     g: 7.74e+03
#     K: 9.32e+02
#     log_sigma2: 3.69e-01
#
# [Epoch 15] | Phase: emission
#   ELBO:       4.7691e+04
#   NLL:        4.7569e+04
#   KL(t):      5.8937e+01
#   KL(p):      8.7117e-09
#   t_cont:     3.2532e-01
#   Transition: -1.6328e+01
#   L1:         4.6660e+01
#   Grad Norms:
#     edge_logits: 0.00e+00
#     branch_logits: 0.00e+00
#     alpha: 0.00e+00
#     beta: 0.00e+00
#     g: 8.77e+03
#     K: 1.01e+03
#     log_sigma2: 4.05e-01
#
# [Epoch 16] | Phase: emission
#   ELBO:       4.8634e+04
#   NLL:        4.8512e+04
#   KL(t):      5.8927e+01
#   KL(p):      8.6530e-09
#   t_cont:     3.1821e-01
#   Transition: -1.6263e+01
#   L1:         4.6487e+01
#   Grad Norms:
#     edge_logits: 0.00e+00
#     branch_logits: 0.00e+00
#     alpha: 0.00e+00
#     beta: 0.00e+00
#     g: 9.32e+03
#     K: 1.13e+03
#     log_sigma2: 3.75e-01
#
# [Epoch 17] | Phase: emission
#   ELBO:       4.7881e+04
#   NLL:        4.7818e+04
#   KL(t):      3.3891e-01
#   KL(p):      8.4804e-09
#   t_cont:     3.4221e-01
#   Transition: -1.6277e+01
#   L1:         4.6372e+01
#   Grad Norms:
#     edge_logits: 0.00e+00
#     branch_logits: 0.00e+00
#     alpha: 0.00e+00
#     beta: 0.00e+00
#     g: 9.34e+03
#     K: 1.19e+03
#     log_sigma2: 4.07e-01
#
# [Epoch 18] | Phase: emission
#   ELBO:       4.7120e+04
#   NLL:        4.7057e+04
#   KL(t):      3.3393e-01
#   KL(p):      8.7437e-09
#   t_cont:     3.2265e-01
#   Transition: -1.6304e+01
#   L1:         4.6508e+01
#   Grad Norms:
#     edge_logits: 0.00e+00
#     branch_logits: 0.00e+00
#     alpha: 0.00e+00
#     beta: 0.00e+00
#     g: 8.39e+03
#     K: 1.13e+03
#     log_sigma2: 3.79e-01
#
# [Epoch 19] | Phase: emission
#   ELBO:       4.9226e+04
#   NLL:        4.9162e+04
#   KL(t):      3.5603e-01
#   KL(p):      8.5245e-09
#   t_cont:     3.3197e-01
#   Transition: -1.6313e+01
#   L1:         4.6526e+01
#   Grad Norms:
#     edge_logits: 0.00e+00
#     branch_logits: 0.00e+00
#     alpha: 0.00e+00
#     beta: 0.00e+00
#     g: 8.55e+03
#     K: 1.08e+03
#     log_sigma2: 3.70e-01
#
# [Epoch 20] | Phase: emission
#   ELBO:       4.8660e+04
#   NLL:        4.8597e+04
#   KL(t):      3.3740e-01
#   KL(p):      8.4936e-09
#   t_cont:     3.3425e-01
#   Transition: -1.6271e+01
#   L1:         4.6480e+01
#   Grad Norms:
#     edge_logits: 0.00e+00
#     branch_logits: 0.00e+00
#     alpha: 0.00e+00
#     beta: 0.00e+00
#     g: 8.11e+03
#     K: 9.74e+02
#     log_sigma2: 3.77e-01
#
# [Epoch 21] | Phase: emission
#   ELBO:       4.7128e+04
#   NLL:        4.7064e+04
#   KL(t):      3.4463e-01
#   KL(p):      8.5566e-09
#   t_cont:     3.3951e-01
#   Transition: -1.6377e+01
#   L1:         4.6467e+01
#   Grad Norms:
#     edge_logits: 0.00e+00
#     branch_logits: 0.00e+00
#     alpha: 0.00e+00
#     beta: 0.00e+00
#     g: 8.32e+03
#     K: 9.80e+02
#     log_sigma2: 3.70e-01
#
# [Epoch 22] | Phase: emission
#   ELBO:       4.9659e+04
#   NLL:        4.9596e+04
#   KL(t):      3.3141e-01
#   KL(p):      8.7547e-09
#   t_cont:     3.3545e-01
#   Transition: -1.6349e+01
#   L1:         4.6307e+01
#   Grad Norms:
#     edge_logits: 0.00e+00
#     branch_logits: 0.00e+00
#     alpha: 0.00e+00
#     beta: 0.00e+00
#     g: 9.73e+03
#     K: 1.14e+03
#     log_sigma2: 4.10e-01
#
# [Epoch 23] | Phase: emission
#   ELBO:       4.7002e+04
#   NLL:        4.6880e+04
#   KL(t):      5.8932e+01
#   KL(p):      8.6135e-09
#   t_cont:     3.2978e-01
#   Transition: -1.6300e+01
#   L1:         4.6580e+01
#   Grad Norms:
#     edge_logits: 0.00e+00
#     branch_logits: 0.00e+00
#     alpha: 0.00e+00
#     beta: 0.00e+00
#     g: 8.36e+03
#     K: 1.08e+03
#     log_sigma2: 3.99e-01
#
# [Epoch 24] | Phase: emission
#   ELBO:       4.9426e+04
#   NLL:        4.9362e+04
#   KL(t):      3.4439e-01
#   KL(p):      8.4408e-09
#   t_cont:     3.2256e-01
#   Transition: -1.6286e+01
#   L1:         4.6824e+01
#   Grad Norms:
#     edge_logits: 0.00e+00
#     branch_logits: 0.00e+00
#     alpha: 0.00e+00
#     beta: 0.00e+00
#     g: 8.81e+03
#     K: 1.25e+03
#     log_sigma2: 4.05e-01
# --- Switching to posterior phase ---
#
# [Epoch 25] | Phase: posterior
#   ELBO:       4.7829e+04
#   NLL:        4.7766e+04
#   KL(t):      3.5013e-01
#   KL(p):      8.6907e-09
#   t_cont:     3.2964e-01
#   Transition: -1.6282e+01
#   L1:         4.5975e+01
#   Grad Norms:
#     edge_logits: 1.59e-05
#     branch_logits: 0.00e+00
#     alpha: 1.94e+03
#     beta: 2.32e+03
#     g: 8.81e+03
#     K: 1.25e+03
#     log_sigma2: 4.05e-01
#
# [Epoch 26] | Phase: posterior
#   ELBO:       4.6292e+04
#   NLL:        4.6171e+04
#   KL(t):      5.8939e+01
#   KL(p):      8.6571e-09
#   t_cont:     3.4271e-01
#   Transition: -1.6329e+01
#   L1:         4.5975e+01
#   Grad Norms:
#     edge_logits: 1.53e-05
#     branch_logits: 0.00e+00
#     alpha: 2.37e+03
#     beta: 2.45e+03
#     g: 8.81e+03
#     K: 1.25e+03
#     log_sigma2: 4.05e-01
#
# [Epoch 27] | Phase: posterior
#   ELBO:       4.7524e+04
#   NLL:        4.7461e+04
#   KL(t):      3.5798e-01
#   KL(p):      9.1939e-09
#   t_cont:     3.2370e-01
#   Transition: -1.6248e+01
#   L1:         4.5975e+01
#   Grad Norms:
#     edge_logits: 1.52e-05
#     branch_logits: 0.00e+00
#     alpha: 2.41e+03
#     beta: 1.43e+03
#     g: 8.81e+03
#     K: 1.25e+03
#     log_sigma2: 4.05e-01
#
# [Epoch 28] | Phase: posterior
#   ELBO:       4.7678e+04
#   NLL:        4.7615e+04
#   KL(t):      3.5916e-01
#   KL(p):      8.4996e-09
#   t_cont:     3.2359e-01
#   Transition: -1.6367e+01
#   L1:         4.5975e+01
#   Grad Norms:
#     edge_logits: 1.60e-05
#     branch_logits: 0.00e+00
#     alpha: 2.38e+03
#     beta: 1.98e+03
#     g: 8.81e+03
#     K: 1.25e+03
#     log_sigma2: 4.05e-01
#
# [Epoch 29] | Phase: posterior
#   ELBO:       4.7286e+04
#   NLL:        4.7223e+04
#   KL(t):      3.5510e-01
#   KL(p):      7.4241e-09
#   t_cont:     3.3509e-01
#   Transition: -1.6299e+01
#   L1:         4.5975e+01
#   Grad Norms:
#     edge_logits: 1.54e-05
#     branch_logits: 0.00e+00
#     alpha: 1.79e+03
#     beta: 3.49e+03
#     g: 8.81e+03
#     K: 1.25e+03
#     log_sigma2: 4.05e-01
#
# [Epoch 30] | Phase: posterior
#   ELBO:       4.7912e+04
#   NLL:        4.7849e+04
#   KL(t):      3.7557e-01
#   KL(p):      7.7201e-09
#   t_cont:     3.2857e-01
#   Transition: -1.6286e+01
#   L1:         4.5975e+01
#   Grad Norms:
#     edge_logits: 1.53e-05
#     branch_logits: 0.00e+00
#     alpha: 2.30e+03
#     beta: 2.08e+03
#     g: 8.81e+03
#     K: 1.25e+03
#     log_sigma2: 4.05e-01
#
# [Epoch 31] | Phase: posterior
#   ELBO:       4.7049e+04
#   NLL:        4.6986e+04
#   KL(t):      3.7291e-01
#   KL(p):      7.3982e-09
#   t_cont:     3.2592e-01
#   Transition: -1.6273e+01
#   L1:         4.5975e+01
#   Grad Norms:
#     edge_logits: 1.51e-05
#     branch_logits: 0.00e+00
#     alpha: 2.46e+03
#     beta: 3.07e+03
#     g: 8.81e+03
#     K: 1.25e+03
#     log_sigma2: 4.05e-01
#
# [Epoch 32] | Phase: posterior
#   ELBO:       4.6081e+04
#   NLL:        4.6018e+04
#   KL(t):      3.8094e-01
#   KL(p):      8.9622e-09
#   t_cont:     3.3150e-01
#   Transition: -1.6325e+01
#   L1:         4.5975e+01
#   Grad Norms:
#     edge_logits: 1.54e-05
#     branch_logits: 0.00e+00
#     alpha: 1.80e+03
#     beta: 1.89e+03
#     g: 8.81e+03
#     K: 1.25e+03
#     log_sigma2: 4.05e-01
#
# [Epoch 33] | Phase: posterior
#   ELBO:       4.8306e+04
#   NLL:        4.8184e+04
#   KL(t):      5.8990e+01
#   KL(p):      6.2635e-09
#   t_cont:     3.2251e-01
#   Transition: -1.6381e+01
#   L1:         4.5975e+01
#   Grad Norms:
#     edge_logits: 1.55e-05
#     branch_logits: 0.00e+00
#     alpha: 2.46e+03
#     beta: 2.62e+03
#     g: 8.81e+03
#     K: 1.25e+03
#     log_sigma2: 4.05e-01
#
# [Epoch 34] | Phase: posterior
#   ELBO:       4.6162e+04
#   NLL:        4.6099e+04
#   KL(t):      4.1045e-01
#   KL(p):      8.6660e-09
#   t_cont:     3.3573e-01
#   Transition: -1.6316e+01
#   L1:         4.5975e+01
#   Grad Norms:
#     edge_logits: 1.50e-05
#     branch_logits: 0.00e+00
#     alpha: 2.30e+03
#     beta: 1.94e+03
#     g: 8.81e+03
#     K: 1.25e+03
#     log_sigma2: 4.05e-01
#
# [Epoch 35] | Phase: posterior
#   ELBO:       4.6121e+04
#   NLL:        4.6058e+04
#   KL(t):      4.1893e-01
#   KL(p):      7.5207e-09
#   t_cont:     3.2781e-01
#   Transition: -1.6311e+01
#   L1:         4.5975e+01
#   Grad Norms:
#     edge_logits: 1.53e-05
#     branch_logits: 0.00e+00
#     alpha: 2.17e+03
#     beta: 1.99e+03
#     g: 8.81e+03
#     K: 1.25e+03
#     log_sigma2: 4.05e-01
#
# [Epoch 36] | Phase: posterior
#   ELBO:       4.6350e+04
#   NLL:        4.6228e+04
#   KL(t):      5.9029e+01
#   KL(p):      7.9057e-09
#   t_cont:     3.3505e-01
#   Transition: -1.6332e+01
#   L1:         4.5975e+01
#   Grad Norms:
#     edge_logits: 1.51e-05
#     branch_logits: 0.00e+00
#     alpha: 2.22e+03
#     beta: 1.99e+03
#     g: 8.81e+03
#     K: 1.25e+03
#     log_sigma2: 4.05e-01
#
# [Epoch 37] | Phase: posterior
#   ELBO:       4.6312e+04
#   NLL:        4.6132e+04
#   KL(t):      1.1763e+02
#   KL(p):      8.0702e-09
#   t_cont:     3.3293e-01
#   Transition: -1.6287e+01
#   L1:         4.5975e+01
#   Grad Norms:
#     edge_logits: 1.56e-05
#     branch_logits: 0.00e+00
#     alpha: 2.60e+03
#     beta: 1.95e+03
#     g: 8.81e+03
#     K: 1.25e+03
#     log_sigma2: 4.05e-01
#
# [Epoch 38] | Phase: posterior
#   ELBO:       4.6599e+04
#   NLL:        4.6536e+04
#   KL(t):      4.3484e-01
#   KL(p):      4.8020e-09
#   t_cont:     3.2384e-01
#   Transition: -1.6291e+01
#   L1:         4.5975e+01
#   Grad Norms:
#     edge_logits: 1.50e-05
#     branch_logits: 0.00e+00
#     alpha: 2.75e+03
#     beta: 2.32e+03
#     g: 8.81e+03
#     K: 1.25e+03
#     log_sigma2: 4.05e-01
#
# [Epoch 39] | Phase: posterior
#   ELBO:       4.6840e+04
#   NLL:        4.6777e+04
#   KL(t):      4.6145e-01
#   KL(p):      8.3021e-09
#   t_cont:     3.2993e-01
#   Transition: -1.6361e+01
#   L1:         4.5975e+01
#   Grad Norms:
#     edge_logits: 1.56e-05
#     branch_logits: 0.00e+00
#     alpha: 2.26e+03
#     beta: 2.33e+03
#     g: 8.81e+03
#     K: 1.25e+03
#     log_sigma2: 4.05e-01
#
# [Epoch 40] | Phase: posterior
#   ELBO:       4.4641e+04
#   NLL:        4.4578e+04
#   KL(t):      4.5410e-01
#   KL(p):      7.9847e-09
#   t_cont:     3.3071e-01
#   Transition: -1.6283e+01
#   L1:         4.5975e+01
#   Grad Norms:
#     edge_logits: 1.53e-05
#     branch_logits: 0.00e+00
#     alpha: 2.67e+03
#     beta: 2.51e+03
#     g: 8.81e+03
#     K: 1.25e+03
#     log_sigma2: 4.05e-01
#
# [Epoch 41] | Phase: posterior
#   ELBO:       4.6357e+04
#   NLL:        4.6294e+04
#   KL(t):      4.6444e-01
#   KL(p):      8.2267e-09
#   t_cont:     3.3071e-01
#   Transition: -1.6301e+01
#   L1:         4.5975e+01
#   Grad Norms:
#     edge_logits: 1.58e-05
#     branch_logits: 0.00e+00
#     alpha: 2.41e+03
#     beta: 3.68e+03
#     g: 8.81e+03
#     K: 1.25e+03
#     log_sigma2: 4.05e-01
#
# [Epoch 42] | Phase: posterior
#   ELBO:       4.6622e+04
#   NLL:        4.6500e+04
#   KL(t):      5.9078e+01
#   KL(p):      7.6615e-09
#   t_cont:     3.3231e-01
#   Transition: -1.6348e+01
#   L1:         4.5975e+01
#   Grad Norms:
#     edge_logits: 1.52e-05
#     branch_logits: 0.00e+00
#     alpha: 2.44e+03
#     beta: 2.16e+03
#     g: 8.81e+03
#     K: 1.25e+03
#     log_sigma2: 4.05e-01
#
# [Epoch 43] | Phase: posterior
#   ELBO:       4.6515e+04
#   NLL:        4.6276e+04
#   KL(t):      1.7629e+02
#   KL(p):      8.0951e-09
#   t_cont:     3.3209e-01
#   Transition: -1.6311e+01
#   L1:         4.5975e+01
#   Grad Norms:
#     edge_logits: 1.54e-05
#     branch_logits: 0.00e+00
#     alpha: 1.85e+03
#     beta: 1.96e+03
#     g: 8.81e+03
#     K: 1.25e+03
#     log_sigma2: 4.05e-01
#
# [Epoch 44] | Phase: posterior
#   ELBO:       4.4762e+04
#   NLL:        4.4640e+04
#   KL(t):      5.9099e+01
#   KL(p):      7.3039e-09
#   t_cont:     3.3361e-01
#   Transition: -1.6297e+01
#   L1:         4.5975e+01
#   Grad Norms:
#     edge_logits: 1.56e-05
#     branch_logits: 0.00e+00
#     alpha: 1.81e+03
#     beta: 2.79e+03
#     g: 8.81e+03
#     K: 1.25e+03
#     log_sigma2: 4.05e-01
#
# [Epoch 45] | Phase: posterior
#   ELBO:       4.5744e+04
#   NLL:        4.5681e+04
#   KL(t):      5.2336e-01
#   KL(p):      8.3254e-09
#   t_cont:     3.2566e-01
#   Transition: -1.6314e+01
#   L1:         4.5975e+01
#   Grad Norms:
#     edge_logits: 1.54e-05
#     branch_logits: 0.00e+00
#     alpha: 2.42e+03
#     beta: 2.02e+03
#     g: 8.81e+03
#     K: 1.25e+03
#     log_sigma2: 4.05e-01
#
# [Epoch 46] | Phase: posterior
#   ELBO:       4.5364e+04
#   NLL:        4.5243e+04
#   KL(t):      5.9107e+01
#   KL(p):      9.8758e-09
#   t_cont:     3.3980e-01
#   Transition: -1.6299e+01
#   L1:         4.5975e+01
#   Grad Norms:
#     edge_logits: 1.56e-05
#     branch_logits: 0.00e+00
#     alpha: 3.59e+03
#     beta: 1.83e+03
#     g: 8.81e+03
#     K: 1.25e+03
#     log_sigma2: 4.05e-01
#
# [Epoch 47] | Phase: posterior
#   ELBO:       4.4814e+04
#   NLL:        4.4692e+04
#   KL(t):      5.9138e+01
#   KL(p):      7.4750e-09
#   t_cont:     3.2810e-01
#   Transition: -1.6267e+01
#   L1:         4.5975e+01
#   Grad Norms:
#     edge_logits: 1.53e-05
#     branch_logits: 0.00e+00
#     alpha: 2.19e+03
#     beta: 3.48e+03
#     g: 8.81e+03
#     K: 1.25e+03
#     log_sigma2: 4.05e-01
#
# [Epoch 48] | Phase: posterior
#   ELBO:       4.4587e+04
#   NLL:        4.4524e+04
#   KL(t):      5.5024e-01
#   KL(p):      6.6477e-09
#   t_cont:     3.3505e-01
#   Transition: -1.6321e+01
#   L1:         4.5975e+01
#   Grad Norms:
#     edge_logits: 1.52e-05
#     branch_logits: 0.00e+00
#     alpha: 2.33e+03
#     beta: 2.11e+03
#     g: 8.81e+03
#     K: 1.25e+03
#     log_sigma2: 4.05e-01
#
# [Epoch 49] | Phase: posterior
#   ELBO:       4.5730e+04
#   NLL:        4.5666e+04
#   KL(t):      5.6534e-01
#   KL(p):      8.0309e-09
#   t_cont:     3.2850e-01
#   Transition: -1.6333e+01
#   L1:         4.5975e+01
#   Grad Norms:
#     edge_logits: 1.56e-05
#     branch_logits: 0.00e+00
#     alpha: 2.05e+03
#     beta: 3.00e+03
#     g: 8.81e+03
#     K: 1.25e+03
#     log_sigma2: 4.05e-01
#
# [Epoch 50] | Phase: posterior
#   ELBO:       4.5685e+04
#   NLL:        4.5445e+04
#   KL(t):      1.7642e+02
#   KL(p):      8.9687e-09
#   t_cont:     3.2886e-01
#   Transition: -1.6334e+01
#   L1:         4.5975e+01
#   Grad Norms:
#     edge_logits: 1.51e-05
#     branch_logits: 0.00e+00
#     alpha: 2.28e+03
#     beta: 2.23e+03
#     g: 8.81e+03
#     K: 1.25e+03
#     log_sigma2: 4.05e-01
#
# [Epoch 51] | Phase: posterior
#   ELBO:       4.4606e+04
#   NLL:        4.4426e+04
#   KL(t):      1.1777e+02
#   KL(p):      8.4030e-09
#   t_cont:     3.3636e-01
#   Transition: -1.6321e+01
#   L1:         4.5975e+01
#   Grad Norms:
#     edge_logits: 1.58e-05
#     branch_logits: 0.00e+00
#     alpha: 2.96e+03
#     beta: 1.29e+03
#     g: 8.81e+03
#     K: 1.25e+03
#     log_sigma2: 4.05e-01
#
# [Epoch 52] | Phase: posterior
#   ELBO:       4.4692e+04
#   NLL:        4.4422e+04
#   KL(t):      2.0760e+02
#   KL(p):      6.2795e-09
#   t_cont:     3.2767e-01
#   Transition: -1.6265e+01
#   L1:         4.5975e+01
#   Grad Norms:
#     edge_logits: 1.52e-05
#     branch_logits: 0.00e+00
#     alpha: 2.13e+03
#     beta: 2.44e+03
#     g: 8.81e+03
#     K: 1.25e+03
#     log_sigma2: 4.05e-01
#
# [Epoch 53] | Phase: posterior
#   ELBO:       4.7048e+04
#   NLL:        4.6750e+04
#   KL(t):      2.3502e+02
#   KL(p):      7.8483e-09
#   t_cont:     3.3044e-01
#   Transition: -1.6277e+01
#   L1:         4.5975e+01
#   Grad Norms:
#     edge_logits: 1.56e-05
#     branch_logits: 0.00e+00
#     alpha: 2.95e+03
#     beta: 1.97e+03
#     g: 8.81e+03
#     K: 1.25e+03
#     log_sigma2: 4.05e-01
#
# [Epoch 54] | Phase: posterior
#   ELBO:       4.4894e+04
#   NLL:        4.4538e+04
#   KL(t):      2.9360e+02
#   KL(p):      7.4693e-09
#   t_cont:     3.3617e-01
#   Transition: -1.6316e+01
#   L1:         4.5975e+01
#   Grad Norms:
#     edge_logits: 1.53e-05
#     branch_logits: 0.00e+00
#     alpha: 3.62e+03
#     beta: 1.38e+03
#     g: 8.81e+03
#     K: 1.25e+03
#     log_sigma2: 4.05e-01
# --- Switching to emission phase ---
#
# [Epoch 55] | Phase: emission
#   ELBO:       4.5534e+04
#   NLL:        4.5118e+04
#   KL(t):      3.5227e+02
#   KL(p):      6.3281e-09
#   t_cont:     3.3086e-01
#   Transition: -1.6302e+01
#   L1:         4.7352e+01
#   Grad Norms:
#     edge_logits: 1.53e-05
#     branch_logits: 0.00e+00
#     alpha: 3.62e+03
#     beta: 1.38e+03
#     g: 8.91e+03
#     K: 1.23e+03
#     log_sigma2: 3.90e-01
#
# [Epoch 56] | Phase: emission
#   ELBO:       4.5000e+04
#   NLL:        4.4434e+04
#   KL(t):      5.0066e+02
#   KL(p):      6.4000e-09
#   t_cont:     3.2350e-01
#   Transition: -1.6324e+01
#   L1:         4.8214e+01
#   Grad Norms:
#     edge_logits: 1.53e-05
#     branch_logits: 0.00e+00
#     alpha: 3.62e+03
#     beta: 1.38e+03
#     g: 8.20e+03
#     K: 1.18e+03
#     log_sigma2: 3.65e-01
#
# [Epoch 57] | Phase: emission
#   ELBO:       4.5873e+04
#   NLL:        4.5514e+04
#   KL(t):      2.9363e+02
#   KL(p):      6.3758e-09
#   t_cont:     3.2685e-01
#   Transition: -1.6219e+01
#   L1:         4.8834e+01
#   Grad Norms:
#     edge_logits: 1.53e-05
#     branch_logits: 0.00e+00
#     alpha: 3.62e+03
#     beta: 1.38e+03
#     g: 8.43e+03
#     K: 1.11e+03
#     log_sigma2: 3.69e-01
#
# [Epoch 58] | Phase: emission
#   ELBO:       4.5672e+04
#   NLL:        4.5195e+04
#   KL(t):      4.1080e+02
#   KL(p):      6.1713e-09
#   t_cont:     3.3463e-01
#   Transition: -1.6240e+01
#   L1:         4.9624e+01
#   Grad Norms:
#     edge_logits: 1.53e-05
#     branch_logits: 0.00e+00
#     alpha: 3.62e+03
#     beta: 1.38e+03
#     g: 8.49e+03
#     K: 9.62e+02
#     log_sigma2: 4.17e-01
#
# [Epoch 59] | Phase: emission
#   ELBO:       4.3920e+04
#   NLL:        4.3559e+04
#   KL(t):      2.9363e+02
#   KL(p):      6.3295e-09
#   t_cont:     3.2217e-01
#   Transition: -1.6267e+01
#   L1:         5.0153e+01
#   Grad Norms:
#     edge_logits: 1.53e-05
#     branch_logits: 0.00e+00
#     alpha: 3.62e+03
#     beta: 1.38e+03
#     g: 8.21e+03
#     K: 1.06e+03
#     log_sigma2: 4.30e-01
#
# [Epoch 60] | Phase: emission
#   ELBO:       4.6149e+04
#   NLL:        4.5788e+04
#   KL(t):      2.9369e+02
#   KL(p):      6.4124e-09
#   t_cont:     3.2920e-01
#   Transition: -1.6332e+01
#   L1:         5.0808e+01
#   Grad Norms:
#     edge_logits: 1.53e-05
#     branch_logits: 0.00e+00
#     alpha: 3.62e+03
#     beta: 1.38e+03
#     g: 9.82e+03
#     K: 1.21e+03
#     log_sigma2: 3.79e-01
#
# [Epoch 61] | Phase: emission
#   ELBO:       4.5692e+04
#   NLL:        4.5182e+04
#   KL(t):      4.4207e+02
#   KL(p):      6.4257e-09
#   t_cont:     3.2967e-01
#   Transition: -1.6290e+01
#   L1:         5.1391e+01
#   Grad Norms:
#     edge_logits: 1.53e-05
#     branch_logits: 0.00e+00
#     alpha: 3.62e+03
#     beta: 1.38e+03
#     g: 8.26e+03
#     K: 1.08e+03
#     log_sigma2: 3.72e-01
#
# [Epoch 62] | Phase: emission
#   ELBO:       4.3286e+04
#   NLL:        4.3159e+04
#   KL(t):      5.9223e+01
#   KL(p):      6.3311e-09
#   t_cont:     3.3324e-01
#   Transition: -1.6280e+01
#   L1:         5.1350e+01
#   Grad Norms:
#     edge_logits: 1.53e-05
#     branch_logits: 0.00e+00
#     alpha: 3.62e+03
#     beta: 1.38e+03
#     g: 7.84e+03
#     K: 1.00e+03
#     log_sigma2: 3.79e-01
#
# [Epoch 63] | Phase: emission
#   ELBO:       4.5457e+04
#   NLL:        4.5037e+04
#   KL(t):      3.5227e+02
#   KL(p):      6.2993e-09
#   t_cont:     3.2787e-01
#   Transition: -1.6282e+01
#   L1:         5.1117e+01
#   Grad Norms:
#     edge_logits: 1.53e-05
#     branch_logits: 0.00e+00
#     alpha: 3.62e+03
#     beta: 1.38e+03
#     g: 8.60e+03
#     K: 1.16e+03
#     log_sigma2: 4.07e-01
#
# [Epoch 64] | Phase: emission
#   ELBO:       4.4147e+04
#   NLL:        4.3844e+04
#   KL(t):      2.3505e+02
#   KL(p):      6.5511e-09
#   t_cont:     3.2666e-01
#   Transition: -1.6307e+01
#   L1:         5.1758e+01
#   Grad Norms:
#     edge_logits: 1.53e-05
#     branch_logits: 0.00e+00
#     alpha: 3.62e+03
#     beta: 1.38e+03
#     g: 8.05e+03
#     K: 1.11e+03
#     log_sigma2: 3.77e-01
#
# [Epoch 65] | Phase: emission
#   ELBO:       4.4881e+04
#   NLL:        4.4578e+04
#   KL(t):      2.3505e+02
#   KL(p):      6.5190e-09
#   t_cont:     3.3009e-01
#   Transition: -1.6325e+01
#   L1:         5.1993e+01
#   Grad Norms:
#     edge_logits: 1.53e-05
#     branch_logits: 0.00e+00
#     alpha: 3.62e+03
#     beta: 1.38e+03
#     g: 8.31e+03
#     K: 1.01e+03
#     log_sigma2: 3.83e-01
#
# [Epoch 66] | Phase: emission
#   ELBO:       4.4938e+04
#   NLL:        4.4635e+04
#   KL(t):      2.3500e+02
#   KL(p):      6.5663e-09
#   t_cont:     3.2745e-01
#   Transition: -1.6279e+01
#   L1:         5.1546e+01
#   Grad Norms:
#     edge_logits: 1.53e-05
#     branch_logits: 0.00e+00
#     alpha: 3.62e+03
#     beta: 1.38e+03
#     g: 8.44e+03
#     K: 1.08e+03
#     log_sigma2: 5.20e-01
#
# [Epoch 67] | Phase: emission
#   ELBO:       4.4323e+04
#   NLL:        4.3785e+04
#   KL(t):      4.6939e+02
#   KL(p):      6.3358e-09
#   t_cont:     3.3448e-01
#   Transition: -1.6254e+01
#   L1:         5.1449e+01
#   Grad Norms:
#     edge_logits: 1.53e-05
#     branch_logits: 0.00e+00
#     alpha: 3.62e+03
#     beta: 1.38e+03
#     g: 7.31e+03
#     K: 1.05e+03
#     log_sigma2: 3.78e-01
#
# [Epoch 68] | Phase: emission
#   ELBO:       4.5427e+04
#   NLL:        4.5123e+04
#   KL(t):      2.3506e+02
#   KL(p):      6.2945e-09
#   t_cont:     3.4050e-01
#   Transition: -1.6302e+01
#   L1:         5.1650e+01
#   Grad Norms:
#     edge_logits: 1.53e-05
#     branch_logits: 0.00e+00
#     alpha: 3.62e+03
#     beta: 1.38e+03
#     g: 8.74e+03
#     K: 1.13e+03
#     log_sigma2: 3.94e-01
#
# [Epoch 69] | Phase: emission
#   ELBO:       4.5449e+04
#   NLL:        4.5145e+04
#   KL(t):      2.3507e+02
#   KL(p):      6.4240e-09
#   t_cont:     3.3786e-01
#   Transition: -1.6295e+01
#   L1:         5.1496e+01
#   Grad Norms:
#     edge_logits: 1.53e-05
#     branch_logits: 0.00e+00
#     alpha: 3.62e+03
#     beta: 1.38e+03
#     g: 8.40e+03
#     K: 1.08e+03
#     log_sigma2: 4.03e-01
#
# [Epoch 70] | Phase: emission
#   ELBO:       4.4831e+04
#   NLL:        4.4582e+04
#   KL(t):      1.8035e+02
#   KL(p):      6.5897e-09
#   t_cont:     3.3150e-01
#   Transition: -1.6343e+01
#   L1:         5.1464e+01
#   Grad Norms:
#     edge_logits: 1.53e-05
#     branch_logits: 0.00e+00
#     alpha: 3.62e+03
#     beta: 1.38e+03
#     g: 8.24e+03
#     K: 9.78e+02
#     log_sigma2: 4.19e-01
#
# [Epoch 71] | Phase: emission
#   ELBO:       4.4884e+04
#   NLL:        4.4757e+04
#   KL(t):      5.9243e+01
#   KL(p):      6.1063e-09
#   t_cont:     3.3412e-01
#   Transition: -1.6282e+01
#   L1:         5.1675e+01
#   Grad Norms:
#     edge_logits: 1.53e-05
#     branch_logits: 0.00e+00
#     alpha: 3.62e+03
#     beta: 1.38e+03
#     g: 8.14e+03
#     K: 1.32e+03
#     log_sigma2: 3.76e-01
#
# [Epoch 72] | Phase: emission
#   ELBO:       4.4748e+04
#   NLL:        4.4386e+04
#   KL(t):      2.9361e+02
#   KL(p):      6.4322e-09
#   t_cont:     3.3959e-01
#   Transition: -1.6259e+01
#   L1:         5.1833e+01
#   Grad Norms:
#     edge_logits: 1.53e-05
#     branch_logits: 0.00e+00
#     alpha: 3.62e+03
#     beta: 1.38e+03
#     g: 8.21e+03
#     K: 1.03e+03
#     log_sigma2: 3.93e-01
# --- Switching to posterior phase ---
#
# [Epoch 73] | Phase: posterior
#   ELBO:       4.4211e+04
#   NLL:        4.3850e+04
#   KL(t):      2.9359e+02
#   KL(p):      6.4042e-09
#   t_cont:     3.3932e-01
#   Transition: -1.6277e+01
#   L1:         5.1176e+01
#   Grad Norms:
#     edge_logits: 1.55e-05
#     branch_logits: 0.00e+00
#     alpha: 3.71e+03
#     beta: 3.02e+03
#     g: 8.21e+03
#     K: 1.03e+03
#     log_sigma2: 3.93e-01
#
# [Epoch 74] | Phase: posterior
#   ELBO:       4.3780e+04
#   NLL:        4.3360e+04
#   KL(t):      3.5224e+02
#   KL(p):      8.8634e-09
#   t_cont:     3.2772e-01
#   Transition: -1.6349e+01
#   L1:         5.1176e+01
#   Grad Norms:
#     edge_logits: 1.55e-05
#     branch_logits: 0.00e+00
#     alpha: 4.85e+03
#     beta: 5.22e+03
#     g: 8.21e+03
#     K: 1.03e+03
#     log_sigma2: 3.93e-01
#
# [Epoch 75] | Phase: posterior
#   ELBO:       4.4390e+04
#   NLL:        4.4029e+04
#   KL(t):      2.9365e+02
#   KL(p):      8.0612e-09
#   t_cont:     3.3124e-01
#   Transition: -1.6325e+01
#   L1:         5.1176e+01
#   Grad Norms:
#     edge_logits: 1.56e-05
#     branch_logits: 0.00e+00
#     alpha: 2.02e+03
#     beta: 2.81e+03
#     g: 8.21e+03
#     K: 1.03e+03
#     log_sigma2: 3.93e-01
#
# [Epoch 76] | Phase: posterior
#   ELBO:       4.4515e+04
#   NLL:        4.4095e+04
#   KL(t):      3.5225e+02
#   KL(p):      6.2676e-09
#   t_cont:     3.3628e-01
#   Transition: -1.6258e+01
#   L1:         5.1176e+01
#   Grad Norms:
#     edge_logits: 1.55e-05
#     branch_logits: 0.00e+00
#     alpha: 2.93e+03
#     beta: 1.82e+03
#     g: 8.21e+03
#     K: 1.03e+03
#     log_sigma2: 3.93e-01
#
# [Epoch 77] | Phase: posterior
#   ELBO:       4.3714e+04
#   NLL:        4.3146e+04
#   KL(t):      5.0070e+02
#   KL(p):      6.9732e-09
#   t_cont:     3.3767e-01
#   Transition: -1.6353e+01
#   L1:         5.1176e+01
#   Grad Norms:
#     edge_logits: 1.58e-05
#     branch_logits: 0.00e+00
#     alpha: 2.09e+03
#     beta: 2.13e+03
#     g: 8.21e+03
#     K: 1.03e+03
#     log_sigma2: 3.93e-01
#
# [Epoch 78] | Phase: posterior
#   ELBO:       4.3432e+04
#   NLL:        4.3011e+04
#   KL(t):      3.5227e+02
#   KL(p):      6.9209e-09
#   t_cont:     3.3133e-01
#   Transition: -1.6325e+01
#   L1:         5.1176e+01
#   Grad Norms:
#     edge_logits: 1.54e-05
#     branch_logits: 0.00e+00
#     alpha: 2.57e+03
#     beta: 5.14e+03
#     g: 8.21e+03
#     K: 1.03e+03
#     log_sigma2: 3.93e-01
#
# [Epoch 79] | Phase: posterior
#   ELBO:       4.3891e+04
#   NLL:        4.3354e+04
#   KL(t):      4.6947e+02
#   KL(p):      7.0099e-09
#   t_cont:     3.3948e-01
#   Transition: -1.6271e+01
#   L1:         5.1176e+01
#   Grad Norms:
#     edge_logits: 1.52e-05
#     branch_logits: 0.00e+00
#     alpha: 2.52e+03
#     beta: 1.87e+03
#     g: 8.21e+03
#     K: 1.03e+03
#     log_sigma2: 3.93e-01
#
# [Epoch 80] | Phase: posterior
#   ELBO:       4.3265e+04
#   NLL:        4.2728e+04
#   KL(t):      4.6951e+02
#   KL(p):      7.0804e-09
#   t_cont:     3.4183e-01
#   Transition: -1.6325e+01
#   L1:         5.1176e+01
#   Grad Norms:
#     edge_logits: 1.50e-05
#     branch_logits: 0.00e+00
#     alpha: 2.30e+03
#     beta: 2.74e+03
#     g: 8.21e+03
#     K: 1.03e+03
#     log_sigma2: 3.93e-01
#
# [Epoch 81] | Phase: posterior
#   ELBO:       4.3483e+04
#   NLL:        4.3239e+04
#   KL(t):      1.7664e+02
#   KL(p):      6.9706e-09
#   t_cont:     3.3560e-01
#   Transition: -1.6307e+01
#   L1:         5.1176e+01
#   Grad Norms:
#     edge_logits: 1.57e-05
#     branch_logits: 0.00e+00
#     alpha: 3.04e+03
#     beta: 7.36e+03
#     g: 8.21e+03
#     K: 1.03e+03
#     log_sigma2: 3.93e-01
#
# [Epoch 82] | Phase: posterior
#   ELBO:       4.4053e+04
#   NLL:        4.3574e+04
#   KL(t):      4.1092e+02
#   KL(p):      5.5474e-09
#   t_cont:     3.4097e-01
#   Transition: -1.6366e+01
#   L1:         5.1176e+01
#   Grad Norms:
#     edge_logits: 1.60e-05
#     branch_logits: 0.00e+00
#     alpha: 3.35e+03
#     beta: 9.20e+03
#     g: 8.21e+03
#     K: 1.03e+03
#     log_sigma2: 3.93e-01
#
# [Epoch 83] | Phase: posterior
#   ELBO:       4.3879e+04
#   NLL:        4.3517e+04
#   KL(t):      2.9381e+02
#   KL(p):      8.2376e-09
#   t_cont:     3.3716e-01
#   Transition: -1.6264e+01
#   L1:         5.1176e+01
#   Grad Norms:
#     edge_logits: 1.60e-05
#     branch_logits: 0.00e+00
#     alpha: 2.41e+03
#     beta: 2.16e+03
#     g: 8.21e+03
#     K: 1.03e+03
#     log_sigma2: 3.93e-01
#
# [Epoch 84] | Phase: posterior
#   ELBO:       4.3817e+04
#   NLL:        4.3163e+04
#   KL(t):      5.8673e+02
#   KL(p):      8.4139e-09
#   t_cont:     3.3234e-01
#   Transition: -1.6276e+01
#   L1:         5.1176e+01
#   Grad Norms:
#     edge_logits: 1.51e-05
#     branch_logits: 0.00e+00
#     alpha: 3.56e+03
#     beta: 3.22e+03
#     g: 8.21e+03
#     K: 1.03e+03
#     log_sigma2: 3.93e-01
#
# [Epoch 85] | Phase: posterior
#   ELBO:       4.2356e+04
#   NLL:        4.1584e+04
#   KL(t):      7.0405e+02
#   KL(p):      7.0874e-09
#   t_cont:     3.3701e-01
#   Transition: -1.6379e+01
#   L1:         5.1176e+01
#   Grad Norms:
#     edge_logits: 1.59e-05
#     branch_logits: 0.00e+00
#     alpha: 2.83e+03
#     beta: 3.35e+03
#     g: 8.21e+03
#     K: 1.03e+03
#     log_sigma2: 3.93e-01
#
# [Epoch 86] | Phase: posterior
#   ELBO:       4.3537e+04
#   NLL:        4.2999e+04
#   KL(t):      4.6961e+02
#   KL(p):      8.0873e-09
#   t_cont:     3.3314e-01
#   Transition: -1.6303e+01
#   L1:         5.1176e+01
#   Grad Norms:
#     edge_logits: 1.55e-05
#     branch_logits: 0.00e+00
#     alpha: 3.27e+03
#     beta: 3.00e+03
#     g: 8.21e+03
#     K: 1.03e+03
#     log_sigma2: 3.93e-01
#
# [Epoch 87] | Phase: posterior
#   ELBO:       4.2825e+04
#   NLL:        4.2018e+04
#   KL(t):      7.3910e+02
#   KL(p):      6.6874e-09
#   t_cont:     3.3147e-01
#   Transition: -1.6380e+01
#   L1:         5.1176e+01
#   Grad Norms:
#     edge_logits: 1.51e-05
#     branch_logits: 0.00e+00
#     alpha: 3.25e+03
#     beta: 2.66e+03
#     g: 8.21e+03
#     K: 1.03e+03
#     log_sigma2: 3.93e-01
#
# [Epoch 88] | Phase: posterior
#   ELBO:       4.3588e+04
#   NLL:        4.2961e+04
#   KL(t):      5.5947e+02
#   KL(p):      9.5077e-09
#   t_cont:     3.4060e-01
#   Transition: -1.6337e+01
#   L1:         5.1176e+01
#   Grad Norms:
#     edge_logits: 1.57e-05
#     branch_logits: 0.00e+00
#     alpha: 3.58e+03
#     beta: 1.58e+03
#     g: 8.21e+03
#     K: 1.03e+03
#     log_sigma2: 3.93e-01
#
# [Epoch 89] | Phase: posterior
#   ELBO:       4.4197e+04
#   NLL:        4.2808e+04
#   KL(t):      1.3213e+03
#   KL(p):      7.3216e-09
#   t_cont:     3.3050e-01
#   Transition: -1.6330e+01
#   L1:         5.1176e+01
#   Grad Norms:
#     edge_logits: 1.58e-05
#     branch_logits: 0.00e+00
#     alpha: 2.44e+03
#     beta: 2.24e+03
#     g: 8.21e+03
#     K: 1.03e+03
#     log_sigma2: 3.93e-01
#
# [Epoch 90] | Phase: posterior
#   ELBO:       4.3438e+04
#   NLL:        4.2400e+04
#   KL(t):      9.6988e+02
#   KL(p):      7.0671e-09
#   t_cont:     3.3633e-01
#   Transition: -1.6293e+01
#   L1:         5.1176e+01
#   Grad Norms:
#     edge_logits: 1.49e-05
#     branch_logits: 0.00e+00
#     alpha: 5.41e+03
#     beta: 1.86e+03
#     g: 8.21e+03
#     K: 1.03e+03
#     log_sigma2: 3.93e-01
#
# [Epoch 91] | Phase: posterior
#   ELBO:       4.3788e+04
#   NLL:        4.3016e+04
#   KL(t):      7.0409e+02
#   KL(p):      7.4171e-09
#   t_cont:     3.3096e-01
#   Transition: -1.6346e+01
#   L1:         5.1176e+01
#   Grad Norms:
#     edge_logits: 1.53e-05
#     branch_logits: 0.00e+00
#     alpha: 3.17e+03
#     beta: 2.69e+03
#     g: 8.21e+03
#     K: 1.03e+03
#     log_sigma2: 3.93e-01
#
# [Epoch 92] | Phase: posterior
#   ELBO:       4.3402e+04
#   NLL:        4.2044e+04
#   KL(t):      1.2901e+03
#   KL(p):      4.7249e-09
#   t_cont:     3.3495e-01
#   Transition: -1.6294e+01
#   L1:         5.1176e+01
#   Grad Norms:
#     edge_logits: 1.55e-05
#     branch_logits: 0.00e+00
#     alpha: 3.78e+03
#     beta: 1.75e+03
#     g: 8.21e+03
#     K: 1.03e+03
#     log_sigma2: 3.93e-01
#
# [Epoch 93] | Phase: posterior
#   ELBO:       4.2452e+04
#   NLL:        4.1356e+04
#   KL(t):      1.0284e+03
#   KL(p):      7.8344e-09
#   t_cont:     3.3134e-01
#   Transition: -1.6313e+01
#   L1:         5.1176e+01
#   Grad Norms:
#     edge_logits: 1.58e-05
#     branch_logits: 0.00e+00
#     alpha: 3.09e+03
#     beta: 2.19e+03
#     g: 8.21e+03
#     K: 1.03e+03
#     log_sigma2: 3.93e-01
#
# [Epoch 94] | Phase: posterior
#   ELBO:       4.3652e+04
#   NLL:        4.2524e+04
#   KL(t):      1.0596e+03
#   KL(p):      5.5702e-09
#   t_cont:     3.3213e-01
#   Transition: -1.6346e+01
#   L1:         5.1176e+01
#   Grad Norms:
#     edge_logits: 1.56e-05
#     branch_logits: 0.00e+00
#     alpha: 4.24e+03
#     beta: 1.28e+03
#     g: 8.21e+03
#     K: 1.03e+03
#     log_sigma2: 3.93e-01
#
# [Epoch 95] | Phase: posterior
#   ELBO:       4.4143e+04
#   NLL:        4.3222e+04
#   KL(t):      8.5256e+02
#   KL(p):      8.1056e-09
#   t_cont:     3.3617e-01
#   Transition: -1.6263e+01
#   L1:         5.1176e+01
#   Grad Norms:
#     edge_logits: 1.57e-05
#     branch_logits: 0.00e+00
#     alpha: 3.89e+03
#     beta: 1.96e+03
#     g: 8.21e+03
#     K: 1.03e+03
#     log_sigma2: 3.93e-01
# --- Switching to emission phase ---
#
# [Epoch 96] | Phase: emission
#   ELBO:       4.3677e+04
#   NLL:        4.2638e+04
#   KL(t):      9.6982e+02
#   KL(p):      6.0700e-09
#   t_cont:     3.2913e-01
#   Transition: -1.6395e+01
#   L1:         5.2338e+01
#   Grad Norms:
#     edge_logits: 1.57e-05
#     branch_logits: 0.00e+00
#     alpha: 3.89e+03
#     beta: 1.96e+03
#     g: 7.79e+03
#     K: 9.88e+02
#     log_sigma2: 3.97e-01
#
# [Epoch 97] | Phase: emission
#   ELBO:       4.4622e+04
#   NLL:        4.3375e+04
#   KL(t):      1.1769e+03
#   KL(p):      6.0501e-09
#   t_cont:     3.3336e-01
#   Transition: -1.6287e+01
#   L1:         5.3225e+01
#   Grad Norms:
#     edge_logits: 1.57e-05
#     branch_logits: 0.00e+00
#     alpha: 3.89e+03
#     beta: 1.96e+03
#     g: 8.88e+03
#     K: 1.12e+03
#     log_sigma2: 4.45e-01
#
# [Epoch 98] | Phase: emission
#   ELBO:       4.2417e+04
#   NLL:        4.1435e+04
#   KL(t):      9.1119e+02
#   KL(p):      5.9736e-09
#   t_cont:     3.3096e-01
#   Transition: -1.6393e+01
#   L1:         5.3749e+01
#   Grad Norms:
#     edge_logits: 1.57e-05
#     branch_logits: 0.00e+00
#     alpha: 3.89e+03
#     beta: 1.96e+03
#     g: 7.99e+03
#     K: 1.19e+03
#     log_sigma2: 4.00e-01
#
# [Epoch 99] | Phase: emission
#   ELBO:       4.2092e+04
#   NLL:        4.1051e+04
#   KL(t):      9.6975e+02
#   KL(p):      6.1156e-09
#   t_cont:     3.3232e-01
#   Transition: -1.6233e+01
#   L1:         5.4077e+01
#   Grad Norms:
#     edge_logits: 1.57e-05
#     branch_logits: 0.00e+00
#     alpha: 3.89e+03
#     beta: 1.96e+03
#     g: 8.22e+03
#     K: 1.19e+03
#     log_sigma2: 3.78e-01
#
# [Epoch 100] | Phase: emission
#   ELBO:       4.3763e+04
#   NLL:        4.2636e+04
#   KL(t):      1.0558e+03
#   KL(p):      6.1842e-09
#   t_cont:     3.3036e-01
#   Transition: -1.6332e+01
#   L1:         5.4289e+01
#   Grad Norms:
#     edge_logits: 1.57e-05
#     branch_logits: 0.00e+00
#     alpha: 3.89e+03
#     beta: 1.96e+03
#     g: 7.67e+03
#     K: 1.08e+03
#     log_sigma2: 3.37e-01
#
# [Epoch 101] | Phase: emission
#   ELBO:       4.3039e+04
#   NLL:        4.1498e+04
#   KL(t):      1.4698e+03
#   KL(p):      6.1403e-09
#   t_cont:     3.4035e-01
#   Transition: -1.6305e+01
#   L1:         5.4865e+01
#   Grad Norms:
#     edge_logits: 1.57e-05
#     branch_logits: 0.00e+00
#     alpha: 3.89e+03
#     beta: 1.96e+03
#     g: 8.51e+03
#     K: 1.29e+03
#     log_sigma2: 3.74e-01
#
# [Epoch 102] | Phase: emission
#   ELBO:       4.1997e+04
#   NLL:        4.0982e+04
#   KL(t):      9.4238e+02
#   KL(p):      6.2961e-09
#   t_cont:     3.2373e-01
#   Transition: -1.6334e+01
#   L1:         5.5451e+01
#   Grad Norms:
#     edge_logits: 1.57e-05
#     branch_logits: 0.00e+00
#     alpha: 3.89e+03
#     beta: 1.96e+03
#     g: 8.48e+03
#     K: 1.42e+03
#     log_sigma2: 3.89e-01
#
# [Epoch 103] | Phase: emission
#   ELBO:       4.2772e+04
#   NLL:        4.1289e+04
#   KL(t):      1.4112e+03
#   KL(p):      6.1102e-09
#   t_cont:     3.3955e-01
#   Transition: -1.6270e+01
#   L1:         5.5598e+01
#   Grad Norms:
#     edge_logits: 1.57e-05
#     branch_logits: 0.00e+00
#     alpha: 3.89e+03
#     beta: 1.96e+03
#     g: 7.69e+03
#     K: 1.12e+03
#     log_sigma2: 4.01e-01
#
# [Epoch 104] | Phase: emission
#   ELBO:       4.4023e+04
#   NLL:        4.2629e+04
#   KL(t):      1.3214e+03
#   KL(p):      5.8854e-09
#   t_cont:     3.3222e-01
#   Transition: -1.6290e+01
#   L1:         5.5674e+01
#   Grad Norms:
#     edge_logits: 1.57e-05
#     branch_logits: 0.00e+00
#     alpha: 3.89e+03
#     beta: 1.96e+03
#     g: 9.09e+03
#     K: 1.25e+03
#     log_sigma2: 3.74e-01
#
# [Epoch 105] | Phase: emission
#   ELBO:       4.1662e+04
#   NLL:        4.0769e+04
#   KL(t):      8.2142e+02
#   KL(p):      5.9127e-09
#   t_cont:     3.3438e-01
#   Transition: -1.6316e+01
#   L1:         5.5583e+01
#   Grad Norms:
#     edge_logits: 1.57e-05
#     branch_logits: 0.00e+00
#     alpha: 3.89e+03
#     beta: 1.96e+03
#     g: 8.69e+03
#     K: 1.16e+03
#     log_sigma2: 3.91e-01
#
# [Epoch 106] | Phase: emission
#   ELBO:       4.4201e+04
#   NLL:        4.2893e+04
#   KL(t):      1.2354e+03
#   KL(p):      6.0156e-09
#   t_cont:     3.3632e-01
#   Transition: -1.6329e+01
#   L1:         5.5892e+01
#   Grad Norms:
#     edge_logits: 1.57e-05
#     branch_logits: 0.00e+00
#     alpha: 3.89e+03
#     beta: 1.96e+03
#     g: 7.35e+03
#     K: 1.10e+03
#     log_sigma2: 3.79e-01
#
# [Epoch 107] | Phase: emission
#   ELBO:       4.3510e+04
#   NLL:        4.2616e+04
#   KL(t):      8.2144e+02
#   KL(p):      5.9386e-09
#   t_cont:     3.3415e-01
#   Transition: -1.6263e+01
#   L1:         5.6085e+01
#   Grad Norms:
#     edge_logits: 1.57e-05
#     branch_logits: 0.00e+00
#     alpha: 3.89e+03
#     beta: 1.96e+03
#     g: 7.78e+03
#     K: 1.10e+03
#     log_sigma2: 3.83e-01
#
# [Epoch 108] | Phase: emission
#   ELBO:       4.2351e+04
#   NLL:        4.1426e+04
#   KL(t):      8.5268e+02
#   KL(p):      5.9984e-09
#   t_cont:     3.3696e-01
#   Transition: -1.6297e+01
#   L1:         5.6216e+01
#   Grad Norms:
#     edge_logits: 1.57e-05
#     branch_logits: 0.00e+00
#     alpha: 3.89e+03
#     beta: 1.96e+03
#     g: 7.89e+03
#     K: 1.12e+03
#     log_sigma2: 3.61e-01
#
# [Epoch 109] | Phase: emission
#   ELBO:       4.3655e+04
#   NLL:        4.2819e+04
#   KL(t):      7.6297e+02
#   KL(p):      5.9733e-09
#   t_cont:     3.3441e-01
#   Transition: -1.6284e+01
#   L1:         5.6165e+01
#   Grad Norms:
#     edge_logits: 1.57e-05
#     branch_logits: 0.00e+00
#     alpha: 3.89e+03
#     beta: 1.96e+03
#     g: 8.78e+03
#     K: 1.13e+03
#     log_sigma2: 3.87e-01
#
# [Epoch 110] | Phase: emission
#   ELBO:       4.2750e+04
#   NLL:        4.1235e+04
#   KL(t):      1.4425e+03
#   KL(p):      6.0623e-09
#   t_cont:     3.3578e-01
#   Transition: -1.6383e+01
#   L1:         5.6040e+01
#   Grad Norms:
#     edge_logits: 1.57e-05
#     branch_logits: 0.00e+00
#     alpha: 3.89e+03
#     beta: 1.96e+03
#     g: 9.86e+03
#     K: 1.54e+03
#     log_sigma2: 3.99e-01
#
# [Epoch 111] | Phase: emission
#   ELBO:       4.3283e+04
#   NLL:        4.2064e+04
#   KL(t):      1.1457e+03
#   KL(p):      5.9135e-09
#   t_cont:     3.3343e-01
#   Transition: -1.6285e+01
#   L1:         5.6079e+01
#   Grad Norms:
#     edge_logits: 1.57e-05
#     branch_logits: 0.00e+00
#     alpha: 3.89e+03
#     beta: 1.96e+03
#     g: 7.65e+03
#     K: 9.92e+02
#     log_sigma2: 3.87e-01
#
# [Epoch 112] | Phase: emission
#   ELBO:       4.3826e+04
#   NLL:        4.2991e+04
#   KL(t):      7.6280e+02
#   KL(p):      6.1899e-09
#   t_cont:     3.2790e-01
#   Transition: -1.6351e+01
#   L1:         5.5879e+01
#   Grad Norms:
#     edge_logits: 1.57e-05
#     branch_logits: 0.00e+00
#     alpha: 3.89e+03
#     beta: 1.96e+03
#     g: 8.10e+03
#     K: 1.10e+03
#     log_sigma2: 3.94e-01
#
# [Epoch 113] | Phase: emission
#   ELBO:       4.3283e+04
#   NLL:        4.1971e+04
#   KL(t):      1.2393e+03
#   KL(p):      6.1402e-09
#   t_cont:     3.3751e-01
#   Transition: -1.6320e+01
#   L1:         5.5954e+01
#   Grad Norms:
#     edge_logits: 1.57e-05
#     branch_logits: 0.00e+00
#     alpha: 3.89e+03
#     beta: 1.96e+03
#     g: 7.95e+03
#     K: 1.12e+03
#     log_sigma2: 3.47e-01
#
# [Epoch 114] | Phase: emission
#   ELBO:       4.2388e+04
#   NLL:        4.1142e+04
#   KL(t):      1.1729e+03
#   KL(p):      6.1204e-09
#   t_cont:     3.3878e-01
#   Transition: -1.6345e+01
#   L1:         5.6165e+01
#   Grad Norms:
#     edge_logits: 1.57e-05
#     branch_logits: 0.00e+00
#     alpha: 3.89e+03
#     beta: 1.96e+03
#     g: 8.25e+03
#     K: 1.00e+03
#     log_sigma2: 4.38e-01
#
# [Epoch 115] | Phase: emission
#   ELBO:       4.4000e+04
#   NLL:        4.2692e+04
#   KL(t):      1.2355e+03
#   KL(p):      6.0602e-09
#   t_cont:     3.4228e-01
#   Transition: -1.6351e+01
#   L1:         5.6582e+01
#   Grad Norms:
#     edge_logits: 1.57e-05
#     branch_logits: 0.00e+00
#     alpha: 3.89e+03
#     beta: 1.96e+03
#     g: 8.70e+03
#     K: 1.17e+03
#     log_sigma2: 4.29e-01
# --- Switching to posterior phase ---
#
# [Epoch 116] | Phase: posterior
#   ELBO:       4.2312e+04
#   NLL:        4.1211e+04
#   KL(t):      1.0284e+03
#   KL(p):      6.3802e-09
#   t_cont:     3.3532e-01
#   Transition: -1.6330e+01
#   L1:         5.6021e+01
#   Grad Norms:
#     edge_logits: 1.57e-05
#     branch_logits: 0.00e+00
#     alpha: 3.88e+03
#     beta: 2.09e+03
#     g: 8.70e+03
#     K: 1.17e+03
#     log_sigma2: 4.29e-01
#
# [Epoch 117] | Phase: posterior
#   ELBO:       4.2710e+04
#   NLL:        4.1226e+04
#   KL(t):      1.4112e+03
#   KL(p):      8.8024e-09
#   t_cont:     3.2508e-01
#   Transition: -1.6330e+01
#   L1:         5.6021e+01
#   Grad Norms:
#     edge_logits: 1.57e-05
#     branch_logits: 0.00e+00
#     alpha: 3.03e+03
#     beta: 2.78e+03
#     g: 8.70e+03
#     K: 1.17e+03
#     log_sigma2: 4.29e-01
#
# [Epoch 118] | Phase: posterior
#   ELBO:       4.2476e+04
#   NLL:        4.0965e+04
#   KL(t):      1.4387e+03
#   KL(p):      6.9311e-09
#   t_cont:     3.2844e-01
#   Transition: -1.6309e+01
#   L1:         5.6021e+01
#   Grad Norms:
#     edge_logits: 1.56e-05
#     branch_logits: 0.00e+00
#     alpha: 2.85e+03
#     beta: 3.58e+03
#     g: 8.70e+03
#     K: 1.17e+03
#     log_sigma2: 4.29e-01
#
# [Epoch 119] | Phase: posterior
#   ELBO:       4.2121e+04
#   NLL:        4.1137e+04
#   KL(t):      9.1149e+02
#   KL(p):      7.4262e-09
#   t_cont:     3.3425e-01
#   Transition: -1.6442e+01
#   L1:         5.6021e+01
#   Grad Norms:
#     edge_logits: 1.63e-05
#     branch_logits: 0.00e+00
#     alpha: 3.23e+03
#     beta: 2.79e+03
#     g: 8.70e+03
#     K: 1.17e+03
#     log_sigma2: 4.29e-01
#
# [Epoch 120] | Phase: posterior
#   ELBO:       4.2732e+04
#   NLL:        4.1865e+04
#   KL(t):      7.9414e+02
#   KL(p):      5.3440e-09
#   t_cont:     3.3139e-01
#   Transition: -1.6286e+01
#   L1:         5.6021e+01
#   Grad Norms:
#     edge_logits: 1.61e-05
#     branch_logits: 0.00e+00
#     alpha: 2.74e+03
#     beta: 3.73e+03
#     g: 8.70e+03
#     K: 1.17e+03
#     log_sigma2: 4.29e-01
#
# [Epoch 121] | Phase: posterior
#   ELBO:       4.2672e+04
#   NLL:        4.1629e+04
#   KL(t):      9.6992e+02
#   KL(p):      8.4611e-09
#   t_cont:     3.3758e-01
#   Transition: -1.6265e+01
#   L1:         5.6021e+01
#   Grad Norms:
#     edge_logits: 1.55e-05
#     branch_logits: 0.00e+00
#     alpha: 4.65e+03
#     beta: 2.63e+03
#     g: 8.70e+03
#     K: 1.17e+03
#     log_sigma2: 4.29e-01
#
# [Epoch 122] | Phase: posterior
#   ELBO:       4.3123e+04
#   NLL:        4.1526e+04
#   KL(t):      1.5247e+03
#   KL(p):      6.7559e-09
#   t_cont:     3.4085e-01
#   Transition: -1.6362e+01
#   L1:         5.6021e+01
#   Grad Norms:
#     edge_logits: 1.56e-05
#     branch_logits: 0.00e+00
#     alpha: 6.64e+03
#     beta: 3.32e+03
#     g: 8.70e+03
#     K: 1.17e+03
#     log_sigma2: 4.29e-01
#
# [Epoch 123] | Phase: posterior
#   ELBO:       4.1186e+04
#   NLL:        3.9588e+04
#   KL(t):      1.5246e+03
#   KL(p):      7.3592e-09
#   t_cont:     3.4102e-01
#   Transition: -1.6242e+01
#   L1:         5.6021e+01
#   Grad Norms:
#     edge_logits: 1.55e-05
#     branch_logits: 0.00e+00
#     alpha: 4.06e+03
#     beta: 1.97e+03
#     g: 8.70e+03
#     K: 1.17e+03
#     log_sigma2: 4.29e-01
#
# [Epoch 124] | Phase: posterior
#   ELBO:       4.4433e+04
#   NLL:        4.2332e+04
#   KL(t):      2.0284e+03
#   KL(p):      7.4446e-09
#   t_cont:     3.2761e-01
#   Transition: -1.6357e+01
#   L1:         5.6021e+01
#   Grad Norms:
#     edge_logits: 1.57e-05
#     branch_logits: 0.00e+00
#     alpha: 4.29e+03
#     beta: 2.90e+03
#     g: 8.70e+03
#     K: 1.17e+03
#     log_sigma2: 4.29e-01
#
# [Epoch 125] | Phase: posterior
#   ELBO:       4.2494e+04
#   NLL:        4.0834e+04
#   KL(t):      1.5871e+03
#   KL(p):      4.4813e-09
#   t_cont:     3.3984e-01
#   Transition: -1.6249e+01
#   L1:         5.6021e+01
#   Grad Norms:
#     edge_logits: 1.55e-05
#     branch_logits: 0.00e+00
#     alpha: 3.14e+03
#     beta: 3.56e+03
#     g: 8.70e+03
#     K: 1.17e+03
#     log_sigma2: 4.29e-01
#
# [Epoch 126] | Phase: posterior
#   ELBO:       4.3928e+04
#   NLL:        4.2092e+04
#   KL(t):      1.7637e+03
#   KL(p):      7.5886e-09
#   t_cont:     3.4070e-01
#   Transition: -1.6339e+01
#   L1:         5.6021e+01
#   Grad Norms:
#     edge_logits: 1.52e-05
#     branch_logits: 0.00e+00
#     alpha: 4.57e+03
#     beta: 3.05e+03
#     g: 8.70e+03
#     K: 1.17e+03
#     log_sigma2: 4.29e-01
#
# [Epoch 127] | Phase: posterior
#   ELBO:       4.3232e+04
#   NLL:        4.0489e+04
#   KL(t):      2.6698e+03
#   KL(p):      6.9521e-09
#   t_cont:     3.3117e-01
#   Transition: -1.6323e+01
#   L1:         5.6021e+01
#   Grad Norms:
#     edge_logits: 1.56e-05
#     branch_logits: 0.00e+00
#     alpha: 4.26e+03
#     beta: 1.78e+03
#     g: 8.70e+03
#     K: 1.17e+03
#     log_sigma2: 4.29e-01
#
# [Epoch 128] | Phase: posterior
#   ELBO:       4.3503e+04
#   NLL:        4.1198e+04
#   KL(t):      2.2317e+03
#   KL(p):      8.0252e-09
#   t_cont:     3.3977e-01
#   Transition: -1.6270e+01
#   L1:         5.6021e+01
#   Grad Norms:
#     edge_logits: 1.57e-05
#     branch_logits: 0.00e+00
#     alpha: 1.93e+03
#     beta: 3.27e+03
#     g: 8.70e+03
#     K: 1.17e+03
#     log_sigma2: 4.29e-01
#
# ...
#   NLL:        3.8562e+04
#   KL(t):      7.4243e+03
#   KL(p):      6.7287e-09
#   t_cont:     3.3112e-01
#   Transition: -1.6215e+01
#   L1:         5.9560e+01
#   Grad Norms:
#     edge_logits: 1.57e-05
#     branch_logits: 0.00e+00
#     alpha: 3.58e+03
#     beta: 5.85e+03
#     g: 7.32e+03
#     K: 9.47e+02
#     log_sigma2: 3.75e-01
#
# [Epoch 219] | Phase: emission
#   ELBO:       4.8671e+04
#   NLL:        4.0018e+04
#   KL(t):      8.5767e+03
#   KL(p):      6.5992e-09
#   t_cont:     3.3391e-01
#   Transition: -1.6328e+01
#   L1:         5.9865e+01
#   Grad Norms:
#     edge_logits: 1.57e-05
#     branch_logits: 0.00e+00
#     alpha: 3.58e+03
#     beta: 5.85e+03
#     g: 8.99e+03
#     K: 1.27e+03
#     log_sigma2: 3.77e-01
#
# [Epoch 220] | Phase: emission
#   ELBO:       4.6451e+04
#   NLL:        3.8380e+04
#   KL(t):      7.9944e+03
#   KL(p):      6.6603e-09
#   t_cont:     3.4448e-01
#   Transition: -1.6395e+01
#   L1:         5.9949e+01
#   Grad Norms:
#     edge_logits: 1.57e-05
#     branch_logits: 0.00e+00
#     alpha: 3.58e+03
#     beta: 5.85e+03
#     g: 7.58e+03
#     K: 1.01e+03
#     log_sigma2: 3.98e-01
#
# [Epoch 221] | Phase: emission
#   ELBO:       4.6478e+04
#   NLL:        3.8891e+04
#   KL(t):      7.5103e+03
#   KL(p):      6.4724e-09
#   t_cont:     3.4487e-01
#   Transition: -1.6290e+01
#   L1:         6.0004e+01
#   Grad Norms:
#     edge_logits: 1.57e-05
#     branch_logits: 0.00e+00
#     alpha: 3.58e+03
#     beta: 5.85e+03
#     g: 8.23e+03
#     K: 1.14e+03
#     log_sigma2: 4.52e-01
#
# [Epoch 222] | Phase: emission
#   ELBO:       4.9329e+04
#   NLL:        4.0414e+04
#   KL(t):      8.8385e+03
#   KL(p):      6.8550e-09
#   t_cont:     3.2998e-01
#   Transition: -1.6297e+01
#   L1:         5.9934e+01
#   Grad Norms:
#     edge_logits: 1.57e-05
#     branch_logits: 0.00e+00
#     alpha: 3.58e+03
#     beta: 5.85e+03
#     g: 8.13e+03
#     K: 9.76e+02
#     log_sigma2: 4.01e-01
#
# [Epoch 223] | Phase: emission
#   ELBO:       4.7720e+04
#   NLL:        3.8305e+04
#   KL(t):      9.3383e+03
#   KL(p):      6.5956e-09
#   t_cont:     3.4424e-01
#   Transition: -1.6338e+01
#   L1:         6.0022e+01
#   Grad Norms:
#     edge_logits: 1.57e-05
#     branch_logits: 0.00e+00
#     alpha: 3.58e+03
#     beta: 5.85e+03
#     g: 8.36e+03
#     K: 1.04e+03
#     log_sigma2: 3.82e-01
#
# [Epoch 224] | Phase: emission
#   ELBO:       4.6388e+04
#   NLL:        3.8407e+04
#   KL(t):      7.9046e+03
#   KL(p):      6.9698e-09
#   t_cont:     3.4061e-01
#   Transition: -1.6295e+01
#   L1:         5.9521e+01
#   Grad Norms:
#     edge_logits: 1.57e-05
#     branch_logits: 0.00e+00
#     alpha: 3.58e+03
#     beta: 5.85e+03
#     g: 7.98e+03
#     K: 9.46e+02
#     log_sigma2: 3.79e-01
#
# [Epoch 225] | Phase: emission
#   ELBO:       4.8064e+04
#   NLL:        3.9794e+04
#   KL(t):      8.1939e+03
#   KL(p):      6.7481e-09
#   t_cont:     3.3888e-01
#   Transition: -1.6333e+01
#   L1:         5.9270e+01
#   Grad Norms:
#     edge_logits: 1.57e-05
#     branch_logits: 0.00e+00
#     alpha: 3.58e+03
#     beta: 5.85e+03
#     g: 8.51e+03
#     K: 1.02e+03
#     log_sigma2: 4.83e-01
#
# [Epoch 226] | Phase: emission
#   ELBO:       4.4809e+04
#   NLL:        3.7766e+04
#   KL(t):      6.9672e+03
#   KL(p):      6.8105e-09
#   t_cont:     3.3225e-01
#   Transition: -1.6296e+01
#   L1:         5.9175e+01
#   Grad Norms:
#     edge_logits: 1.57e-05
#     branch_logits: 0.00e+00
#     alpha: 3.58e+03
#     beta: 5.85e+03
#     g: 7.67e+03
#     K: 9.71e+02
#     log_sigma2: 4.02e-01
#
# [Epoch 227] | Phase: emission
#   ELBO:       4.6340e+04
#   NLL:        3.8828e+04
#   KL(t):      7.4362e+03
#   KL(p):      6.9421e-09
#   t_cont:     3.3613e-01
#   Transition: -1.6316e+01
#   L1:         5.9170e+01
#   Grad Norms:
#     edge_logits: 1.57e-05
#     branch_logits: 0.00e+00
#     alpha: 3.58e+03
#     beta: 5.85e+03
#     g: 8.09e+03
#     K: 9.50e+02
#     log_sigma2: 3.79e-01
#
# [Epoch 228] | Phase: emission
#   ELBO:       4.6505e+04
#   NLL:        3.9005e+04
#   KL(t):      7.4243e+03
#   KL(p):      6.6788e-09
#   t_cont:     3.4154e-01
#   Transition: -1.6336e+01
#   L1:         5.9377e+01
#   Grad Norms:
#     edge_logits: 1.57e-05
#     branch_logits: 0.00e+00
#     alpha: 3.58e+03
#     beta: 5.85e+03
#     g: 8.60e+03
#     K: 1.25e+03
#     log_sigma2: 3.63e-01
#
# [Epoch 229] | Phase: emission
#   ELBO:       4.8148e+04
#   NLL:        4.0210e+04
#   KL(t):      7.8617e+03
#   KL(p):      6.6374e-09
#   t_cont:     3.3932e-01
#   Transition: -1.6349e+01
#   L1:         5.9417e+01
#   Grad Norms:
#     edge_logits: 1.57e-05
#     branch_logits: 0.00e+00
#     alpha: 3.58e+03
#     beta: 5.85e+03
#     g: 8.25e+03
#     K: 1.22e+03
#     log_sigma2: 4.19e-01
#
# [Epoch 230] | Phase: emission
#   ELBO:       4.7819e+04
#   NLL:        3.9412e+04
#   KL(t):      8.3306e+03
#   KL(p):      6.6517e-09
#   t_cont:     3.3968e-01
#   Transition: -1.6288e+01
#   L1:         5.9719e+01
#   Grad Norms:
#     edge_logits: 1.57e-05
#     branch_logits: 0.00e+00
#     alpha: 3.58e+03
#     beta: 5.85e+03
#     g: 8.15e+03
#     K: 1.06e+03
#     log_sigma2: 3.94e-01
#
# [Epoch 231] | Phase: emission
#   ELBO:       4.6216e+04
#   NLL:        3.8735e+04
#   KL(t):      7.4046e+03
#   KL(p):      6.5282e-09
#   t_cont:     3.4000e-01
#   Transition: -1.6275e+01
#   L1:         5.9521e+01
#   Grad Norms:
#     edge_logits: 1.57e-05
#     branch_logits: 0.00e+00
#     alpha: 3.58e+03
#     beta: 5.85e+03
#     g: 8.44e+03
#     K: 1.17e+03
#     log_sigma2: 3.56e-01
#
# [Epoch 232] | Phase: emission
#   ELBO:       4.7321e+04
#   NLL:        3.9426e+04
#   KL(t):      7.8188e+03
#   KL(p):      6.8139e-09
#   t_cont:     3.3544e-01
#   Transition: -1.6262e+01
#   L1:         5.9280e+01
#   Grad Norms:
#     edge_logits: 1.57e-05
#     branch_logits: 0.00e+00
#     alpha: 3.58e+03
#     beta: 5.85e+03
#     g: 8.21e+03
#     K: 9.99e+02
#     log_sigma2: 3.71e-01
#
# [Epoch 233] | Phase: emission
#   ELBO:       4.6583e+04
#   NLL:        3.8547e+04
#   KL(t):      7.9594e+03
#   KL(p):      6.7559e-09
#   t_cont:     3.4455e-01
#   Transition: -1.6339e+01
#   L1:         5.9209e+01
#   Grad Norms:
#     edge_logits: 1.57e-05
#     branch_logits: 0.00e+00
#     alpha: 3.58e+03
#     beta: 5.85e+03
#     g: 8.69e+03
#     K: 1.19e+03
#     log_sigma2: 3.74e-01
#
# [Epoch 234] | Phase: emission
#   ELBO:       4.5773e+04
#   NLL:        3.8293e+04
#   KL(t):      7.4045e+03
#   KL(p):      6.7715e-09
#   t_cont:     3.4021e-01
#   Transition: -1.6346e+01
#   L1:         5.9472e+01
#   Grad Norms:
#     edge_logits: 1.57e-05
#     branch_logits: 0.00e+00
#     alpha: 3.58e+03
#     beta: 5.85e+03
#     g: 8.12e+03
#     K: 1.12e+03
#     log_sigma2: 3.54e-01
#
# [Epoch 235] | Phase: emission
#   ELBO:       4.5017e+04
#   NLL:        3.7876e+04
#   KL(t):      7.0646e+03
#   KL(p):      6.7759e-09
#   t_cont:     3.3509e-01
#   Transition: -1.6349e+01
#   L1:         5.9692e+01
#   Grad Norms:
#     edge_logits: 1.57e-05
#     branch_logits: 0.00e+00
#     alpha: 3.58e+03
#     beta: 5.85e+03
#     g: 8.26e+03
#     K: 9.99e+02
#     log_sigma2: 3.74e-01
#
# [Epoch 236] | Phase: emission
#   ELBO:       4.5732e+04
#   NLL:        3.8114e+04
#   KL(t):      7.5414e+03
#   KL(p):      6.7752e-09
#   t_cont:     3.4398e-01
#   Transition: -1.6371e+01
#   L1:         5.9753e+01
#   Grad Norms:
#     edge_logits: 1.57e-05
#     branch_logits: 0.00e+00
#     alpha: 3.58e+03
#     beta: 5.85e+03
#     g: 7.69e+03
#     K: 1.08e+03
#     log_sigma2: 3.80e-01
# --- Switching to posterior phase ---
#
# [Epoch 237] | Phase: posterior
#   ELBO:       4.7133e+04
#   NLL:        3.9516e+04
#   KL(t):      7.5413e+03
#   KL(p):      6.7981e-09
#   t_cont:     3.3604e-01
#   Transition: -1.6214e+01
#   L1:         5.9175e+01
#   Grad Norms:
#     edge_logits: 1.55e-05
#     branch_logits: 0.00e+00
#     alpha: 6.53e+03
#     beta: 3.67e+03
#     g: 7.69e+03
#     K: 1.08e+03
#     log_sigma2: 3.80e-01
#
# [Epoch 238] | Phase: posterior
#   ELBO:       4.7316e+04
#   NLL:        3.8984e+04
#   KL(t):      8.2562e+03
#   KL(p):      8.4455e-09
#   t_cont:     3.3846e-01
#   Transition: -1.6294e+01
#   L1:         5.9175e+01
#   Grad Norms:
#     edge_logits: 1.54e-05
#     branch_logits: 0.00e+00
#     alpha: 6.69e+03
#     beta: 1.90e+03
#     g: 7.69e+03
#     K: 1.08e+03
#     log_sigma2: 3.80e-01
#
# [Epoch 239] | Phase: posterior
#   ELBO:       4.8502e+04
#   NLL:        3.8482e+04
#   KL(t):      9.9440e+03
#   KL(p):      6.8716e-09
#   t_cont:     3.4030e-01
#   Transition: -1.6261e+01
#   L1:         5.9175e+01
#   Grad Norms:
#     edge_logits: 1.55e-05
#     branch_logits: 0.00e+00
#     alpha: 6.14e+03
#     beta: 3.57e+03
#     g: 7.69e+03
#     K: 1.08e+03
#     log_sigma2: 3.80e-01
#
# [Epoch 240] | Phase: posterior
#   ELBO:       4.7490e+04
#   NLL:        3.8927e+04
#   KL(t):      8.4871e+03
#   KL(p):      7.6236e-09
#   t_cont:     3.3516e-01
#   Transition: -1.6336e+01
#   L1:         5.9175e+01
#   Grad Norms:
#     edge_logits: 1.54e-05
#     branch_logits: 0.00e+00
#     alpha: 4.04e+03
#     beta: 1.71e+03
#     g: 7.69e+03
#     K: 1.08e+03
#     log_sigma2: 3.80e-01
#
# [Epoch 241] | Phase: posterior
#   ELBO:       4.7227e+04
#   NLL:        3.8277e+04
#   KL(t):      8.8735e+03
#   KL(p):      7.5483e-09
#   t_cont:     3.4665e-01
#   Transition: -1.6398e+01
#   L1:         5.9175e+01
#   Grad Norms:
#     edge_logits: 1.58e-05
#     branch_logits: 0.00e+00
#     alpha: 3.32e+03
#     beta: 3.09e+03
#     g: 7.69e+03
#     K: 1.08e+03
#     log_sigma2: 3.80e-01
#
# [Epoch 242] | Phase: posterior
#   ELBO:       4.5383e+04
#   NLL:        3.7081e+04
#   KL(t):      8.2259e+03
#   KL(p):      7.0154e-09
#   t_cont:     3.4267e-01
#   Transition: -1.6335e+01
#   L1:         5.9175e+01
#   Grad Norms:
#     edge_logits: 1.53e-05
#     branch_logits: 0.00e+00
#     alpha: 3.32e+03
#     beta: 5.74e+03
#     g: 7.69e+03
#     K: 1.08e+03
#     log_sigma2: 3.80e-01
#
# [Epoch 243] | Phase: posterior
#   ELBO:       4.8934e+04
#   NLL:        4.0308e+04
#   KL(t):      8.5494e+03
#   KL(p):      8.1199e-09
#   t_cont:     3.4966e-01
#   Transition: -1.6354e+01
#   L1:         5.9175e+01
#   Grad Norms:
#     edge_logits: 1.57e-05
#     branch_logits: 0.00e+00
#     alpha: 6.76e+03
#     beta: 3.52e+03
#     g: 7.69e+03
#     K: 1.08e+03
#     log_sigma2: 3.80e-01
#
# [Epoch 244] | Phase: posterior
#   ELBO:       4.5767e+04
#   NLL:        3.7181e+04
#   KL(t):      8.5102e+03
#   KL(p):      7.7374e-09
#   t_cont:     3.3154e-01
#   Transition: -1.6312e+01
#   L1:         5.9175e+01
#   Grad Norms:
#     edge_logits: 1.61e-05
#     branch_logits: 0.00e+00
#     alpha: 2.97e+03
#     beta: 3.34e+03
#     g: 7.69e+03
#     K: 1.08e+03
#     log_sigma2: 3.80e-01
#
# [Epoch 245] | Phase: posterior
#   ELBO:       4.7185e+04
#   NLL:        3.7911e+04
#   KL(t):      9.1980e+03
#   KL(p):      6.2472e-09
#   t_cont:     3.4130e-01
#   Transition: -1.6320e+01
#   L1:         5.9175e+01
#   Grad Norms:
#     edge_logits: 1.55e-05
#     branch_logits: 0.00e+00
#     alpha: 1.84e+03
#     beta: 1.54e+03
#     g: 7.69e+03
#     K: 1.08e+03
#     log_sigma2: 3.80e-01
#
# [Epoch 246] | Phase: posterior
#   ELBO:       4.7215e+04
#   NLL:        3.7559e+04
#   KL(t):      9.5805e+03
#   KL(p):      5.7878e-09
#   t_cont:     3.3255e-01
#   Transition: -1.6344e+01
#   L1:         5.9175e+01
#   Grad Norms:
#     edge_logits: 1.58e-05
#     branch_logits: 0.00e+00
#     alpha: 1.23e+04
#     beta: 7.74e+03
#     g: 7.69e+03
#     K: 1.08e+03
#     log_sigma2: 3.80e-01
#
# [Epoch 247] | Phase: posterior
#   ELBO:       4.8631e+04
#   NLL:        3.7981e+04
#   KL(t):      1.0573e+04
#   KL(p):      4.9865e-09
#   t_cont:     3.2826e-01
#   Transition: -1.6335e+01
#   L1:         5.9175e+01
#   Grad Norms:
#     edge_logits: 1.58e-05
#     branch_logits: 0.00e+00
#     alpha: 3.14e+03
#     beta: 3.71e+03
#     g: 7.69e+03
#     K: 1.08e+03
#     log_sigma2: 3.80e-01
#
# [Epoch 248] | Phase: posterior
#   ELBO:       4.9642e+04
#   NLL:        3.8235e+04
#   KL(t):      1.1331e+04
#   KL(p):      4.8011e-09
#   t_cont:     3.3965e-01
#   Transition: -1.6338e+01
#   L1:         5.9175e+01
#   Grad Norms:
#     edge_logits: 1.55e-05
#     branch_logits: 0.00e+00
#     alpha: 2.92e+03
#     beta: 3.02e+03
#     g: 7.69e+03
#     K: 1.08e+03
#     log_sigma2: 3.80e-01
#
# [Epoch 249] | Phase: posterior
#   ELBO:       4.8449e+04
#   NLL:        3.7590e+04
#   KL(t):      1.0784e+04
#   KL(p):      8.0411e-09
#   t_cont:     3.4363e-01
#   Transition: -1.6344e+01
#   L1:         5.9175e+01
#   Grad Norms:
#     edge_logits: 1.58e-05
#     branch_logits: 0.00e+00
#     alpha: 6.94e+03
#     beta: 1.78e+03
#     g: 7.69e+03
#     K: 1.08e+03
#     log_sigma2: 3.80e-01
#
# [Epoch 250] | Phase: posterior
#   ELBO:       4.8101e+04
#   NLL:        3.7663e+04
#   KL(t):      1.0362e+04
#   KL(p):      7.1386e-09
#   t_cont:     3.3375e-01
#   Transition: -1.6400e+01
#   L1:         5.9175e+01
#   Grad Norms:
#     edge_logits: 1.57e-05
#     branch_logits: 0.00e+00
#     alpha: 2.72e+03
#     beta: 2.97e+03
#     g: 7.69e+03
#     K: 1.08e+03
#     log_sigma2: 3.80e-01
#
# [Epoch 251] | Phase: posterior
#   ELBO:       4.9492e+04
#   NLL:        3.8643e+04
#   KL(t):      1.0773e+04
#   KL(p):      5.7993e-09
#   t_cont:     3.3376e-01
#   Transition: -1.6360e+01
#   L1:         5.9175e+01
#   Grad Norms:
#     edge_logits: 1.62e-05
#     branch_logits: 0.00e+00
#     alpha: 3.27e+03
#     beta: 2.68e+03
#     g: 7.69e+03
#     K: 1.08e+03
#     log_sigma2: 3.80e-01
#
# [Epoch 252] | Phase: posterior
#   ELBO:       4.9480e+04
#   NLL:        3.8307e+04
#   KL(t):      1.1097e+04
#   KL(p):      6.6038e-09
#   t_cont:     3.3524e-01
#   Transition: -1.6299e+01
#   L1:         5.9175e+01
#   Grad Norms:
#     edge_logits: 1.65e-05
#     branch_logits: 0.00e+00
#     alpha: 1.33e+04
#     beta: 3.20e+03
#     g: 7.69e+03
#     K: 1.08e+03
#     log_sigma2: 3.80e-01
# --- Switching to emission phase ---
#
# [Epoch 253] | Phase: emission
#   ELBO:       4.9930e+04
#   NLL:        3.8077e+04
#   KL(t):      1.1776e+04
#   KL(p):      6.8607e-09
#   t_cont:     3.4471e-01
#   Transition: -1.6295e+01
#   L1:         6.0095e+01
#   Grad Norms:
#     edge_logits: 1.65e-05
#     branch_logits: 0.00e+00
#     alpha: 1.33e+04
#     beta: 3.20e+03
#     g: 8.26e+03
#     K: 1.15e+03
#     log_sigma2: 3.92e-01
#
# [Epoch 254] | Phase: emission
#   ELBO:       4.9384e+04
#   NLL:        3.8344e+04
#   KL(t):      1.0963e+04
#   KL(p):      6.9923e-09
#   t_cont:     3.4036e-01
#   Transition: -1.6273e+01
#   L1:         6.0439e+01
#   Grad Norms:
#     edge_logits: 1.65e-05
#     branch_logits: 0.00e+00
#     alpha: 1.33e+04
#     beta: 3.20e+03
#     g: 8.05e+03
#     K: 9.31e+02
#     log_sigma2: 3.75e-01
#
# [Epoch 255] | Phase: emission
#   ELBO:       4.9629e+04
#   NLL:        3.9236e+04
#   KL(t):      1.0316e+04
#   KL(p):      6.6907e-09
#   t_cont:     3.3502e-01
#   Transition: -1.6381e+01
#   L1:         6.0876e+01
#   Grad Norms:
#     edge_logits: 1.65e-05
#     branch_logits: 0.00e+00
#     alpha: 1.33e+04
#     beta: 3.20e+03
#     g: 8.07e+03
#     K: 1.18e+03
#     log_sigma2: 3.86e-01
#
# [Epoch 256] | Phase: emission
#   ELBO:       4.8778e+04
#   NLL:        3.8004e+04
#   KL(t):      1.0696e+04
#   KL(p):      6.9387e-09
#   t_cont:     3.3240e-01
#   Transition: -1.6287e+01
#   L1:         6.0656e+01
#   Grad Norms:
#     edge_logits: 1.65e-05
#     branch_logits: 0.00e+00
#     alpha: 1.33e+04
#     beta: 3.20e+03
#     g: 8.23e+03
#     K: 9.21e+02
#     log_sigma2: 4.49e-01
#
# [Epoch 257] | Phase: emission
#   ELBO:       4.9562e+04
#   NLL:        3.9506e+04
#   KL(t):      9.9799e+03
#   KL(p):      6.7898e-09
#   t_cont:     3.3724e-01
#   Transition: -1.6316e+01
#   L1:         6.0037e+01
#   Grad Norms:
#     edge_logits: 1.65e-05
#     branch_logits: 0.00e+00
#     alpha: 1.33e+04
#     beta: 3.20e+03
#     g: 8.11e+03
#     K: 1.07e+03
#     log_sigma2: 3.98e-01
#
# [Epoch 258] | Phase: emission
#   ELBO:       4.9059e+04
#   NLL:        3.8581e+04
#   KL(t):      1.0401e+04
#   KL(p):      6.7657e-09
#   t_cont:     3.3475e-01
#   Transition: -1.6273e+01
#   L1:         6.0379e+01
#   Grad Norms:
#     edge_logits: 1.65e-05
#     branch_logits: 0.00e+00
#     alpha: 1.33e+04
#     beta: 3.20e+03
#     g: 8.37e+03
#     K: 1.09e+03
#     log_sigma2: 3.58e-01
#
# [Epoch 259] | Phase: emission
#   ELBO:       5.0829e+04
#   NLL:        3.8980e+04
#   KL(t):      1.1772e+04
#   KL(p):      6.8155e-09
#   t_cont:     3.3791e-01
#   Transition: -1.6347e+01
#   L1:         6.0319e+01
#   Grad Norms:
#     edge_logits: 1.65e-05
#     branch_logits: 0.00e+00
#     alpha: 1.33e+04
#     beta: 3.20e+03
#     g: 8.31e+03
#     K: 1.15e+03
#     log_sigma2: 3.84e-01
#
# [Epoch 260] | Phase: emission
#   ELBO:       4.9093e+04
#   NLL:        3.8567e+04
#   KL(t):      1.0450e+04
#   KL(p):      6.8425e-09
#   t_cont:     3.4201e-01
#   Transition: -1.6316e+01
#   L1:         5.9878e+01
#   Grad Norms:
#     edge_logits: 1.65e-05
#     branch_logits: 0.00e+00
#     alpha: 1.33e+04
#     beta: 3.20e+03
#     g: 7.60e+03
#     K: 8.59e+02
#     log_sigma2: 3.58e-01

# %%
# from models.loss import compute_elbo_batch
# from utils.inference import batch_indices

# batch_size = 512
# num_epochs = 100
# n_samples = 3
# freeze_epochs = 5
# # Training weights
# kl_weight = 1.0
# kl_p_weight = 1e4
# t_cont_weight = 1.0

# elbo_log = []
# nll_log = []
# kl_t_log = []
# kl_p_log = []
# t_cont_log = []
# transition_log = []
# l1_log = []
# grad_log = []

# # Freeze emission parameters initially
# emission_params = [g, K, log_sigma2]
# for p in emission_params:
#     p.requires_grad_(False)

# optimizer = torch.optim.Adam(
#     [posterior.alpha, posterior.beta, posterior.edge_logits] + emission_params,
#     lr=1e-2
# )

# for epoch in range(num_epochs):
#     total_loss = 0.0
#     total_batches = 0
#     epoch_metrics = {
#         "nll": 0.0,
#         "kl_t": 0.0,
#         "kl_p": 0.0,
#         "t_cont": 0.0,
#         "transition": 0.0,
#         "l1": 0.0
#     }

#     # === Unfreeze after warmup ===
#     if epoch == freeze_epochs:
#         for p in emission_params:
#             p.requires_grad_(True)

#     for batch in batch_indices(X.shape[0], batch_size):
#         assert batch.dtype == torch.long, f"batch dtype is {batch.dtype}, expected torch.long"
#         assert X.dim() == 2, f"X has shape {X.shape}, expected 2D tensor"

#         # print("batch shape:", batch.shape)
#         # print("batch dtype:", batch.dtype)
#         # print("min(batch):", batch.min().item())
#         # print("max(batch):", batch.max().item())
#         # print("X.shape[0]:", X.shape[0])

#         torch.cuda.synchronize()
#         X_batch = X[batch]
#         optimizer.zero_grad()

#         # print("posterior edge list:")
#         # for i, edge in enumerate(posterior.edge_list):
#         #     print(f"{i}: {edge}")
        
#         # print("traj_graph.edge_list:")
#         # for i, edge in enumerate(traj_graph.edge_list):
#         #     print(f"{i}: {edge}")

#         loss, metrics = compute_elbo_batch(
#             X_batch, batch,
#             traj_graph, posterior, edge_to_index,
#             g, K, log_sigma2.exp(),
#             belief_propagator=belief_propagator,
#             n_samples=n_samples,
#             kl_weight=kl_weight,
#             kl_p_weight=kl_p_weight,
#             t_cont_weight=t_cont_weight,
#             transition_weight=1.0,  # adjustable
#             pi=pi
#         )

#         loss.backward()
#         optimizer.step()

#         total_loss += loss.item()
#         for key in epoch_metrics:
#             epoch_metrics[key] += metrics.get(key, 0.0)
#         total_batches += 1

#     # Normalize per batch
#     for key in epoch_metrics:
#         epoch_metrics[key] /= total_batches

#     # === Log gradient norms ===
#     grad_norms = {
#         "alpha": posterior.alpha.grad.norm().item() if posterior.alpha.grad is not None else 0.0,
#         "beta": posterior.beta.grad.norm().item() if posterior.beta.grad is not None else 0.0,
#         "edge_logits": posterior.edge_logits.grad.norm().item() if posterior.edge_logits.grad is not None else 0.0,
#         "g": g.grad.norm().item() if g.grad is not None else 0.0,
#         "K": K.grad.norm().item() if K.grad is not None else 0.0,
#         "log_sigma2": log_sigma2.grad.norm().item() if log_sigma2.grad is not None else 0.0,
#     }

#     # Store logs
#     elbo_log.append(total_loss / total_batches)
#     nll_log.append(epoch_metrics["nll"])
#     kl_t_log.append(epoch_metrics["kl_t"])
#     kl_p_log.append(epoch_metrics["kl_p"])
#     t_cont_log.append(epoch_metrics["t_cont"])
#     transition_log.append(epoch_metrics["transition"])
#     l1_log.append(epoch_metrics["l1"])
#     grad_log.append(grad_norms)

#     # === Print ===
#     print(f"\n[Epoch {epoch}]")
#     print(f"  ELBO:       {elbo_log[-1]:.4e}")
#     print(f"  NLL:        {epoch_metrics['nll']:.4e}")
#     print(f"  KL(t):      {epoch_metrics['kl_t']:.4e}")
#     print(f"  KL(p):      {epoch_metrics['kl_p']:.4e}")
#     print(f"  t_cont:     {epoch_metrics['t_cont']:.4e}")
#     print(f"  transition: {epoch_metrics['transition']:.4e}")
#     print(f"  L1:         {epoch_metrics['l1']:.4e}")
#     print("  Grad Norms:")
#     for k, v in grad_norms.items():
#         print(f"    {k}: {v:.2e}")
# Out:
# [Epoch 0]
#   ELBO:       2.4935e+05
#   NLL:        2.8862e+04
#   KL(t):      2.2047e+05
#   KL(p):      -1.9093e-09
#   t_cont:     3.9220e-01
#   transition: -1.6858e+01
#   L1:         2.9333e+02
#   Grad Norms:
#     alpha: 4.88e+03
#     beta: 1.33e+03
#     edge_logits: 1.52e-05
#     g: 0.00e+00
#     K: 0.00e+00
#     log_sigma2: 0.00e+00
# KeyboardInterrupt

# %%
import matplotlib.pyplot as plt

epochs = range(len(elbo_log))

fig, axes = plt.subplots(1, 2, figsize=(16, 5))

# === ELBO plot ===
axes[0].plot(epochs, elbo_log, label="ELBO", color="black")
axes[0].set_title("ELBO Over Epochs")
axes[0].set_xlabel("Epoch")
axes[0].set_ylabel("ELBO")
axes[0].legend()
axes[0].grid(True)

# === Component losses ===
axes[1].plot(epochs, nll_log, label="NLL")
axes[1].plot(epochs, kl_t_log, label="KL(t)")
axes[1].plot(epochs, kl_p_log, label="KL(p)")
axes[1].plot(epochs, t_cont_log, label="t_cont")
axes[1].plot(epochs, transition_log, label="transition")
axes[1].plot(epochs, l1_log, label="L1")
axes[1].set_title("ELBO Components Over Epochs")
axes[1].set_xlabel("Epoch")
axes[1].set_ylabel("Loss Component Value")
axes[1].legend()
axes[1].grid(True)

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

epochs = range(len(elbo_log))

fig, axes = plt.subplots(1, 2, figsize=(16, 5))

# === ELBO plot ===
axes[0].plot(epochs, elbo_log, label="ELBO", color="black")
axes[0].set_title("ELBO Over Epochs")
axes[0].set_xlabel("Epoch")
axes[0].set_ylabel("ELBO")
axes[0].legend()
axes[0].grid(True)

# === Component losses ===
axes[1].plot(epochs, nll_log, label="NLL")
axes[1].plot(epochs, kl_t_log, label="KL(t)")
axes[1].plot(epochs, kl_p_log, label="KL(p)")
axes[1].plot(epochs, t_cont_log, label="t_cont")
axes[1].plot(epochs, transition_log, label="transition")
axes[1].plot(epochs, l1_log, label="L1")
axes[1].set_title("ELBO Components Over Epochs")
axes[1].set_xlabel("Epoch")
axes[1].set_ylabel("Loss Component Value")
axes[1].legend()
axes[1].grid(True)

plt.tight_layout()
plt.show()

# %%
index_to_edge = {v: k for k, v in edge_to_index.items()}
def extract_fitted_betas_by_argmax(posterior, index_to_edge):
    """
    Extract learned beta distribution parameters using the MAP edge assignment per cell.

    Args:
        posterior: Trained posterior object with `alpha` and `beta` of shape [cells x edges].
        index_to_edge: Dict mapping edge indices (int) to edge names.

    Returns:
        pd.DataFrame: Indexed by cell ID with columns 'edge', 'alpha', and 'beta'.
    """
    alpha = posterior.alpha.data.cpu().numpy()
    beta = posterior.beta.data.cpu().numpy()
    max_idx = (alpha + beta - 2).argmax(axis=1)  # MAP estimate of Beta distribution mean

    records = []
    for i, edge_idx in enumerate(max_idx):
        edge = index_to_edge[edge_idx]
        records.append({
        "cell_id": adata.obs.index[i],  # not just 'i'
        "edge": edge,
        "alpha": alpha[i, edge_idx],
        "beta": beta[i, edge_idx],
    })


    return pd.DataFrame(records).set_index("cell_id")
fitted_betas = extract_fitted_betas_by_argmax(posterior, index_to_edge)

# %%
adata
# Out:
# View of AnnData object with n_obs × n_vars = 0 × 1000
#     obs: 'developmental_day', 'days_num', 'hours_num', 'source_tissue', 'leiden'
#     var: 'n_cells', 'highly_variable', 'means', 'dispersions', 'dispersions_norm'
#     uns: 'Sample_colors', 'developmental_day_colors', 'hvg', 'leiden', 'leiden_colors', 'leiden_sizes', 'log1p', 'neighbors', 'paga', 'pca', 'umap'
#     obsm: 'X_pca', 'X_umap'
#     varm: 'PCs'
#     layers: 'ambiguous', 'counts', 'spliced', 'unspliced'
#     obsp: 'connectivities', 'distances'

# %%
print("adata.obs.shape:", adata.obs.shape)
print("posterior alpha shape:", posterior.alpha.shape)
# Out:
# adata.obs.shape: (0, 5)
# posterior alpha shape: torch.Size([5454, 18])

# %%
fitted_betas["edge"] = fitted_betas["edge"].apply(lambda x: tuple(x) if not isinstance(x, tuple) else x)
fitted_betas
# Out:
#                                            edge     alpha      beta
# cell_id
# TAAGCGTAGGCCCGTT             (split_17, leaf_4)  3.993999  5.905695
# GACCAATAGTCGTCGT             (split_0, split_8)  3.904192  6.028746
# CGAGAAGCATGCTAGT             (split_17, leaf_4)  2.838632  7.054723
# ACGATGTAGGATTCCC             (split_17, leaf_4)  5.247129  4.568557
# GCAGTTAAGGTCATCT             (split_17, leaf_4)  9.847487 -0.010192
# ...                                         ...       ...       ...
# GGAGCAAGTCTAGTGT           (split_11, split_13)  5.985049  3.782763
# TTTACTGTCAGTTCGG  (RootNode_0_0, root_split_12)  8.566421  0.387073
# GAAATGAGTCGGCACT  (RootNode_0_0, root_split_12)  5.783636  3.941775
# CGATGGCAGTGTCTCG  (RootNode_0_0, root_split_12)  3.911122  5.973817
# CATCAAGGTTAAGATG           (split_11, split_13)  7.958752  1.767208
#
# [5454 rows x 3 columns]

# %%
missing = fitted_betas.index.difference(adata.obs.index)
print(f"{len(missing)} missing cell IDs in adata")
# Out:
# 5454 missing cell IDs in adata

# %%
missing_edges = [e for e in fitted_betas["edge"].unique() if e not in traj_graph.G_traj.edges
]
print("Missing edges:", missing_edges)
# Out:
# Missing edges: []

# %%
from viz.trajectory import plot_cells_on_trajectory

plot_cells_on_trajectory(
    traj_graph,
    cell_assignment,
    adata,
    color_key="leiden",  # or any other obs key
    curve_amount=0.8,
    title="Hard Cell Assignments on Trajectory"
)

# %%
from viz.trajectory import plot_pdf_width_ribbons_on_trajectory

plot_pdf_width_ribbons_on_trajectory(
    traj_graph,
    fitted_betas,
    adata,
    color_key="leiden",
    pdf_scale=.1,  # adjust if too narrow/wide
    curve_amount=0.8,
    title="Beta-Modeled Cell Assignments as Ribbons"
)
# Out:
# /work/vanaja_lab/griffin/projects/viCSHMM/viz/trajectory.py:301: RuntimeWarning: overflow encountered in multiply
#   widths = pdfs * (pdf_scale * seg_length) / max_vals
# /work/vanaja_lab/griffin/projects/viCSHMM/viz/trajectory.py:305: RuntimeWarning: invalid value encountered in multiply
#   offset = (width[:, None] / 2) * normals

# %%
# freeze_epochs = 10
# optimizer = torch.optim.Adam([
#     {'params': [posterior.alpha, posterior.beta, posterior.path_logits]},
#     {'params': [g_a, g_b, K, log_sigma2], 'lr': 1e-2}
# ], lr=1e-2)

# for epoch in range(num_epochs):
#     # Freeze emission parameters initially
#     if epoch < freeze_epochs:
#         for p in [g_a, g_b, K, log_sigma2]:
#             p.requires_grad_(False)
#     else:
#         for p in [g_a, g_b, K, log_sigma2]:
#             p.requires_grad_(True)

#     optimizer.zero_grad()
#     loss, metrics = compute_elbo(
#         X, traj_graph, posterior, edge_to_index,
#         g_a, g_b, K, log_sigma2.exp(),
#         pi=pi,
#         belief_propagator=belief_propagator,
#         n_samples=n_samples,
#         kl_weight=kl_weight,
#         kl_p_weight=kl_p_weight,
#         t_cont_weight=t_cont_weight,
#     )
#     loss.backward()
#     optimizer.step()

#     print(f"[Epoch {epoch}] Loss={loss.item():.2e}, NLL={metrics['nll']:.2e}, KL(t)={metrics['kl_t']:.3f}")

# %%
inference_params = [posterior.alpha, posterior.beta, posterior.path_logits]
generative_params = [g_a, g_b, K, log_sigma2]

optimizer_inf = torch.optim.Adam(inference_params, lr=1e-2)
optimizer_gen = torch.optim.Adam(generative_params, lr=1e-2)

n_inf_steps = 8
n_gen_steps = 3
batch_size = 512

elbo_log = []
metrics_log = []

for epoch in range(num_epochs):
    print(f"\n[Epoch {epoch}]")

    # === Inference Phase ===
    for _ in range(n_inf_steps):
        optimizer_inf.zero_grad()
        total_elbo = 0
        total_metrics = {
            "nll": 0.0,
            "kl_t": 0.0,
            "kl_p": 0.0,
            "t_cont": 0.0
        }
        n_batches = 0

        for batch in batch_indices(X.shape[0], batch_size):
            X_batch = X[batch]
            elbo, metrics = compute_elbo_batch(
                X_batch, batch,
                traj_graph, posterior, edge_to_index,
                g_a, g_b, K, log_sigma2.exp(),
                belief_propagator=belief_propagator,
                n_samples=n_samples,
                kl_weight=kl_weight,
                kl_p_weight=kl_p_weight,
                t_cont_weight=t_cont_weight,
                pi=pi
            )
            elbo.backward()
            total_elbo += elbo.item()
            for k in total_metrics:
                total_metrics[k] += metrics[k]
            n_batches += 1

        optimizer_inf.step()

        for k in total_metrics:
            total_metrics[k] /= n_batches

        print(f"Inference ELBO: {total_elbo:.2e}")
        print(f"  NLL:     {total_metrics['nll']:.3e}")
        print(f"  KL(t):   {total_metrics['kl_t']:.3e}")
        print(f"  KL(p):   {total_metrics['kl_p']:.3e}")
        print(f"  t_cont:  {total_metrics['t_cont']:.3e}")

        # Check gradients
        for p in inference_params:
            print(f"  Grad | {p.shape}: {p.grad.norm().item():.3e}")

        elbo_log.append(("inference", epoch, total_elbo))
        metrics_log.append(("inference", epoch, total_metrics.copy()))

    # === Generative Phase ===
    for _ in range(n_gen_steps):
        optimizer_gen.zero_grad()
        total_elbo = 0
        total_metrics = {
            "nll": 0.0,
            "kl_t": 0.0,
            "kl_p": 0.0,
            "t_cont": 0.0
        }
        n_batches = 0

        for batch in batch_indices(X.shape[0], batch_size):
            X_batch = X[batch]
            elbo, metrics = compute_elbo_batch(
                X_batch, batch,
                traj_graph, posterior, edge_to_index,
                g_a, g_b, K, log_sigma2.exp(),
                belief_propagator=belief_propagator,
                n_samples=n_samples,
                kl_weight=kl_weight,
                kl_p_weight=kl_p_weight,
                t_cont_weight=t_cont_weight,
                pi=pi
            )
            elbo.backward()
            total_elbo += elbo.item()
            for k in total_metrics:
                total_metrics[k] += metrics[k]
            n_batches += 1

        optimizer_gen.step()

        for k in total_metrics:
            total_metrics[k] /= n_batches

        print(f"Generative ELBO: {total_elbo:.2e}")
        print(f"  NLL:     {total_metrics['nll']:.3e}")
        print(f"  KL(t):   {total_metrics['kl_t']:.3e}")
        print(f"  KL(p):   {total_metrics['kl_p']:.3e}")
        print(f"  t_cont:  {total_metrics['t_cont']:.3e}")

        # Check gradients
        for p in generative_params:
            print(f"  Grad | {p.shape}: {p.grad.norm().item():.3e}")

        elbo_log.append(("generative", epoch, total_elbo))
        metrics_log.append(("generative", epoch, total_metrics.copy()))
# Out:
# [Epoch 0]
# Inference ELBO: 6.06e+05
#   NLL:     5.510e+04
#   KL(t):   6.602e-01
#   KL(p):   3.236e-02
#   t_cont:  3.984e-01
#   Grad | torch.Size([5454, 9]): 5.421e+03
#   Grad | torch.Size([5454, 9]): 5.214e+03
#   Grad | torch.Size([5454, 9]): 1.107e-02
# Inference ELBO: 6.24e+05
#   NLL:     5.676e+04
#   KL(t):   6.625e-01
#   KL(p):   3.129e-02
#   t_cont:  3.923e-01
#   Grad | torch.Size([5454, 9]): 5.667e+03
#   Grad | torch.Size([5454, 9]): 5.241e+03
#   Grad | torch.Size([5454, 9]): 1.082e-02
# Inference ELBO: 6.06e+05
#   NLL:     5.507e+04
#   KL(t):   6.753e-01
#   KL(p):   3.048e-02
#   t_cont:  3.930e-01
#   Grad | torch.Size([5454, 9]): 5.893e+03
#   Grad | torch.Size([5454, 9]): 5.189e+03
#   Grad | torch.Size([5454, 9]): 1.073e-02
# Inference ELBO: 5.99e+05
#   NLL:     5.446e+04
#   KL(t):   6.731e-01
#   KL(p):   2.948e-02
#   t_cont:  4.002e-01
#   Grad | torch.Size([5454, 9]): 5.762e+03
#   Grad | torch.Size([5454, 9]): 5.317e+03
#   Grad | torch.Size([5454, 9]): 1.050e-02
# Inference ELBO: 5.94e+05
#   NLL:     5.404e+04
#   KL(t):   6.895e-01
#   KL(p):   2.852e-02
#   t_cont:  3.902e-01
#   Grad | torch.Size([5454, 9]): 5.865e+03
#   Grad | torch.Size([5454, 9]): 5.156e+03
#   Grad | torch.Size([5454, 9]): 1.031e-02
# Inference ELBO: 5.80e+05
#   NLL:     5.273e+04
#   KL(t):   7.100e-01
#   KL(p):   2.760e-02
#   t_cont:  4.016e-01
#   Grad | torch.Size([5454, 9]): 5.858e+03
#   Grad | torch.Size([5454, 9]): 5.084e+03
#   Grad | torch.Size([5454, 9]): 1.014e-02
# Inference ELBO: 6.03e+05
#   NLL:     5.483e+04
#   KL(t):   7.041e-01
#   KL(p):   2.667e-02
#   t_cont:  3.945e-01
#   Grad | torch.Size([5454, 9]): 5.722e+03
#   Grad | torch.Size([5454, 9]): 4.994e+03
#   Grad | torch.Size([5454, 9]): 9.905e-03
# Inference ELBO: 5.95e+05
#   NLL:     5.405e+04
#   KL(t):   7.293e-01
#   KL(p):   2.590e-02
#   t_cont:  3.934e-01
#   Grad | torch.Size([5454, 9]): 5.638e+03
#   Grad | torch.Size([5454, 9]): 5.074e+03
#   Grad | torch.Size([5454, 9]): 9.785e-03
# Generative ELBO: 6.12e+05
#   NLL:     5.564e+04
#   KL(t):   7.295e-01
#   KL(p):   2.508e-02
#   t_cont:  4.012e-01
#   Grad | torch.Size([18, 1000]): 2.803e+04
#   Grad | torch.Size([18, 1000]): 1.106e+04
#   Grad | torch.Size([18, 1000]): 3.447e+03
#   Grad | torch.Size([18, 1000]): 1.413e+01
# Generative ELBO: 5.98e+05
#   NLL:     5.436e+04
#   KL(t):   7.414e-01
#   KL(p):   2.504e-02
#   t_cont:  3.969e-01
#   Grad | torch.Size([18, 1000]): 3.062e+04
#   Grad | torch.Size([18, 1000]): 1.626e+04
#   Grad | torch.Size([18, 1000]): 5.339e+03
#   Grad | torch.Size([18, 1000]): 1.511e+01
# Generative ELBO: 5.89e+05
#   NLL:     5.351e+04
#   KL(t):   7.333e-01
#   KL(p):   2.507e-02
#   t_cont:  3.991e-01
#   Grad | torch.Size([18, 1000]): 2.717e+04
#   Grad | torch.Size([18, 1000]): 1.397e+04
#   Grad | torch.Size([18, 1000]): 4.398e+03
#   Grad | torch.Size([18, 1000]): 1.547e+01
#
# [Epoch 1]
# Inference ELBO: 5.97e+05
#   NLL:     5.427e+04
#   KL(t):   7.344e-01
#   KL(p):   2.502e-02
#   t_cont:  4.013e-01
#   Grad | torch.Size([5454, 9]): 6.424e+03
#   Grad | torch.Size([5454, 9]): 5.780e+03
#   Grad | torch.Size([5454, 9]): 9.580e-03
# Inference ELBO: 6.13e+05
#   NLL:     5.573e+04
#   KL(t):   7.478e-01
#   KL(p):   2.426e-02
#   t_cont:  4.014e-01
#   Grad | torch.Size([5454, 9]): 6.501e+03
#   Grad | torch.Size([5454, 9]): 6.016e+03
#   Grad | torch.Size([5454, 9]): 9.447e-03
# Inference ELBO: 6.15e+05
#   NLL:     5.588e+04
#   KL(t):   7.502e-01
#   KL(p):   2.354e-02
#   t_cont:  3.991e-01
#   Grad | torch.Size([5454, 9]): 6.362e+03
#   Grad | torch.Size([5454, 9]): 5.873e+03
#   Grad | torch.Size([5454, 9]): 9.323e-03
# Inference ELBO: 5.80e+05
#   NLL:     5.268e+04
#   KL(t):   7.714e-01
#   KL(p):   2.270e-02
#   t_cont:  4.057e-01
#   Grad | torch.Size([5454, 9]): 6.132e+03
#   Grad | torch.Size([5454, 9]): 4.984e+03
#   Grad | torch.Size([5454, 9]): 9.023e-03
# Inference ELBO: 5.97e+05
#   NLL:     5.431e+04
#   KL(t):   7.824e-01
#   KL(p):   2.206e-02
#   t_cont:  4.010e-01
#   Grad | torch.Size([5454, 9]): 6.508e+03
#   Grad | torch.Size([5454, 9]): 6.069e+03
#   Grad | torch.Size([5454, 9]): 8.942e-03
# Inference ELBO: 5.84e+05
#   NLL:     5.306e+04
#   KL(t):   8.059e-01
#   KL(p):   2.129e-02
#   t_cont:  4.034e-01
#   Grad | torch.Size([5454, 9]): 5.943e+03
#   Grad | torch.Size([5454, 9]): 5.553e+03
#   Grad | torch.Size([5454, 9]): 8.779e-03
# Inference ELBO: 5.76e+05
#   NLL:     5.232e+04
#   KL(t):   8.135e-01
#   KL(p):   2.071e-02
#   t_cont:  4.025e-01
#   Grad | torch.Size([5454, 9]): 6.090e+03
#   Grad | torch.Size([5454, 9]): 5.601e+03
#   Grad | torch.Size([5454, 9]): 8.643e-03
# Inference ELBO: 5.98e+05
#   NLL:     5.432e+04
#   KL(t):   5.943e+01
#   KL(p):   1.996e-02
#   t_cont:  4.015e-01
#   Grad | torch.Size([5454, 9]): 7.003e+03
#   Grad | torch.Size([5454, 9]): 5.838e+03
#   Grad | torch.Size([5454, 9]): 8.414e-03
# Generative ELBO: 5.73e+05
#   NLL:     5.200e+04
#   KL(t):   5.944e+01
#   KL(p):   1.945e-02
#   t_cont:  4.052e-01
#   Grad | torch.Size([18, 1000]): 2.785e+04
#   Grad | torch.Size([18, 1000]): 1.338e+04
#   Grad | torch.Size([18, 1000]): 4.475e+03
#   Grad | torch.Size([18, 1000]): 1.496e+01
# Generative ELBO: 5.76e+05
#   NLL:     5.234e+04
#   KL(t):   5.943e+01
#   KL(p):   1.932e-02
#   t_cont:  4.043e-01
#   Grad | torch.Size([18, 1000]): 3.043e+04
#   Grad | torch.Size([18, 1000]): 1.167e+04
#   Grad | torch.Size([18, 1000]): 3.795e+03
#   Grad | torch.Size([18, 1000]): 1.430e+01
# Generative ELBO: 5.94e+05
#   NLL:     5.397e+04
#   KL(t):   8.393e-01
#   KL(p):   1.929e-02
#   t_cont:  4.118e-01
#   Grad | torch.Size([18, 1000]): 2.603e+04
#   Grad | torch.Size([18, 1000]): 1.191e+04
#   Grad | torch.Size([18, 1000]): 3.896e+03
#   Grad | torch.Size([18, 1000]): 1.403e+01
#
# [Epoch 2]
# KeyboardInterrupt

# %% [markdown]
# # Test Plotting

# %%
from utils import make_beta_assignment_df

beta_assignments = make_beta_assignment_df(posterior, cell_assignment, sharpness=0.01)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[55], line 3
#       1 from utils import make_beta_assignment_df
# ----> 3 beta_assignments = make_beta_assignment_df(posterior, cell_assignment, sharpness=0.01)
#
# File /work/vanaja_lab/griffin/projects/viCSHMM/utils/inference.py:60, in make_beta_assignment_df(posterior, cell_assignment, sharpness)
#      40 """
#      41 Convert hard cell assignments to a DataFrame of beta distribution parameters
#      42 usable for probabilistic trajectory visualization.
#    (...)
#      56     pd.DataFrame: Indexed by cell ID, with columns 'edge', 'alpha', 'beta'.
#      57 """
#      58 from utils.inference import initialize_beta_from_cell_assignment, find_path_index_for_edge
# ---> 60 initialize_beta_from_cell_assignment(posterior, cell_assignment, sharpness=sharpness)
#      62 cell_ids = list(cell_assignment.index)
#      63 edges = list(cell_assignment["edge"])
#
# TypeError: initialize_beta_from_cell_assignment() missing 1 required positional argument: 'edge_to_index'

# %%
from viz.trajectory import plot_pdf_width_ribbons_on_trajectory

plot_pdf_width_ribbons_on_trajectory(
    traj_graph,
    beta_assignments,
    adata,
    color_key="leiden",
    pdf_scale=0.1,  # adjust if too narrow/wide
    curve_amount=0.8,
    title="Beta-Modeled Cell Assignments as Ribbons"
)

# %%
adata.var
# Out:
#           n_cells  highly_variable     means  dispersions  dispersions_norm
# Lypla1       2576             True  0.250853    -0.930302          1.950977
# Ncoa2         993             True  0.099955    -0.569126          1.877314
# Gm10566        76             True  0.010847    -0.106430          1.912057
# Imp4         3037             True  0.295466    -1.094584          1.782918
# Fam168b      2119             True  0.204745    -0.815239          1.617195
# ...           ...              ...       ...          ...               ...
# Rps7-ps3     2274             True  0.221367    -0.861823          1.828743
# Map3k15       346             True  0.038561    -0.390028          2.149240
# Syap1         970             True  0.100843    -0.545244          1.989039
# Ctps2        2537             True  0.264015    -0.860618          2.211714
# Cltrn         729             True  0.067131    -0.568660          1.657125
#
# [1000 rows x 5 columns]

# %%
from scipy.stats import beta
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import matplotlib.colors as mcolors
import networkx as nx
import pandas as pd

def plot_gene_dynamics_on_trajectory(
    G_traj, beta_assignments, adata, gene_name,
    resolution=100, curve_scale=1.0, blend_fraction=0.1,
    title="Gene Dynamics with Uncertainty"
):
    """
    Visualizes gene expression dynamics along trajectory edges while incorporating
    uncertainty from cell assignments. The tree structure is drawn first (nodes and
    straight edges). Over each edge, we compute for a set of t-values:
      - A weighted gene expression (which becomes the vertical offset from the base edge)
      - A weighted certainty (a proxy using each cell's beta PDF peak)
    
    The curve is drawn along the edge offset perpendicularly by the weighted expression
    (scaled by curve_scale). If the source node of an edge is a split, the first few points
    of the branch are blended with the parent's endpoint (source node position) using the 
    transition probability (attribute "A") from that edge.
    
    Args:
        G_traj: Trajectory graph (networkx.DiGraph or TrajectoryGraph object).
        beta_assignments (pd.DataFrame): Indexed by cell IDs with columns:
            'edge' (tuple of two node IDs), 'alpha', 'beta'.
        adata: AnnData-like object (for gene expression and cell IDs).
        gene_name (str): Gene to visualize (must be in adata.var_names).
        resolution (int): Number of t-values along each edge.
        curve_scale (float): Factor to scale the vertical offset of the curve.
        blend_fraction (float): Fraction of the curve (from t=0) to blend at split nodes.
        title (str): Plot title.
    """
    # If G_traj is a TrajectoryGraph, extract its underlying networkx graph.
    if hasattr(G_traj, 'G_traj'):
        G_traj = G_traj.G_traj

    # Compute node positions using graphviz layout.
    pos = nx.nx_agraph.graphviz_layout(G_traj, prog="dot", args="-Grankdir=LR")
    plt.figure(figsize=(12, 7))
    
    # Draw the tree structure: nodes and edges.
    for node, (x, y) in pos.items():
        plt.scatter(x, y, color='black', s=500, zorder=3)
        plt.text(x, y, node, fontsize=10, ha="center", va="center", zorder=4)
    for src, dst in G_traj.edges():
        if src not in pos or dst not in pos:
            continue
        P0, P1 = np.array(pos[src]), np.array(pos[dst])
        plt.plot([P0[0], P1[0]], [P0[1], P1[1]], color='lightgrey', lw=5, alpha=0.5, zorder=1)
    
    # Extract gene expression as a pandas Series (indexed by cell IDs).
    if gene_name in adata.var_names:
        gene_idx = adata.var_names.get_loc(gene_name)
        expr_array = (adata.X[:, gene_idx].toarray().ravel() 
                      if hasattr(adata.X, "toarray") 
                      else np.array(adata.X[:, gene_idx]).ravel())
        expr_series = pd.Series(expr_array, index=adata.obs_names)
    else:
        raise ValueError(f"Gene '{gene_name}' not found in adata.var_names")
    
    # Group cells by edge.
    # For each cell, compute its beta PDF along a grid of t-values.
    t_vals = np.linspace(0, 1, resolution)
    edge_groups = {}  # { edge: list of dicts for each cell }
    for cell_id, row in beta_assignments.iterrows():
        edge = row['edge']
        alpha_param = row['alpha']
        beta_param = row['beta']
        if not edge or alpha_param <= 0 or beta_param <= 0:
            continue
        # Compute beta PDF for this cell.
        pdf_vals = beta.pdf(t_vals, alpha_param, beta_param)
        pdf_vals = np.nan_to_num(pdf_vals)
        # Use the maximum of the PDF as a simple measure of certainty.
        cert = pdf_vals.max()
        if edge not in edge_groups:
            edge_groups[edge] = []
        edge_groups[edge].append({
            "cell_id": cell_id,
            "pdf": pdf_vals,
            "expr": expr_series.loc[cell_id],
            "cert": cert
        })
    
    # Prepare a colormap for certainty: blue = low, red = high.
    cmap = cm.RdBu_r

    # For each edge, compute the weighted gene expression and certainty along t.
    for edge, cells in edge_groups.items():
        src, dst = edge
        if src not in pos or dst not in pos:
            continue
        P0 = np.array(pos[src])
        P1 = np.array(pos[dst])
        direction = P1 - P0
        seg_length = np.linalg.norm(direction)
        if seg_length == 0:
            continue
        direction = direction / seg_length
        # Compute a perpendicular (normal) vector.
        normal = np.array([-direction[1], direction[0]])
        
        # Initialize accumulators for weighted expression and certainty.
        weighted_expr = np.zeros_like(t_vals, dtype=float)
        weighted_cert = np.zeros_like(t_vals, dtype=float)
        weight_sum = np.zeros_like(t_vals, dtype=float)
        
        for cell in cells:
            pdf_vals = cell["pdf"]
            weighted_expr += cell["expr"] * pdf_vals
            weighted_cert += cell["cert"] * pdf_vals
            weight_sum += pdf_vals
        
        mask = weight_sum > 0
        weighted_expr[mask] /= weight_sum[mask]
        weighted_cert[mask] /= weight_sum[mask]
        
        # Compute the base curve along the edge.
        base_curve = np.array([P0 + t * (P1 - P0) for t in t_vals])
        # Offset the base curve by the weighted expression along the normal,
        # scaling the offset by curve_scale.
        curve_pts = base_curve + np.outer(weighted_expr * curve_scale, normal)
        
        # If the source node is a split, blend the first few points with the parent's endpoint.
        # We assume that a split node is identified by its type attribute containing "split".
        if "split" in G_traj.nodes[src].get("type", ""):
            # Get the transition probability for this edge (default to 1 if not defined)
            A = G_traj.edges[src, dst].get("A", 1.0)
            # Blend the first blend_count points.
            blend_count = max(2, int(blend_fraction * resolution))
            for i in range(blend_count):
                blend_weight = A * (i / blend_count)  # gradually ramp from 0 to A
                # Blend parent's endpoint (P0) and the computed branch start.
                curve_pts[i] = (1 - blend_weight) * P0 + blend_weight * curve_pts[i]
        
        # Normalize certainty values for color mapping.
        cert_min, cert_max = weighted_cert.min(), weighted_cert.max()
        if cert_max > cert_min:
            norm_cert = (weighted_cert - cert_min) / (cert_max - cert_min)
        else:
            norm_cert = np.full_like(weighted_cert, 0.5)
        
        # Draw the curve as a series of short segments colored by certainty.
        for i in range(resolution - 1):
            seg_x = curve_pts[i:i+2, 0]
            seg_y = curve_pts[i:i+2, 1]
            seg_color = cmap(norm_cert[i])
            plt.plot(seg_x, seg_y, color=seg_color, lw=2, zorder=2)
    
    plt.title(title)
    plt.axis("off")
    plt.tight_layout()
    plt.show()

# %%
plot_gene_dynamics_on_trajectory(traj_graph, beta_assignments, adata, gene_name='Lypla1',
                                 resolution=100, curve_scale=100.0, blend_fraction=0.1,
                                 title="Gene Dynamics on Trajectory for Lypla1")
