# %%
# # Path to h5ad dataset
# dataset_path = '/work/vanaja_lab/griffin/projects/cshmm/results/pancreas_dev.h5ad'

# # Load and prepare AnnData
# if os.path.exists(dataset_path):
#     print("File exists. Loading the dataset...")
#     adata = sc.read_h5ad(dataset_path)
#     print("Dataset loaded successfully!")
#     print("Dataset shape:", adata.shape)
# else:
#     raise FileNotFoundError(f"File not found at: {dataset_path}")

# adata.obs_names_make_unique()

# # Preprocessing steps
# sc.pp.normalize_total(adata, target_sum=1e4)
# sc.pp.log1p(adata)

# # Min-max scaling
# scaler = MinMaxScaler()
# adata.X = scaler.fit_transform(adata.X.toarray())

# # HVG selection
# sc.pp.highly_variable_genes(adata, n_top_genes=1000, flavor='seurat')
# adata = adata[:, adata.var['highly_variable']].copy()

# print(f"Dataset shape after selecting top 1000 HVGs: {adata.shape}")

# %%
# Dimensionality reduction and clustering
# sc.pp.pca(adata)
# sc.pp.neighbors(adata)
# sc.tl.umap(adata)
# sc.tl.leiden(adata, resolution=2, key_added="leiden")

# # Plot UMAP with clusters
# sc.pl.umap(adata, color="leiden", legend_loc="on data", title="UMAP - Leiden Clusters")

# # PAGA
# sc.tl.paga(adata, groups='leiden')
# sc.pl.paga(adata, color='leiden', title="PAGA Connectivity Graph")
# sc.pl.umap(adata, color=['leiden'], edges=True, title="UMAP with PAGA Connectivity")

# %%
#adata.write('data/mouse_panc_dev.h5ad')

# %%
import os
import scanpy as sc
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler

from models import TrajectoryGraph, initialize_trajectory
# Out:
# /work/vanaja_lab/griffin/miniconda3/envs/cellrank/lib/python3.12/site-packages/anndata/utils.py:429: FutureWarning: Importing read_csv from `anndata` is deprecated. Import anndata.io.read_csv instead.
#   warnings.warn(msg, FutureWarning)
# /work/vanaja_lab/griffin/miniconda3/envs/cellrank/lib/python3.12/site-packages/anndata/utils.py:429: FutureWarning: Importing read_excel from `anndata` is deprecated. Import anndata.io.read_excel instead.
#   warnings.warn(msg, FutureWarning)
# /work/vanaja_lab/griffin/miniconda3/envs/cellrank/lib/python3.12/site-packages/anndata/utils.py:429: FutureWarning: Importing read_hdf from `anndata` is deprecated. Import anndata.io.read_hdf instead.
#   warnings.warn(msg, FutureWarning)
# /work/vanaja_lab/griffin/miniconda3/envs/cellrank/lib/python3.12/site-packages/anndata/utils.py:429: FutureWarning: Importing read_loom from `anndata` is deprecated. Import anndata.io.read_loom instead.
#   warnings.warn(msg, FutureWarning)
# /work/vanaja_lab/griffin/miniconda3/envs/cellrank/lib/python3.12/site-packages/anndata/utils.py:429: FutureWarning: Importing read_mtx from `anndata` is deprecated. Import anndata.io.read_mtx instead.
#   warnings.warn(msg, FutureWarning)
# /work/vanaja_lab/griffin/miniconda3/envs/cellrank/lib/python3.12/site-packages/anndata/utils.py:429: FutureWarning: Importing read_text from `anndata` is deprecated. Import anndata.io.read_text instead.
#   warnings.warn(msg, FutureWarning)
# /work/vanaja_lab/griffin/miniconda3/envs/cellrank/lib/python3.12/site-packages/anndata/utils.py:429: FutureWarning: Importing read_umi_tools from `anndata` is deprecated. Import anndata.io.read_umi_tools instead.
#   warnings.warn(msg, FutureWarning)

# %%
adata = sc.read('data/mouse_panc_dev.h5ad')

# %%
# Build the trajectory graph
traj_graph, cell_assignment = initialize_trajectory(
    adata=adata,
    random_state=41,
    debug=True
)
# Out:
# Trajectory graph nodes: ['leaf_0', 'split_1', 'leaf_2', 'split_3', 'leaf_4', 'split_5', 'leaf_6', 'split_7', 'split_8', 'leaf_9', 'split_10', 'leaf_11', 'int_12', 'leaf_13', 'leaf_14', 'split_15', 'leaf_16', 'root_split_17', 'RootNode_0_0']
# Trajectory graph edges: [('split_1', 'leaf_13'), ('split_1', 'leaf_14'), ('split_3', 'split_7'), ('split_3', 'split_8'), ('split_5', 'int_12'), ('split_5', 'leaf_16'), ('split_7', 'leaf_2'), ('split_7', 'leaf_6'), ('split_8', 'leaf_0'), ('split_8', 'leaf_9'), ('split_10', 'split_5'), ('split_10', 'split_15'), ('int_12', 'leaf_11'), ('split_15', 'split_1'), ('split_15', 'leaf_4'), ('root_split_17', 'split_3'), ('root_split_17', 'split_10'), ('RootNode_0_0', 'root_split_17')]
#
# Sample cell assignments:
#                                  edge  latent_time
# TAAGCGTAGGCCCGTT  (split_15, leaf_4)     0.773956
# GACCAATAGTCGTCGT  (split_3, split_8)     0.438878
# CGAGAAGCATGCTAGT  (split_15, leaf_4)     0.858598
# ACGATGTAGGATTCCC  (split_15, leaf_4)     0.697368
# GCAGTTAAGGTCATCT  (split_15, leaf_4)     0.094177

# %%
# Visualize trajectory graph with cells assigned
traj_graph.plot_cells_on_trajectory(
    cell_assignment=cell_assignment,
    color_key='leiden',
    curve_amount=0.8,
    node_size=500,
    cell_size=30,
    horizontal_thresh=0.01,
    edge_width=5,
    edge_color='lightgrey',
    title="Cells on Stochastic PAGA Trajectory",
    plot_transitions=True
)

# %%
# # === Imports ===

import torch
import numpy as np
from models.posterior import TreeVariationalPosterior
from models.belief import BeliefPropagator
from models.emission import pack_emission_params
from models.loss import compute_elbo
from utils.inference import initialize_beta_from_cell_assignment, find_path_index_for_edge

# # === Setup ===
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
# Out:
# /work/vanaja_lab/griffin/miniconda3/envs/cellrank/lib/python3.12/site-packages/torch/cuda/__init__.py:129: UserWarning: CUDA initialization: The NVIDIA driver on your system is too old (found version 11040). Please update your GPU driver by downloading and installing a new version from the URL: http://www.nvidia.com/Download/index.aspx Alternatively, go to: https://pytorch.org to install a PyTorch version that has been compiled with your version of the CUDA driver. (Triggered internally at ../c10/cuda/CUDAFunctions.cpp:108.)
#   return torch._C._cuda_getDeviceCount() > 0

# %%
# === Prepare expression data ===
X = torch.tensor(
    adata.X.toarray() if hasattr(adata.X, 'toarray') else adata.X,
    dtype=torch.float32,
    device=device
)

# === Initialize trajectory graph ===
traj_graph, cell_assignment = initialize_trajectory(adata, debug=True)
traj_graph.edge_list = list(traj_graph.G_traj.edges())

all_nodes = set(traj_graph.node_to_index.keys())
emission_nodes = set(traj_graph.node_emission.keys())
missing = all_nodes - emission_nodes
print(f"\nAll nodes:      {sorted(all_nodes)}")
print(f"Emission nodes: {sorted(emission_nodes)}")
print(f"Missing nodes:  {sorted(missing)}")

# === Emission parameter initialization ===
edge_to_index, g_a, g_b, K, sigma2, pi, g = pack_emission_params(traj_graph, device=device)

# === Wrap emission parameters in nn.Parameter for autograd ===
g = torch.nn.Parameter(g)
K = torch.nn.Parameter(K)
log_sigma2 = torch.nn.Parameter(torch.log(sigma2))

# === Posterior setup ===
n_cells = X.shape[0]
posterior = TreeVariationalPosterior(traj_graph, n_cells=n_cells, device=device)
print("edge_logits requires_grad:", posterior.edge_logits.requires_grad)

# === Initialize beta from trajectory assignment (optional) ===
initialize_beta_from_cell_assignment(posterior, cell_assignment, edge_to_index, sharpness=0.1)

# === Belief propagator ===
belief_propagator = BeliefPropagator(traj_graph, posterior)

# === Diagnostics ===
print("g requires_grad:", g.requires_grad)
print("Initial alpha mean:", posterior.alpha.mean().item())
print("Initial beta mean:", posterior.beta.mean().item())

# === Group learnable emission parameters (if needed elsewhere) ===
emission_params = [g, K, log_sigma2]
# Out:
# Trajectory graph nodes: ['leaf_0', 'leaf_1', 'split_2', 'split_3', 'split_4', 'int_5', 'leaf_6', 'leaf_7', 'split_8', 'split_9', 'split_10', 'leaf_11', 'leaf_12', 'leaf_13', 'leaf_14', 'root_split_15', 'split_16', 'leaf_17', 'RootNode_0_0']
# Trajectory graph edges: [('split_2', 'leaf_1'), ('split_2', 'leaf_14'), ('split_3', 'split_4'), ('split_3', 'split_16'), ('split_4', 'split_2'), ('split_4', 'leaf_17'), ('int_5', 'leaf_13'), ('split_8', 'leaf_0'), ('split_8', 'leaf_12'), ('split_9', 'split_8'), ('split_9', 'split_10'), ('split_10', 'leaf_6'), ('split_10', 'leaf_11'), ('root_split_15', 'split_3'), ('root_split_15', 'split_9'), ('split_16', 'int_5'), ('split_16', 'leaf_7'), ('RootNode_0_0', 'root_split_15')]
#
# Sample cell assignments:
#                                  edge  latent_time
# TAAGCGTAGGCCCGTT  (split_3, split_4)     0.773956
# GACCAATAGTCGTCGT  (split_9, split_8)     0.438878
# CGAGAAGCATGCTAGT  (split_3, split_4)     0.858598
# ACGATGTAGGATTCCC  (split_3, split_4)     0.697368
# GCAGTTAAGGTCATCT  (split_3, split_4)     0.094177
#
# All nodes:      ['RootNode_0_0', 'int_5', 'leaf_0', 'leaf_1', 'leaf_11', 'leaf_12', 'leaf_13', 'leaf_14', 'leaf_17', 'leaf_6', 'leaf_7', 'root_split_15', 'split_10', 'split_16', 'split_2', 'split_3', 'split_4', 'split_8', 'split_9']
# Emission nodes: ['RootNode_0_0', 'int_5', 'leaf_0', 'leaf_1', 'leaf_11', 'leaf_12', 'leaf_13', 'leaf_14', 'leaf_17', 'leaf_6', 'leaf_7', 'root_split_15', 'split_10', 'split_16', 'split_2', 'split_3', 'split_4', 'split_8', 'split_9']
# Missing nodes:  []
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[9], line 20
#      17 print(f"Missing nodes:  {sorted(missing)}")
#      19 # === Emission parameter initialization ===
# ---> 20 edge_to_index, g_a, g_b, K, sigma2, pi, g = pack_emission_params(traj_graph, device=device)
#      22 # === Wrap emission parameters in nn.Parameter for autograd ===
#      23 g = torch.nn.Parameter(g)
#
# ValueError: not enough values to unpack (expected 7, got 5)

# %%
import torch
import scanpy as sc
import numpy as np
import time

# --- Core Model/Training Imports ---
# Assumes your project structure has models/, training/, utils/, viz/ directories
from models.trajectory import initialize_trajectory
from training.loop import VIRunner # VIRunner is in training/loop.py
from training.structure_learner import TrajectoryStructureLearner

# ============================================
# 1. Load Data & Initialize Graph
# ============================================
# Replace with your actual data loading and preprocessing steps
# Ensure adata has clustering (e.g., 'leiden') and PAGA connectivities computed
print("Loading data and initializing graph...")
try:
    # Example using scanpy's built-in pbmc3k dataset
    # Replace this with your adata = sc.read_h5ad("your_data.h5ad")
    adata = sc.datasets.pbmc3k_processed()
    # Basic PAGA example (replace with your actual PAGA parameters)
    sc.tl.paga(adata, groups='louvain') # Assuming 'louvain' is the clustering key
    sc.pl.paga(adata, show=False) # Compute layout for initialization

    # Initialize the trajectory graph object
    # Using 'louvain' as the cluster key based on the example above
    traj_graph, initial_assignment = initialize_trajectory(adata, cluster_key='louvain', random_state=42)

    # Prepare the data tensor (ensure it's float32)
    if hasattr(adata.X, "toarray"):
        X_np = adata.X.toarray().astype(np.float32)
    else:
        X_np = np.asarray(adata.X, dtype=np.float32) # Ensure it's a dense numpy array
    X = torch.tensor(X_np, dtype=torch.float32)
    print(f"Data loaded: {X.shape[0]} cells, {X.shape[1]} genes")
    print(f"Initial graph: {traj_graph.G_traj.number_of_nodes()} nodes, {traj_graph.G_traj.number_of_edges()} edges")

except Exception as e:
    print(f"Error during data loading or graph initialization: {e}")
    print("Please replace placeholder data loading with your actual code.")
    # Exit or raise error if essential setup fails
    raise SystemExit("Data/Graph Initialization Failed") from e

# ============================================
# 2. Configure VIRunner
# ============================================
# All available configuration options for VIRunner
vi_config = {
    # --- Learnability Control ---
    # "learn_K": True,              # Default: True. Learn the edge rate parameter K.
    # "learn_g": False,             # FIXED: False. Node means 'g' are always recalculated.
    # "learn_sigma2": False,        # FIXED: False. Edge variances 'sigma2' are always recalculated.

    # --- Optimization Strategy ---
    "use_lagging": True,           # Default: False. Use alternating E/M steps vs standard VI.
    "minibatch": False,            # Default: False. Use minibatches vs full dataset per epoch.
    "batch_size": 512,            # Default: 512. Size if minibatch=True.
    "lr": 0.01,                   # Default: 0.01. Learning rate.

    # --- Training Duration & Sampling ---
    "num_epochs": 50,             # Default: 100. Total epochs for optimization run. (Reduced for example)
    "n_samples": 3,               # Default: 3. MC samples for ELBO expectation.
    "inference_steps": 5,         # Default: 5. E-steps per epoch if use_lagging=True.
    "generative_steps": 1,        # Default: 1. M-steps per epoch if use_lagging=True.

    # --- Curriculum Learning (Only affects K if learn_K=True) ---
    "freeze_epochs": 10,          # Default: 10. Freeze K for N epochs (if learn_K=True & use_lagging=False).

    # --- Loss Term Weights ---
    "kl_weight": 1.0,             # Default: 1.0. Weight for KL(time posterior || Uniform).
    "kl_p_weight": 1.0,             # Default: 1.0. Weight for KL(edge posterior || Prior/Uniform).
    "t_cont_weight": 1.0,           # Default: 1.0. Weight for time continuity penalty.
    "l1_K_weight": 1e-4,          # Default: 0.0. L1 sparsity penalty on K parameter (encourages K -> 0).
    "branch_entropy_weight": 1.0,   # Default: 1.0. Encourages diverse branching probabilities.
    "struct_prior_weight": 0.0,     # Default: 0.0. Weight for KL divergence against structural prior.

    # --- Annealing Schedules ---
    "anneal_start_epoch": 10,     # Default: 10. Epoch to start annealing (adjusted if freeze_epochs is later).
    "anneal_epochs": 30,          # Default: 50. Number of epochs to anneal over (Reduced for example).
    "logit_temp_start": 5.0,      # Default: 5.0. Initial temperature for edge softmax.
    "logit_temp_end": 1.0,        # Default: 1.0. Final temperature.
    "struct_prior_anneal_start": 0.0, # Default: 0.0. Start weight for structural prior KL.
    "struct_prior_anneal_end": 0.5,   # Default: 1.0. Final weight for structural prior KL. (Example: lower final weight)

    # --- Other ---
    "use_belief_propagator": False, # Default: True. Diffuse edge probs using graph structure? (Turned off in user request)
    "recalc_prior_std": 0.1,      # Default: 0.1. Small std dev added to recalculated sigma2.
    "verbose": True,              # Default: True. Print training progress.
    # "short_run": False,         # Default: False. Run fewer epochs (uses eval_epochs).
    # "eval_epochs": 20           # Default: 20. Epochs if short_run=True.
}

# Instantiate the runner (device selection is handled internally)
vi_runner = VIRunner(default_config=vi_config)
print(f"VIRunner configured on device: {vi_runner.device}")

# ============================================
# 3. Configure TrajectoryStructureLearner
# ============================================
# All available configuration options for TrajectoryStructureLearner
learner_config = {
    "max_structure_iterations": 1, # Default: 1. Phase 1 only runs 1 iteration. Increase for future phases.
    "analysis_thresholds": {
        "time_boundary": 0.1,         # Default: 0.1. Mode < boundary or > 1-boundary.
        "discontinuity": 1.5,         # Default: 1.0. Propose SPLIT if D(v) > this.
        "prune_mass_fraction": 0.05,  # Default: 0.05. Propose PRUNE if Mass(e) < frac * avg_mass.
        "merge_similarity": 0.8,      # Default: 0.5. Propose MERGE if ||g_u-g_v|| < this.
        "min_cells_for_discontinuity": 10 # Default: 10. Min cells needed at boundary ends.
    },
    "structure_modification": { # Configurations for future structure modification steps
        "enabled": False,             # Default: False. Set to True to enable proposing/evaluating changes.
        "max_proposals_to_evaluate": 3, # Default: 3. How many top proposals to test per iteration.
        "evaluation_epochs": 20         # Default: 20. Epochs used for evaluating candidate structures.
    },
    "verbose": True,                  # Default: True. Print analysis summaries.
}

# Instantiate the learner
# Note: Pass the data tensor directly, not a dictionary
structure_learner = TrajectoryStructureLearner(
    initial_graph=traj_graph,
    data_X=X, # Pass the torch tensor X
    vi_runner=vi_runner,
    config=learner_config
)
print("TrajectoryStructureLearner configured.")

# ============================================
# 4. Run the Learning Process (Phase 1)
# ============================================
print("\nStarting structure learning (Phase 1: Optimize & Analyze)...")
start_time = time.time()
# This runs the initial optimization and the subsequent analysis
final_graph, history = structure_learner.learn_structure()
end_time = time.time()
print(f"Structure learning process finished in {end_time - start_time:.2f} seconds.")

# ============================================
# 5. Examine Results
# ============================================
if not history:
    print("\nNo history recorded. Structure learning might have failed early.")
else:
    print("\n--- Final Iteration Results ---")
    # Get results from the last (and only, in Phase 1) iteration
    last_iter_results = history[-1]

    if last_iter_results.get("status") == "Completed":
        final_elbo = last_iter_results.get('final_elbo', 'N/A')
        print(f"Final ELBO: {final_elbo}")

        # Log the analysis report from the final state
        final_analysis = last_iter_results.get('analysis_post_optim')
        if final_analysis and 'error' not in final_analysis:
            structure_learner.log_analysis("Final Post-Optimization Analysis", final_analysis)
        elif final_analysis and 'error' in final_analysis:
            print(f"Final analysis failed: {final_analysis['error']}")
        else:
            print("Final analysis results not found in history.")

        # Access final parameters and posterior if needed
        final_params = last_iter_results.get('params_optimized')
        final_posterior = last_iter_results.get('posterior_optimized')

        if final_params and final_posterior:
            print("\nAccessing final parameters (CPU) and posterior (device)...")
            # Example: print shape of learned K
            if 'K' in final_params and final_params['K'] is not None:
                print(f"  Learned K shape: {final_params['K'].shape}")
            # Example: print shape of posterior alpha
            if hasattr(final_posterior, 'alpha'):
                print(f"  Posterior alpha shape: {final_posterior.alpha.shape}")

            # --- TODO: Add your visualization calls here ---
            # Example using placeholder visualization functions
            # from viz import plot_cells_on_trajectory, plot_pdf_width_ribbons_on_trajectory
            #
            # # Create assignment DataFrame from posterior (example - needs implementation)
            # from utils.inference import get_assignments_from_posterior # Assumes this exists
            # assignments_df = get_assignments_from_posterior(final_posterior, final_graph.node_to_index, final_posterior.edge_to_index)
            #
            # if assignments_df is not None:
            #     plot_cells_on_trajectory(final_graph, assignments_df, adata, color_key='louvain', title="Final Cell Assignments")
            #     plot_pdf_width_ribbons_on_trajectory(final_graph, assignments_df, adata, color_key='louvain', title="Final Posterior Widths")

    else:
        print(f"Final iteration status: {last_iter_results.get('status', 'Unknown')}")

# %%
def test_branch_logits_grad_flow(posterior):
    print("\n=== TEST: branch_logits Gradient Flow ===")

    posterior.branch_logits.data.uniform_(-0.1, 0.1)
    posterior.branch_logits.grad = None

    B = posterior.compute_branch_probs()
    print("B.sum():", B.sum().item())

    # Force a scalar from B that depends on all branch_logits
    scalar = (B * torch.arange(1, len(B)+1, device=B.device)).sum()
    scalar.backward()

    print("branch_logits.grad:")
    print(posterior.branch_logits.grad)
    print("branch_logits.grad norm:", posterior.branch_logits.grad.norm().item())
    print("=========================================")

# %%
test_branch_logits_grad_flow(posterior)
# Out:
# === TEST: branch_logits Gradient Flow ===
# B.sum(): 10.0
# branch_logits.grad:
# tensor([-0.2499,  0.2499, -0.2494,  0.2494, -0.2498,  0.2498, -0.2492,  0.2492,
#         -0.2496,  0.2496, -0.2481,  0.2481,  0.0000, -0.2489,  0.2489, -0.2500,
#          0.2500,  0.0000])
# branch_logits.grad norm: 0.9974830150604248
# =========================================

# %% [markdown]
# # Test Standard Full Code

# %%
# # === Run Variational Model ===
# for epoch in range(num_epochs):
#     optimizer.zero_grad()

#     loss, metrics = compute_elbo(
#         X, traj_graph, posterior, edge_to_index,
#         g_a, g_b, K, log_sigma2.exp(),
#         pi=pi,
#         belief_propagator=belief_propagator,
#         n_samples=n_samples,
#         kl_weight=kl_weight,
#         kl_p_weight=kl_p_weight,
#         t_cont_weight=t_cont_weight
#     )

#     loss.backward()
#     print_grad_stats()
#     log_epoch(epoch, loss, metrics)
#     optimizer.step()

# %%
import os
os.environ["CUDA_LAUNCH_BLOCKING"] = "1"

# %%
print("branch_logits requires_grad:", posterior.branch_logits.requires_grad)
# Out:
# branch_logits requires_grad: True

# %%
import torch
from models.loss import compute_elbo_batch
from utils.inference import batch_indices

def print_grad_status(name, param):
    if not param.requires_grad:
        print(f"🚫 {name}: requires_grad=False")
    elif param.grad is None:
        print(f"❌ {name}.grad is None")
    elif param.grad.norm().item() < 1e-10:
        print(f"⚠️ {name}.grad norm is ~0.0")
    else:
        print(f"✅ {name}.grad norm = {param.grad.norm().item():.2e}")

# === Logging containers ===
elbo_log, nll_log, kl_t_log, kl_p_log = [], [], [], []
t_cont_log, transition_log, l1_log, grad_log = [], [], [], []

# === Config ===
batch_size = 512
num_epochs = 500
n_samples = 3
kl_weight = 1.0
kl_p_weight = 1e4
t_cont_weight = 1.0
transition_weight = 1.0
l1_weight = 1.0
entropy_weight = 100
lr = 1e-2

# === Phase toggling ===
phase = "emission"
max_phase_epochs = 10
patience = 5
tol = 1e-3
best_loss = torch.tensor(float("inf"), device=X.device)
epochs_since_improvement = 0
phase_epoch = 0

# === Training loop ===
for epoch in range(num_epochs):
    # === Phase-specific parameter control ===
    if phase == "emission":
        posterior.freeze()
        for p in [g, K, log_sigma2]:
            p.requires_grad_(True)
        posterior.branch_logits.requires_grad_(True)
    else:
        posterior.unfreeze()
        for p in [g, K, log_sigma2]:
            p.requires_grad_(False)

    # === Optimizer setup ===
    trainable_params = list(p for p in posterior.parameters() if p.requires_grad) + \
                       [p for p in [g, K, log_sigma2] if p.requires_grad]
    optimizer = torch.optim.Adam(trainable_params, lr=lr)

    total_loss = torch.tensor(0.0, device=X.device)
    total_batches = 0
    epoch_metrics = {k: 0.0 for k in ["nll", "kl_t", "kl_p", "t_cont", "transition", "l1", "emission_cont", "entropy"]}

    for batch in batch_indices(X.shape[0], batch_size):
        X_batch = X[batch]
        optimizer.zero_grad()

        loss, metrics = compute_elbo_batch(
            X_batch, batch, traj_graph, posterior, edge_to_index,
            g, K, log_sigma2.exp(),
            belief_propagator=belief_propagator,
            n_samples=n_samples,
            kl_weight=kl_weight,
            kl_p_weight=kl_p_weight,
            t_cont_weight=t_cont_weight,
            transition_weight=transition_weight,
            l1_weight=l1_weight,
            pi=pi
        )
        with torch.autograd.set_detect_anomaly(True):
            loss.backward()

        # print("\n--- GRADIENT STATUS (before step) ---")
        # print_grad_status("posterior.edge_logits", posterior.edge_logits)
        print_grad_status("posterior.branch_logits", posterior.branch_logits)
        # print_grad_status("posterior.alpha", posterior.alpha)
        # print_grad_status("posterior.beta", posterior.beta)
        # print_grad_status("g", g)
        # print_grad_status("K", K)
        # print_grad_status("log_sigma2", log_sigma2)

        optimizer.step()

        total_loss += loss
        for key in epoch_metrics:
            epoch_metrics[key] += metrics.get(key, 0.0)
        total_batches += 1

    for key in epoch_metrics:
        epoch_metrics[key] /= total_batches

    avg_loss = total_loss / total_batches
    elbo_log.append(avg_loss.item())
    nll_log.append(epoch_metrics["nll"])
    kl_t_log.append(epoch_metrics["kl_t"])
    kl_p_log.append(epoch_metrics["kl_p"])
    t_cont_log.append(epoch_metrics["t_cont"])
    transition_log.append(epoch_metrics["transition"])
    l1_log.append(epoch_metrics["l1"])
    grad_log.append({k: v.grad.norm().item() if v.grad is not None else 0.0
                     for k, v in zip(["edge_logits", "branch_logits", "alpha", "beta", "g", "K", "log_sigma2"],
                                     [posterior.edge_logits, posterior.branch_logits,
                                      posterior.alpha, posterior.beta,
                                      g, K, log_sigma2])})

    print(f"\n[Epoch {epoch}] | Phase: {phase}")
    print(f"  ELBO:         {avg_loss.item():.4e}")
    print(f"  NLL:          {epoch_metrics['nll']:.4e}")
    print(f"  KL(t):        {epoch_metrics['kl_t']:.4e}")
    print(f"  KL(p):        {epoch_metrics['kl_p']:.4e}")
    print(f"  t_cont:       {epoch_metrics['t_cont']:.4e}")
    print(f"  Transition:   {epoch_metrics['transition']:.4e}")
    print(f"  L1:           {epoch_metrics['l1']:.4e}")
    print(f"  Emission MSE: {epoch_metrics['emission_cont']:.4e}")
    print(f"  Entropy:      {epoch_metrics['entropy']:.4e}")

    # === Phase switching ===
    if avg_loss < best_loss - tol:
        best_loss = avg_loss
        epochs_since_improvement = 0
    else:
        epochs_since_improvement += 1

    phase_epoch += 1
    if epochs_since_improvement >= patience or phase_epoch >= max_phase_epochs:
        phase = "posterior" if phase == "emission" else "emission"
        best_loss = torch.tensor(float("inf"), device=X.device)
        epochs_since_improvement = 0
        phase_epoch = 0
        print(f"--- Switching to {phase} phase ---")
# Out:
# ✅ posterior.branch_logits.grad norm = 1.53e-01
# ✅ posterior.branch_logits.grad norm = 1.44e-01
# ✅ posterior.branch_logits.grad norm = 1.25e-01
# ✅ posterior.branch_logits.grad norm = 1.10e-01
# ✅ posterior.branch_logits.grad norm = 9.58e-02
# ✅ posterior.branch_logits.grad norm = 8.30e-02
# ✅ posterior.branch_logits.grad norm = 9.69e-02
# ✅ posterior.branch_logits.grad norm = 8.25e-02
# ✅ posterior.branch_logits.grad norm = 7.55e-02
# ✅ posterior.branch_logits.grad norm = 6.85e-02
# ✅ posterior.branch_logits.grad norm = 6.43e-02
#
# [Epoch 0] | Phase: emission
#   ELBO:         7.3720e+05
#   NLL:          7.3717e+05
#   KL(t):        1.0641e-01
#   KL(p):        7.9103e-10
#   t_cont:       3.3298e-01
#   Transition:   -1.2530e+01
#   L1:           2.3011e+01
#   Emission MSE: 2.2450e-03
#   Entropy:      5.5424e+00
# ✅ posterior.branch_logits.grad norm = 5.98e-02
# ✅ posterior.branch_logits.grad norm = 4.54e-02
# ✅ posterior.branch_logits.grad norm = 4.05e-02
# ✅ posterior.branch_logits.grad norm = 2.58e-02
# ✅ posterior.branch_logits.grad norm = 2.98e-02
# ✅ posterior.branch_logits.grad norm = 1.95e-02
# ✅ posterior.branch_logits.grad norm = 1.55e-02
# ✅ posterior.branch_logits.grad norm = 9.68e-03
# ✅ posterior.branch_logits.grad norm = 8.67e-03
# ✅ posterior.branch_logits.grad norm = 1.48e-02
# ✅ posterior.branch_logits.grad norm = 1.37e-02
#
# [Epoch 1] | Phase: emission
#   ELBO:         4.6710e+05
#   NLL:          4.6707e+05
#   KL(t):        1.1056e-01
#   KL(p):        1.0329e-09
#   t_cont:       3.3520e-01
#   Transition:   -1.2489e+01
#   L1:           2.0802e+01
#   Emission MSE: 1.4007e-03
#   Entropy:      5.5426e+00
# ✅ posterior.branch_logits.grad norm = 2.04e-02
# ✅ posterior.branch_logits.grad norm = 1.83e-02
# ✅ posterior.branch_logits.grad norm = 1.39e-02
# ✅ posterior.branch_logits.grad norm = 1.40e-02
# ✅ posterior.branch_logits.grad norm = 9.31e-03
# ✅ posterior.branch_logits.grad norm = 1.57e-02
# ✅ posterior.branch_logits.grad norm = 1.63e-02
# ✅ posterior.branch_logits.grad norm = 8.19e-03
# ✅ posterior.branch_logits.grad norm = 7.70e-03
# ✅ posterior.branch_logits.grad norm = 6.25e-03
# ✅ posterior.branch_logits.grad norm = 2.10e-02
#
# [Epoch 2] | Phase: emission
#   ELBO:         2.7050e+05
#   NLL:          2.7048e+05
#   KL(t):        9.5065e-02
#   KL(p):        8.5104e-10
#   t_cont:       3.3708e-01
#   Transition:   -1.2510e+01
#   L1:           1.9914e+01
#   Emission MSE: 1.0712e-03
#   Entropy:      5.5417e+00
# ✅ posterior.branch_logits.grad norm = 4.85e-03
# ✅ posterior.branch_logits.grad norm = 2.06e-02
# ✅ posterior.branch_logits.grad norm = 6.54e-03
# ✅ posterior.branch_logits.grad norm = 7.94e-03
# ✅ posterior.branch_logits.grad norm = 1.41e-02
# ✅ posterior.branch_logits.grad norm = 9.93e-03
# ✅ posterior.branch_logits.grad norm = 8.60e-03
# ✅ posterior.branch_logits.grad norm = 4.83e-03
# ✅ posterior.branch_logits.grad norm = 9.53e-03
# ✅ posterior.branch_logits.grad norm = 9.45e-03
# ✅ posterior.branch_logits.grad norm = 7.81e-03
#
# [Epoch 3] | Phase: emission
#   ELBO:         1.6500e+05
#   NLL:          1.6497e+05
#   KL(t):        1.0622e-01
#   KL(p):        7.8116e-10
#   t_cont:       3.3390e-01
#   Transition:   -1.2551e+01
#   L1:           1.9761e+01
#   Emission MSE: 1.1007e-03
#   Entropy:      5.5414e+00
# ✅ posterior.branch_logits.grad norm = 5.44e-03
# ✅ posterior.branch_logits.grad norm = 1.55e-02
# ✅ posterior.branch_logits.grad norm = 1.17e-02
# ✅ posterior.branch_logits.grad norm = 1.51e-02
# ✅ posterior.branch_logits.grad norm = 1.12e-02
# ✅ posterior.branch_logits.grad norm = 1.09e-02
# ✅ posterior.branch_logits.grad norm = 7.73e-03
# ✅ posterior.branch_logits.grad norm = 1.45e-02
# ✅ posterior.branch_logits.grad norm = 6.10e-03
# ✅ posterior.branch_logits.grad norm = 1.07e-02
# ✅ posterior.branch_logits.grad norm = 1.59e-02
#
# [Epoch 4] | Phase: emission
#   ELBO:         1.1160e+05
#   NLL:          1.1157e+05
#   KL(t):        1.0035e-01
#   KL(p):        7.3617e-10
#   t_cont:       3.3411e-01
#   Transition:   -1.2633e+01
#   L1:           2.0213e+01
#   Emission MSE: 1.3620e-03
#   Entropy:      5.5415e+00
# ✅ posterior.branch_logits.grad norm = 7.16e-03
# ✅ posterior.branch_logits.grad norm = 1.48e-02
# ✅ posterior.branch_logits.grad norm = 1.13e-02
# ✅ posterior.branch_logits.grad norm = 7.83e-03
# ✅ posterior.branch_logits.grad norm = 1.21e-02
# ✅ posterior.branch_logits.grad norm = 1.03e-02
# ✅ posterior.branch_logits.grad norm = 8.52e-03
# ✅ posterior.branch_logits.grad norm = 5.67e-03
# ✅ posterior.branch_logits.grad norm = 1.15e-02
# ✅ posterior.branch_logits.grad norm = 8.58e-03
# ✅ posterior.branch_logits.grad norm = 1.20e-02
#
# [Epoch 5] | Phase: emission
#   ELBO:         8.9293e+04
#   NLL:          8.9265e+04
#   KL(t):        8.9873e-02
#   KL(p):        8.1172e-10
#   t_cont:       3.4027e-01
#   Transition:   -1.2561e+01
#   L1:           2.0635e+01
#   Emission MSE: 1.5756e-03
#   Entropy:      5.5415e+00
# ✅ posterior.branch_logits.grad norm = 5.88e-03
# ✅ posterior.branch_logits.grad norm = 1.66e-02
# ✅ posterior.branch_logits.grad norm = 6.94e-03
# ✅ posterior.branch_logits.grad norm = 1.17e-02
# ✅ posterior.branch_logits.grad norm = 1.02e-02
# ✅ posterior.branch_logits.grad norm = 9.87e-03
# ✅ posterior.branch_logits.grad norm = 7.90e-03
# ✅ posterior.branch_logits.grad norm = 6.83e-03
# ✅ posterior.branch_logits.grad norm = 1.24e-02
# ✅ posterior.branch_logits.grad norm = 7.09e-03
# ✅ posterior.branch_logits.grad norm = 8.43e-03
#
# [Epoch 6] | Phase: emission
#   ELBO:         8.0985e+04
#   NLL:          8.0957e+04
#   KL(t):        1.0897e-01
#   KL(p):        7.5516e-10
#   t_cont:       3.3497e-01
#   Transition:   -1.2557e+01
#   L1:           2.0341e+01
#   Emission MSE: 1.6356e-03
#   Entropy:      5.5416e+00
# ✅ posterior.branch_logits.grad norm = 6.95e-03
# ✅ posterior.branch_logits.grad norm = 2.37e-02
# ✅ posterior.branch_logits.grad norm = 9.22e-03
# ✅ posterior.branch_logits.grad norm = 1.34e-02
# ✅ posterior.branch_logits.grad norm = 1.94e-02
# ✅ posterior.branch_logits.grad norm = 1.83e-02
# ✅ posterior.branch_logits.grad norm = 1.08e-02
# ✅ posterior.branch_logits.grad norm = 8.79e-03
# ✅ posterior.branch_logits.grad norm = 1.35e-02
# ✅ posterior.branch_logits.grad norm = 8.56e-03
# ✅ posterior.branch_logits.grad norm = 1.05e-02
#
# [Epoch 7] | Phase: emission
#   ELBO:         8.0298e+04
#   NLL:          8.0271e+04
#   KL(t):        7.9016e-02
#   KL(p):        7.7498e-10
#   t_cont:       3.3572e-01
#   Transition:   -1.2594e+01
#   L1:           1.9429e+01
#   Emission MSE: 1.5093e-03
#   Entropy:      5.5417e+00
# ✅ posterior.branch_logits.grad norm = 7.09e-03
# ✅ posterior.branch_logits.grad norm = 1.59e-02
# ✅ posterior.branch_logits.grad norm = 8.78e-03
# ✅ posterior.branch_logits.grad norm = 1.05e-02
# ✅ posterior.branch_logits.grad norm = 1.04e-02
# ✅ posterior.branch_logits.grad norm = 1.15e-02
# ✅ posterior.branch_logits.grad norm = 8.24e-03
# ✅ posterior.branch_logits.grad norm = 6.07e-03
# ✅ posterior.branch_logits.grad norm = 1.03e-02
# ✅ posterior.branch_logits.grad norm = 9.78e-03
# ✅ posterior.branch_logits.grad norm = 1.17e-02
#
# [Epoch 8] | Phase: emission
#   ELBO:         7.6646e+04
#   NLL:          7.6621e+04
#   KL(t):        1.0402e-01
#   KL(p):        8.4972e-10
#   t_cont:       3.3439e-01
#   Transition:   -1.2547e+01
#   L1:           1.8159e+01
#   Emission MSE: 1.2644e-03
#   Entropy:      5.5417e+00
# ✅ posterior.branch_logits.grad norm = 5.17e-03
# ✅ posterior.branch_logits.grad norm = 1.80e-02
# ✅ posterior.branch_logits.grad norm = 1.01e-02
# ✅ posterior.branch_logits.grad norm = 7.97e-03
# ✅ posterior.branch_logits.grad norm = 1.14e-02
# ✅ posterior.branch_logits.grad norm = 1.68e-02
# ✅ posterior.branch_logits.grad norm = 8.28e-03
# ✅ posterior.branch_logits.grad norm = 1.11e-02
# ✅ posterior.branch_logits.grad norm = 8.90e-03
# ✅ posterior.branch_logits.grad norm = 7.57e-03
# ✅ posterior.branch_logits.grad norm = 1.25e-02
#
# [Epoch 9] | Phase: emission
#   ELBO:         7.6069e+04
#   NLL:          7.6044e+04
#   KL(t):        1.1462e-01
#   KL(p):        8.2827e-10
#   t_cont:       3.2527e-01
#   Transition:   -1.2525e+01
#   L1:           1.6998e+01
#   Emission MSE: 1.0431e-03
#   Entropy:      5.5416e+00
# --- Switching to posterior phase ---
# ✅ posterior.branch_logits.grad norm = 1.03e-02
# ✅ posterior.branch_logits.grad norm = 1.60e-02
# ✅ posterior.branch_logits.grad norm = 1.39e-02
# ✅ posterior.branch_logits.grad norm = 7.90e-03
# ✅ posterior.branch_logits.grad norm = 1.19e-02
# ✅ posterior.branch_logits.grad norm = 1.48e-02
# ✅ posterior.branch_logits.grad norm = 9.37e-03
# ✅ posterior.branch_logits.grad norm = 8.63e-03
# ✅ posterior.branch_logits.grad norm = 8.36e-03
# ✅ posterior.branch_logits.grad norm = 1.02e-02
# ✅ posterior.branch_logits.grad norm = 1.58e-02
#
# [Epoch 10] | Phase: posterior
#   ELBO:         7.6222e+04
#   NLL:          7.6199e+04
#   KL(t):        1.0112e-01
#   KL(p):        7.5122e-10
#   t_cont:       3.3135e-01
#   Transition:   -1.2570e+01
#   L1:           1.5180e+01
#   Emission MSE: 9.4457e-04
#   Entropy:      5.5416e+00
# ✅ posterior.branch_logits.grad norm = 9.24e-03
# ✅ posterior.branch_logits.grad norm = 1.43e-02
# ✅ posterior.branch_logits.grad norm = 1.00e-02
# ✅ posterior.branch_logits.grad norm = 6.55e-03
# ✅ posterior.branch_logits.grad norm = 9.17e-03
# ✅ posterior.branch_logits.grad norm = 9.13e-03
# ✅ posterior.branch_logits.grad norm = 1.30e-02
# ✅ posterior.branch_logits.grad norm = 9.38e-03
# ✅ posterior.branch_logits.grad norm = 7.20e-03
# ✅ posterior.branch_logits.grad norm = 1.47e-02
# ✅ posterior.branch_logits.grad norm = 9.45e-03
#
# [Epoch 11] | Phase: posterior
#   ELBO:         7.5327e+04
#   NLL:          7.5305e+04
#   KL(t):        9.5986e-02
#   KL(p):        3.4961e-09
#   t_cont:       3.3337e-01
#   Transition:   -1.2556e+01
#   L1:           1.5180e+01
#   Emission MSE: 9.4457e-04
#   Entropy:      5.5416e+00
# ✅ posterior.branch_logits.grad norm = 4.95e-03
# ✅ posterior.branch_logits.grad norm = 1.50e-02
# ✅ posterior.branch_logits.grad norm = 6.96e-03
# ✅ posterior.branch_logits.grad norm = 7.78e-03
# ✅ posterior.branch_logits.grad norm = 1.73e-02
# ✅ posterior.branch_logits.grad norm = 8.80e-03
# ✅ posterior.branch_logits.grad norm = 7.92e-03
# ✅ posterior.branch_logits.grad norm = 7.21e-03
# ✅ posterior.branch_logits.grad norm = 1.31e-02
# ✅ posterior.branch_logits.grad norm = 1.28e-02
# ✅ posterior.branch_logits.grad norm = 6.86e-03
#
# [Epoch 12] | Phase: posterior
#   ELBO:         7.6480e+04
#   NLL:          7.6458e+04
#   KL(t):        7.9998e-02
#   KL(p):        3.4273e-09
#   t_cont:       3.3546e-01
#   Transition:   -1.2484e+01
#   L1:           1.5180e+01
#   Emission MSE: 9.4457e-04
#   Entropy:      5.5415e+00
# ✅ posterior.branch_logits.grad norm = 5.73e-03
# ✅ posterior.branch_logits.grad norm = 1.66e-02
# ✅ posterior.branch_logits.grad norm = 1.49e-02
# ✅ posterior.branch_logits.grad norm = 6.51e-03
# ✅ posterior.branch_logits.grad norm = 1.19e-02
# ✅ posterior.branch_logits.grad norm = 1.26e-02
# ✅ posterior.branch_logits.grad norm = 1.08e-02
# ✅ posterior.branch_logits.grad norm = 5.34e-03
# ✅ posterior.branch_logits.grad norm = 1.37e-02
# ✅ posterior.branch_logits.grad norm = 7.96e-03
# ✅ posterior.branch_logits.grad norm = 1.06e-02
#
# [Epoch 13] | Phase: posterior
#   ELBO:         7.5981e+04
#   NLL:          7.5958e+04
#   KL(t):        9.4503e-02
#   KL(p):        2.8393e-09
#   t_cont:       3.3449e-01
#   Transition:   -1.2632e+01
#   L1:           1.5180e+01
#   Emission MSE: 9.4457e-04
#   Entropy:      5.5414e+00
# ✅ posterior.branch_logits.grad norm = 1.10e-02
# ✅ posterior.branch_logits.grad norm = 1.75e-02
# ✅ posterior.branch_logits.grad norm = 8.64e-03
# ✅ posterior.branch_logits.grad norm = 6.43e-03
# ✅ posterior.branch_logits.grad norm = 1.19e-02
# ✅ posterior.branch_logits.grad norm = 1.06e-02
# ✅ posterior.branch_logits.grad norm = 5.70e-03
# ✅ posterior.branch_logits.grad norm = 9.62e-03
# ✅ posterior.branch_logits.grad norm = 9.62e-03
# ✅ posterior.branch_logits.grad norm = 8.97e-03
# ✅ posterior.branch_logits.grad norm = 1.00e-02
#
# [Epoch 14] | Phase: posterior
#   ELBO:         7.6091e+04
#   NLL:          7.6068e+04
#   KL(t):        8.3531e-02
#   KL(p):        2.7036e-09
#   t_cont:       3.3559e-01
#   Transition:   -1.2494e+01
#   L1:           1.5180e+01
#   Emission MSE: 9.4457e-04
#   Entropy:      5.5412e+00
# ✅ posterior.branch_logits.grad norm = 9.44e-03
# ✅ posterior.branch_logits.grad norm = 1.59e-02
# ✅ posterior.branch_logits.grad norm = 8.84e-03
# ✅ posterior.branch_logits.grad norm = 8.71e-03
# ✅ posterior.branch_logits.grad norm = 1.21e-02
# ✅ posterior.branch_logits.grad norm = 1.05e-02
# ✅ posterior.branch_logits.grad norm = 6.30e-03
# ✅ posterior.branch_logits.grad norm = 1.29e-02
# ✅ posterior.branch_logits.grad norm = 6.64e-03
# ✅ posterior.branch_logits.grad norm = 1.03e-02
# ✅ posterior.branch_logits.grad norm = 9.86e-03
#
# [Epoch 15] | Phase: posterior
#   ELBO:         7.9274e+04
#   NLL:          7.9251e+04
#   KL(t):        1.0351e-01
#   KL(p):        5.5289e-09
#   t_cont:       3.3578e-01
#   Transition:   -1.2618e+01
#   L1:           1.5180e+01
#   Emission MSE: 9.4457e-04
#   Entropy:      5.5419e+00
# ✅ posterior.branch_logits.grad norm = 6.27e-03
# ✅ posterior.branch_logits.grad norm = 1.59e-02
# ✅ posterior.branch_logits.grad norm = 9.31e-03
# ✅ posterior.branch_logits.grad norm = 7.23e-03
# ✅ posterior.branch_logits.grad norm = 1.12e-02
# ✅ posterior.branch_logits.grad norm = 1.49e-02
# ✅ posterior.branch_logits.grad norm = 1.61e-02
# ✅ posterior.branch_logits.grad norm = 2.67e-03
# ✅ posterior.branch_logits.grad norm = 8.06e-03
# ✅ posterior.branch_logits.grad norm = 9.82e-03
# ✅ posterior.branch_logits.grad norm = 1.23e-02
#
# [Epoch 16] | Phase: posterior
#   ELBO:         7.6267e+04
#   NLL:          7.6244e+04
#   KL(t):        7.5512e-02
#   KL(p):        3.3851e-09
#   t_cont:       3.3159e-01
#   Transition:   -1.2530e+01
#   L1:           1.5180e+01
#   Emission MSE: 9.4457e-04
#   Entropy:      5.5416e+00
# --- Switching to emission phase ---
# ✅ posterior.branch_logits.grad norm = 8.15e-03
# ✅ posterior.branch_logits.grad norm = 1.40e-02
# ✅ posterior.branch_logits.grad norm = 9.75e-03
# ✅ posterior.branch_logits.grad norm = 5.54e-03
# ✅ posterior.branch_logits.grad norm = 1.06e-02
# ✅ posterior.branch_logits.grad norm = 8.65e-03
# ✅ posterior.branch_logits.grad norm = 1.40e-02
# ✅ posterior.branch_logits.grad norm = 8.05e-03
# ✅ posterior.branch_logits.grad norm = 6.80e-03
# ✅ posterior.branch_logits.grad norm = 7.13e-03
# ✅ posterior.branch_logits.grad norm = 7.94e-03
#
# [Epoch 17] | Phase: emission
#   ELBO:         7.5104e+04
#   NLL:          7.5081e+04
#   KL(t):        8.2187e-02
#   KL(p):        3.2029e-09
#   t_cont:       3.3930e-01
#   Transition:   -1.2468e+01
#   L1:           1.6157e+01
#   Emission MSE: 9.0373e-04
#   Entropy:      5.5412e+00
# ✅ posterior.branch_logits.grad norm = 1.31e-02
# ✅ posterior.branch_logits.grad norm = 1.38e-02
# ✅ posterior.branch_logits.grad norm = 1.42e-02
# ✅ posterior.branch_logits.grad norm = 1.05e-02
# ✅ posterior.branch_logits.grad norm = 1.66e-02
# ✅ posterior.branch_logits.grad norm = 1.04e-02
# ✅ posterior.branch_logits.grad norm = 7.06e-03
# ✅ posterior.branch_logits.grad norm = 4.16e-03
# ✅ posterior.branch_logits.grad norm = 1.45e-02
# ✅ posterior.branch_logits.grad norm = 7.93e-03
# ✅ posterior.branch_logits.grad norm = 8.23e-03
#
# [Epoch 18] | Phase: emission
#   ELBO:         7.6889e+04
#   NLL:          7.6866e+04
#   KL(t):        8.1779e-02
#   KL(p):        3.1798e-09
#   t_cont:       3.3652e-01
#   Transition:   -1.2642e+01
#   L1:           1.5598e+01
#   Emission MSE: 8.2756e-04
#   Entropy:      5.5414e+00
# ✅ posterior.branch_logits.grad norm = 7.13e-03
# ✅ posterior.branch_logits.grad norm = 1.73e-02
# ✅ posterior.branch_logits.grad norm = 1.09e-02
# ✅ posterior.branch_logits.grad norm = 8.67e-03
# ✅ posterior.branch_logits.grad norm = 1.28e-02
# ✅ posterior.branch_logits.grad norm = 1.03e-02
# ✅ posterior.branch_logits.grad norm = 1.28e-02
# ✅ posterior.branch_logits.grad norm = 2.78e-03
# ✅ posterior.branch_logits.grad norm = 9.59e-03
# ✅ posterior.branch_logits.grad norm = 1.05e-02
# ✅ posterior.branch_logits.grad norm = 7.62e-03
#
# [Epoch 19] | Phase: emission
#   ELBO:         7.5368e+04
#   NLL:          7.5345e+04
#   KL(t):        8.5759e-02
#   KL(p):        3.0129e-09
#   t_cont:       3.3059e-01
#   Transition:   -1.2557e+01
#   L1:           1.5380e+01
#   Emission MSE: 7.9122e-04
#   Entropy:      5.5414e+00
# ✅ posterior.branch_logits.grad norm = 1.75e-02
# ✅ posterior.branch_logits.grad norm = 1.58e-02
# ✅ posterior.branch_logits.grad norm = 7.27e-03
# ✅ posterior.branch_logits.grad norm = 7.72e-03
# ✅ posterior.branch_logits.grad norm = 1.47e-02
# ✅ posterior.branch_logits.grad norm = 1.50e-02
# ✅ posterior.branch_logits.grad norm = 6.30e-03
# ✅ posterior.branch_logits.grad norm = 7.64e-03
# ✅ posterior.branch_logits.grad norm = 1.32e-02
# ✅ posterior.branch_logits.grad norm = 8.10e-03
# ✅ posterior.branch_logits.grad norm = 1.50e-02
#
# [Epoch 20] | Phase: emission
#   ELBO:         7.8388e+04
#   NLL:          7.8365e+04
#   KL(t):        8.3013e-02
#   KL(p):        2.9163e-09
#   t_cont:       3.3373e-01
#   Transition:   -1.2611e+01
#   L1:           1.5247e+01
#   Emission MSE: 7.6804e-04
#   Entropy:      5.5413e+00
# ✅ posterior.branch_logits.grad norm = 1.07e-02
# ✅ posterior.branch_logits.grad norm = 1.50e-02
# ✅ posterior.branch_logits.grad norm = 1.18e-02
# ✅ posterior.branch_logits.grad norm = 5.26e-03
# ✅ posterior.branch_logits.grad norm = 1.40e-02
# ✅ posterior.branch_logits.grad norm = 1.02e-02
# ✅ posterior.branch_logits.grad norm = 1.19e-02
# ✅ posterior.branch_logits.grad norm = 1.32e-02
# ✅ posterior.branch_logits.grad norm = 6.74e-03
# ✅ posterior.branch_logits.grad norm = 1.37e-02
# ✅ posterior.branch_logits.grad norm = 9.64e-03
#
# [Epoch 21] | Phase: emission
#   ELBO:         7.5724e+04
#   NLL:          7.5702e+04
#   KL(t):        8.0705e-02
#   KL(p):        3.2937e-09
#   t_cont:       3.3019e-01
#   Transition:   -1.2535e+01
#   L1:           1.4864e+01
#   Emission MSE: 7.2670e-04
#   Entropy:      5.5416e+00
# ✅ posterior.branch_logits.grad norm = 4.16e-03
# ✅ posterior.branch_logits.grad norm = 2.09e-02
# ✅ posterior.branch_logits.grad norm = 1.20e-02
# ✅ posterior.branch_logits.grad norm = 8.18e-03
# ✅ posterior.branch_logits.grad norm = 1.31e-02
# ✅ posterior.branch_logits.grad norm = 1.45e-02
# ✅ posterior.branch_logits.grad norm = 1.38e-02
# ✅ posterior.branch_logits.grad norm = 7.70e-03
# ✅ posterior.branch_logits.grad norm = 6.48e-03
# ✅ posterior.branch_logits.grad norm = 1.11e-02
# ✅ posterior.branch_logits.grad norm = 1.05e-02
#
# [Epoch 22] | Phase: emission
#   ELBO:         7.5394e+04
#   NLL:          7.5372e+04
#   KL(t):        8.0391e-02
#   KL(p):        3.0589e-09
#   t_cont:       3.3413e-01
#   Transition:   -1.2644e+01
#   L1:           1.4633e+01
#   Emission MSE: 7.0209e-04
#   Entropy:      5.5415e+00
# --- Switching to posterior phase ---
# ✅ posterior.branch_logits.grad norm = 1.22e-02
# ✅ posterior.branch_logits.grad norm = 1.57e-02
# ✅ posterior.branch_logits.grad norm = 1.31e-02
# ✅ posterior.branch_logits.grad norm = 9.72e-03
# ✅ posterior.branch_logits.grad norm = 1.12e-02
# ✅ posterior.branch_logits.grad norm = 9.95e-03
# ✅ posterior.branch_logits.grad norm = 1.27e-02
# ✅ posterior.branch_logits.grad norm = 4.71e-03
# ✅ posterior.branch_logits.grad norm = 7.89e-03
# ✅ posterior.branch_logits.grad norm = 1.75e-02
# ✅ posterior.branch_logits.grad norm = 1.17e-02
#
# [Epoch 23] | Phase: posterior
#   ELBO:         7.5187e+04
#   NLL:          7.5166e+04
#   KL(t):        7.7346e-02
#   KL(p):        3.0998e-09
#   t_cont:       3.3369e-01
#   Transition:   -1.2503e+01
#   L1:           1.3254e+01
#   Emission MSE: 6.9332e-04
#   Entropy:      5.5416e+00
# ✅ posterior.branch_logits.grad norm = 6.14e-03
# ✅ posterior.branch_logits.grad norm = 1.53e-02
# ✅ posterior.branch_logits.grad norm = 1.25e-02
# ✅ posterior.branch_logits.grad norm = 6.07e-03
# ✅ posterior.branch_logits.grad norm = 1.46e-02
# ✅ posterior.branch_logits.grad norm = 1.41e-02
# ✅ posterior.branch_logits.grad norm = 8.62e-03
# ✅ posterior.branch_logits.grad norm = 4.74e-03
# ✅ posterior.branch_logits.grad norm = 9.44e-03
# ✅ posterior.branch_logits.grad norm = 8.39e-03
# ✅ posterior.branch_logits.grad norm = 7.36e-03
#
# [Epoch 24] | Phase: posterior
#   ELBO:         7.4583e+04
#   NLL:          7.4562e+04
#   KL(t):        9.0254e-02
#   KL(p):        1.8957e-09
#   t_cont:       3.3807e-01
#   Transition:   -1.2516e+01
#   L1:           1.3254e+01
#   Emission MSE: 6.9332e-04
#   Entropy:      5.5416e+00
# ✅ posterior.branch_logits.grad norm = 1.60e-02
# ✅ posterior.branch_logits.grad norm = 2.09e-02
# ✅ posterior.branch_logits.grad norm = 1.80e-02
# ✅ posterior.branch_logits.grad norm = 6.11e-03
# ✅ posterior.branch_logits.grad norm = 1.31e-02
# ✅ posterior.branch_logits.grad norm = 1.12e-02
# ✅ posterior.branch_logits.grad norm = 9.22e-03
# ✅ posterior.branch_logits.grad norm = 5.17e-03
# ✅ posterior.branch_logits.grad norm = 8.01e-03
# ✅ posterior.branch_logits.grad norm = 6.93e-03
# ✅ posterior.branch_logits.grad norm = 1.53e-02
#
# [Epoch 25] | Phase: posterior
#   ELBO:         7.4790e+04
#   NLL:          7.4770e+04
#   KL(t):        7.9314e-02
#   KL(p):        3.7184e-09
#   t_cont:       3.3104e-01
#   Transition:   -1.2473e+01
#   L1:           1.3254e+01
#   Emission MSE: 6.9332e-04
#   Entropy:      5.5414e+00
# ✅ posterior.branch_logits.grad norm = 9.31e-03
# ✅ posterior.branch_logits.grad norm = 1.22e-02
# ✅ posterior.branch_logits.grad norm = 1.87e-02
# ✅ posterior.branch_logits.grad norm = 1.24e-02
# ✅ posterior.branch_logits.grad norm = 9.40e-03
# ✅ posterior.branch_logits.grad norm = 1.02e-02
# ✅ posterior.branch_logits.grad norm = 1.26e-02
# ✅ posterior.branch_logits.grad norm = 5.14e-03
# ✅ posterior.branch_logits.grad norm = 1.32e-02
# ✅ posterior.branch_logits.grad norm = 7.56e-03
# ✅ posterior.branch_logits.grad norm = 7.38e-03
#
# [Epoch 26] | Phase: posterior
#   ELBO:         7.6088e+04
#   NLL:          7.6067e+04
#   KL(t):        7.3883e-02
#   KL(p):        2.9863e-09
#   t_cont:       3.3578e-01
#   Transition:   -1.2521e+01
#   L1:           1.3254e+01
#   Emission MSE: 6.9332e-04
#   Entropy:      5.5417e+00
# ✅ posterior.branch_logits.grad norm = 4.59e-03
# ✅ posterior.branch_logits.grad norm = 2.06e-02
# ✅ posterior.branch_logits.grad norm = 5.05e-03
# ✅ posterior.branch_logits.grad norm = 8.91e-03
# ✅ posterior.branch_logits.grad norm = 1.30e-02
# ✅ posterior.branch_logits.grad norm = 1.40e-02
# ✅ posterior.branch_logits.grad norm = 1.30e-02
# ✅ posterior.branch_logits.grad norm = 7.88e-03
# ✅ posterior.branch_logits.grad norm = 8.48e-03
# ✅ posterior.branch_logits.grad norm = 8.27e-03
# ✅ posterior.branch_logits.grad norm = 5.70e-03
#
# [Epoch 27] | Phase: posterior
#   ELBO:         7.4843e+04
#   NLL:          7.4822e+04
#   KL(t):        8.1884e-02
#   KL(p):        4.5929e-09
#   t_cont:       3.3256e-01
#   Transition:   -1.2595e+01
#   L1:           1.3254e+01
#   Emission MSE: 6.9332e-04
#   Entropy:      5.5418e+00
# ✅ posterior.branch_logits.grad norm = 1.11e-02
# ✅ posterior.branch_logits.grad norm = 1.64e-02
# ✅ posterior.branch_logits.grad norm = 6.53e-03
# ✅ posterior.branch_logits.grad norm = 1.70e-02
# ✅ posterior.branch_logits.grad norm = 1.78e-02
# ✅ posterior.branch_logits.grad norm = 9.60e-03
# ✅ posterior.branch_logits.grad norm = 5.84e-03
# ✅ posterior.branch_logits.grad norm = 8.71e-03
# ✅ posterior.branch_logits.grad norm = 1.17e-02
# ✅ posterior.branch_logits.grad norm = 2.15e-02
# ✅ posterior.branch_logits.grad norm = 1.15e-02
#
# [Epoch 28] | Phase: posterior
#   ELBO:         7.4982e+04
#   NLL:          7.4962e+04
#   KL(t):        8.4071e-02
#   KL(p):        2.2861e-09
#   t_cont:       3.2913e-01
#   Transition:   -1.2594e+01
#   L1:           1.3254e+01
#   Emission MSE: 6.9332e-04
#   Entropy:      5.5414e+00
# ✅ posterior.branch_logits.grad norm = 7.88e-03
# ✅ posterior.branch_logits.grad norm = 1.86e-02
# ✅ posterior.branch_logits.grad norm = 6.13e-03
# ✅ posterior.branch_logits.grad norm = 6.68e-03
# ✅ posterior.branch_logits.grad norm = 1.24e-02
# ✅ posterior.branch_logits.grad norm = 9.19e-03
# ✅ posterior.branch_logits.grad norm = 8.81e-03
# ✅ posterior.branch_logits.grad norm = 5.33e-03
# ✅ posterior.branch_logits.grad norm = 7.99e-03
# ✅ posterior.branch_logits.grad norm = 1.33e-02
# ✅ posterior.branch_logits.grad norm = 1.21e-02
#
# [Epoch 29] | Phase: posterior
#   ELBO:         7.5686e+04
#   NLL:          7.5665e+04
#   KL(t):        7.9684e-02
#   KL(p):        2.4502e-09
#   t_cont:       3.3171e-01
#   Transition:   -1.2439e+01
#   L1:           1.3254e+01
#   Emission MSE: 6.9332e-04
#   Entropy:      5.5414e+00
# --- Switching to emission phase ---
# ✅ posterior.branch_logits.grad norm = 6.19e-03
# ✅ posterior.branch_logits.grad norm = 1.60e-02
# ✅ posterior.branch_logits.grad norm = 1.06e-02
# ✅ posterior.branch_logits.grad norm = 1.32e-02
# ✅ posterior.branch_logits.grad norm = 1.18e-02
# ✅ posterior.branch_logits.grad norm = 1.12e-02
# ✅ posterior.branch_logits.grad norm = 7.03e-03
# ✅ posterior.branch_logits.grad norm = 5.57e-03
# ✅ posterior.branch_logits.grad norm = 8.08e-03
# ✅ posterior.branch_logits.grad norm = 8.11e-03
# ✅ posterior.branch_logits.grad norm = 1.28e-02
#
# [Epoch 30] | Phase: emission
#   ELBO:         7.6081e+04
#   NLL:          7.6059e+04
#   KL(t):        7.8559e-02
#   KL(p):        4.1164e-09
#   t_cont:       3.2769e-01
#   Transition:   -1.2524e+01
#   L1:           1.4807e+01
#   Emission MSE: 7.2434e-04
#   Entropy:      5.5416e+00
# ✅ posterior.branch_logits.grad norm = 1.25e-02
# ✅ posterior.branch_logits.grad norm = 1.54e-02
# ✅ posterior.branch_logits.grad norm = 8.98e-03
# ✅ posterior.branch_logits.grad norm = 1.63e-02
# ✅ posterior.branch_logits.grad norm = 1.20e-02
# ✅ posterior.branch_logits.grad norm = 1.21e-02
# ✅ posterior.branch_logits.grad norm = 1.10e-02
# ✅ posterior.branch_logits.grad norm = 3.47e-03
# ✅ posterior.branch_logits.grad norm = 7.95e-03
# ✅ posterior.branch_logits.grad norm = 1.43e-02
# ✅ posterior.branch_logits.grad norm = 1.70e-02
#
# [Epoch 31] | Phase: emission
#   ELBO:         7.4338e+04
#   NLL:          7.4315e+04
#   KL(t):        7.8955e-02
#   KL(p):        3.9583e-09
#   t_cont:       3.3694e-01
#   Transition:   -1.2560e+01
#   L1:           1.4988e+01
#   Emission MSE: 7.6513e-04
#   Entropy:      5.5413e+00
# ✅ posterior.branch_logits.grad norm = 1.00e-02
# ✅ posterior.branch_logits.grad norm = 1.39e-02
# ✅ posterior.branch_logits.grad norm = 1.32e-02
# ✅ posterior.branch_logits.grad norm = 1.10e-02
# ✅ posterior.branch_logits.grad norm = 1.24e-02
# ✅ posterior.branch_logits.grad norm = 1.45e-02
# ✅ posterior.branch_logits.grad norm = 8.16e-03
# ✅ posterior.branch_logits.grad norm = 6.98e-03
# ✅ posterior.branch_logits.grad norm = 8.83e-03
# ✅ posterior.branch_logits.grad norm = 8.18e-03
# ✅ posterior.branch_logits.grad norm = 1.26e-02
#
# [Epoch 32] | Phase: emission
#   ELBO:         7.7395e+04
#   NLL:          7.7372e+04
#   KL(t):        8.1280e-02
#   KL(p):        4.1794e-09
#   t_cont:       3.3422e-01
#   Transition:   -1.2542e+01
#   L1:           1.5200e+01
#   Emission MSE: 8.0406e-04
#   Entropy:      5.5412e+00
# ✅ posterior.branch_logits.grad norm = 1.60e-02
# ✅ posterior.branch_logits.grad norm = 1.49e-02
# ✅ posterior.branch_logits.grad norm = 7.70e-03
# ✅ posterior.branch_logits.grad norm = 7.80e-03
# ✅ posterior.branch_logits.grad norm = 1.44e-02
# ✅ posterior.branch_logits.grad norm = 1.07e-02
# ✅ posterior.branch_logits.grad norm = 4.87e-03
# ✅ posterior.branch_logits.grad norm = 6.85e-03
# ✅ posterior.branch_logits.grad norm = 7.58e-03
# ✅ posterior.branch_logits.grad norm = 1.51e-02
# ✅ posterior.branch_logits.grad norm = 7.29e-03
#
# [Epoch 33] | Phase: emission
#   ELBO:         7.2928e+04
#   NLL:          7.2905e+04
#   KL(t):        7.7487e-02
#   KL(p):        3.9624e-09
#   t_cont:       3.3218e-01
#   Transition:   -1.2617e+01
#   L1:           1.5529e+01
#   Emission MSE: 8.5303e-04
#   Entropy:      5.5416e+00
# ✅ posterior.branch_logits.grad norm = 6.32e-03
# ✅ posterior.branch_logits.grad norm = 2.13e-02
# ✅ posterior.branch_logits.grad norm = 7.67e-03
# ✅ posterior.branch_logits.grad norm = 7.06e-03
# ✅ posterior.branch_logits.grad norm = 1.38e-02
# ✅ posterior.branch_logits.grad norm = 1.02e-02
# ✅ posterior.branch_logits.grad norm = 1.09e-02
# ✅ posterior.branch_logits.grad norm = 6.94e-03
# ✅ posterior.branch_logits.grad norm = 6.44e-03
# ✅ posterior.branch_logits.grad norm = 9.35e-03
# ✅ posterior.branch_logits.grad norm = 8.35e-03
#
# [Epoch 34] | Phase: emission
#   ELBO:         7.5949e+04
#   NLL:          7.5926e+04
#   KL(t):        7.9606e-02
#   KL(p):        4.0256e-09
#   t_cont:       3.2346e-01
#   Transition:   -1.2486e+01
#   L1:           1.5769e+01
#   Emission MSE: 9.0530e-04
#   Entropy:      5.5415e+00
# ✅ posterior.branch_logits.grad norm = 6.59e-03
# ✅ posterior.branch_logits.grad norm = 1.79e-02
# ✅ posterior.branch_logits.grad norm = 8.71e-03
# ✅ posterior.branch_logits.grad norm = 8.28e-03
# ✅ posterior.branch_logits.grad norm = 1.28e-02
# ✅ posterior.branch_logits.grad norm = 1.01e-02
# ✅ posterior.branch_logits.grad norm = 6.35e-03
# ✅ posterior.branch_logits.grad norm = 5.45e-03
# ✅ posterior.branch_logits.grad norm = 1.05e-02
# ✅ posterior.branch_logits.grad norm = 1.07e-02
# ✅ posterior.branch_logits.grad norm = 7.07e-03
#
# [Epoch 35] | Phase: emission
#   ELBO:         7.5040e+04
#   NLL:          7.5016e+04
#   KL(t):        8.3499e-02
#   KL(p):        3.8744e-09
#   t_cont:       3.3711e-01
#   Transition:   -1.2482e+01
#   L1:           1.6202e+01
#   Emission MSE: 9.8979e-04
#   Entropy:      5.5413e+00
# ✅ posterior.branch_logits.grad norm = 4.80e-03
# ✅ posterior.branch_logits.grad norm = 1.63e-02
# ✅ posterior.branch_logits.grad norm = 9.79e-03
# ✅ posterior.branch_logits.grad norm = 1.25e-02
# ✅ posterior.branch_logits.grad norm = 1.19e-02
# ✅ posterior.branch_logits.grad norm = 1.49e-02
# ✅ posterior.branch_logits.grad norm = 1.39e-02
# ✅ posterior.branch_logits.grad norm = 5.07e-03
# ✅ posterior.branch_logits.grad norm = 8.57e-03
# ✅ posterior.branch_logits.grad norm = 8.36e-03
# ✅ posterior.branch_logits.grad norm = 2.18e-02
#
# [Epoch 36] | Phase: emission
#   ELBO:         7.5568e+04
#   NLL:          7.5544e+04
#   KL(t):        8.2154e-02
#   KL(p):        3.8625e-09
#   t_cont:       3.3441e-01
#   Transition:   -1.2540e+01
#   L1:           1.6353e+01
#   Emission MSE: 1.0380e-03
#   Entropy:      5.5412e+00
# ✅ posterior.branch_logits.grad norm = 7.59e-03
# ✅ posterior.branch_logits.grad norm = 1.57e-02
# ✅ posterior.branch_logits.grad norm = 1.25e-02
# ✅ posterior.branch_logits.grad norm = 1.52e-02
# ✅ posterior.branch_logits.grad norm = 1.73e-02
# ✅ posterior.branch_logits.grad norm = 1.22e-02
# ✅ posterior.branch_logits.grad norm = 5.60e-03
# ✅ posterior.branch_logits.grad norm = 8.02e-03
# ✅ posterior.branch_logits.grad norm = 9.10e-03
# ✅ posterior.branch_logits.grad norm = 1.41e-02
# ✅ posterior.branch_logits.grad norm = 1.52e-02
#
# [Epoch 37] | Phase: emission
#   ELBO:         7.4532e+04
#   NLL:          7.4508e+04
#   KL(t):        7.7286e-02
#   KL(p):        3.9295e-09
#   t_cont:       3.3326e-01
#   Transition:   -1.2537e+01
#   L1:           1.6584e+01
#   Emission MSE: 1.0665e-03
#   Entropy:      5.5415e+00
# ✅ posterior.branch_logits.grad norm = 1.03e-02
# ✅ posterior.branch_logits.grad norm = 2.07e-02
# ✅ posterior.branch_logits.grad norm = 1.59e-02
# ✅ posterior.branch_logits.grad norm = 6.45e-03
# ✅ posterior.branch_logits.grad norm = 1.38e-02
# ✅ posterior.branch_logits.grad norm = 1.47e-02
# ✅ posterior.branch_logits.grad norm = 1.16e-02
# ✅ posterior.branch_logits.grad norm = 4.98e-03
# ✅ posterior.branch_logits.grad norm = 1.03e-02
# ✅ posterior.branch_logits.grad norm = 1.14e-02
# ✅ posterior.branch_logits.grad norm = 7.52e-03
#
# [Epoch 38] | Phase: emission
#   ELBO:         7.6486e+04
#   NLL:          7.6462e+04
#   KL(t):        6.6805e-02
#   KL(p):        4.1544e-09
#   t_cont:       3.2890e-01
#   Transition:   -1.2617e+01
#   L1:           1.6871e+01
#   Emission MSE: 1.1214e-03
#   Entropy:      5.5418e+00
# --- Switching to posterior phase ---
# ✅ posterior.branch_logits.grad norm = 7.34e-03
# ✅ posterior.branch_logits.grad norm = 1.33e-02
# ✅ posterior.branch_logits.grad norm = 1.19e-02
# ✅ posterior.branch_logits.grad norm = 5.33e-03
# ✅ posterior.branch_logits.grad norm = 1.25e-02
# ✅ posterior.branch_logits.grad norm = 7.90e-03
# ✅ posterior.branch_logits.grad norm = 1.30e-02
# ✅ posterior.branch_logits.grad norm = 9.33e-03
# ✅ posterior.branch_logits.grad norm = 1.10e-02
# ✅ posterior.branch_logits.grad norm = 1.10e-02
# ✅ posterior.branch_logits.grad norm = 9.60e-03
#
# [Epoch 39] | Phase: posterior
#   ELBO:         7.6198e+04
#   NLL:          7.6174e+04
#   KL(t):        7.4861e-02
#   KL(p):        4.0451e-09
#   t_cont:       3.2721e-01
#   Transition:   -1.2679e+01
#   L1:           1.5718e+01
#   Emission MSE: 1.1382e-03
#   Entropy:      5.5417e+00
# ✅ posterior.branch_logits.grad norm = 5.17e-03
# ✅ posterior.branch_logits.grad norm = 2.05e-02
# ✅ posterior.branch_logits.grad norm = 1.04e-02
# ✅ posterior.branch_logits.grad norm = 8.12e-03
# ✅ posterior.branch_logits.grad norm = 1.20e-02
# ✅ posterior.branch_logits.grad norm = 1.69e-02
# ✅ posterior.branch_logits.grad norm = 2.23e-02
# ✅ posterior.branch_logits.grad norm = 1.51e-02
# ✅ posterior.branch_logits.grad norm = 1.30e-02
# ✅ posterior.branch_logits.grad norm = 9.75e-03
# ✅ posterior.branch_logits.grad norm = 1.52e-02
#
# [Epoch 40] | Phase: posterior
#   ELBO:         7.6295e+04
#   NLL:          7.6272e+04
#   KL(t):        7.8569e-02
#   KL(p):        1.6123e-09
#   t_cont:       3.3219e-01
#   Transition:   -1.2483e+01
#   L1:           1.5718e+01
#   Emission MSE: 1.1382e-03
#   Entropy:      5.5414e+00
# ✅ posterior.branch_logits.grad norm = 1.26e-02
# ✅ posterior.branch_logits.grad norm = 1.90e-02
# ✅ posterior.branch_logits.grad norm = 1.64e-02
# ✅ posterior.branch_logits.grad norm = 9.46e-03
# ✅ posterior.branch_logits.grad norm = 8.77e-03
# ✅ posterior.branch_logits.grad norm = 9.10e-03
# ✅ posterior.branch_logits.grad norm = 1.03e-02
# ✅ posterior.branch_logits.grad norm = 9.34e-03
# ✅ posterior.branch_logits.grad norm = 1.30e-02
# ✅ posterior.branch_logits.grad norm = 1.41e-02
# ✅ posterior.branch_logits.grad norm = 7.00e-03
#
# [Epoch 41] | Phase: posterior
#   ELBO:         7.4442e+04
#   NLL:          7.4419e+04
#   KL(t):        7.9448e-02
#   KL(p):        5.3183e-10
#   t_cont:       3.2585e-01
#   Transition:   -1.2494e+01
#   L1:           1.5718e+01
#   Emission MSE: 1.1382e-03
#   Entropy:      5.5416e+00
# ✅ posterior.branch_logits.grad norm = 4.55e-03
# ✅ posterior.branch_logits.grad norm = 2.04e-02
# ✅ posterior.branch_logits.grad norm = 1.40e-02
# ✅ posterior.branch_logits.grad norm = 8.76e-03
# ✅ posterior.branch_logits.grad norm = 1.31e-02
# ✅ posterior.branch_logits.grad norm = 1.51e-02
# ✅ posterior.branch_logits.grad norm = 1.52e-02
# ✅ posterior.branch_logits.grad norm = 2.68e-03
# ✅ posterior.branch_logits.grad norm = 7.04e-03
# ✅ posterior.branch_logits.grad norm = 1.42e-02
# ✅ posterior.branch_logits.grad norm = 1.26e-02
#
# [Epoch 42] | Phase: posterior
#   ELBO:         7.5141e+04
#   NLL:          7.5118e+04
#   KL(t):        7.9548e-02
#   KL(p):        1.1091e-09
#   t_cont:       3.3203e-01
#   Transition:   -1.2535e+01
#   L1:           1.5718e+01
#   Emission MSE: 1.1382e-03
#   Entropy:      5.5413e+00
# ✅ posterior.branch_logits.grad norm = 1.12e-02
# ✅ posterior.branch_logits.grad norm = 2.45e-02
# ✅ posterior.branch_logits.grad norm = 8.36e-03
# ✅ posterior.branch_logits.grad norm = 1.33e-02
# ✅ posterior.branch_logits.grad norm = 1.03e-02
# ✅ posterior.branch_logits.grad norm = 1.54e-02
# ✅ posterior.branch_logits.grad norm = 1.91e-02
# ✅ posterior.branch_logits.grad norm = 1.16e-02
# ✅ posterior.branch_logits.grad norm = 1.44e-02
# ✅ posterior.branch_logits.grad norm = 7.67e-03
# ✅ posterior.branch_logits.grad norm = 1.09e-02
#
# [Epoch 43] | Phase: posterior
#   ELBO:         7.3741e+04
#   NLL:          7.3718e+04
#   KL(t):        8.3519e-02
#   KL(p):        2.3222e-09
#   t_cont:       3.3106e-01
#   Transition:   -1.2419e+01
#   L1:           1.5718e+01
#   Emission MSE: 1.1382e-03
#   Entropy:      5.5413e+00
# ✅ posterior.branch_logits.grad norm = 7.16e-03
# ✅ posterior.branch_logits.grad norm = 1.75e-02
# ✅ posterior.branch_logits.grad norm = 8.79e-03
# ✅ posterior.branch_logits.grad norm = 1.63e-02
# ✅ posterior.branch_logits.grad norm = 1.20e-02
# ✅ posterior.branch_logits.grad norm = 9.98e-03
# ✅ posterior.branch_logits.grad norm = 6.96e-03
# ✅ posterior.branch_logits.grad norm = 6.69e-03
# ✅ posterior.branch_logits.grad norm = 6.24e-03
# ✅ posterior.branch_logits.grad norm = 8.99e-03
# ✅ posterior.branch_logits.grad norm = 6.58e-03
#
# [Epoch 44] | Phase: posterior
#   ELBO:         7.5133e+04
#   NLL:          7.5110e+04
#   KL(t):        8.7055e-02
#   KL(p):        3.0631e-09
#   t_cont:       3.3095e-01
#   Transition:   -1.2536e+01
#   L1:           1.5718e+01
#   Emission MSE: 1.1382e-03
#   Entropy:      5.5415e+00
# ✅ posterior.branch_logits.grad norm = 7.14e-03
# ✅ posterior.branch_logits.grad norm = 1.56e-02
# ✅ posterior.branch_logits.grad norm = 7.76e-03
# ✅ posterior.branch_logits.grad norm = 6.81e-03
# ✅ posterior.branch_logits.grad norm = 1.12e-02
# ✅ posterior.branch_logits.grad norm = 9.96e-03
# ✅ posterior.branch_logits.grad norm = 6.74e-03
# ✅ posterior.branch_logits.grad norm = 3.78e-03
# ✅ posterior.branch_logits.grad norm = 7.12e-03
# ✅ posterior.branch_logits.grad norm = 1.06e-02
# ✅ posterior.branch_logits.grad norm = 9.03e-03
#
# [Epoch 45] | Phase: posterior
#   ELBO:         7.5032e+04
#   NLL:          7.5009e+04
#   KL(t):        8.4842e-02
#   KL(p):        2.1955e-09
#   t_cont:       3.2824e-01
#   Transition:   -1.2513e+01
#   L1:           1.5718e+01
#   Emission MSE: 1.1382e-03
#   Entropy:      5.5417e+00
# ✅ posterior.branch_logits.grad norm = 6.48e-03
# ✅ posterior.branch_logits.grad norm = 1.75e-02
# ✅ posterior.branch_logits.grad norm = 1.17e-02
# ✅ posterior.branch_logits.grad norm = 1.38e-02
# ✅ posterior.branch_logits.grad norm = 1.55e-02
# ✅ posterior.branch_logits.grad norm = 1.41e-02
# ✅ posterior.branch_logits.grad norm = 5.20e-03
# ✅ posterior.branch_logits.grad norm = 4.45e-03
# ✅ posterior.branch_logits.grad norm = 6.75e-03
# ✅ posterior.branch_logits.grad norm = 8.51e-03
# ✅ posterior.branch_logits.grad norm = 1.40e-02
#
# [Epoch 46] | Phase: posterior
#   ELBO:         7.4117e+04
#   NLL:          7.4094e+04
#   KL(t):        7.5629e-02
#   KL(p):        5.4674e-10
#   t_cont:       3.2992e-01
#   Transition:   -1.2688e+01
#   L1:           1.5718e+01
#   Emission MSE: 1.1382e-03
#   Entropy:      5.5420e+00
# ✅ posterior.branch_logits.grad norm = 7.09e-03
# ✅ posterior.branch_logits.grad norm = 2.23e-02
# ✅ posterior.branch_logits.grad norm = 1.36e-02
# ✅ posterior.branch_logits.grad norm = 8.18e-03
# ✅ posterior.branch_logits.grad norm = 1.14e-02
# ✅ posterior.branch_logits.grad norm = 1.01e-02
# ✅ posterior.branch_logits.grad norm = 5.96e-03
# ✅ posterior.branch_logits.grad norm = 9.00e-03
# ✅ posterior.branch_logits.grad norm = 1.44e-02
# ✅ posterior.branch_logits.grad norm = 7.51e-03
# ✅ posterior.branch_logits.grad norm = 1.21e-02
#
# [Epoch 47] | Phase: posterior
#   ELBO:         7.3808e+04
#   NLL:          7.3785e+04
#   KL(t):        8.8822e-02
#   KL(p):        2.6080e-09
#   t_cont:       3.2573e-01
#   Transition:   -1.2627e+01
#   L1:           1.5718e+01
#   Emission MSE: 1.1382e-03
#   Entropy:      5.5417e+00
# ✅ posterior.branch_logits.grad norm = 1.22e-02
# ✅ posterior.branch_logits.grad norm = 1.82e-02
# ✅ posterior.branch_logits.grad norm = 1.57e-02
# ✅ posterior.branch_logits.grad norm = 7.63e-03
# ✅ posterior.branch_logits.grad norm = 1.41e-02
# ✅ posterior.branch_logits.grad norm = 9.68e-03
# ✅ posterior.branch_logits.grad norm = 1.20e-02
# ✅ posterior.branch_logits.grad norm = 4.56e-03
# ✅ posterior.branch_logits.grad norm = 5.74e-03
# ✅ posterior.branch_logits.grad norm = 9.96e-03
# ✅ posterior.branch_logits.grad norm = 9.21e-03
#
# [Epoch 48] | Phase: posterior
#   ELBO:         7.5113e+04
#   NLL:          7.5089e+04
#   KL(t):        8.4389e-02
#   KL(p):        5.0153e-09
#   t_cont:       3.2396e-01
#   Transition:   -1.2587e+01
#   L1:           1.5718e+01
#   Emission MSE: 1.1382e-03
#   Entropy:      5.5417e+00
# --- Switching to emission phase ---
# ✅ posterior.branch_logits.grad norm = 9.09e-03
# ✅ posterior.branch_logits.grad norm = 1.73e-02
# ✅ posterior.branch_logits.grad norm = 1.31e-02
# ✅ posterior.branch_logits.grad norm = 5.99e-03
# ✅ posterior.branch_logits.grad norm = 1.15e-02
# ✅ posterior.branch_logits.grad norm = 2.12e-02
# ✅ posterior.branch_logits.grad norm = 7.28e-03
# ✅ posterior.branch_logits.grad norm = 1.27e-02
# ✅ posterior.branch_logits.grad norm = 5.24e-03
# ✅ posterior.branch_logits.grad norm = 8.21e-03
# ✅ posterior.branch_logits.grad norm = 7.14e-03
#
# [Epoch 49] | Phase: emission
#   ELBO:         7.5933e+04
#   NLL:          7.5909e+04
#   KL(t):        8.4903e-02
#   KL(p):        1.8938e-09
#   t_cont:       3.2940e-01
#   Transition:   -1.2510e+01
#   L1:           1.7339e+01
#   Emission MSE: 1.2163e-03
#   Entropy:      5.5416e+00
# ✅ posterior.branch_logits.grad norm = 9.30e-03
# ✅ posterior.branch_logits.grad norm = 1.67e-02
# ✅ posterior.branch_logits.grad norm = 1.40e-02
# ✅ posterior.branch_logits.grad norm = 6.27e-03
# ✅ posterior.branch_logits.grad norm = 1.35e-02
# ✅ posterior.branch_logits.grad norm = 1.17e-02
# ✅ posterior.branch_logits.grad norm = 6.01e-03
# ✅ posterior.branch_logits.grad norm = 1.71e-02
# ✅ posterior.branch_logits.grad norm = 7.89e-03
# ✅ posterior.branch_logits.grad norm = 8.81e-03
# ✅ posterior.branch_logits.grad norm = 8.14e-03
#
# [Epoch 50] | Phase: emission
#   ELBO:         7.3911e+04
#   NLL:          7.3886e+04
#   KL(t):        8.8098e-02
#   KL(p):        1.7762e-09
#   t_cont:       3.2769e-01
#   Transition:   -1.2412e+01
#   L1:           1.8098e+01
#   Emission MSE: 1.3923e-03
#   Entropy:      5.5411e+00
# ✅ posterior.branch_logits.grad norm = 1.07e-02
# ✅ posterior.branch_logits.grad norm = 1.59e-02
# ✅ posterior.branch_logits.grad norm = 6.82e-03
# ✅ posterior.branch_logits.grad norm = 9.84e-03
# ✅ posterior.branch_logits.grad norm = 1.31e-02
# ✅ posterior.branch_logits.grad norm = 8.98e-03
# ✅ posterior.branch_logits.grad norm = 1.42e-02
# ✅ posterior.branch_logits.grad norm = 5.08e-03
# ✅ posterior.branch_logits.grad norm = 8.20e-03
# ✅ posterior.branch_logits.grad norm = 8.82e-03
# ✅ posterior.branch_logits.grad norm = 6.36e-03
#
# [Epoch 51] | Phase: emission
#   ELBO:         7.5835e+04
#   NLL:          7.5809e+04
#   KL(t):        8.6307e-02
#   KL(p):        1.7747e-09
#   t_cont:       3.3038e-01
#   Transition:   -1.2474e+01
#   L1:           1.8598e+01
#   Emission MSE: 1.5084e-03
#   Entropy:      5.5414e+00
# ✅ posterior.branch_logits.grad norm = 4.90e-03
# ✅ posterior.branch_logits.grad norm = 1.75e-02
# ✅ posterior.branch_logits.grad norm = 1.05e-02
# ✅ posterior.branch_logits.grad norm = 7.57e-03
# ✅ posterior.branch_logits.grad norm = 1.48e-02
# ✅ posterior.branch_logits.grad norm = 1.33e-02
# ✅ posterior.branch_logits.grad norm = 1.10e-02
# ✅ posterior.branch_logits.grad norm = 3.78e-03
# ✅ posterior.branch_logits.grad norm = 9.18e-03
# ✅ posterior.branch_logits.grad norm = 8.78e-03
# ✅ posterior.branch_logits.grad norm = 9.43e-03
#
# [Epoch 52] | Phase: emission
#   ELBO:         7.4160e+04
#   NLL:          7.4134e+04
#   KL(t):        8.5365e-02
#   KL(p):        1.6660e-09
#   t_cont:       3.3118e-01
#   Transition:   -1.2640e+01
#   L1:           1.9102e+01
#   Emission MSE: 1.6463e-03
#   Entropy:      5.5415e+00
# ✅ posterior.branch_logits.grad norm = 1.06e-02
# ✅ posterior.branch_logits.grad norm = 1.17e-02
# ✅ posterior.branch_logits.grad norm = 1.09e-02
# ✅ posterior.branch_logits.grad norm = 7.16e-03
# ✅ posterior.branch_logits.grad norm = 1.11e-02
# ✅ posterior.branch_logits.grad norm = 9.48e-03
# ✅ posterior.branch_logits.grad norm = 1.42e-02
# ✅ posterior.branch_logits.grad norm = 8.06e-03
# ✅ posterior.branch_logits.grad norm = 9.25e-03
# ✅ posterior.branch_logits.grad norm = 6.38e-03
# ✅ posterior.branch_logits.grad norm = 7.82e-03
#
# [Epoch 53] | Phase: emission
#   ELBO:         7.4634e+04
#   NLL:          7.4607e+04
#   KL(t):        8.3887e-02
#   KL(p):        1.7676e-09
#   t_cont:       3.3366e-01
#   Transition:   -1.2509e+01
#   L1:           1.9856e+01
#   Emission MSE: 1.8335e-03
#   Entropy:      5.5415e+00
# ✅ posterior.branch_logits.grad norm = 7.64e-03
# ✅ posterior.branch_logits.grad norm = 2.04e-02
# ✅ posterior.branch_logits.grad norm = 8.04e-03
# ✅ posterior.branch_logits.grad norm = 9.11e-03
# ✅ posterior.branch_logits.grad norm = 1.48e-02
# ✅ posterior.branch_logits.grad norm = 1.73e-02
# ✅ posterior.branch_logits.grad norm = 6.95e-03
# ✅ posterior.branch_logits.grad norm = 5.60e-03
# ✅ posterior.branch_logits.grad norm = 1.86e-02
# ✅ posterior.branch_logits.grad norm = 8.00e-03
# ✅ posterior.branch_logits.grad norm = 1.42e-02
#
# [Epoch 54] | Phase: emission
#   ELBO:         7.5898e+04
#   NLL:          7.5871e+04
#   KL(t):        8.7117e-02
#   KL(p):        1.9141e-09
#   t_cont:       3.3235e-01
#   Transition:   -1.2584e+01
#   L1:           2.0258e+01
#   Emission MSE: 1.9336e-03
#   Entropy:      5.5416e+00
# ✅ posterior.branch_logits.grad norm = 1.34e-02
# ✅ posterior.branch_logits.grad norm = 1.60e-02
# ✅ posterior.branch_logits.grad norm = 7.31e-03
# ✅ posterior.branch_logits.grad norm = 5.24e-03
# ✅ posterior.branch_logits.grad norm = 1.08e-02
# ✅ posterior.branch_logits.grad norm = 8.84e-03
# ✅ posterior.branch_logits.grad norm = 8.47e-03
# ✅ posterior.branch_logits.grad norm = 4.28e-03
# ✅ posterior.branch_logits.grad norm = 5.99e-03
# ✅ posterior.branch_logits.grad norm = 9.87e-03
# ✅ posterior.branch_logits.grad norm = 7.41e-03
#
# [Epoch 55] | Phase: emission
#   ELBO:         7.4702e+04
#   NLL:          7.4674e+04
#   KL(t):        8.6060e-02
#   KL(p):        1.4503e-09
#   t_cont:       3.2943e-01
#   Transition:   -1.2511e+01
#   L1:           2.0623e+01
#   Emission MSE: 2.0224e-03
#   Entropy:      5.5417e+00
# --- Switching to posterior phase ---
# ✅ posterior.branch_logits.grad norm = 3.73e-03
# ✅ posterior.branch_logits.grad norm = 1.99e-02
# ✅ posterior.branch_logits.grad norm = 1.56e-02
# ✅ posterior.branch_logits.grad norm = 8.19e-03
# ✅ posterior.branch_logits.grad norm = 2.13e-02
# ✅ posterior.branch_logits.grad norm = 1.68e-02
# ✅ posterior.branch_logits.grad norm = 9.87e-03
# ✅ posterior.branch_logits.grad norm = 8.46e-03
# ✅ posterior.branch_logits.grad norm = 7.49e-03
# ✅ posterior.branch_logits.grad norm = 9.26e-03
# ✅ posterior.branch_logits.grad norm = 1.49e-02
#
# [Epoch 56] | Phase: posterior
#   ELBO:         7.5536e+04
#   NLL:          7.5509e+04
#   KL(t):        8.8453e-02
#   KL(p):        1.7879e-09
#   t_cont:       3.2715e-01
#   Transition:   -1.2636e+01
#   L1:           1.9691e+01
#   Emission MSE: 2.0849e-03
#   Entropy:      5.5418e+00
# ✅ posterior.branch_logits.grad norm = 7.94e-03
# ✅ posterior.branch_logits.grad norm = 1.70e-02
# ✅ posterior.branch_logits.grad norm = 1.16e-02
# ✅ posterior.branch_logits.grad norm = 5.00e-03
# ✅ posterior.branch_logits.grad norm = 8.41e-03
# ✅ posterior.branch_logits.grad norm = 9.48e-03
# ✅ posterior.branch_logits.grad norm = 6.32e-03
# ✅ posterior.branch_logits.grad norm = 1.01e-02
# ✅ posterior.branch_logits.grad norm = 1.59e-02
# ✅ posterior.branch_logits.grad norm = 9.23e-03
# ✅ posterior.branch_logits.grad norm = 7.41e-03
#
# [Epoch 57] | Phase: posterior
#   ELBO:         7.2065e+04
#   NLL:          7.2038e+04
#   KL(t):        8.6211e-02
#   KL(p):        2.1006e-09
#   t_cont:       3.3023e-01
#   Transition:   -1.2495e+01
#   L1:           1.9691e+01
#   Emission MSE: 2.0849e-03
#   Entropy:      5.5421e+00
# ✅ posterior.branch_logits.grad norm = 1.16e-02
# ✅ posterior.branch_logits.grad norm = 1.70e-02
# ✅ posterior.branch_logits.grad norm = 1.26e-02
# ✅ posterior.branch_logits.grad norm = 7.36e-03
# ✅ posterior.branch_logits.grad norm = 1.67e-02
# ✅ posterior.branch_logits.grad norm = 9.86e-03
# ✅ posterior.branch_logits.grad norm = 9.30e-03
# ✅ posterior.branch_logits.grad norm = 1.37e-02
# ✅ posterior.branch_logits.grad norm = 9.74e-03
# ✅ posterior.branch_logits.grad norm = 1.06e-02
# ✅ posterior.branch_logits.grad norm = 1.39e-02
#
# [Epoch 58] | Phase: posterior
#   ELBO:         7.3873e+04
#   NLL:          7.3846e+04
#   KL(t):        8.1238e-02
#   KL(p):        2.6519e-09
#   t_cont:       3.2619e-01
#   Transition:   -1.2547e+01
#   L1:           1.9691e+01
#   Emission MSE: 2.0849e-03
#   Entropy:      5.5413e+00
# ✅ posterior.branch_logits.grad norm = 5.65e-03
# ✅ posterior.branch_logits.grad norm = 2.81e-02
# ✅ posterior.branch_logits.grad norm = 4.99e-03
# ✅ posterior.branch_logits.grad norm = 6.75e-03
# ✅ posterior.branch_logits.grad norm = 1.47e-02
# ✅ posterior.branch_logits.grad norm = 1.04e-02
# ✅ posterior.branch_logits.grad norm = 5.17e-03
# ✅ posterior.branch_logits.grad norm = 6.51e-03
# ✅ posterior.branch_logits.grad norm = 1.46e-02
# ✅ posterior.branch_logits.grad norm = 1.04e-02
# ✅ posterior.branch_logits.grad norm = 1.43e-02
#
# [Epoch 59] | Phase: posterior
#   ELBO:         7.2691e+04
#   NLL:          7.2664e+04
#   KL(t):        9.1032e-02
#   KL(p):        1.5486e-09
#   t_cont:       3.2923e-01
#   Transition:   -1.2456e+01
#   L1:           1.9691e+01
#   Emission MSE: 2.0849e-03
#   Entropy:      5.5411e+00
# ✅ posterior.branch_logits.grad norm = 4.69e-03
# ✅ posterior.branch_logits.grad norm = 1.70e-02
# ✅ posterior.branch_logits.grad norm = 1.18e-02
# ✅ posterior.branch_logits.grad norm = 7.22e-03
# ✅ posterior.branch_logits.grad norm = 1.18e-02
# ...
#   Emission MSE: 2.1211e-02
#   Entropy:      5.5416e+00
# ✅ posterior.branch_logits.grad norm = 6.71e-03
# ✅ posterior.branch_logits.grad norm = 1.82e-02
# ✅ posterior.branch_logits.grad norm = 7.68e-03
# ✅ posterior.branch_logits.grad norm = 7.84e-03
# ✅ posterior.branch_logits.grad norm = 1.09e-02
# ✅ posterior.branch_logits.grad norm = 9.57e-03
# ✅ posterior.branch_logits.grad norm = 8.22e-03
# ✅ posterior.branch_logits.grad norm = 1.12e-02
# ✅ posterior.branch_logits.grad norm = 6.92e-03
# ✅ posterior.branch_logits.grad norm = 9.37e-03
# ✅ posterior.branch_logits.grad norm = 1.51e-02
#
# [Epoch 480] | Phase: posterior
#   ELBO:         8.1599e+04
#   NLL:          4.3634e+04
#   KL(t):        3.7900e+04
#   KL(p):        1.5266e-09
#   t_cont:       3.3495e-01
#   Transition:   -1.2504e+01
#   L1:           5.7256e+01
#   Emission MSE: 2.1211e-02
#   Entropy:      5.5411e+00
# ✅ posterior.branch_logits.grad norm = 6.94e-03
# ✅ posterior.branch_logits.grad norm = 2.08e-02
# ✅ posterior.branch_logits.grad norm = 7.33e-03
# ✅ posterior.branch_logits.grad norm = 6.94e-03
# ✅ posterior.branch_logits.grad norm = 1.08e-02
# ✅ posterior.branch_logits.grad norm = 1.04e-02
# ✅ posterior.branch_logits.grad norm = 7.01e-03
# ✅ posterior.branch_logits.grad norm = 5.60e-03
# ✅ posterior.branch_logits.grad norm = 5.50e-03
# ✅ posterior.branch_logits.grad norm = 9.35e-03
# ✅ posterior.branch_logits.grad norm = 1.24e-02
#
# [Epoch 481] | Phase: posterior
#   ELBO:         8.0445e+04
#   NLL:          4.3539e+04
#   KL(t):        3.6842e+04
#   KL(p):        1.2541e-09
#   t_cont:       3.3975e-01
#   Transition:   -1.2550e+01
#   L1:           5.7256e+01
#   Emission MSE: 2.1211e-02
#   Entropy:      5.5415e+00
# ✅ posterior.branch_logits.grad norm = 7.87e-03
# ✅ posterior.branch_logits.grad norm = 1.52e-02
# ✅ posterior.branch_logits.grad norm = 1.24e-02
# ✅ posterior.branch_logits.grad norm = 6.66e-03
# ✅ posterior.branch_logits.grad norm = 1.16e-02
# ✅ posterior.branch_logits.grad norm = 1.01e-02
# ✅ posterior.branch_logits.grad norm = 8.66e-03
# ✅ posterior.branch_logits.grad norm = 7.80e-03
# ✅ posterior.branch_logits.grad norm = 1.47e-02
# ✅ posterior.branch_logits.grad norm = 1.37e-02
# ✅ posterior.branch_logits.grad norm = 9.60e-03
#
# [Epoch 482] | Phase: posterior
#   ELBO:         7.9757e+04
#   NLL:          4.4053e+04
#   KL(t):        3.5639e+04
#   KL(p):        3.1000e-09
#   t_cont:       3.3633e-01
#   Transition:   -1.2591e+01
#   L1:           5.7256e+01
#   Emission MSE: 2.1211e-02
#   Entropy:      5.5420e+00
# ✅ posterior.branch_logits.grad norm = 7.42e-03
# ✅ posterior.branch_logits.grad norm = 1.51e-02
# ✅ posterior.branch_logits.grad norm = 7.75e-03
# ✅ posterior.branch_logits.grad norm = 8.34e-03
# ✅ posterior.branch_logits.grad norm = 1.12e-02
# ✅ posterior.branch_logits.grad norm = 1.14e-02
# ✅ posterior.branch_logits.grad norm = 7.60e-03
# ✅ posterior.branch_logits.grad norm = 4.33e-03
# ✅ posterior.branch_logits.grad norm = 8.34e-03
# ✅ posterior.branch_logits.grad norm = 9.61e-03
# ✅ posterior.branch_logits.grad norm = 8.81e-03
#
# [Epoch 483] | Phase: posterior
#   ELBO:         8.3487e+04
#   NLL:          4.4034e+04
#   KL(t):        3.9388e+04
#   KL(p):        2.0027e-09
#   t_cont:       3.3000e-01
#   Transition:   -1.2533e+01
#   L1:           5.7256e+01
#   Emission MSE: 2.1211e-02
#   Entropy:      5.5416e+00
# ✅ posterior.branch_logits.grad norm = 9.10e-03
# ✅ posterior.branch_logits.grad norm = 1.78e-02
# ✅ posterior.branch_logits.grad norm = 1.08e-02
# ✅ posterior.branch_logits.grad norm = 1.55e-02
# ✅ posterior.branch_logits.grad norm = 1.42e-02
# ✅ posterior.branch_logits.grad norm = 1.33e-02
# ✅ posterior.branch_logits.grad norm = 6.82e-03
# ✅ posterior.branch_logits.grad norm = 5.98e-03
# ✅ posterior.branch_logits.grad norm = 9.42e-03
# ✅ posterior.branch_logits.grad norm = 1.03e-02
# ✅ posterior.branch_logits.grad norm = 7.39e-03
#
# [Epoch 484] | Phase: posterior
#   ELBO:         8.3446e+04
#   NLL:          4.2672e+04
#   KL(t):        4.0710e+04
#   KL(p):        1.4313e-09
#   t_cont:       3.3336e-01
#   Transition:   -1.2486e+01
#   L1:           5.7256e+01
#   Emission MSE: 2.1211e-02
#   Entropy:      5.5416e+00
# --- Switching to emission phase ---
# ✅ posterior.branch_logits.grad norm = 9.79e-03
# ✅ posterior.branch_logits.grad norm = 1.41e-02
# ✅ posterior.branch_logits.grad norm = 1.37e-02
# ✅ posterior.branch_logits.grad norm = 6.73e-03
# ✅ posterior.branch_logits.grad norm = 1.18e-02
# ✅ posterior.branch_logits.grad norm = 1.11e-02
# ✅ posterior.branch_logits.grad norm = 8.19e-03
# ✅ posterior.branch_logits.grad norm = 1.13e-02
# ✅ posterior.branch_logits.grad norm = 6.43e-03
# ✅ posterior.branch_logits.grad norm = 6.96e-03
# ✅ posterior.branch_logits.grad norm = 1.22e-02
#
# [Epoch 485] | Phase: emission
#   ELBO:         8.4139e+04
#   NLL:          4.4165e+04
#   KL(t):        3.9908e+04
#   KL(p):        1.5145e-09
#   t_cont:       3.3377e-01
#   Transition:   -1.2489e+01
#   L1:           5.8148e+01
#   Emission MSE: 2.1066e-02
#   Entropy:      5.5415e+00
# ✅ posterior.branch_logits.grad norm = 8.23e-03
# ✅ posterior.branch_logits.grad norm = 1.63e-02
# ✅ posterior.branch_logits.grad norm = 7.22e-03
# ✅ posterior.branch_logits.grad norm = 2.15e-02
# ✅ posterior.branch_logits.grad norm = 1.93e-02
# ✅ posterior.branch_logits.grad norm = 1.47e-02
# ✅ posterior.branch_logits.grad norm = 6.83e-03
# ✅ posterior.branch_logits.grad norm = 2.81e-03
# ✅ posterior.branch_logits.grad norm = 7.99e-03
# ✅ posterior.branch_logits.grad norm = 8.08e-03
# ✅ posterior.branch_logits.grad norm = 9.11e-03
#
# [Epoch 486] | Phase: emission
#   ELBO:         8.2824e+04
#   NLL:          4.3050e+04
#   KL(t):        3.9709e+04
#   KL(p):        1.5322e-09
#   t_cont:       3.3774e-01
#   Transition:   -1.2513e+01
#   L1:           5.7642e+01
#   Emission MSE: 2.0855e-02
#   Entropy:      5.5417e+00
# ✅ posterior.branch_logits.grad norm = 7.95e-03
# ✅ posterior.branch_logits.grad norm = 1.86e-02
# ✅ posterior.branch_logits.grad norm = 8.18e-03
# ✅ posterior.branch_logits.grad norm = 9.83e-03
# ✅ posterior.branch_logits.grad norm = 1.11e-02
# ✅ posterior.branch_logits.grad norm = 1.03e-02
# ✅ posterior.branch_logits.grad norm = 1.07e-02
# ✅ posterior.branch_logits.grad norm = 3.98e-03
# ✅ posterior.branch_logits.grad norm = 6.70e-03
# ✅ posterior.branch_logits.grad norm = 6.90e-03
# ✅ posterior.branch_logits.grad norm = 1.82e-02
#
# [Epoch 487] | Phase: emission
#   ELBO:         8.3903e+04
#   NLL:          4.3075e+04
#   KL(t):        4.0763e+04
#   KL(p):        1.3809e-09
#   t_cont:       3.3935e-01
#   Transition:   -1.2628e+01
#   L1:           5.7583e+01
#   Emission MSE: 2.0654e-02
#   Entropy:      5.5416e+00
# ✅ posterior.branch_logits.grad norm = 9.98e-03
# ✅ posterior.branch_logits.grad norm = 2.09e-02
# ✅ posterior.branch_logits.grad norm = 5.45e-03
# ✅ posterior.branch_logits.grad norm = 6.62e-03
# ✅ posterior.branch_logits.grad norm = 1.39e-02
# ✅ posterior.branch_logits.grad norm = 1.25e-02
# ✅ posterior.branch_logits.grad norm = 7.75e-03
# ✅ posterior.branch_logits.grad norm = 9.94e-03
# ✅ posterior.branch_logits.grad norm = 9.02e-03
# ✅ posterior.branch_logits.grad norm = 9.53e-03
# ✅ posterior.branch_logits.grad norm = 8.02e-03
#
# [Epoch 488] | Phase: emission
#   ELBO:         8.1092e+04
#   NLL:          4.2517e+04
#   KL(t):        3.8510e+04
#   KL(p):        1.6239e-09
#   t_cont:       3.3996e-01
#   Transition:   -1.2600e+01
#   L1:           5.7713e+01
#   Emission MSE: 2.0635e-02
#   Entropy:      5.5416e+00
# ✅ posterior.branch_logits.grad norm = 7.96e-03
# ✅ posterior.branch_logits.grad norm = 1.44e-02
# ✅ posterior.branch_logits.grad norm = 7.56e-03
# ✅ posterior.branch_logits.grad norm = 9.34e-03
# ✅ posterior.branch_logits.grad norm = 1.12e-02
# ✅ posterior.branch_logits.grad norm = 8.12e-03
# ✅ posterior.branch_logits.grad norm = 7.38e-03
# ✅ posterior.branch_logits.grad norm = 8.56e-03
# ✅ posterior.branch_logits.grad norm = 7.29e-03
# ✅ posterior.branch_logits.grad norm = 8.78e-03
# ✅ posterior.branch_logits.grad norm = 1.03e-02
#
# [Epoch 489] | Phase: emission
#   ELBO:         8.3705e+04
#   NLL:          4.2493e+04
#   KL(t):        4.1147e+04
#   KL(p):        1.3974e-09
#   t_cont:       3.4024e-01
#   Transition:   -1.2431e+01
#   L1:           5.7762e+01
#   Emission MSE: 2.0701e-02
#   Entropy:      5.5411e+00
# ✅ posterior.branch_logits.grad norm = 7.67e-03
# ✅ posterior.branch_logits.grad norm = 1.62e-02
# ✅ posterior.branch_logits.grad norm = 1.44e-02
# ✅ posterior.branch_logits.grad norm = 1.49e-02
# ✅ posterior.branch_logits.grad norm = 1.10e-02
# ✅ posterior.branch_logits.grad norm = 1.02e-02
# ✅ posterior.branch_logits.grad norm = 1.54e-02
# ✅ posterior.branch_logits.grad norm = 5.93e-03
# ✅ posterior.branch_logits.grad norm = 7.45e-03
# ✅ posterior.branch_logits.grad norm = 1.23e-02
# ✅ posterior.branch_logits.grad norm = 8.88e-03
#
# [Epoch 490] | Phase: emission
#   ELBO:         8.3183e+04
#   NLL:          4.3116e+04
#   KL(t):        4.0002e+04
#   KL(p):        1.8311e-09
#   t_cont:       3.4174e-01
#   Transition:   -1.2557e+01
#   L1:           5.7872e+01
#   Emission MSE: 2.0817e-02
#   Entropy:      5.5414e+00
# ✅ posterior.branch_logits.grad norm = 8.22e-03
# ✅ posterior.branch_logits.grad norm = 1.42e-02
# ✅ posterior.branch_logits.grad norm = 2.34e-02
# ✅ posterior.branch_logits.grad norm = 5.80e-03
# ✅ posterior.branch_logits.grad norm = 1.29e-02
# ✅ posterior.branch_logits.grad norm = 1.00e-02
# ✅ posterior.branch_logits.grad norm = 8.48e-03
# ✅ posterior.branch_logits.grad norm = 1.00e-02
# ✅ posterior.branch_logits.grad norm = 1.22e-02
# ✅ posterior.branch_logits.grad norm = 1.13e-02
# ✅ posterior.branch_logits.grad norm = 1.04e-02
#
# [Epoch 491] | Phase: emission
#   ELBO:         8.3772e+04
#   NLL:          4.3498e+04
#   KL(t):        4.0208e+04
#   KL(p):        1.5796e-09
#   t_cont:       3.3596e-01
#   Transition:   -1.2559e+01
#   L1:           5.8206e+01
#   Emission MSE: 2.0978e-02
#   Entropy:      5.5415e+00
# ✅ posterior.branch_logits.grad norm = 3.90e-03
# ✅ posterior.branch_logits.grad norm = 1.95e-02
# ✅ posterior.branch_logits.grad norm = 5.86e-03
# ✅ posterior.branch_logits.grad norm = 8.07e-03
# ✅ posterior.branch_logits.grad norm = 1.37e-02
# ✅ posterior.branch_logits.grad norm = 1.08e-02
# ✅ posterior.branch_logits.grad norm = 6.19e-03
# ✅ posterior.branch_logits.grad norm = 9.45e-03
# ✅ posterior.branch_logits.grad norm = 5.25e-03
# ✅ posterior.branch_logits.grad norm = 7.68e-03
# ✅ posterior.branch_logits.grad norm = 1.21e-02
#
# [Epoch 492] | Phase: emission
#   ELBO:         8.3895e+04
#   NLL:          4.2793e+04
#   KL(t):        4.1037e+04
#   KL(p):        1.4392e-09
#   t_cont:       3.4135e-01
#   Transition:   -1.2527e+01
#   L1:           5.8042e+01
#   Emission MSE: 2.0952e-02
#   Entropy:      5.5416e+00
# ✅ posterior.branch_logits.grad norm = 6.43e-03
# ✅ posterior.branch_logits.grad norm = 1.60e-02
# ✅ posterior.branch_logits.grad norm = 4.70e-03
# ✅ posterior.branch_logits.grad norm = 5.79e-03
# ✅ posterior.branch_logits.grad norm = 9.73e-03
# ✅ posterior.branch_logits.grad norm = 7.98e-03
# ✅ posterior.branch_logits.grad norm = 8.30e-03
# ✅ posterior.branch_logits.grad norm = 4.00e-03
# ✅ posterior.branch_logits.grad norm = 7.17e-03
# ✅ posterior.branch_logits.grad norm = 8.50e-03
# ✅ posterior.branch_logits.grad norm = 1.32e-02
#
# [Epoch 493] | Phase: emission
#   ELBO:         8.0036e+04
#   NLL:          4.2551e+04
#   KL(t):        3.7420e+04
#   KL(p):        1.6897e-09
#   t_cont:       3.3777e-01
#   Transition:   -1.2520e+01
#   L1:           5.7809e+01
#   Emission MSE: 2.0726e-02
#   Entropy:      5.5414e+00
# ✅ posterior.branch_logits.grad norm = 6.81e-03
# ✅ posterior.branch_logits.grad norm = 1.79e-02
# ✅ posterior.branch_logits.grad norm = 9.40e-03
# ✅ posterior.branch_logits.grad norm = 1.56e-02
# ✅ posterior.branch_logits.grad norm = 1.44e-02
# ✅ posterior.branch_logits.grad norm = 1.13e-02
# ✅ posterior.branch_logits.grad norm = 7.18e-03
# ✅ posterior.branch_logits.grad norm = 3.09e-03
# ✅ posterior.branch_logits.grad norm = 8.07e-03
# ✅ posterior.branch_logits.grad norm = 9.34e-03
# ✅ posterior.branch_logits.grad norm = 8.08e-03
#
# [Epoch 494] | Phase: emission
#   ELBO:         8.2867e+04
#   NLL:          4.3346e+04
#   KL(t):        3.9455e+04
#   KL(p):        1.1720e-09
#   t_cont:       3.4242e-01
#   Transition:   -1.2507e+01
#   L1:           5.7870e+01
#   Emission MSE: 2.0718e-02
#   Entropy:      5.5413e+00
# --- Switching to posterior phase ---
# ✅ posterior.branch_logits.grad norm = 6.13e-03
# ✅ posterior.branch_logits.grad norm = 1.54e-02
# ✅ posterior.branch_logits.grad norm = 7.67e-03
# ✅ posterior.branch_logits.grad norm = 9.53e-03
# ✅ posterior.branch_logits.grad norm = 1.36e-02
# ✅ posterior.branch_logits.grad norm = 1.12e-02
# ✅ posterior.branch_logits.grad norm = 1.25e-02
# ✅ posterior.branch_logits.grad norm = 1.05e-02
# ✅ posterior.branch_logits.grad norm = 1.78e-02
# ✅ posterior.branch_logits.grad norm = 8.49e-03
# ✅ posterior.branch_logits.grad norm = 9.10e-03
#
# [Epoch 495] | Phase: posterior
#   ELBO:         8.3748e+04
#   NLL:          4.3474e+04
#   KL(t):        4.0209e+04
#   KL(p):        1.5544e-09
#   t_cont:       3.3813e-01
#   Transition:   -1.2491e+01
#   L1:           5.7391e+01
#   Emission MSE: 2.0888e-02
#   Entropy:      5.5416e+00
# ✅ posterior.branch_logits.grad norm = 5.56e-03
# ✅ posterior.branch_logits.grad norm = 2.05e-02
# ✅ posterior.branch_logits.grad norm = 6.67e-03
# ✅ posterior.branch_logits.grad norm = 8.63e-03
# ✅ posterior.branch_logits.grad norm = 1.34e-02
# ✅ posterior.branch_logits.grad norm = 1.49e-02
# ✅ posterior.branch_logits.grad norm = 1.30e-02
# ✅ posterior.branch_logits.grad norm = 9.80e-03
# ✅ posterior.branch_logits.grad norm = 6.37e-03
# ✅ posterior.branch_logits.grad norm = 1.05e-02
# ✅ posterior.branch_logits.grad norm = 9.67e-03
#
# [Epoch 496] | Phase: posterior
#   ELBO:         8.0858e+04
#   NLL:          4.2167e+04
#   KL(t):        3.8627e+04
#   KL(p):        2.5356e-09
#   t_cont:       3.3647e-01
#   Transition:   -1.2450e+01
#   L1:           5.7391e+01
#   Emission MSE: 2.0888e-02
#   Entropy:      5.5416e+00
# ✅ posterior.branch_logits.grad norm = 1.30e-02
# ✅ posterior.branch_logits.grad norm = 1.16e-02
# ✅ posterior.branch_logits.grad norm = 1.27e-02
# ✅ posterior.branch_logits.grad norm = 8.98e-03
# ✅ posterior.branch_logits.grad norm = 9.77e-03
# ✅ posterior.branch_logits.grad norm = 9.74e-03
# ✅ posterior.branch_logits.grad norm = 9.34e-03
# ✅ posterior.branch_logits.grad norm = 4.05e-03
# ✅ posterior.branch_logits.grad norm = 1.12e-02
# ✅ posterior.branch_logits.grad norm = 1.59e-02
# ✅ posterior.branch_logits.grad norm = 1.53e-02
#
# [Epoch 497] | Phase: posterior
#   ELBO:         8.3575e+04
#   NLL:          4.3630e+04
#   KL(t):        3.9880e+04
#   KL(p):        1.0687e-09
#   t_cont:       3.3618e-01
#   Transition:   -1.2600e+01
#   L1:           5.7391e+01
#   Emission MSE: 2.0888e-02
#   Entropy:      5.5415e+00
# ✅ posterior.branch_logits.grad norm = 5.50e-03
# ✅ posterior.branch_logits.grad norm = 2.34e-02
# ✅ posterior.branch_logits.grad norm = 1.03e-02
# ✅ posterior.branch_logits.grad norm = 1.41e-02
# ✅ posterior.branch_logits.grad norm = 1.44e-02
# ✅ posterior.branch_logits.grad norm = 2.01e-02
# ✅ posterior.branch_logits.grad norm = 1.36e-02
# ✅ posterior.branch_logits.grad norm = 1.20e-02
# ✅ posterior.branch_logits.grad norm = 8.72e-03
# ✅ posterior.branch_logits.grad norm = 9.34e-03
# ✅ posterior.branch_logits.grad norm = 9.85e-03
#
# [Epoch 498] | Phase: posterior
#   ELBO:         8.7150e+04
#   NLL:          4.2338e+04
#   KL(t):        4.4748e+04
#   KL(p):        1.7634e-09
#   t_cont:       3.3770e-01
#   Transition:   -1.2549e+01
#   L1:           5.7391e+01
#   Emission MSE: 2.0888e-02
#   Entropy:      5.5417e+00
# ✅ posterior.branch_logits.grad norm = 9.67e-03
# ✅ posterior.branch_logits.grad norm = 1.78e-02
# ✅ posterior.branch_logits.grad norm = 4.88e-03
# ✅ posterior.branch_logits.grad norm = 1.05e-02
# ✅ posterior.branch_logits.grad norm = 1.67e-02
# ✅ posterior.branch_logits.grad norm = 9.68e-03
# ✅ posterior.branch_logits.grad norm = 1.20e-02
# ✅ posterior.branch_logits.grad norm = 4.70e-03
# ✅ posterior.branch_logits.grad norm = 7.12e-03
# ✅ posterior.branch_logits.grad norm = 1.05e-02
# ✅ posterior.branch_logits.grad norm = 6.86e-03
#
# [Epoch 499] | Phase: posterior
#   ELBO:         8.3991e+04
#   NLL:          4.2616e+04
#   KL(t):        4.1310e+04
#   KL(p):        -2.8768e-10
#   t_cont:       3.3551e-01
#   Transition:   -1.2654e+01
#   L1:           5.7391e+01
#   Emission MSE: 2.0888e-02
#   Entropy:      5.5417e+00

# %%
# from models.loss import compute_elbo_batch
# from utils.inference import batch_indices

# batch_size = 512
# num_epochs = 100
# n_samples = 3
# freeze_epochs = 5
# # Training weights
# kl_weight = 1.0
# kl_p_weight = 1e4
# t_cont_weight = 1.0

# elbo_log = []
# nll_log = []
# kl_t_log = []
# kl_p_log = []
# t_cont_log = []
# transition_log = []
# l1_log = []
# grad_log = []

# # Freeze emission parameters initially
# emission_params = [g, K, log_sigma2]
# for p in emission_params:
#     p.requires_grad_(False)

# optimizer = torch.optim.Adam(
#     [posterior.alpha, posterior.beta, posterior.edge_logits] + emission_params,
#     lr=1e-2
# )

# for epoch in range(num_epochs):
#     total_loss = 0.0
#     total_batches = 0
#     epoch_metrics = {
#         "nll": 0.0,
#         "kl_t": 0.0,
#         "kl_p": 0.0,
#         "t_cont": 0.0,
#         "transition": 0.0,
#         "l1": 0.0
#     }

#     # === Unfreeze after warmup ===
#     if epoch == freeze_epochs:
#         for p in emission_params:
#             p.requires_grad_(True)

#     for batch in batch_indices(X.shape[0], batch_size):
#         assert batch.dtype == torch.long, f"batch dtype is {batch.dtype}, expected torch.long"
#         assert X.dim() == 2, f"X has shape {X.shape}, expected 2D tensor"

#         # print("batch shape:", batch.shape)
#         # print("batch dtype:", batch.dtype)
#         # print("min(batch):", batch.min().item())
#         # print("max(batch):", batch.max().item())
#         # print("X.shape[0]:", X.shape[0])

#         torch.cuda.synchronize()
#         X_batch = X[batch]
#         optimizer.zero_grad()

#         # print("posterior edge list:")
#         # for i, edge in enumerate(posterior.edge_list):
#         #     print(f"{i}: {edge}")
        
#         # print("traj_graph.edge_list:")
#         # for i, edge in enumerate(traj_graph.edge_list):
#         #     print(f"{i}: {edge}")

#         loss, metrics = compute_elbo_batch(
#             X_batch, batch,
#             traj_graph, posterior, edge_to_index,
#             g, K, log_sigma2.exp(),
#             belief_propagator=belief_propagator,
#             n_samples=n_samples,
#             kl_weight=kl_weight,
#             kl_p_weight=kl_p_weight,
#             t_cont_weight=t_cont_weight,
#             transition_weight=1.0,  # adjustable
#             pi=pi
#         )

#         loss.backward()
#         optimizer.step()

#         total_loss += loss.item()
#         for key in epoch_metrics:
#             epoch_metrics[key] += metrics.get(key, 0.0)
#         total_batches += 1

#     # Normalize per batch
#     for key in epoch_metrics:
#         epoch_metrics[key] /= total_batches

#     # === Log gradient norms ===
#     grad_norms = {
#         "alpha": posterior.alpha.grad.norm().item() if posterior.alpha.grad is not None else 0.0,
#         "beta": posterior.beta.grad.norm().item() if posterior.beta.grad is not None else 0.0,
#         "edge_logits": posterior.edge_logits.grad.norm().item() if posterior.edge_logits.grad is not None else 0.0,
#         "g": g.grad.norm().item() if g.grad is not None else 0.0,
#         "K": K.grad.norm().item() if K.grad is not None else 0.0,
#         "log_sigma2": log_sigma2.grad.norm().item() if log_sigma2.grad is not None else 0.0,
#     }

#     # Store logs
#     elbo_log.append(total_loss / total_batches)
#     nll_log.append(epoch_metrics["nll"])
#     kl_t_log.append(epoch_metrics["kl_t"])
#     kl_p_log.append(epoch_metrics["kl_p"])
#     t_cont_log.append(epoch_metrics["t_cont"])
#     transition_log.append(epoch_metrics["transition"])
#     l1_log.append(epoch_metrics["l1"])
#     grad_log.append(grad_norms)

#     # === Print ===
#     print(f"\n[Epoch {epoch}]")
#     print(f"  ELBO:       {elbo_log[-1]:.4e}")
#     print(f"  NLL:        {epoch_metrics['nll']:.4e}")
#     print(f"  KL(t):      {epoch_metrics['kl_t']:.4e}")
#     print(f"  KL(p):      {epoch_metrics['kl_p']:.4e}")
#     print(f"  t_cont:     {epoch_metrics['t_cont']:.4e}")
#     print(f"  transition: {epoch_metrics['transition']:.4e}")
#     print(f"  L1:         {epoch_metrics['l1']:.4e}")
#     print("  Grad Norms:")
#     for k, v in grad_norms.items():
#         print(f"    {k}: {v:.2e}")

# %%
import matplotlib.pyplot as plt

epochs = range(len(elbo_log))

fig, axes = plt.subplots(1, 2, figsize=(16, 5))

# === ELBO plot ===
axes[0].plot(epochs, elbo_log, label="ELBO", color="black")
axes[0].set_title("ELBO Over Epochs")
axes[0].set_xlabel("Epoch")
axes[0].set_ylabel("ELBO")
axes[0].legend()
axes[0].grid(True)

# === Component losses ===
axes[1].plot(epochs, nll_log, label="NLL")
axes[1].plot(epochs, kl_t_log, label="KL(t)")
axes[1].plot(epochs, kl_p_log, label="KL(p)")
axes[1].plot(epochs, t_cont_log, label="t_cont")
axes[1].plot(epochs, transition_log, label="transition")
axes[1].plot(epochs, l1_log, label="L1")
axes[1].set_title("ELBO Components Over Epochs")
axes[1].set_xlabel("Epoch")
axes[1].set_ylabel("Loss Component Value")
axes[1].legend()
axes[1].grid(True)

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

epochs = range(len(elbo_log))

fig, axes = plt.subplots(1, 2, figsize=(16, 5))

# === ELBO plot ===
axes[0].plot(epochs, elbo_log, label="ELBO", color="black")
axes[0].set_title("ELBO Over Epochs")
axes[0].set_xlabel("Epoch")
axes[0].set_ylabel("ELBO")
axes[0].legend()
axes[0].grid(True)

# === Component losses ===
axes[1].plot(epochs, nll_log, label="NLL")
axes[1].plot(epochs, kl_t_log, label="KL(t)")
axes[1].plot(epochs, kl_p_log, label="KL(p)")
axes[1].plot(epochs, t_cont_log, label="t_cont")
axes[1].plot(epochs, transition_log, label="transition")
axes[1].plot(epochs, l1_log, label="L1")
axes[1].set_title("ELBO Components Over Epochs")
axes[1].set_xlabel("Epoch")
axes[1].set_ylabel("Loss Component Value")
axes[1].legend()
axes[1].grid(True)

plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 3
#       1 import matplotlib.pyplot as plt
# ----> 3 epochs = range(len(elbo_log))
#       5 fig, axes = plt.subplots(1, 2, figsize=(16, 5))
#       7 # === ELBO plot ===
#
# NameError: name 'elbo_log' is not defined

# %%
index_to_edge = {v: k for k, v in edge_to_index.items()}
def extract_fitted_betas_by_argmax(posterior, index_to_edge):
    """
    Extract learned beta distribution parameters using the MAP edge assignment per cell.

    Args:
        posterior: Trained posterior object with `alpha` and `beta` of shape [cells x edges].
        index_to_edge: Dict mapping edge indices (int) to edge names.

    Returns:
        pd.DataFrame: Indexed by cell ID with columns 'edge', 'alpha', and 'beta'.
    """
    alpha = posterior.alpha.data.cpu().numpy()
    beta = posterior.beta.data.cpu().numpy()
    max_idx = (alpha + beta - 2).argmax(axis=1)  # MAP estimate of Beta distribution mean

    records = []
    for i, edge_idx in enumerate(max_idx):
        edge = index_to_edge[edge_idx]
        records.append({
        "cell_id": adata.obs.index[i],  # not just 'i'
        "edge": edge,
        "alpha": alpha[i, edge_idx],
        "beta": beta[i, edge_idx],
    })


    return pd.DataFrame(records).set_index("cell_id")
fitted_betas = extract_fitted_betas_by_argmax(posterior, index_to_edge)

# %%
adata
# Out:
# View of AnnData object with n_obs × n_vars = 0 × 1000
#     obs: 'developmental_day', 'days_num', 'hours_num', 'source_tissue', 'leiden'
#     var: 'n_cells', 'highly_variable', 'means', 'dispersions', 'dispersions_norm'
#     uns: 'Sample_colors', 'developmental_day_colors', 'hvg', 'leiden', 'leiden_colors', 'leiden_sizes', 'log1p', 'neighbors', 'paga', 'pca', 'umap'
#     obsm: 'X_pca', 'X_umap'
#     varm: 'PCs'
#     layers: 'ambiguous', 'counts', 'spliced', 'unspliced'
#     obsp: 'connectivities', 'distances'

# %%
print("adata.obs.shape:", adata.obs.shape)
print("posterior alpha shape:", posterior.alpha.shape)
# Out:
# adata.obs.shape: (0, 5)
# posterior alpha shape: torch.Size([5454, 18])

# %%
fitted_betas["edge"] = fitted_betas["edge"].apply(lambda x: tuple(x) if not isinstance(x, tuple) else x)
fitted_betas
# Out:
#                                 edge     alpha      beta
# cell_id
# TAAGCGTAGGCCCGTT  (split_2, split_4)  2.260439  7.739561
# GACCAATAGTCGTCGT  (split_2, split_8)  5.611216  4.388784
# CGAGAAGCATGCTAGT  (split_2, split_4)  1.414021  8.585979
# ACGATGTAGGATTCCC  (split_2, split_4)  3.026320  6.973680
# GCAGTTAAGGTCATCT  (split_2, split_4)  9.058227  0.941773
# ...                              ...       ...       ...
# GGAGCAAGTCTAGTGT    (int_5, leaf_13)  5.544000  4.456000
# TTTACTGTCAGTTCGG  (split_8, leaf_12)  9.941500  0.058500
# GAAATGAGTCGGCACT  (split_8, leaf_12)  4.255378  5.744622
# CGATGGCAGTGTCTCG  (split_8, leaf_12)  2.524941  7.475059
# CATCAAGGTTAAGATG    (int_5, leaf_13)  8.254477  1.745524
#
# [5454 rows x 3 columns]

# %%
missing = fitted_betas.index.difference(adata.obs.index)
print(f"{len(missing)} missing cell IDs in adata")
# Out:
# 5454 missing cell IDs in adata

# %%
missing_edges = [e for e in fitted_betas["edge"].unique() if e not in traj_graph.G_traj.edges
]
print("Missing edges:", missing_edges)
# Out:
# Missing edges: []

# %%
from viz.trajectory import plot_cells_on_trajectory

plot_cells_on_trajectory(
    traj_graph,
    cell_assignment,
    adata,
    color_key="leiden",  # or any other obs key
    curve_amount=0.8,
    title="Hard Cell Assignments on Trajectory"
)

# %%
from viz.trajectory import plot_pdf_width_ribbons_on_trajectory

plot_pdf_width_ribbons_on_trajectory(
    traj_graph,
    fitted_betas,
    adata,
    color_key="leiden",
    pdf_scale=.1,  # adjust if too narrow/wide
    curve_amount=0.8,
    title="Beta-Modeled Cell Assignments as Ribbons"
)
# Out:
# /work/vanaja_lab/griffin/projects/viCSHMM/viz/trajectory.py:301: RuntimeWarning: overflow encountered in multiply
#   widths = pdfs * (pdf_scale * seg_length) / max_vals
# /work/vanaja_lab/griffin/projects/viCSHMM/viz/trajectory.py:305: RuntimeWarning: invalid value encountered in multiply
#   offset = (width[:, None] / 2) * normals

# %%
# freeze_epochs = 10
# optimizer = torch.optim.Adam([
#     {'params': [posterior.alpha, posterior.beta, posterior.path_logits]},
#     {'params': [g_a, g_b, K, log_sigma2], 'lr': 1e-2}
# ], lr=1e-2)

# for epoch in range(num_epochs):
#     # Freeze emission parameters initially
#     if epoch < freeze_epochs:
#         for p in [g_a, g_b, K, log_sigma2]:
#             p.requires_grad_(False)
#     else:
#         for p in [g_a, g_b, K, log_sigma2]:
#             p.requires_grad_(True)

#     optimizer.zero_grad()
#     loss, metrics = compute_elbo(
#         X, traj_graph, posterior, edge_to_index,
#         g_a, g_b, K, log_sigma2.exp(),
#         pi=pi,
#         belief_propagator=belief_propagator,
#         n_samples=n_samples,
#         kl_weight=kl_weight,
#         kl_p_weight=kl_p_weight,
#         t_cont_weight=t_cont_weight,
#     )
#     loss.backward()
#     optimizer.step()

#     print(f"[Epoch {epoch}] Loss={loss.item():.2e}, NLL={metrics['nll']:.2e}, KL(t)={metrics['kl_t']:.3f}")

# %%
inference_params = [posterior.alpha, posterior.beta, posterior.path_logits]
generative_params = [g_a, g_b, K, log_sigma2]

optimizer_inf = torch.optim.Adam(inference_params, lr=1e-2)
optimizer_gen = torch.optim.Adam(generative_params, lr=1e-2)

n_inf_steps = 8
n_gen_steps = 3
batch_size = 512

elbo_log = []
metrics_log = []

for epoch in range(num_epochs):
    print(f"\n[Epoch {epoch}]")

    # === Inference Phase ===
    for _ in range(n_inf_steps):
        optimizer_inf.zero_grad()
        total_elbo = 0
        total_metrics = {
            "nll": 0.0,
            "kl_t": 0.0,
            "kl_p": 0.0,
            "t_cont": 0.0
        }
        n_batches = 0

        for batch in batch_indices(X.shape[0], batch_size):
            X_batch = X[batch]
            elbo, metrics = compute_elbo_batch(
                X_batch, batch,
                traj_graph, posterior, edge_to_index,
                g_a, g_b, K, log_sigma2.exp(),
                belief_propagator=belief_propagator,
                n_samples=n_samples,
                kl_weight=kl_weight,
                kl_p_weight=kl_p_weight,
                t_cont_weight=t_cont_weight,
                pi=pi
            )
            elbo.backward()
            total_elbo += elbo.item()
            for k in total_metrics:
                total_metrics[k] += metrics[k]
            n_batches += 1

        optimizer_inf.step()

        for k in total_metrics:
            total_metrics[k] /= n_batches

        print(f"Inference ELBO: {total_elbo:.2e}")
        print(f"  NLL:     {total_metrics['nll']:.3e}")
        print(f"  KL(t):   {total_metrics['kl_t']:.3e}")
        print(f"  KL(p):   {total_metrics['kl_p']:.3e}")
        print(f"  t_cont:  {total_metrics['t_cont']:.3e}")

        # Check gradients
        for p in inference_params:
            print(f"  Grad | {p.shape}: {p.grad.norm().item():.3e}")

        elbo_log.append(("inference", epoch, total_elbo))
        metrics_log.append(("inference", epoch, total_metrics.copy()))

    # === Generative Phase ===
    for _ in range(n_gen_steps):
        optimizer_gen.zero_grad()
        total_elbo = 0
        total_metrics = {
            "nll": 0.0,
            "kl_t": 0.0,
            "kl_p": 0.0,
            "t_cont": 0.0
        }
        n_batches = 0

        for batch in batch_indices(X.shape[0], batch_size):
            X_batch = X[batch]
            elbo, metrics = compute_elbo_batch(
                X_batch, batch,
                traj_graph, posterior, edge_to_index,
                g_a, g_b, K, log_sigma2.exp(),
                belief_propagator=belief_propagator,
                n_samples=n_samples,
                kl_weight=kl_weight,
                kl_p_weight=kl_p_weight,
                t_cont_weight=t_cont_weight,
                pi=pi
            )
            elbo.backward()
            total_elbo += elbo.item()
            for k in total_metrics:
                total_metrics[k] += metrics[k]
            n_batches += 1

        optimizer_gen.step()

        for k in total_metrics:
            total_metrics[k] /= n_batches

        print(f"Generative ELBO: {total_elbo:.2e}")
        print(f"  NLL:     {total_metrics['nll']:.3e}")
        print(f"  KL(t):   {total_metrics['kl_t']:.3e}")
        print(f"  KL(p):   {total_metrics['kl_p']:.3e}")
        print(f"  t_cont:  {total_metrics['t_cont']:.3e}")

        # Check gradients
        for p in generative_params:
            print(f"  Grad | {p.shape}: {p.grad.norm().item():.3e}")

        elbo_log.append(("generative", epoch, total_elbo))
        metrics_log.append(("generative", epoch, total_metrics.copy()))
# Out:
# [Epoch 0]
# Inference ELBO: 6.06e+05
#   NLL:     5.510e+04
#   KL(t):   6.602e-01
#   KL(p):   3.236e-02
#   t_cont:  3.984e-01
#   Grad | torch.Size([5454, 9]): 5.421e+03
#   Grad | torch.Size([5454, 9]): 5.214e+03
#   Grad | torch.Size([5454, 9]): 1.107e-02
# Inference ELBO: 6.24e+05
#   NLL:     5.676e+04
#   KL(t):   6.625e-01
#   KL(p):   3.129e-02
#   t_cont:  3.923e-01
#   Grad | torch.Size([5454, 9]): 5.667e+03
#   Grad | torch.Size([5454, 9]): 5.241e+03
#   Grad | torch.Size([5454, 9]): 1.082e-02
# Inference ELBO: 6.06e+05
#   NLL:     5.507e+04
#   KL(t):   6.753e-01
#   KL(p):   3.048e-02
#   t_cont:  3.930e-01
#   Grad | torch.Size([5454, 9]): 5.893e+03
#   Grad | torch.Size([5454, 9]): 5.189e+03
#   Grad | torch.Size([5454, 9]): 1.073e-02
# Inference ELBO: 5.99e+05
#   NLL:     5.446e+04
#   KL(t):   6.731e-01
#   KL(p):   2.948e-02
#   t_cont:  4.002e-01
#   Grad | torch.Size([5454, 9]): 5.762e+03
#   Grad | torch.Size([5454, 9]): 5.317e+03
#   Grad | torch.Size([5454, 9]): 1.050e-02
# Inference ELBO: 5.94e+05
#   NLL:     5.404e+04
#   KL(t):   6.895e-01
#   KL(p):   2.852e-02
#   t_cont:  3.902e-01
#   Grad | torch.Size([5454, 9]): 5.865e+03
#   Grad | torch.Size([5454, 9]): 5.156e+03
#   Grad | torch.Size([5454, 9]): 1.031e-02
# Inference ELBO: 5.80e+05
#   NLL:     5.273e+04
#   KL(t):   7.100e-01
#   KL(p):   2.760e-02
#   t_cont:  4.016e-01
#   Grad | torch.Size([5454, 9]): 5.858e+03
#   Grad | torch.Size([5454, 9]): 5.084e+03
#   Grad | torch.Size([5454, 9]): 1.014e-02
# Inference ELBO: 6.03e+05
#   NLL:     5.483e+04
#   KL(t):   7.041e-01
#   KL(p):   2.667e-02
#   t_cont:  3.945e-01
#   Grad | torch.Size([5454, 9]): 5.722e+03
#   Grad | torch.Size([5454, 9]): 4.994e+03
#   Grad | torch.Size([5454, 9]): 9.905e-03
# Inference ELBO: 5.95e+05
#   NLL:     5.405e+04
#   KL(t):   7.293e-01
#   KL(p):   2.590e-02
#   t_cont:  3.934e-01
#   Grad | torch.Size([5454, 9]): 5.638e+03
#   Grad | torch.Size([5454, 9]): 5.074e+03
#   Grad | torch.Size([5454, 9]): 9.785e-03
# Generative ELBO: 6.12e+05
#   NLL:     5.564e+04
#   KL(t):   7.295e-01
#   KL(p):   2.508e-02
#   t_cont:  4.012e-01
#   Grad | torch.Size([18, 1000]): 2.803e+04
#   Grad | torch.Size([18, 1000]): 1.106e+04
#   Grad | torch.Size([18, 1000]): 3.447e+03
#   Grad | torch.Size([18, 1000]): 1.413e+01
# Generative ELBO: 5.98e+05
#   NLL:     5.436e+04
#   KL(t):   7.414e-01
#   KL(p):   2.504e-02
#   t_cont:  3.969e-01
#   Grad | torch.Size([18, 1000]): 3.062e+04
#   Grad | torch.Size([18, 1000]): 1.626e+04
#   Grad | torch.Size([18, 1000]): 5.339e+03
#   Grad | torch.Size([18, 1000]): 1.511e+01
# Generative ELBO: 5.89e+05
#   NLL:     5.351e+04
#   KL(t):   7.333e-01
#   KL(p):   2.507e-02
#   t_cont:  3.991e-01
#   Grad | torch.Size([18, 1000]): 2.717e+04
#   Grad | torch.Size([18, 1000]): 1.397e+04
#   Grad | torch.Size([18, 1000]): 4.398e+03
#   Grad | torch.Size([18, 1000]): 1.547e+01
#
# [Epoch 1]
# Inference ELBO: 5.97e+05
#   NLL:     5.427e+04
#   KL(t):   7.344e-01
#   KL(p):   2.502e-02
#   t_cont:  4.013e-01
#   Grad | torch.Size([5454, 9]): 6.424e+03
#   Grad | torch.Size([5454, 9]): 5.780e+03
#   Grad | torch.Size([5454, 9]): 9.580e-03
# Inference ELBO: 6.13e+05
#   NLL:     5.573e+04
#   KL(t):   7.478e-01
#   KL(p):   2.426e-02
#   t_cont:  4.014e-01
#   Grad | torch.Size([5454, 9]): 6.501e+03
#   Grad | torch.Size([5454, 9]): 6.016e+03
#   Grad | torch.Size([5454, 9]): 9.447e-03
# Inference ELBO: 6.15e+05
#   NLL:     5.588e+04
#   KL(t):   7.502e-01
#   KL(p):   2.354e-02
#   t_cont:  3.991e-01
#   Grad | torch.Size([5454, 9]): 6.362e+03
#   Grad | torch.Size([5454, 9]): 5.873e+03
#   Grad | torch.Size([5454, 9]): 9.323e-03
# Inference ELBO: 5.80e+05
#   NLL:     5.268e+04
#   KL(t):   7.714e-01
#   KL(p):   2.270e-02
#   t_cont:  4.057e-01
#   Grad | torch.Size([5454, 9]): 6.132e+03
#   Grad | torch.Size([5454, 9]): 4.984e+03
#   Grad | torch.Size([5454, 9]): 9.023e-03
# Inference ELBO: 5.97e+05
#   NLL:     5.431e+04
#   KL(t):   7.824e-01
#   KL(p):   2.206e-02
#   t_cont:  4.010e-01
#   Grad | torch.Size([5454, 9]): 6.508e+03
#   Grad | torch.Size([5454, 9]): 6.069e+03
#   Grad | torch.Size([5454, 9]): 8.942e-03
# Inference ELBO: 5.84e+05
#   NLL:     5.306e+04
#   KL(t):   8.059e-01
#   KL(p):   2.129e-02
#   t_cont:  4.034e-01
#   Grad | torch.Size([5454, 9]): 5.943e+03
#   Grad | torch.Size([5454, 9]): 5.553e+03
#   Grad | torch.Size([5454, 9]): 8.779e-03
# Inference ELBO: 5.76e+05
#   NLL:     5.232e+04
#   KL(t):   8.135e-01
#   KL(p):   2.071e-02
#   t_cont:  4.025e-01
#   Grad | torch.Size([5454, 9]): 6.090e+03
#   Grad | torch.Size([5454, 9]): 5.601e+03
#   Grad | torch.Size([5454, 9]): 8.643e-03
# Inference ELBO: 5.98e+05
#   NLL:     5.432e+04
#   KL(t):   5.943e+01
#   KL(p):   1.996e-02
#   t_cont:  4.015e-01
#   Grad | torch.Size([5454, 9]): 7.003e+03
#   Grad | torch.Size([5454, 9]): 5.838e+03
#   Grad | torch.Size([5454, 9]): 8.414e-03
# Generative ELBO: 5.73e+05
#   NLL:     5.200e+04
#   KL(t):   5.944e+01
#   KL(p):   1.945e-02
#   t_cont:  4.052e-01
#   Grad | torch.Size([18, 1000]): 2.785e+04
#   Grad | torch.Size([18, 1000]): 1.338e+04
#   Grad | torch.Size([18, 1000]): 4.475e+03
#   Grad | torch.Size([18, 1000]): 1.496e+01
# Generative ELBO: 5.76e+05
#   NLL:     5.234e+04
#   KL(t):   5.943e+01
#   KL(p):   1.932e-02
#   t_cont:  4.043e-01
#   Grad | torch.Size([18, 1000]): 3.043e+04
#   Grad | torch.Size([18, 1000]): 1.167e+04
#   Grad | torch.Size([18, 1000]): 3.795e+03
#   Grad | torch.Size([18, 1000]): 1.430e+01
# Generative ELBO: 5.94e+05
#   NLL:     5.397e+04
#   KL(t):   8.393e-01
#   KL(p):   1.929e-02
#   t_cont:  4.118e-01
#   Grad | torch.Size([18, 1000]): 2.603e+04
#   Grad | torch.Size([18, 1000]): 1.191e+04
#   Grad | torch.Size([18, 1000]): 3.896e+03
#   Grad | torch.Size([18, 1000]): 1.403e+01
#
# [Epoch 2]
# KeyboardInterrupt

# %% [markdown]
# # Test Plotting

# %%
from utils import make_beta_assignment_df

beta_assignments = make_beta_assignment_df(posterior, cell_assignment, sharpness=0.01)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[55], line 3
#       1 from utils import make_beta_assignment_df
# ----> 3 beta_assignments = make_beta_assignment_df(posterior, cell_assignment, sharpness=0.01)
#
# File /work/vanaja_lab/griffin/projects/viCSHMM/utils/inference.py:60, in make_beta_assignment_df(posterior, cell_assignment, sharpness)
#      40 """
#      41 Convert hard cell assignments to a DataFrame of beta distribution parameters
#      42 usable for probabilistic trajectory visualization.
#    (...)
#      56     pd.DataFrame: Indexed by cell ID, with columns 'edge', 'alpha', 'beta'.
#      57 """
#      58 from utils.inference import initialize_beta_from_cell_assignment, find_path_index_for_edge
# ---> 60 initialize_beta_from_cell_assignment(posterior, cell_assignment, sharpness=sharpness)
#      62 cell_ids = list(cell_assignment.index)
#      63 edges = list(cell_assignment["edge"])
#
# TypeError: initialize_beta_from_cell_assignment() missing 1 required positional argument: 'edge_to_index'

# %%
from viz.trajectory import plot_pdf_width_ribbons_on_trajectory

plot_pdf_width_ribbons_on_trajectory(
    traj_graph,
    beta_assignments,
    adata,
    color_key="leiden",
    pdf_scale=0.1,  # adjust if too narrow/wide
    curve_amount=0.8,
    title="Beta-Modeled Cell Assignments as Ribbons"
)

# %%
adata.var
# Out:
#           n_cells  highly_variable     means  dispersions  dispersions_norm
# Lypla1       2576             True  0.250853    -0.930302          1.950977
# Ncoa2         993             True  0.099955    -0.569126          1.877314
# Gm10566        76             True  0.010847    -0.106430          1.912057
# Imp4         3037             True  0.295466    -1.094584          1.782918
# Fam168b      2119             True  0.204745    -0.815239          1.617195
# ...           ...              ...       ...          ...               ...
# Rps7-ps3     2274             True  0.221367    -0.861823          1.828743
# Map3k15       346             True  0.038561    -0.390028          2.149240
# Syap1         970             True  0.100843    -0.545244          1.989039
# Ctps2        2537             True  0.264015    -0.860618          2.211714
# Cltrn         729             True  0.067131    -0.568660          1.657125
#
# [1000 rows x 5 columns]

# %%
from scipy.stats import beta
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import matplotlib.colors as mcolors
import networkx as nx
import pandas as pd

def plot_gene_dynamics_on_trajectory(
    G_traj, beta_assignments, adata, gene_name,
    resolution=100, curve_scale=1.0, blend_fraction=0.1,
    title="Gene Dynamics with Uncertainty"
):
    """
    Visualizes gene expression dynamics along trajectory edges while incorporating
    uncertainty from cell assignments. The tree structure is drawn first (nodes and
    straight edges). Over each edge, we compute for a set of t-values:
      - A weighted gene expression (which becomes the vertical offset from the base edge)
      - A weighted certainty (a proxy using each cell's beta PDF peak)
    
    The curve is drawn along the edge offset perpendicularly by the weighted expression
    (scaled by curve_scale). If the source node of an edge is a split, the first few points
    of the branch are blended with the parent's endpoint (source node position) using the 
    transition probability (attribute "A") from that edge.
    
    Args:
        G_traj: Trajectory graph (networkx.DiGraph or TrajectoryGraph object).
        beta_assignments (pd.DataFrame): Indexed by cell IDs with columns:
            'edge' (tuple of two node IDs), 'alpha', 'beta'.
        adata: AnnData-like object (for gene expression and cell IDs).
        gene_name (str): Gene to visualize (must be in adata.var_names).
        resolution (int): Number of t-values along each edge.
        curve_scale (float): Factor to scale the vertical offset of the curve.
        blend_fraction (float): Fraction of the curve (from t=0) to blend at split nodes.
        title (str): Plot title.
    """
    # If G_traj is a TrajectoryGraph, extract its underlying networkx graph.
    if hasattr(G_traj, 'G_traj'):
        G_traj = G_traj.G_traj

    # Compute node positions using graphviz layout.
    pos = nx.nx_agraph.graphviz_layout(G_traj, prog="dot", args="-Grankdir=LR")
    plt.figure(figsize=(12, 7))
    
    # Draw the tree structure: nodes and edges.
    for node, (x, y) in pos.items():
        plt.scatter(x, y, color='black', s=500, zorder=3)
        plt.text(x, y, node, fontsize=10, ha="center", va="center", zorder=4)
    for src, dst in G_traj.edges():
        if src not in pos or dst not in pos:
            continue
        P0, P1 = np.array(pos[src]), np.array(pos[dst])
        plt.plot([P0[0], P1[0]], [P0[1], P1[1]], color='lightgrey', lw=5, alpha=0.5, zorder=1)
    
    # Extract gene expression as a pandas Series (indexed by cell IDs).
    if gene_name in adata.var_names:
        gene_idx = adata.var_names.get_loc(gene_name)
        expr_array = (adata.X[:, gene_idx].toarray().ravel() 
                      if hasattr(adata.X, "toarray") 
                      else np.array(adata.X[:, gene_idx]).ravel())
        expr_series = pd.Series(expr_array, index=adata.obs_names)
    else:
        raise ValueError(f"Gene '{gene_name}' not found in adata.var_names")
    
    # Group cells by edge.
    # For each cell, compute its beta PDF along a grid of t-values.
    t_vals = np.linspace(0, 1, resolution)
    edge_groups = {}  # { edge: list of dicts for each cell }
    for cell_id, row in beta_assignments.iterrows():
        edge = row['edge']
        alpha_param = row['alpha']
        beta_param = row['beta']
        if not edge or alpha_param <= 0 or beta_param <= 0:
            continue
        # Compute beta PDF for this cell.
        pdf_vals = beta.pdf(t_vals, alpha_param, beta_param)
        pdf_vals = np.nan_to_num(pdf_vals)
        # Use the maximum of the PDF as a simple measure of certainty.
        cert = pdf_vals.max()
        if edge not in edge_groups:
            edge_groups[edge] = []
        edge_groups[edge].append({
            "cell_id": cell_id,
            "pdf": pdf_vals,
            "expr": expr_series.loc[cell_id],
            "cert": cert
        })
    
    # Prepare a colormap for certainty: blue = low, red = high.
    cmap = cm.RdBu_r

    # For each edge, compute the weighted gene expression and certainty along t.
    for edge, cells in edge_groups.items():
        src, dst = edge
        if src not in pos or dst not in pos:
            continue
        P0 = np.array(pos[src])
        P1 = np.array(pos[dst])
        direction = P1 - P0
        seg_length = np.linalg.norm(direction)
        if seg_length == 0:
            continue
        direction = direction / seg_length
        # Compute a perpendicular (normal) vector.
        normal = np.array([-direction[1], direction[0]])
        
        # Initialize accumulators for weighted expression and certainty.
        weighted_expr = np.zeros_like(t_vals, dtype=float)
        weighted_cert = np.zeros_like(t_vals, dtype=float)
        weight_sum = np.zeros_like(t_vals, dtype=float)
        
        for cell in cells:
            pdf_vals = cell["pdf"]
            weighted_expr += cell["expr"] * pdf_vals
            weighted_cert += cell["cert"] * pdf_vals
            weight_sum += pdf_vals
        
        mask = weight_sum > 0
        weighted_expr[mask] /= weight_sum[mask]
        weighted_cert[mask] /= weight_sum[mask]
        
        # Compute the base curve along the edge.
        base_curve = np.array([P0 + t * (P1 - P0) for t in t_vals])
        # Offset the base curve by the weighted expression along the normal,
        # scaling the offset by curve_scale.
        curve_pts = base_curve + np.outer(weighted_expr * curve_scale, normal)
        
        # If the source node is a split, blend the first few points with the parent's endpoint.
        # We assume that a split node is identified by its type attribute containing "split".
        if "split" in G_traj.nodes[src].get("type", ""):
            # Get the transition probability for this edge (default to 1 if not defined)
            A = G_traj.edges[src, dst].get("A", 1.0)
            # Blend the first blend_count points.
            blend_count = max(2, int(blend_fraction * resolution))
            for i in range(blend_count):
                blend_weight = A * (i / blend_count)  # gradually ramp from 0 to A
                # Blend parent's endpoint (P0) and the computed branch start.
                curve_pts[i] = (1 - blend_weight) * P0 + blend_weight * curve_pts[i]
        
        # Normalize certainty values for color mapping.
        cert_min, cert_max = weighted_cert.min(), weighted_cert.max()
        if cert_max > cert_min:
            norm_cert = (weighted_cert - cert_min) / (cert_max - cert_min)
        else:
            norm_cert = np.full_like(weighted_cert, 0.5)
        
        # Draw the curve as a series of short segments colored by certainty.
        for i in range(resolution - 1):
            seg_x = curve_pts[i:i+2, 0]
            seg_y = curve_pts[i:i+2, 1]
            seg_color = cmap(norm_cert[i])
            plt.plot(seg_x, seg_y, color=seg_color, lw=2, zorder=2)
    
    plt.title(title)
    plt.axis("off")
    plt.tight_layout()
    plt.show()

# %%
plot_gene_dynamics_on_trajectory(traj_graph, beta_assignments, adata, gene_name='Lypla1',
                                 resolution=100, curve_scale=100.0, blend_fraction=0.1,
                                 title="Gene Dynamics on Trajectory for Lypla1")
