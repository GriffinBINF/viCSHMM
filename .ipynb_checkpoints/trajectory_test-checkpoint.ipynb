# %%
# # Path to h5ad dataset
# dataset_path = '/work/vanaja_lab/griffin/projects/cshmm/results/pancreas_dev.h5ad'

# # Load and prepare AnnData
# if os.path.exists(dataset_path):
#     print("File exists. Loading the dataset...")
#     adata = sc.read_h5ad(dataset_path)
#     print("Dataset loaded successfully!")
#     print("Dataset shape:", adata.shape)
# else:
#     raise FileNotFoundError(f"File not found at: {dataset_path}")

# adata.obs_names_make_unique()

# # Preprocessing steps
# sc.pp.normalize_total(adata, target_sum=1e4)
# sc.pp.log1p(adata)

# # Min-max scaling
# scaler = MinMaxScaler()
# adata.X = scaler.fit_transform(adata.X.toarray())

# # HVG selection
# sc.pp.highly_variable_genes(adata, n_top_genes=1000, flavor='seurat')
# adata = adata[:, adata.var['highly_variable']].copy()

# print(f"Dataset shape after selecting top 1000 HVGs: {adata.shape}")

# %%
# Dimensionality reduction and clustering
# sc.pp.pca(adata)
# sc.pp.neighbors(adata)
# sc.tl.umap(adata)
# sc.tl.leiden(adata, resolution=2, key_added="leiden")

# # Plot UMAP with clusters
# sc.pl.umap(adata, color="leiden", legend_loc="on data", title="UMAP - Leiden Clusters")

# # PAGA
# sc.tl.paga(adata, groups='leiden')
# sc.pl.paga(adata, color='leiden', title="PAGA Connectivity Graph")
# sc.pl.umap(adata, color=['leiden'], edges=True, title="UMAP with PAGA Connectivity")

# %%
#adata.write('data/mouse_panc_dev.h5ad')

# %%
import os
import scanpy as sc
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler

from models import TrajectoryGraph, initialize_trajectory
# Out:
# /work/vanaja_lab/griffin/miniconda3/envs/cellrank/lib/python3.12/site-packages/anndata/utils.py:429: FutureWarning: Importing read_csv from `anndata` is deprecated. Import anndata.io.read_csv instead.
#   warnings.warn(msg, FutureWarning)
# /work/vanaja_lab/griffin/miniconda3/envs/cellrank/lib/python3.12/site-packages/anndata/utils.py:429: FutureWarning: Importing read_excel from `anndata` is deprecated. Import anndata.io.read_excel instead.
#   warnings.warn(msg, FutureWarning)
# /work/vanaja_lab/griffin/miniconda3/envs/cellrank/lib/python3.12/site-packages/anndata/utils.py:429: FutureWarning: Importing read_hdf from `anndata` is deprecated. Import anndata.io.read_hdf instead.
#   warnings.warn(msg, FutureWarning)
# /work/vanaja_lab/griffin/miniconda3/envs/cellrank/lib/python3.12/site-packages/anndata/utils.py:429: FutureWarning: Importing read_loom from `anndata` is deprecated. Import anndata.io.read_loom instead.
#   warnings.warn(msg, FutureWarning)
# /work/vanaja_lab/griffin/miniconda3/envs/cellrank/lib/python3.12/site-packages/anndata/utils.py:429: FutureWarning: Importing read_mtx from `anndata` is deprecated. Import anndata.io.read_mtx instead.
#   warnings.warn(msg, FutureWarning)
# /work/vanaja_lab/griffin/miniconda3/envs/cellrank/lib/python3.12/site-packages/anndata/utils.py:429: FutureWarning: Importing read_text from `anndata` is deprecated. Import anndata.io.read_text instead.
#   warnings.warn(msg, FutureWarning)
# /work/vanaja_lab/griffin/miniconda3/envs/cellrank/lib/python3.12/site-packages/anndata/utils.py:429: FutureWarning: Importing read_umi_tools from `anndata` is deprecated. Import anndata.io.read_umi_tools instead.
#   warnings.warn(msg, FutureWarning)

# %%
adata = sc.read('data/mouse_panc_dev.h5ad')

# %%
# Build the trajectory graph
traj_graph, cell_assignment = initialize_trajectory(
    adata=adata,
    random_state=41,
    debug=True
)
# Out:
# Trajectory graph nodes: ['leaf_0', 'leaf_1', 'leaf_2', 'split_3', 'leaf_4', 'root_split_5', 'leaf_6', 'split_7', 'split_8', 'split_9', 'split_10', 'int_11', 'leaf_12', 'leaf_13', 'split_14', 'split_15', 'leaf_16', 'leaf_17', 'RootNode_0_0']
# Trajectory graph edges: [('split_3', 'split_7'), ('split_3', 'split_8'), ('root_split_5', 'split_3'), ('root_split_5', 'split_15'), ('split_7', 'leaf_4'), ('split_7', 'leaf_17'), ('split_8', 'leaf_0'), ('split_8', 'leaf_12'), ('split_9', 'leaf_1'), ('split_9', 'leaf_6'), ('split_10', 'split_9'), ('split_10', 'leaf_16'), ('int_11', 'leaf_13'), ('split_14', 'leaf_2'), ('split_14', 'int_11'), ('split_15', 'split_10'), ('split_15', 'split_14'), ('RootNode_0_0', 'root_split_5')]
#
# Sample cell assignments:
#                                  edge  latent_time
# TAAGCGTAGGCCCGTT   (split_7, leaf_4)     0.773956
# GACCAATAGTCGTCGT  (split_3, split_8)     0.438878
# CGAGAAGCATGCTAGT   (split_7, leaf_4)     0.858598
# ACGATGTAGGATTCCC   (split_7, leaf_4)     0.697368
# GCAGTTAAGGTCATCT   (split_7, leaf_4)     0.094177

# %%
# Visualize trajectory graph with cells assigned
traj_graph.plot_cells_on_trajectory(
    cell_assignment=cell_assignment,
    color_key='leiden',
    curve_amount=0.8,
    node_size=500,
    cell_size=30,
    horizontal_thresh=0.01,
    edge_width=5,
    edge_color='lightgrey',
    title="Cells on Stochastic PAGA Trajectory",
    plot_transitions=True
)

# %%
# # === Imports ===

import torch
import numpy as np
from models.posterior import TreeVariationalPosterior
from models.belief import BeliefPropagator
from models.emission import pack_emission_params
from models.loss import compute_elbo
from utils.inference import initialize_beta_from_cell_assignment, find_path_index_for_edge

# # === Setup ===
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
# Prepare expression data
X = torch.tensor(
    adata.X.toarray() if hasattr(adata.X, 'toarray') else adata.X,
    dtype=torch.float32
).to(device)

# === Trajectory graph initialization ===
traj_graph, cell_assignment = initialize_trajectory(adata, debug=True)
all_nodes = set(traj_graph.node_to_index.keys())
emission_nodes = set(traj_graph.node_emission.keys())
missing = all_nodes - emission_nodes

print(f"\nAll nodes:      {sorted(all_nodes)}")
print(f"Emission nodes: {sorted(emission_nodes)}")
print(f"Missing nodes:  {sorted(missing)}")

edge_to_index, g_a, g_b, K, sigma2, pi, g = pack_emission_params(traj_graph, device=device)


# Convert to learnable parameters
g = g.requires_grad_()
K = K.requires_grad_()
log_sigma2 = torch.log(sigma2).clone().detach().requires_grad_()

# === Posterior setup ===
n_cells = X.shape[0]
posterior = TreeVariationalPosterior(traj_graph, n_cells=n_cells, device=device)

# === Optional beta init from trajectory assignment ===
initialize_beta_from_cell_assignment(posterior, cell_assignment, edge_to_index, sharpness=0.01)

# === Belief propagator over edge topology ===
belief_propagator = BeliefPropagator(traj_graph, posterior)

print("g requires_grad:", g.requires_grad)
print("Initial alpha mean:", posterior.alpha.mean().item())
print("Initial beta mean:", posterior.beta.mean().item())
# Out:
# Trajectory graph nodes: ['root_split_0', 'int_1', 'split_2', 'split_3', 'split_4', 'leaf_5', 'leaf_6', 'split_7', 'leaf_8', 'split_9', 'leaf_10', 'leaf_11', 'leaf_12', 'leaf_13', 'leaf_14', 'split_15', 'split_16', 'leaf_17', 'RootNode_0_0']
# Trajectory graph edges: [('root_split_0', 'split_2'), ('root_split_0', 'split_16'), ('int_1', 'leaf_11'), ('split_2', 'split_7'), ('split_2', 'split_15'), ('split_3', 'leaf_13'), ('split_3', 'leaf_14'), ('split_4', 'leaf_12'), ('split_4', 'leaf_17'), ('split_7', 'leaf_5'), ('split_7', 'leaf_8'), ('split_9', 'leaf_6'), ('split_9', 'leaf_10'), ('split_15', 'int_1'), ('split_15', 'split_3'), ('split_16', 'split_4'), ('split_16', 'split_9'), ('RootNode_0_0', 'root_split_0')]
#
# Sample cell assignments:
#                                   edge  latent_time
# TAAGCGTAGGCCCGTT  (split_16, split_4)     0.773956
# GACCAATAGTCGTCGT    (split_7, leaf_8)     0.438878
# CGAGAAGCATGCTAGT  (split_16, split_4)     0.858598
# ACGATGTAGGATTCCC  (split_16, split_4)     0.697368
# GCAGTTAAGGTCATCT  (split_16, split_4)     0.094177
#
# All nodes:      ['RootNode_0_0', 'int_1', 'leaf_10', 'leaf_11', 'leaf_12', 'leaf_13', 'leaf_14', 'leaf_17', 'leaf_5', 'leaf_6', 'leaf_8', 'root_split_0', 'split_15', 'split_16', 'split_2', 'split_3', 'split_4', 'split_7', 'split_9']
# Emission nodes: ['RootNode_0_0', 'int_1', 'leaf_10', 'leaf_11', 'leaf_12', 'leaf_13', 'leaf_14', 'leaf_17', 'leaf_5', 'leaf_6', 'leaf_8', 'root_split_0', 'split_15', 'split_16', 'split_2', 'split_3', 'split_4', 'split_7', 'split_9']
# Missing nodes:  []
# g requires_grad: True
# Initial alpha mean: 3.7523298263549805
# Initial beta mean: 3.69211483001709

# %% [markdown]
# # Test Standard Full Code

# %%
# # === Run Variational Model ===
# for epoch in range(num_epochs):
#     optimizer.zero_grad()

#     loss, metrics = compute_elbo(
#         X, traj_graph, posterior, edge_to_index,
#         g_a, g_b, K, log_sigma2.exp(),
#         pi=pi,
#         belief_propagator=belief_propagator,
#         n_samples=n_samples,
#         kl_weight=kl_weight,
#         kl_p_weight=kl_p_weight,
#         t_cont_weight=t_cont_weight
#     )

#     loss.backward()
#     print_grad_stats()
#     log_epoch(epoch, loss, metrics)
#     optimizer.step()

# %%
import os
os.environ["CUDA_LAUNCH_BLOCKING"] = "1"

# %%
from models.loss import compute_elbo_batch
from utils.inference import batch_indices

batch_size = 512
num_epochs = 100
n_samples = 3
freeze_epochs = 5
# Training weights
kl_weight = 1.0
kl_p_weight = 1.0
t_cont_weight = 1.0

elbo_log = []
nll_log = []
kl_t_log = []
kl_p_log = []
t_cont_log = []
transition_log = []
l1_log = []
grad_log = []

# Freeze emission parameters initially
emission_params = [g, K, log_sigma2]
for p in emission_params:
    p.requires_grad_(False)

optimizer = torch.optim.Adam(
    [posterior.alpha, posterior.beta, posterior.edge_logits] + emission_params,
    lr=1e-2
)

for epoch in range(num_epochs):
    total_loss = 0.0
    total_batches = 0
    epoch_metrics = {
        "nll": 0.0,
        "kl_t": 0.0,
        "kl_p": 0.0,
        "t_cont": 0.0,
        "transition": 0.0,
        "l1": 0.0
    }

    # === Unfreeze after warmup ===
    if epoch == freeze_epochs:
        for p in emission_params:
            p.requires_grad_(True)

    for batch in batch_indices(X.shape[0], batch_size):
        assert batch.dtype == torch.long, f"batch dtype is {batch.dtype}, expected torch.long"
        assert X.dim() == 2, f"X has shape {X.shape}, expected 2D tensor"

        # print("batch shape:", batch.shape)
        # print("batch dtype:", batch.dtype)
        # print("min(batch):", batch.min().item())
        # print("max(batch):", batch.max().item())
        # print("X.shape[0]:", X.shape[0])

        torch.cuda.synchronize()
        X_batch = X[batch]
        optimizer.zero_grad()

        # print("posterior edge list:")
        # for i, edge in enumerate(posterior.edge_list):
        #     print(f"{i}: {edge}")
        
        # print("traj_graph.edge_list:")
        # for i, edge in enumerate(traj_graph.edge_list):
        #     print(f"{i}: {edge}")

        loss, metrics = compute_elbo_batch(
            X_batch, batch,
            traj_graph, posterior, edge_to_index,
            g, K, log_sigma2.exp(),
            belief_propagator=belief_propagator,
            n_samples=n_samples,
            kl_weight=kl_weight,
            kl_p_weight=kl_p_weight,
            t_cont_weight=t_cont_weight,
            transition_weight=1.0,  # adjustable
            pi=pi
        )

        loss.backward()
        optimizer.step()

        total_loss += loss.item()
        for key in epoch_metrics:
            epoch_metrics[key] += metrics.get(key, 0.0)
        total_batches += 1

    # Normalize per batch
    for key in epoch_metrics:
        epoch_metrics[key] /= total_batches

    # === Log gradient norms ===
    grad_norms = {
        "alpha": posterior.alpha.grad.norm().item() if posterior.alpha.grad is not None else 0.0,
        "beta": posterior.beta.grad.norm().item() if posterior.beta.grad is not None else 0.0,
        "edge_logits": posterior.edge_logits.grad.norm().item() if posterior.edge_logits.grad is not None else 0.0,
        "g": g.grad.norm().item() if g.grad is not None else 0.0,
        "K": K.grad.norm().item() if K.grad is not None else 0.0,
        "log_sigma2": log_sigma2.grad.norm().item() if log_sigma2.grad is not None else 0.0,
    }

    # Store logs
    elbo_log.append(total_loss / total_batches)
    nll_log.append(epoch_metrics["nll"])
    kl_t_log.append(epoch_metrics["kl_t"])
    kl_p_log.append(epoch_metrics["kl_p"])
    t_cont_log.append(epoch_metrics["t_cont"])
    transition_log.append(epoch_metrics["transition"])
    l1_log.append(epoch_metrics["l1"])
    grad_log.append(grad_norms)

    # === Print ===
    print(f"\n[Epoch {epoch}]")
    print(f"  ELBO:       {elbo_log[-1]:.4e}")
    print(f"  NLL:        {epoch_metrics['nll']:.4e}")
    print(f"  KL(t):      {epoch_metrics['kl_t']:.4e}")
    print(f"  KL(p):      {epoch_metrics['kl_p']:.4e}")
    print(f"  t_cont:     {epoch_metrics['t_cont']:.4e}")
    print(f"  transition: {epoch_metrics['transition']:.4e}")
    print(f"  L1:         {epoch_metrics['l1']:.4e}")
    print("  Grad Norms:")
    for k, v in grad_norms.items():
        print(f"    {k}: {v:.2e}")
# Out:
# [Epoch 0]
#   ELBO:       6.2128e+05
#   NLL:        6.2126e+05
#   KL(t):      1.0866e-01
#   KL(p):      0.0000e+00
#   t_cont:     3.3503e-01
#   transition: -1.5913e+01
#   L1:         2.4551e+01
#   Grad Norms:
#     alpha: 1.34e+03
#     beta: 1.17e+03
#     edge_logits: 1.55e-10
#     g: 0.00e+00
#     K: 0.00e+00
#     log_sigma2: 0.00e+00
#
# [Epoch 1]
#   ELBO:       6.3669e+05
#   NLL:        6.3667e+05
#   KL(t):      1.0143e-01
#   KL(p):      0.0000e+00
#   t_cont:     3.3708e-01
#   transition: -1.5881e+01
#   L1:         2.4551e+01
#   Grad Norms:
#     alpha: 1.39e+03
#     beta: 1.17e+03
#     edge_logits: 1.55e-10
#     g: 0.00e+00
#     K: 0.00e+00
#     log_sigma2: 0.00e+00
#
# [Epoch 2]
#   ELBO:       6.4005e+05
#   NLL:        6.4003e+05
#   KL(t):      1.0920e-01
#   KL(p):      0.0000e+00
#   t_cont:     3.3577e-01
#   transition: -1.5938e+01
#   L1:         2.4551e+01
#   Grad Norms:
#     alpha: 1.47e+03
#     beta: 1.17e+03
#     edge_logits: 1.55e-10
#     g: 0.00e+00
#     K: 0.00e+00
#     log_sigma2: 0.00e+00
#
# [Epoch 3]
#   ELBO:       6.2394e+05
#   NLL:        6.2393e+05
#   KL(t):      1.0626e-01
#   KL(p):      0.0000e+00
#   t_cont:     3.2982e-01
#   transition: -1.5928e+01
#   L1:         2.4551e+01
#   Grad Norms:
#     alpha: 1.15e+03
#     beta: 1.05e+03
#     edge_logits: 1.55e-10
#     g: 0.00e+00
#     K: 0.00e+00
#     log_sigma2: 0.00e+00
#
# [Epoch 4]
#   ELBO:       6.3569e+05
#   NLL:        6.3568e+05
#   KL(t):      1.1157e-01
#   KL(p):      0.0000e+00
#   t_cont:     3.2717e-01
#   transition: -1.5884e+01
#   L1:         2.4551e+01
#   Grad Norms:
#     alpha: 1.52e+03
#     beta: 1.30e+03
#     edge_logits: 1.55e-10
#     g: 0.00e+00
#     K: 0.00e+00
#     log_sigma2: 0.00e+00
#
# [Epoch 5]
#   ELBO:       5.3080e+05
#   NLL:        5.3078e+05
#   KL(t):      1.0626e-01
#   KL(p):      0.0000e+00
#   t_cont:     3.2106e-01
#   transition: -1.5936e+01
#   L1:         2.6210e+01
#   Grad Norms:
#     alpha: 1.03e+03
#     beta: 8.99e+02
#     edge_logits: 1.55e-10
#     g: 5.66e+04
#     K: 1.89e+03
#     log_sigma2: 2.62e+01
#
# [Epoch 6]
#   ELBO:       3.5473e+05
#   NLL:        3.5472e+05
#   KL(t):      1.1183e-01
#   KL(p):      0.0000e+00
#   t_cont:     3.2405e-01
#   transition: -1.5921e+01
#   L1:         2.9550e+01
#   Grad Norms:
#     alpha: 7.87e+02
#     beta: 6.04e+02
#     edge_logits: 1.55e-10
#     g: 4.37e+04
#     K: 1.17e+03
#     log_sigma2: 1.90e+01
#
# [Epoch 7]
#   ELBO:       2.3175e+05
#   NLL:        2.3174e+05
#   KL(t):      1.1209e-01
#   KL(p):      0.0000e+00
#   t_cont:     3.2181e-01
#   transition: -1.5938e+01
#   L1:         3.3385e+01
#   Grad Norms:
#     alpha: 5.99e+02
#     beta: 4.55e+02
#     edge_logits: 1.55e-10
#     g: 2.69e+04
#     K: 6.85e+02
#     log_sigma2: 1.15e+01
#
# [Epoch 8]
#   ELBO:       1.5231e+05
#   NLL:        1.5229e+05
#   KL(t):      1.2428e-01
#   KL(p):      0.0000e+00
#   t_cont:     3.2168e-01
#   transition: -1.5906e+01
#   L1:         3.7497e+01
#   Grad Norms:
#     alpha: 4.46e+02
#     beta: 3.90e+02
#     edge_logits: 1.55e-10
#     g: 1.90e+04
#     K: 5.03e+02
#     log_sigma2: 9.14e+00
#
# [Epoch 9]
#   ELBO:       1.1299e+05
#   NLL:        1.1297e+05
#   KL(t):      1.2177e-01
#   KL(p):      0.0000e+00
#   t_cont:     3.2400e-01
#   transition: -1.5921e+01
#   L1:         4.1664e+01
#   Grad Norms:
#     alpha: 4.09e+02
#     beta: 3.40e+02
#     edge_logits: 1.55e-10
#     g: 1.52e+04
#     K: 4.84e+02
#     log_sigma2: 5.54e+00
#
# [Epoch 10]
#   ELBO:       8.8015e+04
#   NLL:        8.7999e+04
#   KL(t):      1.2181e-01
#   KL(p):      0.0000e+00
#   t_cont:     3.1683e-01
#   transition: -1.5922e+01
#   L1:         4.5710e+01
#   Grad Norms:
#     alpha: 6.32e+02
#     beta: 4.62e+02
#     edge_logits: 1.55e-10
#     g: 1.17e+04
#     K: 4.66e+02
#     log_sigma2: 5.69e+00
#
# [Epoch 11]
#   ELBO:       7.2342e+04
#   NLL:        7.2325e+04
#   KL(t):      1.2098e-01
#   KL(p):      0.0000e+00
#   t_cont:     3.1923e-01
#   transition: -1.5911e+01
#   L1:         4.9562e+01
#   Grad Norms:
#     alpha: 4.00e+02
#     beta: 3.82e+02
#     edge_logits: 1.55e-10
#     g: 1.10e+04
#     K: 4.95e+02
#     log_sigma2: 5.06e+00
#
# [Epoch 12]
#   ELBO:       6.4904e+04
#   NLL:        6.4887e+04
#   KL(t):      1.2908e-01
#   KL(p):      0.0000e+00
#   t_cont:     3.0913e-01
#   transition: -1.5952e+01
#   L1:         5.2730e+01
#   Grad Norms:
#     alpha: 3.66e+02
#     beta: 3.12e+02
#     edge_logits: 1.55e-10
#     g: 9.61e+03
#     K: 4.93e+02
#     log_sigma2: 3.65e+00
#
# [Epoch 13]
#   ELBO:       5.9583e+04
#   NLL:        5.9567e+04
#   KL(t):      1.2892e-01
#   KL(p):      0.0000e+00
#   t_cont:     3.1438e-01
#   transition: -1.5855e+01
#   L1:         5.5124e+01
#   Grad Norms:
#     alpha: 3.77e+02
#     beta: 3.15e+02
#     edge_logits: 1.55e-10
#     g: 9.51e+03
#     K: 4.72e+02
#     log_sigma2: 3.58e+00
#
# [Epoch 14]
#   ELBO:       5.7039e+04
#   NLL:        5.7023e+04
#   KL(t):      1.3231e-01
#   KL(p):      0.0000e+00
#   t_cont:     3.0724e-01
#   transition: -1.5945e+01
#   L1:         5.6710e+01
#   Grad Norms:
#     alpha: 4.65e+02
#     beta: 3.74e+02
#     edge_logits: 1.55e-10
#     g: 1.01e+04
#     K: 4.80e+02
#     log_sigma2: 4.29e+00
#
# [Epoch 15]
#   ELBO:       5.4610e+04
#   NLL:        5.4593e+04
#   KL(t):      1.3384e-01
#   KL(p):      0.0000e+00
#   t_cont:     3.1495e-01
#   transition: -1.5880e+01
#   L1:         5.7842e+01
#   Grad Norms:
#     alpha: 3.80e+02
#     beta: 3.23e+02
#     edge_logits: 1.55e-10
#     g: 9.28e+03
#     K: 5.78e+02
#     log_sigma2: 3.38e+00
#
# [Epoch 16]
#   ELBO:       5.3900e+04
#   NLL:        5.3884e+04
#   KL(t):      1.3441e-01
#   KL(p):      0.0000e+00
#   t_cont:     2.9872e-01
#   transition: -1.6013e+01
#   L1:         5.9067e+01
#   Grad Norms:
#     alpha: 3.16e+02
#     beta: 2.59e+02
#     edge_logits: 1.55e-10
#     g: 8.41e+03
#     K: 5.12e+02
#     log_sigma2: 3.84e+00
#
# [Epoch 17]
#   ELBO:       5.3222e+04
#   NLL:        5.3206e+04
#   KL(t):      1.3721e-01
#   KL(p):      0.0000e+00
#   t_cont:     3.0792e-01
#   transition: -1.5859e+01
#   L1:         6.0566e+01
#   Grad Norms:
#     alpha: 3.68e+02
#     beta: 3.31e+02
#     edge_logits: 1.55e-10
#     g: 9.49e+03
#     K: 6.26e+02
#     log_sigma2: 3.39e+00
#
# [Epoch 18]
#   ELBO:       5.5735e+04
#   NLL:        5.5719e+04
#   KL(t):      1.4099e-01
#   KL(p):      0.0000e+00
#   t_cont:     3.1053e-01
#   transition: -1.5881e+01
#   L1:         6.1419e+01
#   Grad Norms:
#     alpha: 4.86e+02
#     beta: 3.54e+02
#     edge_logits: 1.55e-10
#     g: 9.94e+03
#     K: 5.45e+02
#     log_sigma2: 4.73e+00
#
# [Epoch 19]
#   ELBO:       5.4129e+04
#   NLL:        5.4113e+04
#   KL(t):      1.4721e-01
#   KL(p):      0.0000e+00
#   t_cont:     3.1331e-01
#   transition: -1.5955e+01
#   L1:         6.2274e+01
#   Grad Norms:
#     alpha: 4.20e+02
#     beta: 3.23e+02
#     edge_logits: 1.55e-10
#     g: 1.04e+04
#     K: 6.41e+02
#     log_sigma2: 3.65e+00
#
# [Epoch 20]
#   ELBO:       5.5298e+04
#   NLL:        5.5282e+04
#   KL(t):      1.5072e-01
#   KL(p):      0.0000e+00
#   t_cont:     3.1389e-01
#   transition: -1.5969e+01
#   L1:         6.3611e+01
#   Grad Norms:
#     alpha: 3.72e+02
#     beta: 3.51e+02
#     edge_logits: 1.55e-10
#     g: 9.16e+03
#     K: 5.31e+02
#     log_sigma2: 5.41e+00
#
# [Epoch 21]
#   ELBO:       5.4166e+04
#   NLL:        5.4150e+04
#   KL(t):      1.4951e-01
#   KL(p):      0.0000e+00
#   t_cont:     3.1092e-01
#   transition: -1.5915e+01
#   L1:         6.4586e+01
#   Grad Norms:
#     alpha: 4.16e+02
#     beta: 3.88e+02
#     edge_logits: 1.55e-10
#     g: 9.75e+03
#     K: 6.10e+02
#     log_sigma2: 4.38e+00
#
# [Epoch 22]
#   ELBO:       5.3916e+04
#   NLL:        5.3900e+04
#   KL(t):      1.5838e-01
#   KL(p):      0.0000e+00
#   t_cont:     3.1087e-01
#   transition: -1.5958e+01
#   L1:         6.6255e+01
#   Grad Norms:
#     alpha: 3.79e+02
#     beta: 3.36e+02
#     edge_logits: 1.55e-10
#     g: 8.45e+03
#     K: 5.16e+02
#     log_sigma2: 2.86e+00
#
# [Epoch 23]
#   ELBO:       5.3407e+04
#   NLL:        5.3391e+04
#   KL(t):      1.6566e-01
#   KL(p):      0.0000e+00
#   t_cont:     3.1807e-01
#   transition: -1.6000e+01
#   L1:         6.8370e+01
#   Grad Norms:
#     alpha: 3.31e+02
#     beta: 2.86e+02
#     edge_logits: 1.55e-10
#     g: 9.19e+03
#     K: 5.71e+02
#     log_sigma2: 3.47e+00
#
# [Epoch 24]
#   ELBO:       5.3053e+04
#   NLL:        5.3036e+04
#   KL(t):      1.6395e-01
#   KL(p):      0.0000e+00
#   t_cont:     3.1204e-01
#   transition: -1.5939e+01
#   L1:         7.0196e+01
#   Grad Norms:
#     alpha: 3.81e+02
#     beta: 2.90e+02
#     edge_logits: 1.55e-10
#     g: 9.54e+03
#     K: 5.33e+02
#     log_sigma2: 2.38e+00
#
# [Epoch 25]
#   ELBO:       5.3327e+04
#   NLL:        5.3311e+04
#   KL(t):      1.7664e-01
#   KL(p):      0.0000e+00
#   t_cont:     3.1844e-01
#   transition: -1.5926e+01
#   L1:         7.2964e+01
#   Grad Norms:
#     alpha: 3.89e+02
#     beta: 3.64e+02
#     edge_logits: 1.55e-10
#     g: 8.49e+03
#     K: 5.54e+02
#     log_sigma2: 2.92e+00
#
# [Epoch 26]
#   ELBO:       5.2456e+04
#   NLL:        5.2439e+04
#   KL(t):      1.8804e-01
#   KL(p):      0.0000e+00
#   t_cont:     3.0685e-01
#   transition: -1.5919e+01
#   L1:         7.6339e+01
#   Grad Norms:
#     alpha: 4.77e+02
#     beta: 3.76e+02
#     edge_logits: 1.55e-10
#     g: 9.54e+03
#     K: 5.68e+02
#     log_sigma2: 2.80e+00
#
# [Epoch 27]
#   ELBO:       5.2987e+04
#   NLL:        5.2971e+04
#   KL(t):      1.8818e-01
#   KL(p):      0.0000e+00
#   t_cont:     3.1730e-01
#   transition: -1.5860e+01
#   L1:         7.9355e+01
#   Grad Norms:
#     alpha: 6.92e+02
#     beta: 5.97e+02
#     edge_logits: 1.55e-10
#     g: 9.98e+03
#     K: 5.96e+02
#     log_sigma2: 3.41e+00
#
# [Epoch 28]
#   ELBO:       5.3198e+04
#   NLL:        5.3182e+04
#   KL(t):      1.9741e-01
#   KL(p):      0.0000e+00
#   t_cont:     3.1643e-01
#   transition: -1.5892e+01
#   L1:         8.2054e+01
#   Grad Norms:
#     alpha: 5.27e+02
#     beta: 4.56e+02
#     edge_logits: 1.55e-10
#     g: 9.68e+03
#     K: 6.04e+02
#     log_sigma2: 3.00e+00
#
# [Epoch 29]
#   ELBO:       5.1685e+04
#   NLL:        5.1669e+04
#   KL(t):      2.1179e-01
#   KL(p):      0.0000e+00
#   t_cont:     3.1971e-01
#   transition: -1.5953e+01
#   L1:         8.5319e+01
#   Grad Norms:
#     alpha: 5.38e+02
#     beta: 4.05e+02
#     edge_logits: 1.55e-10
#     g: 8.48e+03
#     K: 5.37e+02
#     log_sigma2: 2.25e+00
#
# [Epoch 30]
#   ELBO:       5.3512e+04
#   NLL:        5.3496e+04
#   KL(t):      2.2288e-01
#   KL(p):      0.0000e+00
#   t_cont:     3.1810e-01
#   transition: -1.5967e+01
#   L1:         8.9543e+01
#   Grad Norms:
#     alpha: 7.52e+02
#     beta: 6.02e+02
#     edge_logits: 1.55e-10
#     g: 9.83e+03
#     K: 6.55e+02
#     log_sigma2: 3.62e+00
#
# [Epoch 31]
#   ELBO:       5.2934e+04
#   NLL:        5.2917e+04
#   KL(t):      2.3153e-01
#   KL(p):      0.0000e+00
#   t_cont:     3.1566e-01
#   transition: -1.5982e+01
#   L1:         9.3098e+01
#   Grad Norms:
#     alpha: 7.18e+02
#     beta: 5.44e+02
#     edge_logits: 1.55e-10
#     g: 9.20e+03
#     K: 6.36e+02
#     log_sigma2: 2.97e+00
#
# [Epoch 32]
#   ELBO:       5.1377e+04
#   NLL:        5.1360e+04
#   KL(t):      2.4934e-01
#   KL(p):      0.0000e+00
#   t_cont:     3.2063e-01
#   transition: -1.5876e+01
#   L1:         9.6786e+01
#   Grad Norms:
#     alpha: 8.10e+02
#     beta: 5.81e+02
#     edge_logits: 1.55e-10
#     g: 8.65e+03
#     K: 6.33e+02
#     log_sigma2: 2.42e+00
#
# [Epoch 33]
#   ELBO:       5.0713e+04
#   NLL:        5.0696e+04
#   KL(t):      2.5738e-01
#   KL(p):      0.0000e+00
#   t_cont:     3.1456e-01
#   transition: -1.5951e+01
#   L1:         1.0008e+02
#   Grad Norms:
#     alpha: 7.37e+02
#     beta: 6.46e+02
#     edge_logits: 1.55e-10
#     g: 9.19e+03
#     K: 6.55e+02
#     log_sigma2: 2.29e+00
#
# [Epoch 34]
#   ELBO:       5.3193e+04
#   NLL:        5.3176e+04
#   KL(t):      2.7922e-01
#   KL(p):      0.0000e+00
#   t_cont:     3.1810e-01
#   transition: -1.5971e+01
#   L1:         1.0454e+02
#   Grad Norms:
#     alpha: 1.08e+03
#     beta: 8.10e+02
#     edge_logits: 1.55e-10
#     g: 9.85e+03
#     K: 8.06e+02
#     log_sigma2: 2.92e+00
#
# [Epoch 35]
#   ELBO:       5.0852e+04
#   NLL:        5.0835e+04
#   KL(t):      3.0898e-01
#   KL(p):      0.0000e+00
#   t_cont:     3.1730e-01
#   transition: -1.5985e+01
#   L1:         1.0951e+02
#   Grad Norms:
#     alpha: 9.33e+02
#     beta: 7.33e+02
#     edge_logits: 1.55e-10
#     g: 8.81e+03
#     K: 7.13e+02
#     log_sigma2: 2.39e+00
#
# [Epoch 36]
#   ELBO:       5.1755e+04
#   NLL:        5.1680e+04
#   KL(t):      5.8931e+01
#   KL(p):      0.0000e+00
#   t_cont:     3.3071e-01
#   transition: -1.5911e+01
#   L1:         1.1516e+02
#   Grad Norms:
#     alpha: 1.01e+03
#     beta: 9.28e+02
#     edge_logits: 1.55e-10
#     g: 9.35e+03
#     K: 7.12e+02
#     log_sigma2: 2.09e+00
#
# [Epoch 37]
#   ELBO:       5.0854e+04
#   NLL:        5.0779e+04
#   KL(t):      5.8950e+01
#   KL(p):      0.0000e+00
#   t_cont:     3.2893e-01
#   transition: -1.5937e+01
#   L1:         1.1937e+02
#   Grad Norms:
#     alpha: 1.12e+03
#     beta: 1.54e+03
#     edge_logits: 1.55e-10
#     g: 9.41e+03
#     K: 8.05e+02
#     log_sigma2: 2.49e+00
#
# [Epoch 38]
#   ELBO:       5.1572e+04
#   NLL:        5.1437e+04
#   KL(t):      1.1867e+02
#   KL(p):      0.0000e+00
#   t_cont:     3.2193e-01
#   transition: -1.5929e+01
#   L1:         1.2330e+02
#   Grad Norms:
#     alpha: 1.42e+05
#     beta: 1.28e+03
#     edge_logits: 1.55e-10
#     g: 9.90e+03
#     K: 8.61e+02
#     log_sigma2: 2.33e+00
#
# [Epoch 39]
#   ELBO:       5.1197e+04
#   NLL:        5.0770e+04
#   KL(t):      4.1061e+02
#   KL(p):      0.0000e+00
#   t_cont:     3.3032e-01
#   transition: -1.5949e+01
#   L1:         1.2891e+02
#   Grad Norms:
#     alpha: 1.58e+03
#     beta: 1.01e+03
#     edge_logits: 1.55e-10
#     g: 9.24e+03
#     K: 7.22e+02
#     log_sigma2: 1.82e+00
#
# [Epoch 40]
#   ELBO:       4.9776e+04
#   NLL:        4.9349e+04
#   KL(t):      4.1065e+02
#   KL(p):      0.0000e+00
#   t_cont:     3.2250e-01
#   transition: -1.5856e+01
#   L1:         1.3459e+02
#   Grad Norms:
#     alpha: 1.27e+03
#     beta: 9.89e+02
#     edge_logits: 1.55e-10
#     g: 8.55e+03
#     K: 7.16e+02
#     log_sigma2: 2.22e+00
#
# [Epoch 41]
#   ELBO:       5.0509e+04
#   NLL:        4.9906e+04
#   KL(t):      5.8654e+02
#   KL(p):      0.0000e+00
#   t_cont:     3.2668e-01
#   transition: -1.5918e+01
#   L1:         1.4041e+02
#   Grad Norms:
#     alpha: 1.71e+03
#     beta: 1.60e+03
#     edge_logits: 1.55e-10
#     g: 1.25e+04
#     K: 9.85e+02
#     log_sigma2: 1.98e+00
#
# [Epoch 42]
#   ELBO:       4.7866e+04
#   NLL:        4.7321e+04
#   KL(t):      5.2792e+02
#   KL(p):      0.0000e+00
#   t_cont:     3.2592e-01
#   transition: -1.5941e+01
#   L1:         1.4551e+02
#   Grad Norms:
#     alpha: 1.23e+03
#     beta: 1.04e+03
#     edge_logits: 1.55e-10
#     g: 8.15e+03
#     K: 8.43e+02
#     log_sigma2: 2.09e+00
#
# [Epoch 43]
#   ELBO:       5.0768e+04
#   NLL:        4.9989e+04
#   KL(t):      7.6248e+02
#   KL(p):      0.0000e+00
#   t_cont:     3.2338e-01
#   transition: -1.6021e+01
#   L1:         1.5019e+02
#   Grad Norms:
#     alpha: 1.68e+03
#     beta: 1.60e+03
#     edge_logits: 1.55e-10
#     g: 9.03e+03
#     K: 8.30e+02
#     log_sigma2: 2.18e+00
#
# [Epoch 44]
#   ELBO:       4.7961e+04
#   NLL:        4.6592e+04
#   KL(t):      1.3525e+03
#   KL(p):      0.0000e+00
#   t_cont:     3.2317e-01
#   transition: -1.5941e+01
#   L1:         1.5616e+02
#   Grad Norms:
#     alpha: 1.56e+03
#     beta: 1.29e+03
#     edge_logits: 1.55e-10
#     g: 7.99e+03
#     K: 7.48e+02
#     log_sigma2: 1.75e+00
#
# [Epoch 45]
#   ELBO:       4.6848e+04
#   NLL:        4.5010e+04
#   KL(t):      1.8213e+03
#   KL(p):      0.0000e+00
#   t_cont:     3.2864e-01
#   transition: -1.5869e+01
#   L1:         1.6180e+02
#   Grad Norms:
#     alpha: 2.17e+03
#     beta: 1.79e+03
#     edge_logits: 1.55e-10
#     g: 9.15e+03
#     K: 9.20e+02
#     log_sigma2: 1.73e+00
#
# [Epoch 46]
#   ELBO:       4.8361e+04
#   NLL:        4.6086e+04
#   KL(t):      2.2588e+03
#   KL(p):      0.0000e+00
#   t_cont:     3.3156e-01
#   transition: -1.5957e+01
#   L1:         1.6698e+02
#   Grad Norms:
#     alpha: 1.77e+03
#     beta: 1.37e+03
#     edge_logits: 1.55e-10
#     g: 8.52e+03
#     K: 7.98e+02
#     log_sigma2: 1.64e+00
#
# [Epoch 47]
#   ELBO:       5.0152e+04
#   NLL:        4.5642e+04
#   KL(t):      4.4934e+03
#   KL(p):      0.0000e+00
#   t_cont:     3.2934e-01
#   transition: -1.5896e+01
#   L1:         1.7130e+02
#   Grad Norms:
#     alpha: 1.81e+03
#     beta: 1.63e+03
#     edge_logits: 1.55e-10
#     g: 8.80e+03
#     K: 8.64e+02
#     log_sigma2: 1.61e+00
#
# [Epoch 48]
#   ELBO:       4.9819e+04
#   NLL:        4.5512e+04
#   KL(t):      4.2904e+03
#   KL(p):      0.0000e+00
#   t_cont:     3.4021e-01
#   transition: -1.5875e+01
#   L1:         1.7637e+02
#   Grad Norms:
#     alpha: 2.22e+03
#     beta: 1.53e+03
#     edge_logits: 1.55e-10
#     g: 8.99e+03
#     K: 1.05e+03
#     log_sigma2: 1.70e+00
#
# [Epoch 49]
#   ELBO:       5.0409e+04
#   NLL:        4.4372e+04
#   KL(t):      6.0210e+03
#   KL(p):      0.0000e+00
#   t_cont:     3.3544e-01
#   transition: -1.5873e+01
#   L1:         1.8098e+02
#   Grad Norms:
#     alpha: 1.72e+03
#     beta: 2.23e+03
#     edge_logits: 1.55e-10
#     g: 7.88e+03
#     K: 8.18e+02
#     log_sigma2: 1.85e+00
#
# [Epoch 50]
#   ELBO:       4.9348e+04
#   NLL:        4.2282e+04
#   KL(t):      7.0501e+03
#   KL(p):      0.0000e+00
#   t_cont:     3.3552e-01
#   transition: -1.5943e+01
#   L1:         1.8602e+02
#   Grad Norms:
#     alpha: 4.73e+03
#     beta: 1.82e+03
#     edge_logits: 1.55e-10
#     g: 7.82e+03
#     K: 9.94e+02
#     log_sigma2: 1.54e+00
#
# [Epoch 51]
#   ELBO:       5.1055e+04
#   NLL:        4.2990e+04
#   KL(t):      8.0490e+03
#   KL(p):      0.0000e+00
#   t_cont:     3.3514e-01
#   transition: -1.5991e+01
#   L1:         1.9175e+02
#   Grad Norms:
#     alpha: 3.13e+03
#     beta: 1.64e+03
#     edge_logits: 1.55e-10
#     g: 7.32e+03
#     K: 8.18e+02
#     log_sigma2: 1.92e+00
#
# [Epoch 52]
#   ELBO:       5.2594e+04
#   NLL:        4.2818e+04
#   KL(t):      9.7600e+03
#   KL(p):      0.0000e+00
#   t_cont:     3.3498e-01
#   transition: -1.5874e+01
#   L1:         1.9563e+02
#   Grad Norms:
#     alpha: 2.35e+03
#     beta: 1.65e+03
#     edge_logits: 1.55e-10
#     g: 8.34e+03
#     K: 9.27e+02
#     log_sigma2: 1.44e+00
#
# [Epoch 53]
#   ELBO:       5.2611e+04
#   NLL:        4.1935e+04
#   KL(t):      1.0659e+04
#   KL(p):      0.0000e+00
#   t_cont:     3.3691e-01
#   transition: -1.5891e+01
#   L1:         1.9988e+02
#   Grad Norms:
#     alpha: 2.23e+03
#     beta: 2.56e+03
#     edge_logits: 1.55e-10
#     g: 7.75e+03
#     K: 8.23e+02
#     log_sigma2: 1.21e+00
#
# [Epoch 54]
#   ELBO:       5.6815e+04
#   NLL:        4.1776e+04
#   KL(t):      1.5023e+04
#   KL(p):      0.0000e+00
#   t_cont:     3.3834e-01
#   transition: -1.5881e+01
#   L1:         2.0389e+02
#   Grad Norms:
#     alpha: 2.13e+03
#     beta: 1.93e+03
#     edge_logits: 1.55e-10
#     g: 7.95e+03
#     K: 1.07e+03
#     log_sigma2: 1.10e+00
#
# [Epoch 55]
#   ELBO:       5.6968e+04
#   NLL:        3.9691e+04
#   KL(t):      1.7261e+04
#   KL(p):      0.0000e+00
#   t_cont:     3.4764e-01
#   transition: -1.5906e+01
#   L1:         2.0808e+02
#   Grad Norms:
#     alpha: 2.40e+03
#     beta: 1.59e+03
#     edge_logits: 1.55e-10
#     g: 8.02e+03
#     K: 8.32e+02
#     log_sigma2: 1.16e+00
#
# [Epoch 56]
#   ELBO:       5.9585e+04
#   NLL:        3.7652e+04
#   KL(t):      2.1917e+04
#   KL(p):      0.0000e+00
#   t_cont:     3.3714e-01
#   transition: -1.5844e+01
#   L1:         2.1216e+02
#   Grad Norms:
#     alpha: 2.00e+03
#     beta: 3.96e+05
#     edge_logits: 1.55e-10
#     g: 7.26e+03
#     K: 8.67e+02
#     log_sigma2: 1.82e+00
#
# [Epoch 57]
#   ELBO:       6.2817e+04
#   NLL:        4.0340e+04
#   KL(t):      2.2461e+04
#   KL(p):      0.0000e+00
#   t_cont:     3.5813e-01
#   transition: -1.5943e+01
#   L1:         2.1624e+02
#   Grad Norms:
#     alpha: 1.83e+03
#     beta: 1.39e+03
#     edge_logits: 1.55e-10
#     g: 6.91e+03
#     K: 7.45e+02
#     log_sigma2: 1.11e+00
#
# [Epoch 58]
#   ELBO:       6.3949e+04
#   NLL:        3.7925e+04
#   KL(t):      2.6008e+04
#   KL(p):      0.0000e+00
#   t_cont:     3.4652e-01
#   transition: -1.5896e+01
#   L1:         2.1909e+02
#   Grad Norms:
#     alpha: 2.68e+03
#     beta: 2.09e+03
#     edge_logits: 1.55e-10
#     g: 7.44e+03
#     K: 9.08e+02
#     log_sigma2: 1.02e+00
#
# [Epoch 59]
#   ELBO:       6.6272e+04
#   NLL:        3.8255e+04
#   KL(t):      2.8001e+04
#   KL(p):      0.0000e+00
#   t_cont:     3.5248e-01
#   transition: -1.5887e+01
#   L1:         2.2171e+02
#   Grad Norms:
#     alpha: 5.35e+03
#     beta: 1.47e+03
#     edge_logits: 1.55e-10
#     g: 7.73e+03
#     K: 9.01e+02
#     log_sigma2: 1.34e+00
#
# [Epoch 60]
#   ELBO:       7.1122e+04
#   NLL:        3.8155e+04
#   KL(t):      3.2950e+04
#   KL(p):      0.0000e+00
#   t_cont:     3.5293e-01
#   transition: -1.5860e+01
#   L1:         2.2438e+02
#   Grad Norms:
#     alpha: 3.17e+03
#     beta: 2.21e+03
#     edge_logits: 1.55e-10
#     g: 7.56e+03
#     K: 8.56e+02
#     log_sigma2: 1.56e+00
#
# [Epoch 61]
#   ELBO:       7.2537e+04
#   NLL:        3.7589e+04
#   KL(t):      3.4931e+04
#   KL(p):      0.0000e+00
#   t_cont:     3.4845e-01
#   transition: -1.5864e+01
#   L1:         2.2726e+02
#   Grad Norms:
#     alpha: 2.57e+03
#     beta: 2.32e+03
#     edge_logits: 1.55e-10
#     g: 8.11e+03
#     K: 9.97e+02
#     log_sigma2: 1.56e+00
#
# [Epoch 62]
#   ELBO:       7.6373e+04
#   NLL:        3.6600e+04
#   KL(t):      3.9757e+04
#   KL(p):      0.0000e+00
#   t_cont:     3.5454e-01
#   transition: -1.5828e+01
#   L1:         2.3080e+02
#   Grad Norms:
#     alpha: 5.69e+03
#     beta: 2.13e+03
#     edge_logits: 1.55e-10
#     g: 7.77e+03
#     K: 8.54e+02
#     log_sigma2: 8.58e-01
#
# [Epoch 63]
#   ELBO:       7.9544e+04
#   NLL:        3.6276e+04
#   KL(t):      4.3252e+04
#   KL(p):      0.0000e+00
#   t_cont:     3.5083e-01
#   transition: -1.5915e+01
#   L1:         2.3444e+02
#   Grad Norms:
#     alpha: 4.22e+03
#     beta: 4.00e+03
#     edge_logits: 1.55e-10
#     g: 7.76e+03
#     K: 8.77e+02
#     log_sigma2: 1.46e+00
#
# [Epoch 64]
#   ELBO:       8.5088e+04
#   NLL:        3.6675e+04
#   KL(t):      4.8397e+04
#   KL(p):      0.0000e+00
#   t_cont:     3.4686e-01
#   transition: -1.5966e+01
#   L1:         2.3570e+02
#   Grad Norms:
#     alpha: 2.74e+03
#     beta: 1.49e+03
#     edge_logits: 1.55e-10
#     g: 7.82e+03
#     K: 9.75e+02
#     log_sigma2: 1.07e+00
#
# [Epoch 65]
#   ELBO:       8.9910e+04
#   NLL:        3.6393e+04
#   KL(t):      5.3500e+04
#   KL(p):      0.0000e+00
#   t_cont:     3.5769e-01
#   transition: -1.5967e+01
#   L1:         2.3771e+02
#   Grad Norms:
#     alpha: 4.26e+03
#     beta: 2.83e+03
#     edge_logits: 1.55e-10
#     g: 8.15e+03
#     K: 8.61e+02
#     log_sigma2: 1.09e+00
#
# [Epoch 66]
#   ELBO:       9.1486e+04
#   NLL:        3.5071e+04
#   KL(t):      5.6399e+04
#   KL(p):      0.0000e+00
#   t_cont:     3.6071e-01
#   transition: -1.5877e+01
#   L1:         2.4066e+02
#   Grad Norms:
#     alpha: 5.94e+03
#     beta: 3.22e+03
#     edge_logits: 1.55e-10
#     g: 7.18e+03
#     K: 8.97e+02
#     log_sigma2: 1.42e+00
#
# [Epoch 67]
#   ELBO:       9.2410e+04
#   NLL:        3.4894e+04
#   KL(t):      5.7500e+04
#   KL(p):      0.0000e+00
#   t_cont:     3.5653e-01
#   transition: -1.5914e+01
#   L1:         2.4250e+02
#   Grad Norms:
#     alpha: 9.50e+03
#     beta: 4.53e+03
#     edge_logits: 1.55e-10
#     g: 7.20e+03
#     K: 9.05e+02
#     log_sigma2: 2.20e+00
#
# [Epoch 68]
#   ELBO:       1.0237e+05
#   NLL:        3.5147e+04
#   KL(t):      6.7204e+04
#   KL(p):      0.0000e+00
#   t_cont:     3.6865e-01
#   transition: -1.5957e+01
#   L1:         2.4452e+02
#   Grad Norms:
#     alpha: 3.19e+04
#     beta: 4.26e+03
#     edge_logits: 1.55e-10
#     g: 7.52e+03
#     K: 9.05e+02
#     log_sigma2: 9.85e-01
#
# [Epoch 69]
#   ELBO:       1.0157e+05
#   NLL:        3.3290e+04
#   KL(t):      6.8259e+04
#   KL(p):      0.0000e+00
#   t_cont:     3.6487e-01
#   transition: -1.5876e+01
#   L1:         2.4659e+02
#   Grad Norms:
#     alpha: 2.44e+04
#     beta: 1.49e+03
#     edge_logits: 1.55e-10
#     g: 6.93e+03
#     K: 8.68e+02
#     log_sigma2: 1.07e+00
#
# [Epoch 70]
#   ELBO:       1.1193e+05
#   NLL:        3.3052e+04
#   KL(t):      7.8861e+04
#   KL(p):      0.0000e+00
#   t_cont:     3.6447e-01
#   transition: -1.5822e+01
#   L1:         2.4731e+02
#   Grad Norms:
#     alpha: 3.13e+04
#     beta: 2.88e+03
#     edge_logits: 1.55e-10
#     g: 7.44e+03
#     K: 8.59e+02
#     log_sigma2: 1.04e+00
#
# [Epoch 71]
#   ELBO:       1.1003e+05
#   NLL:        3.2391e+04
#   KL(t):      7.7622e+04
#   KL(p):      0.0000e+00
#   t_cont:     3.6074e-01
#   transition: -1.5864e+01
#   L1:         2.4999e+02
#   Grad Norms:
#     alpha: 2.55e+03
#     beta: 3.14e+03
#     edge_logits: 1.55e-10
#     g: 6.47e+03
#     K: 8.26e+02
#     log_sigma2: 1.26e+00
#
# [Epoch 72]
#   ELBO:       1.2074e+05
#   NLL:        3.3058e+04
#   KL(t):      8.7663e+04
#   KL(p):      0.0000e+00
#   t_cont:     3.6018e-01
#   transition: -1.5910e+01
#   L1:         2.5337e+02
#   Grad Norms:
#     alpha: 3.46e+03
#     beta: 1.73e+03
#     edge_logits: 1.55e-10
#     g: 7.20e+03
#     K: 7.97e+02
#     log_sigma2: 1.18e+00
#
# [Epoch 73]
#   ELBO:       1.2511e+05
#   NLL:        3.3530e+04
#   KL(t):      9.1564e+04
#   KL(p):      0.0000e+00
#   t_cont:     3.6663e-01
#   transition: -1.5994e+01
#   L1:         2.5420e+02
#   Grad Norms:
#     alpha: 4.05e+03
#     beta: 5.20e+03
#     edge_logits: 1.55e-10
#     g: 7.50e+03
#     K: 9.54e+02
#     log_sigma2: 1.26e+00
#
# [Epoch 74]
#   ELBO:       1.3108e+05
#   NLL:        3.2355e+04
#   KL(t):      9.8711e+04
#   KL(p):      0.0000e+00
#   t_cont:     3.6744e-01
#   transition: -1.5987e+01
#   L1:         2.5458e+02
#   Grad Norms:
#     alpha: 4.32e+03
#     beta: 2.96e+03
#     edge_logits: 1.55e-10
#     g: 7.41e+03
#     K: 9.15e+02
#     log_sigma2: 1.16e+00
#
# [Epoch 75]
#   ELBO:       1.3671e+05
#   NLL:        3.2898e+04
#   KL(t):      1.0380e+05
#   KL(p):      0.0000e+00
#   t_cont:     3.7743e-01
#   transition: -1.5870e+01
#   L1:         2.5496e+02
#   Grad Norms:
#     alpha: 5.44e+03
#     beta: 3.67e+03
#     edge_logits: 1.55e-10
#     g: 7.31e+03
#     K: 1.03e+03
#     log_sigma2: 1.54e+00
#
# [Epoch 76]
#   ELBO:       1.3913e+05
#   NLL:        3.1328e+04
#   KL(t):      1.0779e+05
#   KL(p):      0.0000e+00
#   t_cont:     3.6779e-01
#   transition: -1.5906e+01
#   L1:         2.5642e+02
#   Grad Norms:
#     alpha: 4.02e+03
#     beta: 1.36e+03
#     edge_logits: 1.55e-10
#     g: 7.06e+03
#     K: 8.10e+02
#     log_sigma2: 1.02e+00
#
# [Epoch 77]
#   ELBO:       1.4902e+05
#   NLL:        3.1470e+04
#   KL(t):      1.1753e+05
#   KL(p):      0.0000e+00
#   t_cont:     3.7065e-01
#   transition: -1.5885e+01
#   L1:         2.5803e+02
#   Grad Norms:
#     alpha: 6.80e+03
#     beta: 2.01e+03
#     edge_logits: 1.55e-10
#     g: 7.77e+03
#     K: 9.86e+02
#     log_sigma2: 1.28e+00
#
# [Epoch 78]
#   ELBO:       1.4880e+05
#   NLL:        3.1434e+04
#   KL(t):      1.1735e+05
#   KL(p):      0.0000e+00
#   t_cont:     3.6426e-01
#   transition: -1.6004e+01
#   L1:         2.5899e+02
#   Grad Norms:
#     alpha: 6.53e+03
#     beta: 1.17e+03
#     edge_logits: 1.55e-10
#     g: 7.02e+03
#     K: 8.31e+02
#     log_sigma2: 1.05e+00
#
# [Epoch 79]
#   ELBO:       1.5844e+05
#   NLL:        3.1599e+04
#   KL(t):      1.2682e+05
#   KL(p):      0.0000e+00
#   t_cont:     3.7933e-01
#   transition: -1.5958e+01
#   L1:         2.5898e+02
#   Grad Norms:
#     alpha: 3.01e+03
#     beta: 1.36e+04
#     edge_logits: 1.55e-10
#     g: 7.35e+03
#     K: 1.05e+03
#     log_sigma2: 1.05e+00
#
# [Epoch 80]
#   ELBO:       1.6020e+05
#   NLL:        3.1460e+04
#   KL(t):      1.2872e+05
#   KL(p):      0.0000e+00
#   t_cont:     3.7096e-01
#   transition: -1.5881e+01
#   L1:         2.5987e+02
#   Grad Norms:
#     alpha: 1.71e+03
#     beta: 1.49e+03
#     edge_logits: 1.55e-10
#     g: 7.09e+03
#     K: 7.49e+02
#     log_sigma2: 1.28e+00
#
# [Epoch 81]
#   ELBO:       1.6047e+05
#   NLL:        3.0816e+04
#   KL(t):      1.2964e+05
#   KL(p):      0.0000e+00
#   t_cont:     3.7178e-01
#   transition: -1.5865e+01
#   L1:         2.6086e+02
#   Grad Norms:
#     alpha: 2.99e+03
#     beta: 2.20e+03
#     edge_logits: 1.55e-10
#     g: 6.82e+03
#     K: 8.11e+02
#     log_sigma2: 8.50e-01
#
# [Epoch 82]
#   ELBO:       1.7264e+05
#   NLL:        3.0791e+04
#   KL(t):      1.4183e+05
#   KL(p):      0.0000e+00
#   t_cont:     3.7423e-01
#   transition: -1.5913e+01
#   L1:         2.6256e+02
#   Grad Norms:
#     alpha: 2.85e+03
#     beta: 3.94e+03
#     edge_logits: 1.55e-10
#     g: 7.00e+03
#     K: 8.70e+02
#     log_sigma2: 7.65e-01
#
# [Epoch 83]
#   ELBO:       1.7406e+05
#   NLL:        3.0873e+04
#   KL(t):      1.4317e+05
#   KL(p):      0.0000e+00
#   t_cont:     3.7731e-01
#   transition: -1.5954e+01
#   L1:         2.6289e+02
#   Grad Norms:
#     alpha: 8.00e+03
#     beta: 1.58e+03
#     edge_logits: 1.55e-10
#     g: 6.67e+03
#     K: 8.48e+02
#     log_sigma2: 1.32e+00
#
# [Epoch 84]
#   ELBO:       1.7599e+05
#   NLL:        3.1603e+04
#   KL(t):      1.4437e+05
#   KL(p):      0.0000e+00
#   t_cont:     3.7791e-01
#   transition: -1.5937e+01
#   L1:         2.6281e+02
#   Grad Norms:
#     alpha: 3.05e+03
#     beta: 4.26e+03
#     edge_logits: 1.55e-10
#     g: 7.48e+03
#     K: 8.21e+02
#     log_sigma2: 8.43e-01
#
# [Epoch 85]
#   ELBO:       1.8097e+05
#   NLL:        2.9885e+04
#   KL(t):      1.5107e+05
#   KL(p):      0.0000e+00
#   t_cont:     3.8424e-01
#   transition: -1.5894e+01
#   L1:         2.6368e+02
#   Grad Norms:
#     alpha: 2.10e+03
#     beta: 2.55e+03
#     edge_logits: 1.55e-10
#     g: 7.78e+03
#     K: 8.56e+02
#     log_sigma2: 9.31e-01
#
# [Epoch 86]
#   ELBO:       1.8693e+05
#   NLL:        2.9376e+04
#   KL(t):      1.5753e+05
#   KL(p):      0.0000e+00
#   t_cont:     3.7820e-01
#   transition: -1.5916e+01
#   L1:         2.6574e+02
#   Grad Norms:
#     alpha: 4.24e+03
#     beta: 3.67e+03
#     edge_logits: 1.55e-10
#     g: 7.42e+03
#     K: 9.12e+02
#     log_sigma2: 9.53e-01
#
# [Epoch 87]
#   ELBO:       1.9494e+05
#   NLL:        2.9375e+04
#   KL(t):      1.6555e+05
#   KL(p):      0.0000e+00
#   t_cont:     3.6542e-01
#   transition: -1.5955e+01
#   L1:         2.6868e+02
#   Grad Norms:
#     alpha: 2.80e+03
#     beta: 1.29e+03
#     edge_logits: 1.55e-10
#     g: 6.49e+03
#     K: 7.50e+02
#     log_sigma2: 7.44e-01
#
# [Epoch 88]
#   ELBO:       1.9967e+05
#   NLL:        2.9955e+04
#   KL(t):      1.6970e+05
#   KL(p):      0.0000e+00
#   t_cont:     3.7558e-01
#   transition: -1.5872e+01
#   L1:         2.6813e+02
#   Grad Norms:
#     alpha: 1.62e+03
#     beta: 1.83e+03
#     edge_logits: 1.55e-10
#     g: 7.01e+03
#     K: 8.26e+02
#     log_sigma2: 8.26e-01
#
# [Epoch 89]
#   ELBO:       2.0025e+05
#   NLL:        2.8782e+04
#   KL(t):      1.7145e+05
#   KL(p):      0.0000e+00
#   t_cont:     3.7520e-01
#   transition: -1.5886e+01
#   L1:         2.6749e+02
#   Grad Norms:
#     alpha: 4.65e+03
#     beta: 1.60e+03
#     edge_logits: 1.55e-10
#     g: 7.03e+03
#     K: 8.73e+02
#     log_sigma2: 9.89e-01
#
# [Epoch 90]
#   ELBO:       2.0402e+05
#   NLL:        2.9884e+04
#   KL(t):      1.7412e+05
#   KL(p):      0.0000e+00
#   t_cont:     3.8011e-01
#   transition: -1.5925e+01
#   L1:         2.6834e+02
#   Grad Norms:
#     alpha: 2.89e+03
#     beta: 2.36e+03
#     edge_logits: 1.55e-10
#     g: 6.67e+03
#     K: 7.98e+02
#     log_sigma2: 8.80e-01
#
# [Epoch 91]
#   ELBO:       2.1339e+05
#   NLL:        2.9903e+04
#   KL(t):      1.8347e+05
#   KL(p):      0.0000e+00
#   t_cont:     3.7851e-01
#   transition: -1.5947e+01
#   L1:         2.6792e+02
#   Grad Norms:
#     alpha: 2.61e+03
#     beta: 3.95e+03
#     edge_logits: 1.55e-10
#     g: 7.07e+03
#     K: 8.22e+02
#     log_sigma2: 7.13e-01
#
# [Epoch 92]
#   ELBO:       2.1301e+05
#   NLL:        2.9323e+04
#   KL(t):      1.8367e+05
#   KL(p):      0.0000e+00
#   t_cont:     3.8134e-01
#   transition: -1.5892e+01
#   L1:         2.6829e+02
#   Grad Norms:
#     alpha: 3.10e+03
#     beta: 2.35e+03
#     edge_logits: 1.55e-10
#     g: 6.40e+03
#     K: 6.71e+02
#     log_sigma2: 1.23e+00
#
# [Epoch 93]
#   ELBO:       2.1563e+05
#   NLL:        2.8779e+04
#   KL(t):      1.8684e+05
#   KL(p):      0.0000e+00
#   t_cont:     3.6810e-01
#   transition: -1.5865e+01
#   L1:         2.7050e+02
#   Grad Norms:
#     alpha: 1.26e+04
#     beta: 2.84e+03
#     edge_logits: 1.55e-10
#     g: 6.44e+03
#     K: 7.77e+02
#     log_sigma2: 7.85e-01
#
# [Epoch 94]
#   ELBO:       2.2928e+05
#   NLL:        2.8426e+04
#   KL(t):      2.0083e+05
#   KL(p):      0.0000e+00
#   t_cont:     3.6920e-01
#   transition: -1.5912e+01
#   L1:         2.6963e+02
#   Grad Norms:
#     alpha: 2.22e+03
#     beta: 1.36e+03
#     edge_logits: 1.55e-10
#     g: 6.86e+03
#     K: 7.85e+02
#     log_sigma2: 9.96e-01
#
# [Epoch 95]
#   ELBO:       2.2669e+05
#   NLL:        2.8740e+04
#   KL(t):      1.9794e+05
#   KL(p):      0.0000e+00
#   t_cont:     3.8271e-01
#   transition: -1.5921e+01
#   L1:         2.6972e+02
#   Grad Norms:
#     alpha: 2.33e+03
#     beta: 3.55e+03
#     edge_logits: 1.55e-10
#     g: 6.78e+03
#     K: 7.42e+02
#     log_sigma2: 1.19e+00
#
# [Epoch 96]
#   ELBO:       2.3553e+05
#   NLL:        2.9594e+04
#   KL(t):      2.0592e+05
#   KL(p):      0.0000e+00
#   t_cont:     3.7939e-01
#   transition: -1.5986e+01
#   L1:         2.6995e+02
#   Grad Norms:
#     alpha: 3.04e+03
#     beta: 5.24e+03
#     edge_logits: 1.55e-10
#     g: 7.14e+03
#     K: 8.08e+02
#     log_sigma2: 9.85e-01
#
# [Epoch 97]
#   ELBO:       2.4033e+05
#   NLL:        2.9359e+04
#   KL(t):      2.1095e+05
#   KL(p):      0.0000e+00
#   t_cont:     3.8247e-01
#   transition: -1.5912e+01
#   L1:         2.6984e+02
#   Grad Norms:
#     alpha: 9.99e+03
#     beta: 3.75e+03
#     edge_logits: 1.55e-10
#     g: 7.32e+03
#     K: 8.05e+02
#     log_sigma2: 8.89e-01
#
# [Epoch 98]
#   ELBO:       2.3908e+05
#   NLL:        2.8416e+04
#   KL(t):      2.1065e+05
#   KL(p):      0.0000e+00
#   t_cont:     3.7535e-01
#   transition: -1.5880e+01
#   L1:         2.6964e+02
#   Grad Norms:
#     alpha: 1.35e+03
#     beta: 1.15e+03
#     edge_logits: 1.55e-10
#     g: 7.20e+03
#     K: 9.01e+02
#     log_sigma2: 6.93e-01
#
# [Epoch 99]
#   ELBO:       2.4134e+05
#   NLL:        2.9105e+04
#   KL(t):      2.1221e+05
#   KL(p):      0.0000e+00
#   t_cont:     3.8319e-01
#   transition: -1.5974e+01
#   L1:         2.7114e+02
#   Grad Norms:
#     alpha: 5.95e+04
#     beta: 2.47e+03
#     edge_logits: 1.55e-10
#     g: 7.38e+03
#     K: 8.27e+02
#     log_sigma2: 1.04e+00

# %%
import torch
import numpy as np
from models.loss import compute_elbo_batch
from utils.inference import batch_indices

elbo_log = []
nll_log = []
kl_t_log = []
kl_p_log = []
t_cont_log = []
transition_log = []
l1_log = []
grad_log = []

# === Config ===
batch_size = 512
num_epochs = 100
n_samples = 3
kl_weight = 1.0
kl_p_weight = 1.0
t_cont_weight = 1.0
transition_weight = 1.0
l1_weight = 1.0

# Pseudo-EM params
phase = "emission"
max_phase_epochs = 30
patience = 5
tol = 1e-4
best_loss = float("inf")
epochs_since_improvement = 0
phase_epoch = 0

# === Logging ===
elbo_log, nll_log, kl_t_log, kl_p_log = [], [], [], []
t_cont_log, transition_log, l1_log, grad_log = [], [], [], []

# === Setup ===
emission_params = [g, K, log_sigma2]
posterior_params = [posterior.alpha, posterior.beta, posterior.edge_logits]

for p in emission_params:
    p.requires_grad_(True)
for p in posterior_params:
    p.requires_grad_(False)

optimizer = torch.optim.Adam(posterior_params + emission_params, lr=1e-2)

# === Training loop ===
for epoch in range(num_epochs):
    total_loss = 0.0
    total_batches = 0
    epoch_metrics = {
        "nll": 0.0,
        "kl_t": 0.0,
        "kl_p": 0.0,
        "t_cont": 0.0,
        "transition": 0.0,
        "l1": 0.0
    }

    for batch in batch_indices(X.shape[0], batch_size):
        X_batch = X[batch]
        optimizer.zero_grad()

        loss, metrics = compute_elbo_batch(
            X_batch, batch,
            traj_graph, posterior, edge_to_index,
            g, K, log_sigma2.exp(),
            belief_propagator=belief_propagator,
            n_samples=n_samples,
            kl_weight=kl_weight,
            kl_p_weight=kl_p_weight,
            t_cont_weight=t_cont_weight,
            transition_weight=transition_weight,
            l1_weight=l1_weight,
            pi=pi
        )

        loss.backward()
        optimizer.step()

        total_loss += loss.item()
        for key in epoch_metrics:
            epoch_metrics[key] += metrics.get(key, 0.0)
        total_batches += 1

    # === Normalize and track ===
    for key in epoch_metrics:
        epoch_metrics[key] /= total_batches

    grad_norms = {
        "alpha": posterior.alpha.grad.norm().item() if posterior.alpha.grad is not None else 0.0,
        "beta": posterior.beta.grad.norm().item() if posterior.beta.grad is not None else 0.0,
        "edge_logits": posterior.edge_logits.grad.norm().item() if posterior.edge_logits.grad is not None else 0.0,
        "g": g.grad.norm().item() if g.grad is not None else 0.0,
        "K": K.grad.norm().item() if K.grad is not None else 0.0,
        "log_sigma2": log_sigma2.grad.norm().item() if log_sigma2.grad is not None else 0.0,
    }

    # === Logging ===
    avg_loss = total_loss / total_batches
    elbo_log.append(avg_loss)
    nll_log.append(epoch_metrics["nll"])
    kl_t_log.append(epoch_metrics["kl_t"])
    kl_p_log.append(epoch_metrics["kl_p"])
    t_cont_log.append(epoch_metrics["t_cont"])
    transition_log.append(epoch_metrics["transition"])
    l1_log.append(epoch_metrics["l1"])
    grad_log.append(grad_norms)

    print(f"\n[Epoch {epoch}] | Phase: {phase}")
    print(f"  ELBO:       {avg_loss:.4e}")
    print(f"  NLL:        {epoch_metrics['nll']:.4e}")
    print(f"  KL(t):      {epoch_metrics['kl_t']:.4e}")
    print(f"  KL(p):      {epoch_metrics['kl_p']:.4e}")
    print(f"  t_cont:     {epoch_metrics['t_cont']:.4e}")
    print(f"  transition: {epoch_metrics['transition']:.4e}")
    print(f"  L1:         {epoch_metrics['l1']:.4e}")
    print("  Grad Norms:")
    for k, v in grad_norms.items():
        print(f"    {k}: {v:.2e}")

    # === Phase Switching ===
    if avg_loss < best_loss - tol:
        best_loss = avg_loss
        epochs_since_improvement = 0
    else:
        epochs_since_improvement += 1

    phase_epoch += 1
    if epochs_since_improvement >= patience or phase_epoch >= max_phase_epochs:
        if phase == "emission":
            for p in emission_params:
                p.requires_grad_(False)
            for p in posterior_params:
                p.requires_grad_(True)
            phase = "posterior"
        else:
            for p in emission_params:
                p.requires_grad_(True)
            for p in posterior_params:
                p.requires_grad_(False)
            phase = "emission"

        best_loss = float("inf")
        epochs_since_improvement = 0
        phase_epoch = 0
        print(f"--- Switching to {phase} phase ---")
# Out:
# [Epoch 0] | Phase: emission
#   ELBO:       5.1447e+05
#   NLL:        5.1443e+05
#   KL(t):      1.0891e-01
#   KL(p):      0.0000e+00
#   t_cont:     3.3226e-01
#   transition: -1.7786e+01
#   L1:         2.4955e+01
#   Grad Norms:
#     alpha: 0.00e+00
#     beta: 0.00e+00
#     edge_logits: 0.00e+00
#     g: 5.03e+04
#     K: 2.00e+03
#     log_sigma2: 2.79e+01
#
# [Epoch 1] | Phase: emission
#   ELBO:       3.4841e+05
#   NLL:        3.4837e+05
#   KL(t):      1.1538e-01
#   KL(p):      0.0000e+00
#   t_cont:     3.2984e-01
#   transition: -1.7787e+01
#   L1:         1.9914e+01
#   Grad Norms:
#     alpha: 0.00e+00
#     beta: 0.00e+00
#     edge_logits: 0.00e+00
#     g: 4.13e+04
#     K: 1.48e+03
#     log_sigma2: 2.02e+01
#
# [Epoch 2] | Phase: emission
#   ELBO:       2.3133e+05
#   NLL:        2.3130e+05
#   KL(t):      1.0880e-01
#   KL(p):      0.0000e+00
#   t_cont:     3.3522e-01
#   transition: -1.7786e+01
#   L1:         1.7186e+01
#   Grad Norms:
#     alpha: 0.00e+00
#     beta: 0.00e+00
#     edge_logits: 0.00e+00
#     g: 2.65e+04
#     K: 7.36e+02
#     log_sigma2: 1.04e+01
#
# [Epoch 3] | Phase: emission
#   ELBO:       1.5436e+05
#   NLL:        1.5432e+05
#   KL(t):      1.0803e-01
#   KL(p):      0.0000e+00
#   t_cont:     3.4321e-01
#   transition: -1.7786e+01
#   L1:         1.6258e+01
#   Grad Norms:
#     alpha: 0.00e+00
#     beta: 0.00e+00
#     edge_logits: 0.00e+00
#     g: 1.90e+04
#     K: 5.21e+02
#     log_sigma2: 7.53e+00
#
# [Epoch 4] | Phase: emission
#   ELBO:       1.1267e+05
#   NLL:        1.1264e+05
#   KL(t):      1.1118e-01
#   KL(p):      0.0000e+00
#   t_cont:     3.3127e-01
#   transition: -1.7786e+01
#   L1:         1.6787e+01
#   Grad Norms:
#     alpha: 0.00e+00
#     beta: 0.00e+00
#     edge_logits: 0.00e+00
#     g: 1.45e+04
#     K: 4.96e+02
#     log_sigma2: 7.27e+00
#
# [Epoch 5] | Phase: emission
#   ELBO:       8.7631e+04
#   NLL:        8.7594e+04
#   KL(t):      1.1188e-01
#   KL(p):      0.0000e+00
#   t_cont:     3.3887e-01
#   transition: -1.7783e+01
#   L1:         1.8146e+01
#   Grad Norms:
#     alpha: 0.00e+00
#     beta: 0.00e+00
#     edge_logits: 0.00e+00
#     g: 1.31e+04
#     K: 5.74e+02
#     log_sigma2: 5.41e+00
#
# [Epoch 6] | Phase: emission
#   ELBO:       7.1283e+04
#   NLL:        7.1245e+04
#   KL(t):      9.8870e-02
#   KL(p):      0.0000e+00
#   t_cont:     3.3071e-01
#   transition: -1.7784e+01
#   L1:         1.9874e+01
#   Grad Norms:
#     alpha: 0.00e+00
#     beta: 0.00e+00
#     edge_logits: 0.00e+00
#     g: 1.09e+04
#     K: 5.25e+02
#     log_sigma2: 6.00e+00
#
# [Epoch 7] | Phase: emission
#   ELBO:       6.5567e+04
#   NLL:        6.5527e+04
#   KL(t):      1.1278e-01
#   KL(p):      0.0000e+00
#   t_cont:     3.3073e-01
#   transition: -1.7787e+01
#   L1:         2.1508e+01
#   Grad Norms:
#     alpha: 0.00e+00
#     beta: 0.00e+00
#     edge_logits: 0.00e+00
#     g: 9.65e+03
#     K: 5.45e+02
#     log_sigma2: 3.48e+00
#
# [Epoch 8] | Phase: emission
#   ELBO:       6.0146e+04
#   NLL:        6.0104e+04
#   KL(t):      1.0846e-01
#   KL(p):      0.0000e+00
#   t_cont:     3.3805e-01
#   transition: -1.7787e+01
#   L1:         2.2897e+01
#   Grad Norms:
#     alpha: 0.00e+00
#     beta: 0.00e+00
#     edge_logits: 0.00e+00
#     g: 1.05e+04
#     K: 5.88e+02
#     log_sigma2: 5.87e+00
#
# [Epoch 9] | Phase: emission
#   ELBO:       5.6556e+04
#   NLL:        5.6514e+04
#   KL(t):      1.0802e-01
#   KL(p):      0.0000e+00
#   t_cont:     3.2576e-01
#   transition: -1.7787e+01
#   L1:         2.3873e+01
#   Grad Norms:
#     alpha: 0.00e+00
#     beta: 0.00e+00
#     edge_logits: 0.00e+00
#     g: 1.07e+04
#     K: 6.76e+02
#     log_sigma2: 4.28e+00
#
# [Epoch 10] | Phase: emission
#   ELBO:       5.5714e+04
#   NLL:        5.5672e+04
#   KL(t):      1.0709e-01
#   KL(p):      0.0000e+00
#   t_cont:     3.3817e-01
#   transition: -1.7787e+01
#   L1:         2.4532e+01
#   Grad Norms:
#     alpha: 0.00e+00
#     beta: 0.00e+00
#     edge_logits: 0.00e+00
#     g: 9.25e+03
#     K: 4.90e+02
#     log_sigma2: 3.10e+00
#
# [Epoch 11] | Phase: emission
#   ELBO:       5.3995e+04
#   NLL:        5.3952e+04
#   KL(t):      1.1068e-01
#   KL(p):      0.0000e+00
#   t_cont:     3.3403e-01
#   transition: -1.7788e+01
#   L1:         2.4875e+01
#   Grad Norms:
#     alpha: 0.00e+00
#     beta: 0.00e+00
#     edge_logits: 0.00e+00
#     g: 8.70e+03
#     K: 5.00e+02
#     log_sigma2: 3.33e+00
#
# [Epoch 12] | Phase: emission
#   ELBO:       5.5210e+04
#   NLL:        5.5167e+04
#   KL(t):      1.1354e-01
#   KL(p):      0.0000e+00
#   t_cont:     3.2738e-01
#   transition: -1.7785e+01
#   L1:         2.4843e+01
#   Grad Norms:
#     alpha: 0.00e+00
#     beta: 0.00e+00
#     edge_logits: 0.00e+00
#     g: 1.10e+04
#     K: 5.39e+02
#     log_sigma2: 2.89e+00
#
# [Epoch 13] | Phase: emission
#   ELBO:       5.4259e+04
#   NLL:        5.4216e+04
#   KL(t):      1.0732e-01
#   KL(p):      0.0000e+00
#   t_cont:     3.3962e-01
#   transition: -1.7787e+01
#   L1:         2.4653e+01
#   Grad Norms:
#     alpha: 0.00e+00
#     beta: 0.00e+00
#     edge_logits: 0.00e+00
#     g: 9.18e+03
#     K: 5.56e+02
#     log_sigma2: 2.96e+00
#
# [Epoch 14] | Phase: emission
#   ELBO:       5.4405e+04
#   NLL:        5.4363e+04
#   KL(t):      1.0460e-01
#   KL(p):      0.0000e+00
#   t_cont:     3.3853e-01
#   transition: -1.7783e+01
#   L1:         2.4447e+01
#   Grad Norms:
#     alpha: 0.00e+00
#     beta: 0.00e+00
#     edge_logits: 0.00e+00
#     g: 8.33e+03
#     K: 4.60e+02
#     log_sigma2: 2.41e+00
#
# [Epoch 15] | Phase: emission
#   ELBO:       5.4669e+04
#   NLL:        5.4626e+04
#   KL(t):      1.0739e-01
#   KL(p):      0.0000e+00
#   t_cont:     3.3492e-01
#   transition: -1.7785e+01
#   L1:         2.4191e+01
#   Grad Norms:
#     alpha: 0.00e+00
#     beta: 0.00e+00
#     edge_logits: 0.00e+00
#     g: 8.95e+03
#     K: 5.37e+02
#     log_sigma2: 3.28e+00
#
# [Epoch 16] | Phase: emission
#   ELBO:       5.4622e+04
#   NLL:        5.4579e+04
#   KL(t):      1.0250e-01
#   KL(p):      0.0000e+00
#   t_cont:     3.2964e-01
#   transition: -1.7787e+01
#   L1:         2.3859e+01
#   Grad Norms:
#     alpha: 0.00e+00
#     beta: 0.00e+00
#     edge_logits: 0.00e+00
#     g: 9.02e+03
#     K: 5.06e+02
#     log_sigma2: 4.79e+00
# --- Switching to posterior phase ---
#
# [Epoch 17] | Phase: posterior
#   ELBO:       5.5645e+04
#   NLL:        5.5603e+04
#   KL(t):      1.0429e-01
#   KL(p):      0.0000e+00
#   t_cont:     3.3496e-01
#   transition: -1.7784e+01
#   L1:         2.3728e+01
#   Grad Norms:
#     alpha: 2.31e+02
#     beta: 2.15e+02
#     edge_logits: 1.55e-10
#     g: 0.00e+00
#     K: 0.00e+00
#     log_sigma2: 0.00e+00
#
# [Epoch 18] | Phase: posterior
#   ELBO:       5.4959e+04
#   NLL:        5.4917e+04
#   KL(t):      1.0973e-01
#   KL(p):      0.0000e+00
#   t_cont:     3.3516e-01
#   transition: -1.7785e+01
#   L1:         2.3728e+01
#   Grad Norms:
#     alpha: 2.93e+02
#     beta: 2.60e+02
#     edge_logits: 1.55e-10
#     g: 0.00e+00
#     K: 0.00e+00
#     log_sigma2: 0.00e+00
#
# [Epoch 19] | Phase: posterior
#   ELBO:       5.3666e+04
#   NLL:        5.3624e+04
#   KL(t):      1.1161e-01
#   KL(p):      0.0000e+00
#   t_cont:     3.3812e-01
#   transition: -1.7786e+01
#   L1:         2.3728e+01
#   Grad Norms:
#     alpha: 2.28e+02
#     beta: 2.02e+02
#     edge_logits: 1.55e-10
#     g: 0.00e+00
#     K: 0.00e+00
#     log_sigma2: 0.00e+00
#
# [Epoch 20] | Phase: posterior
#   ELBO:       5.4810e+04
#   NLL:        5.4768e+04
#   KL(t):      1.1441e-01
#   KL(p):      0.0000e+00
#   t_cont:     3.2806e-01
#   transition: -1.7786e+01
#   L1:         2.3728e+01
#   Grad Norms:
#     alpha: 2.66e+02
#     beta: 2.39e+02
#     edge_logits: 1.55e-10
#     g: 0.00e+00
#     K: 0.00e+00
#     log_sigma2: 0.00e+00
#
# [Epoch 21] | Phase: posterior
#   ELBO:       5.5772e+04
#   NLL:        5.5730e+04
#   KL(t):      1.1241e-01
#   KL(p):      0.0000e+00
#   t_cont:     3.2893e-01
#   transition: -1.7783e+01
#   L1:         2.3728e+01
#   Grad Norms:
#     alpha: 2.69e+02
#     beta: 2.34e+02
#     edge_logits: 1.55e-10
#     g: 0.00e+00
#     K: 0.00e+00
#     log_sigma2: 0.00e+00
#
# [Epoch 22] | Phase: posterior
#   ELBO:       5.2974e+04
#   NLL:        5.2932e+04
#   KL(t):      1.1206e-01
#   KL(p):      0.0000e+00
#   t_cont:     3.3350e-01
#   transition: -1.7786e+01
#   L1:         2.3728e+01
#   Grad Norms:
#     alpha: 2.29e+02
#     beta: 2.04e+02
#     edge_logits: 1.55e-10
#     g: 0.00e+00
#     K: 0.00e+00
#     log_sigma2: 0.00e+00
#
# [Epoch 23] | Phase: posterior
#   ELBO:       5.3106e+04
#   NLL:        5.3065e+04
#   KL(t):      1.1050e-01
#   KL(p):      0.0000e+00
#   t_cont:     3.2746e-01
#   transition: -1.7786e+01
#   L1:         2.3728e+01
#   Grad Norms:
#     alpha: 2.96e+02
#     beta: 2.37e+02
#     edge_logits: 1.55e-10
#     g: 0.00e+00
#     K: 0.00e+00
#     log_sigma2: 0.00e+00
#
# [Epoch 24] | Phase: posterior
#   ELBO:       5.3754e+04
#   NLL:        5.3712e+04
#   KL(t):      1.1936e-01
#   KL(p):      0.0000e+00
#   t_cont:     3.2622e-01
#   transition: -1.7785e+01
#   L1:         2.3728e+01
#   Grad Norms:
#     alpha: 2.13e+02
#     beta: 1.87e+02
#     edge_logits: 1.55e-10
#     g: 0.00e+00
#     K: 0.00e+00
#     log_sigma2: 0.00e+00
#
# [Epoch 25] | Phase: posterior
#   ELBO:       5.6038e+04
#   NLL:        5.5996e+04
#   KL(t):      1.1441e-01
#   KL(p):      0.0000e+00
#   t_cont:     3.3245e-01
#   transition: -1.7783e+01
#   L1:         2.3728e+01
#   Grad Norms:
#     alpha: 2.65e+02
#     beta: 2.81e+02
#     edge_logits: 1.55e-10
#     g: 0.00e+00
#     K: 0.00e+00
#     log_sigma2: 0.00e+00
#
# [Epoch 26] | Phase: posterior
#   ELBO:       5.5492e+04
#   NLL:        5.5450e+04
#   KL(t):      1.1794e-01
#   KL(p):      0.0000e+00
#   t_cont:     3.2803e-01
#   transition: -1.7784e+01
#   L1:         2.3728e+01
#   Grad Norms:
#     alpha: 2.99e+02
#     beta: 2.53e+02
#     edge_logits: 1.55e-10
#     g: 0.00e+00
#     K: 0.00e+00
#     log_sigma2: 0.00e+00
#
# [Epoch 27] | Phase: posterior
#   ELBO:       5.4336e+04
#   NLL:        5.4295e+04
#   KL(t):      1.1708e-01
#   KL(p):      0.0000e+00
#   t_cont:     3.2984e-01
#   transition: -1.7787e+01
#   L1:         2.3728e+01
#   Grad Norms:
#     alpha: 2.49e+02
#     beta: 2.61e+02
#     edge_logits: 1.55e-10
#     g: 0.00e+00
#     K: 0.00e+00
#     log_sigma2: 0.00e+00
# --- Switching to emission phase ---
#
# [Epoch 28] | Phase: emission
#   ELBO:       5.5073e+04
#   NLL:        5.5031e+04
#   KL(t):      1.2443e-01
#   KL(p):      0.0000e+00
#   t_cont:     3.3065e-01
#   transition: -1.7785e+01
#   L1:         2.3718e+01
#   Grad Norms:
#     alpha: 0.00e+00
#     beta: 0.00e+00
#     edge_logits: 0.00e+00
#     g: 1.05e+04
#     K: 5.85e+02
#     log_sigma2: 3.05e+00
#
# [Epoch 29] | Phase: emission
#   ELBO:       5.7312e+04
#   NLL:        5.7271e+04
#   KL(t):      1.2018e-01
#   KL(p):      0.0000e+00
#   t_cont:     3.3405e-01
#   transition: -1.7785e+01
#   L1:         2.3655e+01
#   Grad Norms:
#     alpha: 0.00e+00
#     beta: 0.00e+00
#     edge_logits: 0.00e+00
#     g: 1.07e+04
#     K: 5.98e+02
#     log_sigma2: 2.84e+00
#
# [Epoch 30] | Phase: emission
#   ELBO:       5.4648e+04
#   NLL:        5.4606e+04
#   KL(t):      1.1882e-01
#   KL(p):      0.0000e+00
#   t_cont:     3.3566e-01
#   transition: -1.7785e+01
#   L1:         2.3689e+01
#   Grad Norms:
#     alpha: 0.00e+00
#     beta: 0.00e+00
#     edge_logits: 0.00e+00
#     g: 1.07e+04
#     K: 6.34e+02
#     log_sigma2: 2.93e+00
#
# [Epoch 31] | Phase: emission
#   ELBO:       5.5527e+04
#   NLL:        5.5485e+04
#   KL(t):      1.2130e-01
#   KL(p):      0.0000e+00
#   t_cont:     3.3802e-01
#   transition: -1.7785e+01
#   L1:         2.3855e+01
#   Grad Norms:
#     alpha: 0.00e+00
#     beta: 0.00e+00
#     edge_logits: 0.00e+00
#     g: 9.69e+03
#     K: 5.64e+02
#     log_sigma2: 2.53e+00
#
# [Epoch 32] | Phase: emission
#   ELBO:       5.3316e+04
#   NLL:        5.3273e+04
#   KL(t):      1.2345e-01
#   KL(p):      0.0000e+00
#   t_cont:     3.2329e-01
#   transition: -1.7786e+01
#   L1:         2.4021e+01
#   Grad Norms:
#     alpha: 0.00e+00
#     beta: 0.00e+00
#     edge_logits: 0.00e+00
#     g: 9.95e+03
#     K: 6.20e+02
#     log_sigma2: 3.15e+00
#
# [Epoch 33] | Phase: emission
#   ELBO:       5.5915e+04
#   NLL:        5.5873e+04
#   KL(t):      1.2067e-01
#   KL(p):      0.0000e+00
#   t_cont:     3.2153e-01
#   transition: -1.7787e+01
#   L1:         2.4087e+01
#   Grad Norms:
#     alpha: 0.00e+00
#     beta: 0.00e+00
#     edge_logits: 0.00e+00
#     g: 9.99e+03
#     K: 6.54e+02
#     log_sigma2: 2.97e+00
#
# [Epoch 34] | Phase: emission
#   ELBO:       5.3593e+04
#   NLL:        5.3551e+04
#   KL(t):      1.2564e-01
#   KL(p):      0.0000e+00
#   t_cont:     3.3086e-01
#   transition: -1.7784e+01
#   L1:         2.4101e+01
#   Grad Norms:
#     alpha: 0.00e+00
#     beta: 0.00e+00
#     edge_logits: 0.00e+00
#     g: 9.04e+03
#     K: 5.77e+02
#     log_sigma2: 2.57e+00
#
# [Epoch 35] | Phase: emission
#   ELBO:       5.5623e+04
#   NLL:        5.5581e+04
#   KL(t):      1.1927e-01
#   KL(p):      0.0000e+00
#   t_cont:     3.3295e-01
#   transition: -1.7788e+01
#   L1:         2.4157e+01
#   Grad Norms:
#     alpha: 0.00e+00
#     beta: 0.00e+00
#     edge_logits: 0.00e+00
#     g: 9.56e+03
#     K: 5.72e+02
#     log_sigma2: 3.23e+00
#
# [Epoch 36] | Phase: emission
#   ELBO:       5.4130e+04
#   NLL:        5.4088e+04
#   KL(t):      1.2974e-01
#   KL(p):      0.0000e+00
#   t_cont:     3.1868e-01
#   transition: -1.7787e+01
#   L1:         2.4275e+01
#   Grad Norms:
#     alpha: 0.00e+00
#     beta: 0.00e+00
#     edge_logits: 0.00e+00
#     g: 9.18e+03
#     K: 5.36e+02
#     log_sigma2: 2.12e+00
#
# [Epoch 37] | Phase: emission
#   ELBO:       5.3342e+04
#   NLL:        5.3300e+04
#   KL(t):      1.2747e-01
#   KL(p):      0.0000e+00
#   t_cont:     3.2757e-01
#   transition: -1.7784e+01
#   L1:         2.4376e+01
#   Grad Norms:
#     alpha: 0.00e+00
#     beta: 0.00e+00
#     edge_logits: 0.00e+00
#     g: 9.25e+03
#     K: 5.41e+02
#     log_sigma2: 2.65e+00
# --- Switching to posterior phase ---
#
# [Epoch 38] | Phase: posterior
#   ELBO:       5.5621e+04
#   NLL:        5.5578e+04
#   KL(t):      1.1950e-01
#   KL(p):      0.0000e+00
#   t_cont:     3.2969e-01
#   transition: -1.7786e+01
#   L1:         2.4382e+01
#   Grad Norms:
#     alpha: 3.50e+02
#     beta: 3.20e+02
#     edge_logits: 1.55e-10
#     g: 0.00e+00
#     K: 0.00e+00
#     log_sigma2: 0.00e+00
#
# [Epoch 39] | Phase: posterior
#   ELBO:       5.4888e+04
#   NLL:        5.4845e+04
#   KL(t):      1.2988e-01
#   KL(p):      0.0000e+00
#   t_cont:     3.2533e-01
#   transition: -1.7787e+01
#   L1:         2.4382e+01
#   Grad Norms:
#     alpha: 3.38e+02
#     beta: 3.72e+02
#     edge_logits: 1.55e-10
#     g: 0.00e+00
#     K: 0.00e+00
#     log_sigma2: 0.00e+00
#
# [Epoch 40] | Phase: posterior
#   ELBO:       5.4717e+04
#   NLL:        5.4674e+04
#   KL(t):      1.3111e-01
#   KL(p):      0.0000e+00
#   t_cont:     3.2581e-01
#   transition: -1.7787e+01
#   L1:         2.4382e+01
#   Grad Norms:
#     alpha: 4.17e+02
#     beta: 3.87e+02
#     edge_logits: 1.55e-10
#     g: 0.00e+00
#     K: 0.00e+00
#     log_sigma2: 0.00e+00
#
# [Epoch 41] | Phase: posterior
#   ELBO:       5.3455e+04
#   NLL:        5.3413e+04
#   KL(t):      1.3380e-01
#   KL(p):      0.0000e+00
#   t_cont:     3.2901e-01
#   transition: -1.7787e+01
#   L1:         2.4382e+01
#   Grad Norms:
#     alpha: 4.00e+02
#     beta: 3.62e+02
#     edge_logits: 1.55e-10
#     g: 0.00e+00
#     K: 0.00e+00
#     log_sigma2: 0.00e+00
#
# [Epoch 42] | Phase: posterior
#   ELBO:       5.3478e+04
#   NLL:        5.3435e+04
#   KL(t):      1.4896e-01
#   KL(p):      0.0000e+00
#   t_cont:     3.2560e-01
#   transition: -1.7785e+01
#   L1:         2.4382e+01
#   Grad Norms:
#     alpha: 3.35e+02
#     beta: 3.18e+02
#     edge_logits: 1.55e-10
#     g: 0.00e+00
#     K: 0.00e+00
#     log_sigma2: 0.00e+00
#
# [Epoch 43] | Phase: posterior
#   ELBO:       5.3689e+04
#   NLL:        5.3646e+04
#   KL(t):      1.3958e-01
#   KL(p):      0.0000e+00
#   t_cont:     3.2673e-01
#   transition: -1.7785e+01
#   L1:         2.4382e+01
#   Grad Norms:
#     alpha: 3.45e+02
#     beta: 3.33e+02
#     edge_logits: 1.55e-10
#     g: 0.00e+00
#     K: 0.00e+00
#     log_sigma2: 0.00e+00
#
# [Epoch 44] | Phase: posterior
#   ELBO:       5.2564e+04
#   NLL:        5.2522e+04
#   KL(t):      1.5160e-01
#   KL(p):      0.0000e+00
#   t_cont:     3.2604e-01
#   transition: -1.7787e+01
#   L1:         2.4382e+01
#   Grad Norms:
#     alpha: 3.44e+02
#     beta: 3.80e+02
#     edge_logits: 1.55e-10
#     g: 0.00e+00
#     K: 0.00e+00
#     log_sigma2: 0.00e+00
#
# [Epoch 45] | Phase: posterior
#   ELBO:       5.3707e+04
#   NLL:        5.3664e+04
#   KL(t):      1.5576e-01
#   KL(p):      0.0000e+00
#   t_cont:     3.3177e-01
#   transition: -1.7785e+01
#   L1:         2.4382e+01
#   Grad Norms:
#     alpha: 3.05e+02
#     beta: 2.74e+02
#     edge_logits: 1.55e-10
#     g: 0.00e+00
#     K: 0.00e+00
#     log_sigma2: 0.00e+00
#
# [Epoch 46] | Phase: posterior
#   ELBO:       5.3298e+04
#   NLL:        5.3256e+04
#   KL(t):      1.6334e-01
#   KL(p):      0.0000e+00
#   t_cont:     3.2898e-01
#   transition: -1.7787e+01
#   L1:         2.4382e+01
#   Grad Norms:
#     alpha: 3.69e+02
#     beta: 3.68e+02
#     edge_logits: 1.55e-10
#     g: 0.00e+00
#     K: 0.00e+00
#     log_sigma2: 0.00e+00
#
# [Epoch 47] | Phase: posterior
#   ELBO:       5.3498e+04
#   NLL:        5.3455e+04
#   KL(t):      1.6346e-01
#   KL(p):      0.0000e+00
#   t_cont:     3.2948e-01
#   transition: -1.7788e+01
#   L1:         2.4382e+01
#   Grad Norms:
#     alpha: 2.93e+02
#     beta: 3.08e+02
#     edge_logits: 1.55e-10
#     g: 0.00e+00
#     K: 0.00e+00
#     log_sigma2: 0.00e+00
#
# [Epoch 48] | Phase: posterior
#   ELBO:       5.1853e+04
#   NLL:        5.1810e+04
#   KL(t):      1.7417e-01
#   KL(p):      0.0000e+00
#   t_cont:     3.2998e-01
#   transition: -1.7787e+01
#   L1:         2.4382e+01
#   Grad Norms:
#     alpha: 3.00e+02
#     beta: 2.77e+02
#     edge_logits: 1.55e-10
#     g: 0.00e+00
#     K: 0.00e+00
#     log_sigma2: 0.00e+00
#
# [Epoch 49] | Phase: posterior
#   ELBO:       5.3331e+04
#   NLL:        5.3289e+04
#   KL(t):      1.8081e-01
#   KL(p):      0.0000e+00
#   t_cont:     3.2737e-01
#   transition: -1.7785e+01
#   L1:         2.4382e+01
#   Grad Norms:
#     alpha: 3.23e+02
#     beta: 2.64e+02
#     edge_logits: 1.55e-10
#     g: 0.00e+00
#     K: 0.00e+00
#     log_sigma2: 0.00e+00
#
# [Epoch 50] | Phase: posterior
#   ELBO:       5.2088e+04
#   NLL:        5.2046e+04
#   KL(t):      1.8778e-01
#   KL(p):      0.0000e+00
#   t_cont:     3.3099e-01
#   transition: -1.7788e+01
#   L1:         2.4382e+01
#   Grad Norms:
#     alpha: 3.18e+02
#     beta: 3.50e+02
#     edge_logits: 1.55e-10
#     g: 0.00e+00
#     K: 0.00e+00
#     log_sigma2: 0.00e+00
#
# [Epoch 51] | Phase: posterior
#   ELBO:       5.6801e+04
#   NLL:        5.6759e+04
#   KL(t):      1.9626e-01
#   KL(p):      0.0000e+00
#   t_cont:     3.2899e-01
#   transition: -1.7785e+01
#   L1:         2.4382e+01
#   Grad Norms:
#     alpha: 4.55e+02
#     beta: 4.66e+02
#     edge_logits: 1.55e-10
#     g: 0.00e+00
#     K: 0.00e+00
#     log_sigma2: 0.00e+00
#
# [Epoch 52] | Phase: posterior
#   ELBO:       5.2398e+04
#   NLL:        5.2355e+04
#   KL(t):      2.1055e-01
#   KL(p):      0.0000e+00
#   t_cont:     3.2559e-01
#   transition: -1.7786e+01
#   L1:         2.4382e+01
#   Grad Norms:
#     alpha: 3.81e+02
#     beta: 4.13e+02
#     edge_logits: 1.55e-10
#     g: 0.00e+00
#     K: 0.00e+00
#     log_sigma2: 0.00e+00
#
# [Epoch 53] | Phase: posterior
#   ELBO:       5.2615e+04
#   NLL:        5.2572e+04
#   KL(t):      2.1325e-01
#   KL(p):      0.0000e+00
#   t_cont:     3.3064e-01
#   transition: -1.7786e+01
#   L1:         2.4382e+01
#   Grad Norms:
#     alpha: 3.69e+02
#     beta: 3.80e+02
#     edge_logits: 1.55e-10
#     g: 0.00e+00
#     K: 0.00e+00
#     log_sigma2: 0.00e+00
# --- Switching to emission phase ---
#
# [Epoch 54] | Phase: emission
#   ELBO:       5.3997e+04
#   NLL:        5.3954e+04
#   KL(t):      2.1985e-01
#   KL(p):      0.0000e+00
#   t_cont:     3.2572e-01
#   transition: -1.7786e+01
#   L1:         2.4550e+01
#   Grad Norms:
#     alpha: 0.00e+00
#     beta: 0.00e+00
#     edge_logits: 0.00e+00
#     g: 9.53e+03
#     K: 5.74e+02
#     log_sigma2: 2.40e+00
#
# [Epoch 55] | Phase: emission
#   ELBO:       5.2182e+04
#   NLL:        5.2138e+04
#   KL(t):      2.2027e-01
#   KL(p):      0.0000e+00
#   t_cont:     3.3268e-01
#   transition: -1.7784e+01
#   L1:         2.5373e+01
#   Grad Norms:
#     alpha: 0.00e+00
#     beta: 0.00e+00
#     edge_logits: 0.00e+00
#     g: 8.97e+03
#     K: 6.41e+02
#     log_sigma2: 1.74e+00
#
# [Epoch 56] | Phase: emission
#   ELBO:       5.0425e+04
#   NLL:        5.0380e+04
#   KL(t):      2.2623e-01
#   KL(p):      0.0000e+00
#   t_cont:     3.3775e-01
#   transition: -1.7786e+01
#   L1:         2.6592e+01
#   Grad Norms:
#     alpha: 0.00e+00
#     beta: 0.00e+00
#     edge_logits: 0.00e+00
#     g: 9.33e+03
#     K: 5.92e+02
#     log_sigma2: 2.24e+00
#
# [Epoch 57] | Phase: emission
#   ELBO:       5.1132e+04
#   NLL:        5.1086e+04
#   KL(t):      2.1952e-01
#   KL(p):      0.0000e+00
#   t_cont:     3.2869e-01
#   transition: -1.7786e+01
#   L1:         2.7756e+01
#   Grad Norms:
#     alpha: 0.00e+00
#     beta: 0.00e+00
#     edge_logits: 0.00e+00
#     g: 8.92e+03
#     K: 5.75e+02
#     log_sigma2: 1.89e+00
#
# [Epoch 58] | Phase: emission
#   ELBO:       5.1908e+04
#   NLL:        5.1861e+04
#   KL(t):      2.1707e-01
#   KL(p):      0.0000e+00
#   t_cont:     3.2266e-01
#   transition: -1.7786e+01
#   L1:         2.9147e+01
#   Grad Norms:
#     alpha: 0.00e+00
#     beta: 0.00e+00
#     edge_logits: 0.00e+00
#     g: 8.75e+03
#     K: 6.90e+02
#     log_sigma2: 2.27e+00
#
# [Epoch 59] | Phase: emission
#   ELBO:       5.0619e+04
#   NLL:        5.0570e+04
#   KL(t):      2.2774e-01
#   KL(p):      0.0000e+00
#   t_cont:     3.2863e-01
#   transition: -1.7786e+01
#   L1:         3.0573e+01
#   Grad Norms:
#     alpha: 0.00e+00
#     beta: 0.00e+00
#     edge_logits: 0.00e+00
#     g: 9.08e+03
#     K: 7.51e+02
#     log_sigma2: 2.88e+00
#
# [Epoch 60] | Phase: emission
#   ELBO:       5.2222e+04
#   NLL:        5.2172e+04
#   KL(t):      2.2618e-01
#   KL(p):      0.0000e+00
#   t_cont:     3.2835e-01
#   transition: -1.7788e+01
#   L1:         3.1806e+01
#   Grad Norms:
#     alpha: 0.00e+00
#     beta: 0.00e+00
#     edge_logits: 0.00e+00
#     g: 9.00e+03
#     K: 7.95e+02
#     log_sigma2: 1.95e+00
#
# [Epoch 61] | Phase: emission
#   ELBO:       5.1224e+04
#   NLL:        5.1172e+04
#   KL(t):      2.1891e-01
#   KL(p):      0.0000e+00
#   t_cont:     3.3056e-01
#   transition: -1.7787e+01
#   L1:         3.2996e+01
#   Grad Norms:
#     alpha: 0.00e+00
#     beta: 0.00e+00
#     edge_logits: 0.00e+00
#     g: 9.26e+03
#     K: 7.33e+02
#     log_sigma2: 2.04e+00
# --- Switching to posterior phase ---
#
# [Epoch 62] | Phase: posterior
#   ELBO:       5.0633e+04
#   NLL:        5.0581e+04
#   KL(t):      2.2754e-01
#   KL(p):      0.0000e+00
#   t_cont:     3.3280e-01
#   transition: -1.7787e+01
#   L1:         3.3651e+01
#   Grad Norms:
#     alpha: 1.20e+03
#     beta: 1.10e+03
#     edge_logits: 1.55e-10
#     g: 0.00e+00
#     K: 0.00e+00
#     log_sigma2: 0.00e+00
#
# [Epoch 63] | Phase: posterior
#   ELBO:       4.9602e+04
#   NLL:        4.9550e+04
#   KL(t):      2.3821e-01
#   KL(p):      0.0000e+00
#   t_cont:     3.3246e-01
#   transition: -1.7787e+01
#   L1:         3.3651e+01
#   Grad Norms:
#     alpha: 7.54e+02
#     beta: 7.58e+02
#     edge_logits: 1.55e-10
#     g: 0.00e+00
#     K: 0.00e+00
#     log_sigma2: 0.00e+00
#
# [Epoch 64] | Phase: posterior
#   ELBO:       4.9498e+04
#   NLL:        4.9446e+04
#   KL(t):      2.5314e-01
#   KL(p):      0.0000e+00
#   t_cont:     3.3349e-01
#   transition: -1.7786e+01
#   L1:         3.3651e+01
#   Grad Norms:
#     alpha: 9.02e+02
#     beta: 7.94e+02
#     edge_logits: 1.55e-10
#     g: 0.00e+00
#     K: 0.00e+00
#     log_sigma2: 0.00e+00
#
# [Epoch 65] | Phase: posterior
#   ELBO:       4.9804e+04
#   NLL:        4.9752e+04
#   KL(t):      2.7190e-01
#   KL(p):      0.0000e+00
#   t_cont:     3.2630e-01
#   transition: -1.7784e+01
#   L1:         3.3651e+01
#   Grad Norms:
#     alpha: 9.63e+02
#     beta: 1.11e+03
#     edge_logits: 1.55e-10
#     g: 0.00e+00
#     K: 0.00e+00
#     log_sigma2: 0.00e+00
#
# [Epoch 66] | Phase: posterior
#   ELBO:       5.1154e+04
#   NLL:        5.1102e+04
#   KL(t):      2.8631e-01
#   KL(p):      0.0000e+00
#   t_cont:     3.3490e-01
#   transition: -1.7787e+01
#   L1:         3.3651e+01
#   Grad Norms:
#     alpha: 1.09e+03
#     beta: 1.06e+03
#     edge_logits: 1.55e-10
#     g: 0.00e+00
#     K: 0.00e+00
#     log_sigma2: 0.00e+00
#
# [Epoch 67] | Phase: posterior
#   ELBO:       4.8526e+04
#   NLL:        4.8474e+04
#   KL(t):      3.0479e-01
#   KL(p):      0.0000e+00
#   t_cont:     3.3340e-01
#   transition: -1.7786e+01
#   L1:         3.3651e+01
#   Grad Norms:
#     alpha: 9.86e+02
#     beta: 8.11e+02
#     edge_logits: 1.55e-10
#     g: 0.00e+00
#     K: 0.00e+00
#     log_sigma2: 0.00e+00
#
# [Epoch 68] | Phase: posterior
#   ELBO:       4.8390e+04
#   NLL:        4.8338e+04
#   KL(t):      3.2747e-01
#   KL(p):      0.0000e+00
#   t_cont:     3.3045e-01
#   transition: -1.7786e+01
#   L1:         3.3651e+01
#   Grad Norms:
#     alpha: 1.16e+03
#     beta: 8.21e+02
#     edge_logits: 1.55e-10
#     g: 0.00e+00
#     K: 0.00e+00
#     log_sigma2: 0.00e+00
#
# [Epoch 69] | Phase: posterior
#   ELBO:       4.9330e+04
#   NLL:        4.9278e+04
#   KL(t):      3.6307e-01
#   KL(p):      0.0000e+00
#   t_cont:     3.2984e-01
#   transition: -1.7787e+01
#   L1:         3.3651e+01
#   Grad Norms:
#     alpha: 9.76e+02
#     beta: 8.83e+02
#     edge_logits: 1.55e-10
#     g: 0.00e+00
#     K: 0.00e+00
#     log_sigma2: 0.00e+00
#
# [Epoch 70] | Phase: posterior
#   ELBO:       4.7798e+04
#   NLL:        4.7746e+04
#   KL(t):      3.8168e-01
#   KL(p):      0.0000e+00
#   t_cont:     3.3151e-01
#   transition: -1.7786e+01
#   L1:         3.3651e+01
#   Grad Norms:
#     alpha: 1.20e+03
#     beta: 1.09e+03
#     edge_logits: 1.55e-10
#     g: 0.00e+00
#     K: 0.00e+00
#     log_sigma2: 0.00e+00
#
# [Epoch 71] | Phase: posterior
#   ELBO:       5.0014e+04
#   NLL:        4.9961e+04
#   KL(t):      4.1844e-01
#   KL(p):      0.0000e+00
#   t_cont:     3.3313e-01
#   transition: -1.7786e+01
#   L1:         3.3651e+01
#   Grad Norms:
#     alpha: 1.32e+03
#     beta: 1.60e+03
#     edge_logits: 1.55e-10
#     g: 0.00e+00
#     K: 0.00e+00
#     log_sigma2: 0.00e+00
#
# [Epoch 72] | Phase: posterior
#   ELBO:       4.7266e+04
#   NLL:        4.6979e+04
#   KL(t):      2.3486e+02
#   KL(p):      0.0000e+00
#   t_cont:     3.3198e-01
#   transition: -1.7786e+01
#   L1:         3.3651e+01
#   Grad Norms:
#     alpha: 9.41e+02
#     beta: 9.32e+02
#     edge_logits: 1.55e-10
#     g: 0.00e+00
#     K: 0.00e+00
#     log_sigma2: 0.00e+00
#
# [Epoch 73] | Phase: posterior
#   ELBO:       4.7127e+04
#   NLL:        4.6899e+04
#   KL(t):      1.7628e+02
#   KL(p):      0.0000e+00
#   t_cont:     3.3995e-01
#   transition: -1.7784e+01
#   L1:         3.3651e+01
#   Grad Norms:
#     alpha: 1.03e+03
#     beta: 1.40e+03
#     edge_logits: 1.55e-10
#     g: 0.00e+00
#     K: 0.00e+00
#     log_sigma2: 0.00e+00
#
# [Epoch 74] | Phase: posterior
#   ELBO:       4.8564e+04
#   NLL:        4.8336e+04
#   KL(t):      1.7636e+02
#   KL(p):      0.0000e+00
#   t_cont:     3.3639e-01
#   transition: -1.7783e+01
#   L1:         3.3651e+01
#   Grad Norms:
#     alpha: 1.10e+03
#     beta: 1.77e+03
#     edge_logits: 1.55e-10
#     g: 0.00e+00
#     K: 0.00e+00
#     log_sigma2: 0.00e+00
#
# [Epoch 75] | Phase: posterior
#   ELBO:       4.7949e+04
#   NLL:        4.7514e+04
#   KL(t):      3.8340e+02
#   KL(p):      0.0000e+00
#   t_cont:     3.3755e-01
#   transition: -1.7786e+01
#   L1:         3.3651e+01
#   Grad Norms:
#     alpha: 9.57e+02
#     beta: 1.23e+03
#     edge_logits: 1.55e-10
#     g: 0.00e+00
#     K: 0.00e+00
#     log_sigma2: 0.00e+00
#
# [Epoch 76] | Phase: posterior
#   ELBO:       4.7059e+04
#   NLL:        4.6420e+04
#   KL(t):      5.8669e+02
#   KL(p):      0.0000e+00
#   t_cont:     3.4354e-01
#   transition: -1.7785e+01
#   L1:         3.3651e+01
#   Grad Norms:
#     alpha: 9.48e+02
#     beta: 6.95e+02
#     edge_logits: 1.55e-10
#     g: 0.00e+00
#     K: 0.00e+00
#     log_sigma2: 0.00e+00
#
# [Epoch 77] | Phase: posterior
#   ELBO:       4.6830e+04
#   NLL:        4.5957e+04
#   KL(t):      8.2123e+02
#   KL(p):      0.0000e+00
#   t_cont:     3.3710e-01
#   transition: -1.7783e+01
#   L1:         3.3651e+01
#   Grad Norms:
#     alpha: 8.83e+02
#     beta: 7.11e+02
#     edge_logits: 1.55e-10
#     g: 0.00e+00
#     K: 0.00e+00
#     log_sigma2: 0.00e+00
#
# [Epoch 78] | Phase: posterior
#   ELBO:       5.0418e+04
#   NLL:        4.8752e+04
#   KL(t):      1.6145e+03
#   KL(p):      0.0000e+00
#   t_cont:     3.3695e-01
#   transition: -1.7785e+01
#   L1:         3.3651e+01
#   Grad Norms:
#     alpha: 1.36e+03
#     beta: 2.05e+03
#     edge_logits: 1.55e-10
#     g: 0.00e+00
#     K: 0.00e+00
#     log_sigma2: 0.00e+00
#
# [Epoch 79] | Phase: posterior
#   ELBO:       4.8405e+04
#   NLL:        4.6238e+04
#   KL(t):      2.1143e+03
#   KL(p):      0.0000e+00
#   t_cont:     3.3714e-01
#   transition: -1.7786e+01
#   L1:         3.3651e+01
#   Grad Norms:
#     alpha: 1.18e+03
#     beta: 1.12e+03
#     edge_logits: 1.55e-10
#     g: 0.00e+00
#     K: 0.00e+00
#     log_sigma2: 0.00e+00
#
# [Epoch 80] | Phase: posterior
#   ELBO:       4.8715e+04
#   NLL:        4.4993e+04
#   KL(t):      3.6702e+03
#   KL(p):      0.0000e+00
#   t_cont:     3.3699e-01
#   transition: -1.7788e+01
#   L1:         3.3651e+01
#   Grad Norms:
#     alpha: 9.54e+02
#     beta: 1.41e+03
#     edge_logits: 1.55e-10
#     g: 0.00e+00
#     K: 0.00e+00
#     log_sigma2: 0.00e+00
#
# [Epoch 81] | Phase: posterior
#   ELBO:       5.0671e+04
#   NLL:        4.6298e+04
#   KL(t):      4.3215e+03
#   KL(p):      0.0000e+00
#   t_cont:     3.3961e-01
#   transition: -1.7786e+01
#   L1:         3.3651e+01
#   Grad Norms:
#     alpha: 1.41e+03
#     beta: 2.11e+03
#     edge_logits: 1.55e-10
#     g: 0.00e+00
#     K: 0.00e+00
#     log_sigma2: 0.00e+00
#
# [Epoch 82] | Phase: posterior
#   ELBO:       5.0361e+04
#   NLL:        4.5815e+04
#   KL(t):      4.4938e+03
#   KL(p):      0.0000e+00
#   t_cont:     3.4047e-01
#   transition: -1.7785e+01
#   L1:         3.3651e+01
#   Grad Norms:
#     alpha: 1.03e+03
#     beta: 1.14e+03
#     edge_logits: 1.55e-10
#     g: 0.00e+00
#     K: 0.00e+00
#     log_sigma2: 0.00e+00
# --- Switching to emission phase ---
#
# [Epoch 83] | Phase: emission
#   ELBO:       5.0089e+04
#   NLL:        4.5076e+04
#   KL(t):      4.9610e+03
#   KL(p):      0.0000e+00
#   t_cont:     3.4377e-01
#   transition: -1.7788e+01
#   L1:         3.4610e+01
#   Grad Norms:
#     alpha: 0.00e+00
#     beta: 0.00e+00
#     edge_logits: 0.00e+00
#     g: 8.57e+03
#     K: 7.13e+02
#     log_sigma2: 1.84e+00
#
# [Epoch 84] | Phase: emission
#   ELBO:       4.9867e+04
#   NLL:        4.4349e+04
#   KL(t):      5.4626e+03
#   KL(p):      0.0000e+00
#   t_cont:     3.4098e-01
#   transition: -1.7784e+01
#   L1:         3.7266e+01
#   Grad Norms:
#     alpha: 0.00e+00
#     beta: 0.00e+00
#     edge_logits: 0.00e+00
#     g: 8.56e+03
#     K: 8.57e+02
#     log_sigma2: 2.37e+00
#
# [Epoch 85] | Phase: emission
#   ELBO:       5.0140e+04
#   NLL:        4.3118e+04
#   KL(t):      6.9627e+03
#   KL(p):      0.0000e+00
#   t_cont:     3.4739e-01
#   transition: -1.7787e+01
#   L1:         4.0345e+01
#   Grad Norms:
#     alpha: 0.00e+00
#     beta: 0.00e+00
#     edge_logits: 0.00e+00
#     g: 7.55e+03
#     K: 7.45e+02
#     log_sigma2: 4.56e+00
#
# [Epoch 86] | Phase: emission
#   ELBO:       4.6387e+04
#   NLL:        4.1312e+04
#   KL(t):      5.0133e+03
#   KL(p):      0.0000e+00
#   t_cont:     3.4295e-01
#   transition: -1.7783e+01
#   L1:         4.3560e+01
#   Grad Norms:
#     alpha: 0.00e+00
#     beta: 0.00e+00
#     edge_logits: 0.00e+00
#     g: 7.66e+03
#     K: 7.89e+02
#     log_sigma2: 2.40e+00
#
# [Epoch 87] | Phase: emission
#   ELBO:       4.7066e+04
#   NLL:        4.0506e+04
#   KL(t):      6.4955e+03
#   KL(p):      0.0000e+00
#   t_cont:     3.3819e-01
#   transition: -1.7785e+01
#   L1:         4.6506e+01
#   Grad Norms:
#     alpha: 0.00e+00
#     beta: 0.00e+00
#     edge_logits: 0.00e+00
#     g: 7.81e+03
#     K: 9.00e+02
#     log_sigma2: 2.48e+00
#
# [Epoch 88] | Phase: emission
#   ELBO:       4.5635e+04
#   NLL:        4.0550e+04
#   KL(t):      5.0179e+03
#   KL(p):      0.0000e+00
#   t_cont:     3.3945e-01
#   transition: -1.7786e+01
#   L1:         4.9083e+01
#   Grad Norms:
#     alpha: 0.00e+00
#     beta: 0.00e+00
#     edge_logits: 0.00e+00
#     g: 8.33e+03
#     K: 8.59e+02
#     log_sigma2: 1.73e+00
#
# [Epoch 89] | Phase: emission
#   ELBO:       4.7731e+04
#   NLL:        4.1577e+04
#   KL(t):      6.0840e+03
#   KL(p):      0.0000e+00
#   t_cont:     3.4705e-01
#   transition: -1.7786e+01
#   L1:         5.1584e+01
#   Grad Norms:
#     alpha: 0.00e+00
#     beta: 0.00e+00
#     edge_logits: 0.00e+00
#     g: 9.25e+03
#     K: 1.04e+03
#     log_sigma2: 2.60e+00
#
# [Epoch 90] | Phase: emission
#   ELBO:       4.7170e+04
#   NLL:        4.1774e+04
#   KL(t):      5.3238e+03
#   KL(p):      0.0000e+00
#   t_cont:     3.4970e-01
#   transition: -1.7787e+01
#   L1:         5.3872e+01
#   Grad Norms:
#     alpha: 0.00e+00
#     beta: 0.00e+00
#     edge_logits: 0.00e+00
#     g: 8.34e+03
#     K: 9.59e+02
#     log_sigma2: 1.74e+00
#
# [Epoch 91] | Phase: emission
#   ELBO:       4.5385e+04
#   NLL:        3.9618e+04
#   KL(t):      5.6931e+03
#   KL(p):      0.0000e+00
#   t_cont:     3.4826e-01
#   transition: -1.7786e+01
#   L1:         5.5763e+01
#   Grad Norms:
#     alpha: 0.00e+00
#     beta: 0.00e+00
#     edge_logits: 0.00e+00
#     g: 8.97e+03
#     K: 1.03e+03
#     log_sigma2: 2.84e+00
#
# [Epoch 92] | Phase: emission
#   ELBO:       4.5640e+04
#   NLL:        4.0098e+04
#   KL(t):      5.4665e+03
#   KL(p):      0.0000e+00
#   t_cont:     3.3935e-01
#   transition: -1.7784e+01
#   L1:         5.7486e+01
#   Grad Norms:
#     alpha: 0.00e+00
#     beta: 0.00e+00
#     edge_logits: 0.00e+00
#     g: 7.08e+03
#     K: 8.58e+02
#     log_sigma2: 1.71e+00
#
# [Epoch 93] | Phase: emission
#   ELBO:       4.6148e+04
#   NLL:        4.1054e+04
#   KL(t):      5.0174e+03
#   KL(p):      0.0000e+00
#   t_cont:     3.4867e-01
#   transition: -1.7785e+01
#   L1:         5.9051e+01
#   Grad Norms:
#     alpha: 0.00e+00
#     beta: 0.00e+00
#     edge_logits: 0.00e+00
#     g: 8.20e+03
#     K: 9.22e+02
#     log_sigma2: 2.04e+00
#
# [Epoch 94] | Phase: emission
#   ELBO:       4.4698e+04
#   NLL:        4.0153e+04
#   KL(t):      4.4666e+03
#   KL(p):      0.0000e+00
#   t_cont:     3.4165e-01
#   transition: -1.7786e+01
#   L1:         6.0421e+01
#   Grad Norms:
#     alpha: 0.00e+00
#     beta: 0.00e+00
#     edge_logits: 0.00e+00
#     g: 7.93e+03
#     K: 9.35e+02
#     log_sigma2: 1.69e+00
#
# [Epoch 95] | Phase: emission
#   ELBO:       4.4698e+04
#   NLL:        3.9156e+04
#   KL(t):      5.4625e+03
#   KL(p):      0.0000e+00
#   t_cont:     3.5224e-01
#   transition: -1.7786e+01
#   L1:         6.1681e+01
#   Grad Norms:
#     alpha: 0.00e+00
#     beta: 0.00e+00
#     edge_logits: 0.00e+00
#     g: 7.60e+03
#     K: 9.73e+02
#     log_sigma2: 1.92e+00
#
# [Epoch 96] | Phase: emission
#   ELBO:       4.5888e+04
#   NLL:        4.0203e+04
#   KL(t):      5.6032e+03
#   KL(p):      0.0000e+00
#   t_cont:     3.3706e-01
#   transition: -1.7788e+01
#   L1:         6.2984e+01
#   Grad Norms:
#     alpha: 0.00e+00
#     beta: 0.00e+00
#     edge_logits: 0.00e+00
#     g: 7.77e+03
#     K: 9.31e+02
#     log_sigma2: 1.59e+00
#
# [Epoch 97] | Phase: emission
#   ELBO:       4.5571e+04
#   NLL:        4.1350e+04
#   KL(t):      4.1389e+03
#   KL(p):      0.0000e+00
#   t_cont:     3.4965e-01
#   transition: -1.7788e+01
#   L1:         6.4144e+01
#   Grad Norms:
#     alpha: 0.00e+00
#     beta: 0.00e+00
#     edge_logits: 0.00e+00
#     g: 8.54e+03
#     K: 1.28e+03
#     log_sigma2: 1.57e+00
#
# [Epoch 98] | Phase: emission
#   ELBO:       4.6551e+04
#   NLL:        4.0329e+04
#   KL(t):      6.1386e+03
#   KL(p):      0.0000e+00
#   t_cont:     3.4840e-01
#   transition: -1.7786e+01
#   L1:         6.5325e+01
#   Grad Norms:
#     alpha: 0.00e+00
#     beta: 0.00e+00
#     edge_logits: 0.00e+00
#     g: 8.09e+03
#     K: 1.13e+03
#     log_sigma2: 2.22e+00
#
# [Epoch 99] | Phase: emission
#   ELBO:       4.5430e+04
#   NLL:        3.9945e+04
#   KL(t):      5.4002e+03
#   KL(p):      0.0000e+00
#   t_cont:     3.3871e-01
#   transition: -1.7785e+01
#   L1:         6.6546e+01
#   Grad Norms:
#     alpha: 0.00e+00
#     beta: 0.00e+00
#     edge_logits: 0.00e+00
#     g: 7.86e+03
#     K: 9.36e+02
#     log_sigma2: 1.40e+00
# --- Switching to posterior phase ---

# %%
import matplotlib.pyplot as plt

epochs = range(len(elbo_log))

fig, axes = plt.subplots(1, 2, figsize=(16, 5))

# === ELBO plot ===
axes[0].plot(epochs, elbo_log, label="ELBO", color="black")
axes[0].set_title("ELBO Over Epochs")
axes[0].set_xlabel("Epoch")
axes[0].set_ylabel("ELBO")
axes[0].legend()
axes[0].grid(True)

# === Component losses ===
axes[1].plot(epochs, nll_log, label="NLL")
axes[1].plot(epochs, kl_t_log, label="KL(t)")
axes[1].plot(epochs, kl_p_log, label="KL(p)")
axes[1].plot(epochs, t_cont_log, label="t_cont")
axes[1].plot(epochs, transition_log, label="transition")
axes[1].plot(epochs, l1_log, label="L1")
axes[1].set_title("ELBO Components Over Epochs")
axes[1].set_xlabel("Epoch")
axes[1].set_ylabel("Loss Component Value")
axes[1].legend()
axes[1].grid(True)

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

epochs = range(len(elbo_log))

fig, axes = plt.subplots(1, 2, figsize=(16, 5))

# === ELBO plot ===
axes[0].plot(epochs, elbo_log, label="ELBO", color="black")
axes[0].set_title("ELBO Over Epochs")
axes[0].set_xlabel("Epoch")
axes[0].set_ylabel("ELBO")
axes[0].legend()
axes[0].grid(True)

# === Component losses ===
axes[1].plot(epochs, nll_log, label="NLL")
axes[1].plot(epochs, kl_t_log, label="KL(t)")
axes[1].plot(epochs, kl_p_log, label="KL(p)")
axes[1].plot(epochs, t_cont_log, label="t_cont")
axes[1].plot(epochs, transition_log, label="transition")
axes[1].plot(epochs, l1_log, label="L1")
axes[1].set_title("ELBO Components Over Epochs")
axes[1].set_xlabel("Epoch")
axes[1].set_ylabel("Loss Component Value")
axes[1].legend()
axes[1].grid(True)

plt.tight_layout()
plt.show()

# %%
index_to_edge = {v: k for k, v in edge_to_index.items()}
def extract_fitted_betas_by_argmax(posterior, index_to_edge):
    """
    Extract learned beta distribution parameters using the MAP edge assignment per cell.

    Args:
        posterior: Trained posterior object with `alpha` and `beta` of shape [cells x edges].
        index_to_edge: Dict mapping edge indices (int) to edge names.

    Returns:
        pd.DataFrame: Indexed by cell ID with columns 'edge', 'alpha', and 'beta'.
    """
    alpha = posterior.alpha.data.cpu().numpy()
    beta = posterior.beta.data.cpu().numpy()
    max_idx = (alpha + beta - 2).argmax(axis=1)  # MAP estimate of Beta distribution mean

    records = []
    for i, edge_idx in enumerate(max_idx):
        edge = index_to_edge[edge_idx]
        records.append({
        "cell_id": adata.obs.index[i],  # not just 'i'
        "edge": edge,
        "alpha": alpha[i, edge_idx],
        "beta": beta[i, edge_idx],
    })


    return pd.DataFrame(records).set_index("cell_id")
fitted_betas = extract_fitted_betas_by_argmax(posterior, index_to_edge)

# %%
adata
# Out:
# View of AnnData object with n_obs × n_vars = 0 × 1000
#     obs: 'developmental_day', 'days_num', 'hours_num', 'source_tissue', 'leiden'
#     var: 'n_cells', 'highly_variable', 'means', 'dispersions', 'dispersions_norm'
#     uns: 'Sample_colors', 'developmental_day_colors', 'hvg', 'leiden', 'leiden_colors', 'leiden_sizes', 'log1p', 'neighbors', 'paga', 'pca', 'umap'
#     obsm: 'X_pca', 'X_umap'
#     varm: 'PCs'
#     layers: 'ambiguous', 'counts', 'spliced', 'unspliced'
#     obsp: 'connectivities', 'distances'

# %%
print("adata.obs.shape:", adata.obs.shape)
print("posterior alpha shape:", posterior.alpha.shape)
# Out:
# adata.obs.shape: (0, 5)
# posterior alpha shape: torch.Size([5454, 18])

# %%
fitted_betas["edge"] = fitted_betas["edge"].apply(lambda x: tuple(x) if not isinstance(x, tuple) else x)
fitted_betas
# Out:
#                                  edge      alpha       beta
# cell_id
# TAAGCGTAGGCCCGTT  (split_16, split_4)  22.239080  77.747063
# GACCAATAGTCGTCGT    (split_7, leaf_8)  56.020267  43.855537
# CGAGAAGCATGCTAGT  (split_16, split_4)  14.484331  85.467102
# ACGATGTAGGATTCCC  (split_16, split_4)  29.771139  70.191414
# GCAGTTAAGGTCATCT  (split_16, split_4)  90.170433   9.850772
# ...                               ...        ...        ...
# GGAGCAAGTCTAGTGT   (split_3, leaf_13)  54.859303  44.773724
# TTTACTGTCAGTTCGG   (split_4, leaf_12)  99.004242   0.931278
# GAAATGAGTCGGCACT   (split_4, leaf_12)  42.252842  57.066956
# CGATGGCAGTGTCTCG   (split_4, leaf_12)  25.270227  74.043137
# CATCAAGGTTAAGATG   (split_3, leaf_13)  82.054886  17.921482
#
# [5454 rows x 3 columns]

# %%
records.append({
    "cell_id": adata.obs.index[i],  # not just 'i'
    "edge": edge,
    "alpha": alpha[i, edge_idx],
    "beta": beta[i, edge_idx],
})

# %%
missing = fitted_betas.index.difference(adata.obs.index)
print(f"{len(missing)} missing cell IDs in adata")
# Out:
# 5454 missing cell IDs in adata

# %%
missing_edges = [e for e in fitted_betas["edge"].unique() if e not in traj_graph.G_traj.edges
]
print("Missing edges:", missing_edges)
# Out:
# Missing edges: []

# %%
from viz.trajectory import plot_cells_on_trajectory

plot_cells_on_trajectory(
    traj_graph,
    cell_assignment,
    adata,
    color_key="leiden",  # or any other obs key
    curve_amount=0.8,
    title="Hard Cell Assignments on Trajectory"
)

# %%
from viz.trajectory import plot_pdf_width_ribbons_on_trajectory

plot_pdf_width_ribbons_on_trajectory(
    traj_graph,
    fitted_betas,
    adata,
    color_key="leiden",
    pdf_scale=.1,  # adjust if too narrow/wide
    curve_amount=0.8,
    title="Beta-Modeled Cell Assignments as Ribbons"
)
# Out:
# /work/vanaja_lab/griffin/projects/viCSHMM/viz/trajectory.py:301: RuntimeWarning: overflow encountered in multiply
#   widths = pdfs * (pdf_scale * seg_length) / max_vals
# /work/vanaja_lab/griffin/projects/viCSHMM/viz/trajectory.py:305: RuntimeWarning: invalid value encountered in multiply
#   offset = (width[:, None] / 2) * normals

# %%
# freeze_epochs = 10
# optimizer = torch.optim.Adam([
#     {'params': [posterior.alpha, posterior.beta, posterior.path_logits]},
#     {'params': [g_a, g_b, K, log_sigma2], 'lr': 1e-2}
# ], lr=1e-2)

# for epoch in range(num_epochs):
#     # Freeze emission parameters initially
#     if epoch < freeze_epochs:
#         for p in [g_a, g_b, K, log_sigma2]:
#             p.requires_grad_(False)
#     else:
#         for p in [g_a, g_b, K, log_sigma2]:
#             p.requires_grad_(True)

#     optimizer.zero_grad()
#     loss, metrics = compute_elbo(
#         X, traj_graph, posterior, edge_to_index,
#         g_a, g_b, K, log_sigma2.exp(),
#         pi=pi,
#         belief_propagator=belief_propagator,
#         n_samples=n_samples,
#         kl_weight=kl_weight,
#         kl_p_weight=kl_p_weight,
#         t_cont_weight=t_cont_weight,
#     )
#     loss.backward()
#     optimizer.step()

#     print(f"[Epoch {epoch}] Loss={loss.item():.2e}, NLL={metrics['nll']:.2e}, KL(t)={metrics['kl_t']:.3f}")

# %%
inference_params = [posterior.alpha, posterior.beta, posterior.path_logits]
generative_params = [g_a, g_b, K, log_sigma2]

optimizer_inf = torch.optim.Adam(inference_params, lr=1e-2)
optimizer_gen = torch.optim.Adam(generative_params, lr=1e-2)

n_inf_steps = 8
n_gen_steps = 3
batch_size = 512

elbo_log = []
metrics_log = []

for epoch in range(num_epochs):
    print(f"\n[Epoch {epoch}]")

    # === Inference Phase ===
    for _ in range(n_inf_steps):
        optimizer_inf.zero_grad()
        total_elbo = 0
        total_metrics = {
            "nll": 0.0,
            "kl_t": 0.0,
            "kl_p": 0.0,
            "t_cont": 0.0
        }
        n_batches = 0

        for batch in batch_indices(X.shape[0], batch_size):
            X_batch = X[batch]
            elbo, metrics = compute_elbo_batch(
                X_batch, batch,
                traj_graph, posterior, edge_to_index,
                g_a, g_b, K, log_sigma2.exp(),
                belief_propagator=belief_propagator,
                n_samples=n_samples,
                kl_weight=kl_weight,
                kl_p_weight=kl_p_weight,
                t_cont_weight=t_cont_weight,
                pi=pi
            )
            elbo.backward()
            total_elbo += elbo.item()
            for k in total_metrics:
                total_metrics[k] += metrics[k]
            n_batches += 1

        optimizer_inf.step()

        for k in total_metrics:
            total_metrics[k] /= n_batches

        print(f"Inference ELBO: {total_elbo:.2e}")
        print(f"  NLL:     {total_metrics['nll']:.3e}")
        print(f"  KL(t):   {total_metrics['kl_t']:.3e}")
        print(f"  KL(p):   {total_metrics['kl_p']:.3e}")
        print(f"  t_cont:  {total_metrics['t_cont']:.3e}")

        # Check gradients
        for p in inference_params:
            print(f"  Grad | {p.shape}: {p.grad.norm().item():.3e}")

        elbo_log.append(("inference", epoch, total_elbo))
        metrics_log.append(("inference", epoch, total_metrics.copy()))

    # === Generative Phase ===
    for _ in range(n_gen_steps):
        optimizer_gen.zero_grad()
        total_elbo = 0
        total_metrics = {
            "nll": 0.0,
            "kl_t": 0.0,
            "kl_p": 0.0,
            "t_cont": 0.0
        }
        n_batches = 0

        for batch in batch_indices(X.shape[0], batch_size):
            X_batch = X[batch]
            elbo, metrics = compute_elbo_batch(
                X_batch, batch,
                traj_graph, posterior, edge_to_index,
                g_a, g_b, K, log_sigma2.exp(),
                belief_propagator=belief_propagator,
                n_samples=n_samples,
                kl_weight=kl_weight,
                kl_p_weight=kl_p_weight,
                t_cont_weight=t_cont_weight,
                pi=pi
            )
            elbo.backward()
            total_elbo += elbo.item()
            for k in total_metrics:
                total_metrics[k] += metrics[k]
            n_batches += 1

        optimizer_gen.step()

        for k in total_metrics:
            total_metrics[k] /= n_batches

        print(f"Generative ELBO: {total_elbo:.2e}")
        print(f"  NLL:     {total_metrics['nll']:.3e}")
        print(f"  KL(t):   {total_metrics['kl_t']:.3e}")
        print(f"  KL(p):   {total_metrics['kl_p']:.3e}")
        print(f"  t_cont:  {total_metrics['t_cont']:.3e}")

        # Check gradients
        for p in generative_params:
            print(f"  Grad | {p.shape}: {p.grad.norm().item():.3e}")

        elbo_log.append(("generative", epoch, total_elbo))
        metrics_log.append(("generative", epoch, total_metrics.copy()))
# Out:
# [Epoch 0]
# Inference ELBO: 6.06e+05
#   NLL:     5.510e+04
#   KL(t):   6.602e-01
#   KL(p):   3.236e-02
#   t_cont:  3.984e-01
#   Grad | torch.Size([5454, 9]): 5.421e+03
#   Grad | torch.Size([5454, 9]): 5.214e+03
#   Grad | torch.Size([5454, 9]): 1.107e-02
# Inference ELBO: 6.24e+05
#   NLL:     5.676e+04
#   KL(t):   6.625e-01
#   KL(p):   3.129e-02
#   t_cont:  3.923e-01
#   Grad | torch.Size([5454, 9]): 5.667e+03
#   Grad | torch.Size([5454, 9]): 5.241e+03
#   Grad | torch.Size([5454, 9]): 1.082e-02
# Inference ELBO: 6.06e+05
#   NLL:     5.507e+04
#   KL(t):   6.753e-01
#   KL(p):   3.048e-02
#   t_cont:  3.930e-01
#   Grad | torch.Size([5454, 9]): 5.893e+03
#   Grad | torch.Size([5454, 9]): 5.189e+03
#   Grad | torch.Size([5454, 9]): 1.073e-02
# Inference ELBO: 5.99e+05
#   NLL:     5.446e+04
#   KL(t):   6.731e-01
#   KL(p):   2.948e-02
#   t_cont:  4.002e-01
#   Grad | torch.Size([5454, 9]): 5.762e+03
#   Grad | torch.Size([5454, 9]): 5.317e+03
#   Grad | torch.Size([5454, 9]): 1.050e-02
# Inference ELBO: 5.94e+05
#   NLL:     5.404e+04
#   KL(t):   6.895e-01
#   KL(p):   2.852e-02
#   t_cont:  3.902e-01
#   Grad | torch.Size([5454, 9]): 5.865e+03
#   Grad | torch.Size([5454, 9]): 5.156e+03
#   Grad | torch.Size([5454, 9]): 1.031e-02
# Inference ELBO: 5.80e+05
#   NLL:     5.273e+04
#   KL(t):   7.100e-01
#   KL(p):   2.760e-02
#   t_cont:  4.016e-01
#   Grad | torch.Size([5454, 9]): 5.858e+03
#   Grad | torch.Size([5454, 9]): 5.084e+03
#   Grad | torch.Size([5454, 9]): 1.014e-02
# Inference ELBO: 6.03e+05
#   NLL:     5.483e+04
#   KL(t):   7.041e-01
#   KL(p):   2.667e-02
#   t_cont:  3.945e-01
#   Grad | torch.Size([5454, 9]): 5.722e+03
#   Grad | torch.Size([5454, 9]): 4.994e+03
#   Grad | torch.Size([5454, 9]): 9.905e-03
# Inference ELBO: 5.95e+05
#   NLL:     5.405e+04
#   KL(t):   7.293e-01
#   KL(p):   2.590e-02
#   t_cont:  3.934e-01
#   Grad | torch.Size([5454, 9]): 5.638e+03
#   Grad | torch.Size([5454, 9]): 5.074e+03
#   Grad | torch.Size([5454, 9]): 9.785e-03
# Generative ELBO: 6.12e+05
#   NLL:     5.564e+04
#   KL(t):   7.295e-01
#   KL(p):   2.508e-02
#   t_cont:  4.012e-01
#   Grad | torch.Size([18, 1000]): 2.803e+04
#   Grad | torch.Size([18, 1000]): 1.106e+04
#   Grad | torch.Size([18, 1000]): 3.447e+03
#   Grad | torch.Size([18, 1000]): 1.413e+01
# Generative ELBO: 5.98e+05
#   NLL:     5.436e+04
#   KL(t):   7.414e-01
#   KL(p):   2.504e-02
#   t_cont:  3.969e-01
#   Grad | torch.Size([18, 1000]): 3.062e+04
#   Grad | torch.Size([18, 1000]): 1.626e+04
#   Grad | torch.Size([18, 1000]): 5.339e+03
#   Grad | torch.Size([18, 1000]): 1.511e+01
# Generative ELBO: 5.89e+05
#   NLL:     5.351e+04
#   KL(t):   7.333e-01
#   KL(p):   2.507e-02
#   t_cont:  3.991e-01
#   Grad | torch.Size([18, 1000]): 2.717e+04
#   Grad | torch.Size([18, 1000]): 1.397e+04
#   Grad | torch.Size([18, 1000]): 4.398e+03
#   Grad | torch.Size([18, 1000]): 1.547e+01
#
# [Epoch 1]
# Inference ELBO: 5.97e+05
#   NLL:     5.427e+04
#   KL(t):   7.344e-01
#   KL(p):   2.502e-02
#   t_cont:  4.013e-01
#   Grad | torch.Size([5454, 9]): 6.424e+03
#   Grad | torch.Size([5454, 9]): 5.780e+03
#   Grad | torch.Size([5454, 9]): 9.580e-03
# Inference ELBO: 6.13e+05
#   NLL:     5.573e+04
#   KL(t):   7.478e-01
#   KL(p):   2.426e-02
#   t_cont:  4.014e-01
#   Grad | torch.Size([5454, 9]): 6.501e+03
#   Grad | torch.Size([5454, 9]): 6.016e+03
#   Grad | torch.Size([5454, 9]): 9.447e-03
# Inference ELBO: 6.15e+05
#   NLL:     5.588e+04
#   KL(t):   7.502e-01
#   KL(p):   2.354e-02
#   t_cont:  3.991e-01
#   Grad | torch.Size([5454, 9]): 6.362e+03
#   Grad | torch.Size([5454, 9]): 5.873e+03
#   Grad | torch.Size([5454, 9]): 9.323e-03
# Inference ELBO: 5.80e+05
#   NLL:     5.268e+04
#   KL(t):   7.714e-01
#   KL(p):   2.270e-02
#   t_cont:  4.057e-01
#   Grad | torch.Size([5454, 9]): 6.132e+03
#   Grad | torch.Size([5454, 9]): 4.984e+03
#   Grad | torch.Size([5454, 9]): 9.023e-03
# Inference ELBO: 5.97e+05
#   NLL:     5.431e+04
#   KL(t):   7.824e-01
#   KL(p):   2.206e-02
#   t_cont:  4.010e-01
#   Grad | torch.Size([5454, 9]): 6.508e+03
#   Grad | torch.Size([5454, 9]): 6.069e+03
#   Grad | torch.Size([5454, 9]): 8.942e-03
# Inference ELBO: 5.84e+05
#   NLL:     5.306e+04
#   KL(t):   8.059e-01
#   KL(p):   2.129e-02
#   t_cont:  4.034e-01
#   Grad | torch.Size([5454, 9]): 5.943e+03
#   Grad | torch.Size([5454, 9]): 5.553e+03
#   Grad | torch.Size([5454, 9]): 8.779e-03
# Inference ELBO: 5.76e+05
#   NLL:     5.232e+04
#   KL(t):   8.135e-01
#   KL(p):   2.071e-02
#   t_cont:  4.025e-01
#   Grad | torch.Size([5454, 9]): 6.090e+03
#   Grad | torch.Size([5454, 9]): 5.601e+03
#   Grad | torch.Size([5454, 9]): 8.643e-03
# Inference ELBO: 5.98e+05
#   NLL:     5.432e+04
#   KL(t):   5.943e+01
#   KL(p):   1.996e-02
#   t_cont:  4.015e-01
#   Grad | torch.Size([5454, 9]): 7.003e+03
#   Grad | torch.Size([5454, 9]): 5.838e+03
#   Grad | torch.Size([5454, 9]): 8.414e-03
# Generative ELBO: 5.73e+05
#   NLL:     5.200e+04
#   KL(t):   5.944e+01
#   KL(p):   1.945e-02
#   t_cont:  4.052e-01
#   Grad | torch.Size([18, 1000]): 2.785e+04
#   Grad | torch.Size([18, 1000]): 1.338e+04
#   Grad | torch.Size([18, 1000]): 4.475e+03
#   Grad | torch.Size([18, 1000]): 1.496e+01
# Generative ELBO: 5.76e+05
#   NLL:     5.234e+04
#   KL(t):   5.943e+01
#   KL(p):   1.932e-02
#   t_cont:  4.043e-01
#   Grad | torch.Size([18, 1000]): 3.043e+04
#   Grad | torch.Size([18, 1000]): 1.167e+04
#   Grad | torch.Size([18, 1000]): 3.795e+03
#   Grad | torch.Size([18, 1000]): 1.430e+01
# Generative ELBO: 5.94e+05
#   NLL:     5.397e+04
#   KL(t):   8.393e-01
#   KL(p):   1.929e-02
#   t_cont:  4.118e-01
#   Grad | torch.Size([18, 1000]): 2.603e+04
#   Grad | torch.Size([18, 1000]): 1.191e+04
#   Grad | torch.Size([18, 1000]): 3.896e+03
#   Grad | torch.Size([18, 1000]): 1.403e+01
#
# [Epoch 2]
# KeyboardInterrupt

# %% [markdown]
# # Test Plotting

# %%
from utils import make_beta_assignment_df

beta_assignments = make_beta_assignment_df(posterior, cell_assignment, sharpness=0.01)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[55], line 3
#       1 from utils import make_beta_assignment_df
# ----> 3 beta_assignments = make_beta_assignment_df(posterior, cell_assignment, sharpness=0.01)
#
# File /work/vanaja_lab/griffin/projects/viCSHMM/utils/inference.py:60, in make_beta_assignment_df(posterior, cell_assignment, sharpness)
#      40 """
#      41 Convert hard cell assignments to a DataFrame of beta distribution parameters
#      42 usable for probabilistic trajectory visualization.
#    (...)
#      56     pd.DataFrame: Indexed by cell ID, with columns 'edge', 'alpha', 'beta'.
#      57 """
#      58 from utils.inference import initialize_beta_from_cell_assignment, find_path_index_for_edge
# ---> 60 initialize_beta_from_cell_assignment(posterior, cell_assignment, sharpness=sharpness)
#      62 cell_ids = list(cell_assignment.index)
#      63 edges = list(cell_assignment["edge"])
#
# TypeError: initialize_beta_from_cell_assignment() missing 1 required positional argument: 'edge_to_index'

# %%
from viz.trajectory import plot_pdf_width_ribbons_on_trajectory

plot_pdf_width_ribbons_on_trajectory(
    traj_graph,
    beta_assignments,
    adata,
    color_key="leiden",
    pdf_scale=0.1,  # adjust if too narrow/wide
    curve_amount=0.8,
    title="Beta-Modeled Cell Assignments as Ribbons"
)

# %%
adata.var
# Out:
#           n_cells  highly_variable     means  dispersions  dispersions_norm
# Lypla1       2576             True  0.250853    -0.930302          1.950977
# Ncoa2         993             True  0.099955    -0.569126          1.877314
# Gm10566        76             True  0.010847    -0.106430          1.912057
# Imp4         3037             True  0.295466    -1.094584          1.782918
# Fam168b      2119             True  0.204745    -0.815239          1.617195
# ...           ...              ...       ...          ...               ...
# Rps7-ps3     2274             True  0.221367    -0.861823          1.828743
# Map3k15       346             True  0.038561    -0.390028          2.149240
# Syap1         970             True  0.100843    -0.545244          1.989039
# Ctps2        2537             True  0.264015    -0.860618          2.211714
# Cltrn         729             True  0.067131    -0.568660          1.657125
#
# [1000 rows x 5 columns]

# %%
from scipy.stats import beta
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import matplotlib.colors as mcolors
import networkx as nx
import pandas as pd

def plot_gene_dynamics_on_trajectory(
    G_traj, beta_assignments, adata, gene_name,
    resolution=100, curve_scale=1.0, blend_fraction=0.1,
    title="Gene Dynamics with Uncertainty"
):
    """
    Visualizes gene expression dynamics along trajectory edges while incorporating
    uncertainty from cell assignments. The tree structure is drawn first (nodes and
    straight edges). Over each edge, we compute for a set of t-values:
      - A weighted gene expression (which becomes the vertical offset from the base edge)
      - A weighted certainty (a proxy using each cell's beta PDF peak)
    
    The curve is drawn along the edge offset perpendicularly by the weighted expression
    (scaled by curve_scale). If the source node of an edge is a split, the first few points
    of the branch are blended with the parent's endpoint (source node position) using the 
    transition probability (attribute "A") from that edge.
    
    Args:
        G_traj: Trajectory graph (networkx.DiGraph or TrajectoryGraph object).
        beta_assignments (pd.DataFrame): Indexed by cell IDs with columns:
            'edge' (tuple of two node IDs), 'alpha', 'beta'.
        adata: AnnData-like object (for gene expression and cell IDs).
        gene_name (str): Gene to visualize (must be in adata.var_names).
        resolution (int): Number of t-values along each edge.
        curve_scale (float): Factor to scale the vertical offset of the curve.
        blend_fraction (float): Fraction of the curve (from t=0) to blend at split nodes.
        title (str): Plot title.
    """
    # If G_traj is a TrajectoryGraph, extract its underlying networkx graph.
    if hasattr(G_traj, 'G_traj'):
        G_traj = G_traj.G_traj

    # Compute node positions using graphviz layout.
    pos = nx.nx_agraph.graphviz_layout(G_traj, prog="dot", args="-Grankdir=LR")
    plt.figure(figsize=(12, 7))
    
    # Draw the tree structure: nodes and edges.
    for node, (x, y) in pos.items():
        plt.scatter(x, y, color='black', s=500, zorder=3)
        plt.text(x, y, node, fontsize=10, ha="center", va="center", zorder=4)
    for src, dst in G_traj.edges():
        if src not in pos or dst not in pos:
            continue
        P0, P1 = np.array(pos[src]), np.array(pos[dst])
        plt.plot([P0[0], P1[0]], [P0[1], P1[1]], color='lightgrey', lw=5, alpha=0.5, zorder=1)
    
    # Extract gene expression as a pandas Series (indexed by cell IDs).
    if gene_name in adata.var_names:
        gene_idx = adata.var_names.get_loc(gene_name)
        expr_array = (adata.X[:, gene_idx].toarray().ravel() 
                      if hasattr(adata.X, "toarray") 
                      else np.array(adata.X[:, gene_idx]).ravel())
        expr_series = pd.Series(expr_array, index=adata.obs_names)
    else:
        raise ValueError(f"Gene '{gene_name}' not found in adata.var_names")
    
    # Group cells by edge.
    # For each cell, compute its beta PDF along a grid of t-values.
    t_vals = np.linspace(0, 1, resolution)
    edge_groups = {}  # { edge: list of dicts for each cell }
    for cell_id, row in beta_assignments.iterrows():
        edge = row['edge']
        alpha_param = row['alpha']
        beta_param = row['beta']
        if not edge or alpha_param <= 0 or beta_param <= 0:
            continue
        # Compute beta PDF for this cell.
        pdf_vals = beta.pdf(t_vals, alpha_param, beta_param)
        pdf_vals = np.nan_to_num(pdf_vals)
        # Use the maximum of the PDF as a simple measure of certainty.
        cert = pdf_vals.max()
        if edge not in edge_groups:
            edge_groups[edge] = []
        edge_groups[edge].append({
            "cell_id": cell_id,
            "pdf": pdf_vals,
            "expr": expr_series.loc[cell_id],
            "cert": cert
        })
    
    # Prepare a colormap for certainty: blue = low, red = high.
    cmap = cm.RdBu_r

    # For each edge, compute the weighted gene expression and certainty along t.
    for edge, cells in edge_groups.items():
        src, dst = edge
        if src not in pos or dst not in pos:
            continue
        P0 = np.array(pos[src])
        P1 = np.array(pos[dst])
        direction = P1 - P0
        seg_length = np.linalg.norm(direction)
        if seg_length == 0:
            continue
        direction = direction / seg_length
        # Compute a perpendicular (normal) vector.
        normal = np.array([-direction[1], direction[0]])
        
        # Initialize accumulators for weighted expression and certainty.
        weighted_expr = np.zeros_like(t_vals, dtype=float)
        weighted_cert = np.zeros_like(t_vals, dtype=float)
        weight_sum = np.zeros_like(t_vals, dtype=float)
        
        for cell in cells:
            pdf_vals = cell["pdf"]
            weighted_expr += cell["expr"] * pdf_vals
            weighted_cert += cell["cert"] * pdf_vals
            weight_sum += pdf_vals
        
        mask = weight_sum > 0
        weighted_expr[mask] /= weight_sum[mask]
        weighted_cert[mask] /= weight_sum[mask]
        
        # Compute the base curve along the edge.
        base_curve = np.array([P0 + t * (P1 - P0) for t in t_vals])
        # Offset the base curve by the weighted expression along the normal,
        # scaling the offset by curve_scale.
        curve_pts = base_curve + np.outer(weighted_expr * curve_scale, normal)
        
        # If the source node is a split, blend the first few points with the parent's endpoint.
        # We assume that a split node is identified by its type attribute containing "split".
        if "split" in G_traj.nodes[src].get("type", ""):
            # Get the transition probability for this edge (default to 1 if not defined)
            A = G_traj.edges[src, dst].get("A", 1.0)
            # Blend the first blend_count points.
            blend_count = max(2, int(blend_fraction * resolution))
            for i in range(blend_count):
                blend_weight = A * (i / blend_count)  # gradually ramp from 0 to A
                # Blend parent's endpoint (P0) and the computed branch start.
                curve_pts[i] = (1 - blend_weight) * P0 + blend_weight * curve_pts[i]
        
        # Normalize certainty values for color mapping.
        cert_min, cert_max = weighted_cert.min(), weighted_cert.max()
        if cert_max > cert_min:
            norm_cert = (weighted_cert - cert_min) / (cert_max - cert_min)
        else:
            norm_cert = np.full_like(weighted_cert, 0.5)
        
        # Draw the curve as a series of short segments colored by certainty.
        for i in range(resolution - 1):
            seg_x = curve_pts[i:i+2, 0]
            seg_y = curve_pts[i:i+2, 1]
            seg_color = cmap(norm_cert[i])
            plt.plot(seg_x, seg_y, color=seg_color, lw=2, zorder=2)
    
    plt.title(title)
    plt.axis("off")
    plt.tight_layout()
    plt.show()

# %%
plot_gene_dynamics_on_trajectory(traj_graph, beta_assignments, adata, gene_name='Lypla1',
                                 resolution=100, curve_scale=100.0, blend_fraction=0.1,
                                 title="Gene Dynamics on Trajectory for Lypla1")
